# %% [markdown]
# # references
# 1. https://www.kaggle.com/columbia2131/device-eda-interpolate-by-removing-device-en-ja

# %% [markdown]
# # Load Libraries

# %%
import numpy as np
import pandas as pd
from glob import glob
import os
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from pathlib import Path
import plotly.express as px

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
notebookName = 'Baseline'
PATH = Path(f"./models/{notebookName}")

# %%
if os.path.isdir(PATH):
    dir_list = os.listdir(PATH)
    num_files = 0
    while True:
        if os.path.isfile(str(PATH / f"{num_files}")):
            print(num_files)
            num_files += 1
        else:
            break
else:
    os.mkdir(PATH)
    num_files = 0
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
num_files
# Out:
# 5

# %%
RANDOM_STATE = 42
lr = 0.005
batch_size = 4
EPOCH_NUM = 1000

torch.manual_seed(RANDOM_STATE)

experience_name = f"{num_files}"
checkpoint_name = "check_point"
model_name = str("model - " + experience_name)
param_name = str("param - " + experience_name)
result_name = str("result - " + experience_name)

dummy_path = str(PATH / f"{num_files}")
checkpoint_path = str(PATH / f"{checkpoint_name}.pth")
model_path = str(PATH / f"{model_name}.pth")
param_path = str(PATH / f"{param_name}.pth")
result_path = str(PATH / f"{result_name}.csv")
model_path, param_path, result_path
# Out:
# ('models\\Baseline\\model - 5.pth',
#  'models\\Baseline\\param - 5.pth',
#  'models\\Baseline\\result - 5.csv')

# %% [markdown]
# # Useful Functions

# %%
def calc_haversine(lat1, lon1, lat2, lon2):
    dlat = (lat2 - lat1) % 360
    dlon = (lon2 - lon1) % 360 
    
    dlat, dlon = map(np.radians, [dlat, dlon])
    a = np.sin(dlat / 2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2.0)**2
    c = 2 * np.arcsin(a ** 0.5)
    c = c + np.isnan(c) * ((a > 1) * np.pi/2 + (a < -1) * (-1 * np.pi / 2))
        
    dist = 6_367_000 * c
    return dist

# %%
def check_score(input_df: pd.DataFrame) -> pd.DataFrame:
    output_df = input_df.copy()
    
    output_df['meter'] = input_df.apply(
        lambda r: calc_haversine(
            r.latDeg, r.lngDeg, r.t_latDeg, r.t_lngDeg
        ),
        axis=1
    )

    meter_score = output_df['meter'].mean()
    print(f'error meter: {meter_score}')

    scores = []
    for phone in output_df['phone'].unique():
        _index = output_df['phone']==phone
        p_50 = np.percentile(output_df.loc[_index, 'meter'], 50)
        p_95 = np.percentile(output_df.loc[_index, 'meter'], 95)
        scores.append(p_50)
        scores.append(p_95)

    score = sum(scores) / len(scores)
    print(f'score: {score}')
    
    return output_df, meter_score , score

# %%
def check_score_np(predict:torch.Tensor, target:torch.Tensor):
    m = []
    predict = predict.detach().numpy()
    target = target.detach().numpy()
    for i in range(predict.shape[0]):
        temp = calc_haversine(predict[i,0], predict[i,1], target[i,0], target[i,1])
        m.append(temp)
    
    m = np.array(m)
    score = (np.percentile(m, 50) + np.percentile(m, 95))/2
    
    return score

# %% [markdown]
# # Load Datasets

# %%
data_dir = Path("../input/google-smartphone-decimeter-challenge")
df_train = pd.read_pickle(str(data_dir / "gsdc_train.pkl.gzip"))

# %%
# check score
df_train, default_loss, default_meas = check_score(df_train)
# Out:
# error meter: 4.261468362435763
# score: 5.812326742270749

# %% [markdown]
# # Feature Engineering
# ## Simple view, what is in data frame.

# %%
print(df_train.shape)
df_train.head()
# Out:
# (131342, 111)
#         collectionName       phoneName  millisSinceGpsEpoch     latDeg  \
# 0  2020-05-14-US-MTV-1          Pixel4        1273529463442  37.423575
# 1  2020-05-14-US-MTV-1          Pixel4        1273529464442  37.423578
# 2  2020-05-14-US-MTV-1          Pixel4        1273529465442  37.423573
# 3  2020-05-14-US-MTV-1          Pixel4        1273529466442  37.423583
# 4  2020-05-14-US-MTV-1  Pixel4XLModded        1273529466449  37.423574
#
#        lngDeg  heightAboveWgs84EllipsoidM                               phone  \
# 0 -122.094091                      -34.06          2020-05-14-US-MTV-1_Pixel4
# 1 -122.094101                      -33.29          2020-05-14-US-MTV-1_Pixel4
# 2 -122.094111                      -30.99          2020-05-14-US-MTV-1_Pixel4
# 3 -122.094121                      -32.83          2020-05-14-US-MTV-1_Pixel4
# 4 -122.094137                      -33.20  2020-05-14-US-MTV-1_Pixel4XLModded
#
#    utcTimeMillis_x  elapsedRealtimeNanos_x  UncalGyroXRadPerSec  ...  \
# 0     1.589494e+12            1.965654e+13            -0.000502  ...
# 1     1.589494e+12            1.965754e+13            -0.003537  ...
# 2     1.589494e+12            1.965854e+13             0.002028  ...
# 3     1.589494e+12            1.965954e+13            -0.015753  ...
# 4     1.589494e+12            1.734189e+13             0.875268  ...
#
#    ySatVelMps  zSatVelMps  satClkBiasM  satClkDriftMps        rawPrM  \
# 0     156.040    3559.757     -468.084           0.001  2.379498e+07
# 1     411.162   -3013.649    65954.431          -0.002  2.592442e+07
# 2   -2776.605    -434.445     1223.261           0.000  2.131445e+07
# 3     411.755   -3013.528    65954.426          -0.002  2.592544e+07
# 4     -81.334   -3057.885    -3909.257           0.001  2.318871e+07
#
#    rawPrUncM     isrbM  ionoDelayM  tropoDelayM     meter
# 0     11.992  1134.758      10.866       16.647  4.345847
# 1      3.897  -222.675       7.111        5.174  3.324526
# 2      1.499     0.000       4.777        3.371  2.279173
# 3      3.598  -220.611       7.113        5.183  1.381411
# 4     10.493     0.000       7.313        5.311  0.794351
#
# [5 rows x 111 columns]

# %%
for c in df_train.columns:
    print(c)
    print(df_train[c].describe())
    print()
# Out:
# collectionName
# count                  131342
# unique                     29
# top       2021-01-04-US-RWC-1
# freq                     8293
# Name: collectionName, dtype: object
#
# phoneName
# count     131342
# unique         7
# top       Pixel4
# freq       48153
# Name: phoneName, dtype: object
#
# millisSinceGpsEpoch
# count    1.313420e+05
# mean     1.287913e+12
# std      1.162110e+10
# min      1.273529e+12
# 25%      1.275424e+12
# 50%      1.283279e+12
# 75%      1.302558e+12
# max      1.303771e+12
# Name: millisSinceGpsEpoch, dtype: float64
#
# latDeg
# count    131342.000000
# mean         37.435206
# std           0.082712
# min          37.321683
# 25%          37.371575
# 50%          37.424360
# 75%          37.469109
# max          37.690836
# Name: latDeg, dtype: float64
#
# lngDeg
# count    131342.000000
# mean       -122.154925
# std           0.145974
# min        -122.472214
# 25%        -122.275109
# 50%        -122.118311
# 75%        -122.069091
# max        -121.881855
# Name: lngDeg, dtype: float64
#
# heightAboveWgs84EllipsoidM
# count    131342.000000
# mean         23.832922
# std          72.589312
# min       -6157.470000
# 25%         -26.790000
# 50%           3.230000
# 75%          59.410000
# max       13701.980000
# Name: heightAboveWgs84EllipsoidM, dtype: float64
#
# phone
# count                         131342
# unique                            73
# top       2021-04-22-US-SJC-1_Pixel4
# freq                            2890
# Name: phone, dtype: object
#
# utcTimeMillis_x
#        utcTimeMillis_x  utcTimeMillis_x  utcTimeMillis_x
# count     1.137980e+05     1.313420e+05     3.658900e+04
# mean      1.604680e+12     1.603878e+12     1.619017e+12
# std       1.209329e+10     1.162110e+10     1.172510e+09
# min       1.589494e+12     1.589494e+12     1.615418e+12
# 25%       1.591379e+12     1.591389e+12     1.618523e+12
# 50%       1.609798e+12     1.599243e+12     1.619641e+12
# 75%       1.618523e+12     1.618522e+12     1.619723e+12
# max       1.619735e+12     1.619735e+12     1.619735e+12
#
# elapsedRealtimeNanos_x
#        elapsedRealtimeNanos_x  elapsedRealtimeNanos_x
# count            1.137980e+05            1.137980e+05
# mean             4.735094e+13            4.735094e+13
# std              1.075541e+14            1.075541e+14
# min              2.282485e+11            2.282544e+11
# 25%              8.036286e+12            8.036287e+12
# 50%              1.387414e+13            1.387414e+13
# 75%              6.816902e+13            6.816902e+13
# max              6.041912e+14            6.041912e+14
#
# UncalGyroXRadPerSec
# count    113798.000000
# mean          0.000923
# std           0.084996
# min          -1.824679
# 25%          -0.025551
# 50%           0.000916
# 75%           0.027488
# max           1.769790
# Name: UncalGyroXRadPerSec, dtype: float64
#
# UncalGyroYRadPerSec
# count    113798.000000
# mean         -0.001575
# std           0.092559
# min          -3.528166
# 25%          -0.019481
# 50%           0.000799
# 75%           0.018816
# max           1.880860
# Name: UncalGyroYRadPerSec, dtype: float64
#
# UncalGyroZRadPerSec
# count    113798.000000
# mean          0.000977
# std           0.050096
# min          -2.436228
# 25%          -0.011459
# 50%           0.001222
# 75%           0.014946
# max           2.277408
# Name: UncalGyroZRadPerSec, dtype: float64
#
# DriftXRadPerSec
# count    74725.000000
# mean         0.000195
# std          0.001996
# min         -0.004125
# 25%         -0.000503
# 50%          0.000009
# 75%          0.000837
# max          0.009721
# Name: DriftXRadPerSec, dtype: float64
#
# DriftYRadPerSec
# count    74725.000000
# mean         0.002355
# std          0.004949
# min         -0.002094
# 25%         -0.000251
# 50%          0.000075
# 75%          0.000577
# max          0.015419
# Name: DriftYRadPerSec, dtype: float64
#
# DriftZRadPerSec
# count    74725.000000
# mean         0.002363
# std          0.005364
# min         -0.005965
# 25%         -0.001627
# 50%          0.000601
# 75%          0.004007
# max          0.014271
# Name: DriftZRadPerSec, dtype: float64
#
# utcTimeMillis_y
#        utcTimeMillis_y  utcTimeMillis_y  utcTimeMillis_y
# count     1.137980e+05     1.137980e+05     1.117910e+05
# mean      1.604680e+12     1.604680e+12     1.603703e+12
# std       1.209329e+10     1.209329e+10     1.186885e+10
# min       1.589494e+12     1.589494e+12     1.589494e+12
# 25%       1.591379e+12     1.591379e+12     1.591379e+12
# 50%       1.609798e+12     1.609798e+12     1.599244e+12
# 75%       1.618523e+12     1.618523e+12     1.618522e+12
# max       1.619735e+12     1.619735e+12     1.619735e+12
#
# elapsedRealtimeNanos_y
#        elapsedRealtimeNanos_y  elapsedRealtimeNanos_y
# count            1.137980e+05            3.658900e+04
# mean             4.734853e+13            3.053199e+13
# std              1.075550e+14            2.743854e+13
# min              1.000000e+00            4.003852e+12
# 25%              8.034477e+12            1.176684e+13
# 50%              1.386814e+13            1.740758e+13
# 75%              6.816902e+13            6.710127e+13
# max              6.041912e+14            8.309815e+13
#
# UncalMagXMicroT
# count    113780.000000
# mean         29.201133
# std          39.605883
# min        -116.700000
# 25%           4.980000
# 50%          28.740000
# 75%          48.731492
# max         157.912500
# Name: UncalMagXMicroT, dtype: float64
#
# UncalMagYMicroT
# count    113780.000000
# mean        -52.356617
# std          37.173081
# min        -188.475000
# 25%         -57.937500
# 50%         -43.409250
# 75%         -34.369005
# max         126.753975
# Name: UncalMagYMicroT, dtype: float64
#
# UncalMagZMicroT
# count    113762.000000
# mean          4.066886
# std          67.743703
# min        -218.495760
# 25%         -24.240000
# 50%           0.803906
# 75%          20.510125
# max         260.025000
# Name: UncalMagZMicroT, dtype: float64
#
# BiasXMicroT
# count    74693.000000
# mean        16.093315
# std         42.486049
# min       -117.600000
# 25%         -4.390179
# 50%         13.256575
# 75%         30.476776
# max        135.506530
# Name: BiasXMicroT, dtype: float64
#
# BiasYMicroT
# count    74693.000000
# mean       -14.527748
# std         55.477841
# min       -123.855360
# 25%        -42.649117
# 50%         -9.150366
# 75%          3.924739
# max        202.620000
# Name: BiasYMicroT, dtype: float64
#
# BiasZMicroT
# count    74675.000000
# mean        15.456419
# std         80.564831
# min       -217.118040
# 25%        -37.862960
# 50%          2.663509
# 75%         35.045803
# max        234.596240
# Name: BiasZMicroT, dtype: float64
#
# utcTimeMillis_x
#        utcTimeMillis_x  utcTimeMillis_x  utcTimeMillis_x
# count     1.137980e+05     1.313420e+05     3.658900e+04
# mean      1.604680e+12     1.603878e+12     1.619017e+12
# std       1.209329e+10     1.162110e+10     1.172510e+09
# min       1.589494e+12     1.589494e+12     1.615418e+12
# 25%       1.591379e+12     1.591389e+12     1.618523e+12
# 50%       1.609798e+12     1.599243e+12     1.619641e+12
# 75%       1.618523e+12     1.618522e+12     1.619723e+12
# max       1.619735e+12     1.619735e+12     1.619735e+12
#
# TimeNanos
# count    1.313420e+05
# mean     1.871161e+14
# std      7.720866e+14
# min      4.993900e+10
# 25%      2.326058e+12
# 50%      1.078879e+13
# 75%      3.760431e+13
# max      4.261706e+15
# Name: TimeNanos, dtype: float64
#
# LeapSecond
# count    45928.0
# mean        18.0
# std          0.0
# min         18.0
# 25%         18.0
# 50%         18.0
# 75%         18.0
# max         18.0
# Name: LeapSecond, dtype: float64
#
# TimeUncertaintyNanos
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: TimeUncertaintyNanos, dtype: float64
#
# FullBiasNanos
# count    1.313420e+05
# mean    -1.287726e+18
# std      1.153714e+16
# min     -1.303769e+18
# 25%     -1.299453e+18
# 50%     -1.283273e+18
# 75%     -1.275339e+18
# max     -1.273508e+18
# Name: FullBiasNanos, dtype: float64
#
# BiasNanos
# count    131342.000000
# mean         -0.034683
# std           0.509370
# min          -0.999985
# 25%          -0.413013
# 50%           0.000000
# 75%           0.297781
# max           0.999979
# Name: BiasNanos, dtype: float64
#
# BiasUncertaintyNanos
# count    131342.000000
# mean        138.882081
# std         323.337851
# min           4.410778
# 25%          14.575101
# 50%          17.903321
# 75%          24.439189
# max        1010.203618
# Name: BiasUncertaintyNanos, dtype: float64
#
# DriftNanosPerSecond
# count    117173.000000
# mean         45.715046
# std         139.770830
# min        -133.764974
# 25%         -15.050240
# 50%          -1.192627
# 75%          16.070364
# max         445.000000
# Name: DriftNanosPerSecond, dtype: float64
#
# DriftUncertaintyNanosPerSecond
# count    117173.000000
# mean          9.264991
# std           3.707014
# min           0.743675
# 25%           8.952852
# 50%           9.697816
# 75%          10.821678
# max          41.865084
# Name: DriftUncertaintyNanosPerSecond, dtype: float64
#
# HardwareClockDiscontinuityCount
# count    131342.000000
# mean        904.863547
# std        2067.940289
# min           0.000000
# 25%           1.000000
# 50%           8.000000
# 75%         932.000000
# max       12484.000000
# Name: HardwareClockDiscontinuityCount, dtype: float64
#
# Svid_x
# count    131342.000000
# mean         21.857091
# std          26.931186
# min           1.000000
# 25%           9.000000
# 50%          19.000000
# 75%          27.000000
# max         195.000000
# Name: Svid_x, dtype: float64
#
# TimeOffsetNanos
# count    131342.0
# mean          0.0
# std           0.0
# min           0.0
# 25%           0.0
# 50%           0.0
# 75%           0.0
# max           0.0
# Name: TimeOffsetNanos, dtype: float64
#
# State
# count    131342.000000
# mean      37819.338597
# std       27131.543312
# min           4.000000
# 25%       16399.000000
# 50%       23567.000000
# 75%       49359.000000
# max       85034.000000
# Name: State, dtype: float64
#
# ReceivedSvTimeNanos
# count    1.313420e+05
# mean     3.121059e+14
# std      1.732955e+14
# min      1.328100e+04
# 25%      1.667148e+14
# 50%      4.112899e+14
# 75%      4.270754e+14
# max      5.184634e+14
# Name: ReceivedSvTimeNanos, dtype: float64
#
# ReceivedSvTimeUncertaintyNanos
# count    1.313420e+05
# mean     5.091290e+07
# std      2.198207e+08
# min      2.000000e+00
# 25%      7.000000e+00
# 50%      1.200000e+01
# 75%      2.100000e+01
# max      1.000000e+09
# Name: ReceivedSvTimeUncertaintyNanos, dtype: float64
#
# Cn0DbHz_x
# count    131342.000000
# mean         31.992947
# std           7.658805
# min           7.000000
# 25%          27.300000
# 50%          32.400000
# 75%          37.100000
# max          56.600000
# Name: Cn0DbHz_x, dtype: float64
#
# PseudorangeRateMetersPerSecond
# count    131342.000000
# mean         26.339512
# std        3565.671982
# min     -524008.318948
# 25%        -359.270341
# 50%          22.610368
# 75%         416.577360
# max      524170.529641
# Name: PseudorangeRateMetersPerSecond, dtype: float64
#
# PseudorangeRateUncertaintyMetersPerSecond
# count    1.313420e+05
# mean     1.525417e+07
# std      6.588192e+07
# min      9.465822e-04
# 25%      3.740000e-02
# 50%      6.120000e-02
# 75%      3.065000e-01
# max      2.997925e+08
# Name: PseudorangeRateUncertaintyMetersPerSecond, dtype: float64
#
# AccumulatedDeltaRangeState
# count    131342.000000
# mean         20.949102
# std           6.050364
# min           1.000000
# 25%          17.000000
# 50%          21.000000
# 75%          25.000000
# max          29.000000
# Name: AccumulatedDeltaRangeState, dtype: float64
#
# AccumulatedDeltaRangeMeters
# count    1.313420e+05
# mean    -5.972150e+03
# std      5.628474e+05
# min     -3.910771e+06
# 25%     -7.343367e+04
# 50%      0.000000e+00
# 75%      6.822980e+04
# max      3.896353e+06
# Name: AccumulatedDeltaRangeMeters, dtype: float64
#
# AccumulatedDeltaRangeUncertaintyMeters
# count    1.313420e+05
# mean     3.680766e+37
# std      1.056895e+38
# min     -6.921125e+18
# 25%      1.008556e-03
# 50%      2.354611e-03
# 75%      7.212130e-03
# max      3.402823e+38
# Name: AccumulatedDeltaRangeUncertaintyMeters, dtype: float64
#
# CarrierFrequencyHz_x
# count    1.313420e+05
# mean     1.484393e+09
# std      1.719319e+08
# min      1.176450e+09
# 25%      1.561098e+09
# 50%      1.575420e+09
# 75%      1.575420e+09
# max      1.605375e+09
# Name: CarrierFrequencyHz_x, dtype: float64
#
# CarrierCycles
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: CarrierCycles, dtype: float64
#
# CarrierPhase
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: CarrierPhase, dtype: float64
#
# CarrierPhaseUncertainty
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: CarrierPhaseUncertainty, dtype: float64
#
# MultipathIndicator
# count    131342.00000
# mean          0.03133
# std           0.17421
# min           0.00000
# 25%           0.00000
# 50%           0.00000
# 75%           0.00000
# max           1.00000
# Name: MultipathIndicator, dtype: float64
#
# SnrInDb
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: SnrInDb, dtype: float64
#
# ConstellationType_x
# count    131342.000000
# mean          3.337265
# std           2.166505
# min           1.000000
# 25%           1.000000
# 50%           3.000000
# 75%           6.000000
# max           6.000000
# Name: ConstellationType_x, dtype: float64
#
# AgcDb
# count    123464.000000
# mean         -1.916208
# std          29.264287
# min         -76.000000
# 25%          -1.150000
# 50%           0.380000
# 75%           3.890000
# max          64.818840
# Name: AgcDb, dtype: float64
#
# BasebandCn0DbHz_x
# count    25995.000000
# mean        26.892116
# std          8.898908
# min          6.900000
# 25%         21.437767
# 50%         28.038876
# 75%         33.668024
# max         46.022934
# Name: BasebandCn0DbHz_x, dtype: float64
#
# FullInterSignalBiasNanos
# count    25995.000000
# mean      -703.613103
# std       2609.491071
# min      -7876.281738
# 25%         -6.829505
# 50%          0.000000
# 75%          2.379855
# max       3817.982422
# Name: FullInterSignalBiasNanos, dtype: float64
#
# FullInterSignalBiasUncertaintyNanos
# count    25995.000000
# mean         8.037853
# std        215.055299
# min          0.000000
# 25%          1.000000
# 50%          2.082444
# 75%          6.126178
# max      20000.000000
# Name: FullInterSignalBiasUncertaintyNanos, dtype: float64
#
# SatelliteInterSignalBiasNanos
# count    14204.000000
# mean         5.548503
# std         10.726767
# min         -8.412334
# 25%         -1.235865
# 50%          0.000000
# 75%         10.681106
# max         35.390258
# Name: SatelliteInterSignalBiasNanos, dtype: float64
#
# SatelliteInterSignalBiasUncertaintyNanos
# count    14204.000000
# mean         1.346381
# std          0.292879
# min          1.000000
# 25%          1.000000
# 50%          1.500000
# 75%          1.500000
# max          2.000000
# Name: SatelliteInterSignalBiasUncertaintyNanos, dtype: float64
#
# CodeType
# count     83102
# unique        4
# top           C
# freq      53965
# Name: CodeType, dtype: object
#
# ChipsetElapsedRealtimeNanos
# count    4.861400e+04
# mean     3.429301e+13
# std      3.153181e+13
# min      6.236340e+12
# 25%      1.136069e+13
# 50%      1.715725e+13
# 75%      7.316578e+13
# max      9.553389e+13
# Name: ChipsetElapsedRealtimeNanos, dtype: float64
#
# utcTimeMillis_y
#        utcTimeMillis_y  utcTimeMillis_y  utcTimeMillis_y
# count     1.137980e+05     1.137980e+05     1.117910e+05
# mean      1.604680e+12     1.604680e+12     1.603703e+12
# std       1.209329e+10     1.209329e+10     1.186885e+10
# min       1.589494e+12     1.589494e+12     1.589494e+12
# 25%       1.591379e+12     1.591379e+12     1.591379e+12
# 50%       1.609798e+12     1.609798e+12     1.599244e+12
# 75%       1.618523e+12     1.618523e+12     1.618522e+12
# max       1.619735e+12     1.619735e+12     1.619735e+12
#
# elapsedRealtimeNanos_x
#        elapsedRealtimeNanos_x  elapsedRealtimeNanos_x
# count            1.137980e+05            1.137980e+05
# mean             4.735094e+13            4.735094e+13
# std              1.075541e+14            1.075541e+14
# min              2.282485e+11            2.282544e+11
# 25%              8.036286e+12            8.036287e+12
# 50%              1.387414e+13            1.387414e+13
# 75%              6.816902e+13            6.816902e+13
# max              6.041912e+14            6.041912e+14
#
# UncalAccelXMps2
# count    113798.000000
# mean         -0.206611
# std           1.108711
# min         -19.929222
# 25%          -0.705284
# 50%          -0.244068
# 75%           0.238684
# max           9.878537
# Name: UncalAccelXMps2, dtype: float64
#
# UncalAccelYMps2
# count    113798.000000
# mean          9.156857
# std           2.472644
# min          -5.511575
# 25%           9.318250
# 50%           9.737592
# 75%          10.037734
# max          26.434612
# Name: UncalAccelYMps2, dtype: float64
#
# UncalAccelZMps2
# count    113798.000000
# mean         -0.208391
# std           2.750507
# min         -16.254417
# 25%          -1.201197
# 50%          -0.407976
# 75%           0.822626
# max          14.864664
# Name: UncalAccelZMps2, dtype: float64
#
# BiasXMps2
# count    74725.0
# mean         0.0
# std          0.0
# min          0.0
# 25%          0.0
# 50%          0.0
# 75%          0.0
# max          0.0
# Name: BiasXMps2, dtype: float64
#
# BiasYMps2
# count    74725.0
# mean         0.0
# std          0.0
# min          0.0
# 25%          0.0
# 50%          0.0
# 75%          0.0
# max          0.0
# Name: BiasYMps2, dtype: float64
#
# BiasZMps2
# count    74725.000000
# mean        -0.000455
# std          0.000939
# min         -0.002394
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          0.000000
# Name: BiasZMps2, dtype: float64
#
# utcTimeMillis_x
#        utcTimeMillis_x  utcTimeMillis_x  utcTimeMillis_x
# count     1.137980e+05     1.313420e+05     3.658900e+04
# mean      1.604680e+12     1.603878e+12     1.619017e+12
# std       1.209329e+10     1.162110e+10     1.172510e+09
# min       1.589494e+12     1.589494e+12     1.615418e+12
# 25%       1.591379e+12     1.591389e+12     1.618523e+12
# 50%       1.609798e+12     1.599243e+12     1.619641e+12
# 75%       1.618523e+12     1.618522e+12     1.619723e+12
# max       1.619735e+12     1.619735e+12     1.619735e+12
#
# elapsedRealtimeNanos_y
#        elapsedRealtimeNanos_y  elapsedRealtimeNanos_y
# count            1.137980e+05            3.658900e+04
# mean             4.734853e+13            3.053199e+13
# std              1.075550e+14            2.743854e+13
# min              1.000000e+00            4.003852e+12
# 25%              8.034477e+12            1.176684e+13
# 50%              1.386814e+13            1.740758e+13
# 75%              6.816902e+13            6.710127e+13
# max              6.041912e+14            8.309815e+13
#
# yawDeg
# count    36589.000000
# mean       141.763891
# std         89.888553
# min          0.000000
# 25%         73.000000
# 50%        127.000000
# 75%        180.000000
# max        359.000000
# Name: yawDeg, dtype: float64
#
# rollDeg
# count    36572.000000
# mean        44.125834
# std        152.973663
# min       -180.000000
# 25%       -174.000000
# 50%        146.000000
# 75%        164.000000
# max        179.000000
# Name: rollDeg, dtype: float64
#
# pitchDeg
# count    36572.000000
# mean       -61.415017
# std         34.612914
# min        -89.000000
# 25%        -84.000000
# 50%        -81.000000
# 75%        -45.000000
# max         21.000000
# Name: pitchDeg, dtype: float64
#
# timeSinceFirstFixSeconds
# count    131342.000000
# mean       1213.986316
# std         609.145524
# min          47.430000
# 25%         718.430000
# 50%        1174.430000
# 75%        1659.440000
# max        3216.450000
# Name: timeSinceFirstFixSeconds, dtype: float64
#
# hDop
# count    131342.000000
# mean         10.146238
# std          56.707267
# min           0.000000
# 25%           0.900000
# 50%           1.300000
# 75%           2.500000
# max         655.300000
# Name: hDop, dtype: float64
#
# vDop
# count    131342.0
# mean          0.0
# std           0.0
# min           0.0
# 25%           0.0
# 50%           0.0
# 75%           0.0
# max           0.0
# Name: vDop, dtype: float64
#
# speedMps
# count    131342.000000
# mean         18.220691
# std          12.698756
# min           0.000000
# 25%           5.260000
# 50%          22.020000
# 75%          29.310000
# max          45.010000
# Name: speedMps, dtype: float64
#
# courseDegree
# count    131342.000000
# mean        210.534792
# std         101.127548
# min           0.000000
# 25%         129.000000
# 50%         209.100000
# 75%         309.600000
# max         360.000000
# Name: courseDegree, dtype: float64
#
# t_latDeg
# count    131342.000000
# mean         37.435201
# std           0.082713
# min          37.322839
# 25%          37.371573
# 50%          37.424355
# 75%          37.469097
# max          37.690794
# Name: t_latDeg, dtype: float64
#
# t_lngDeg
# count    131342.000000
# mean       -122.154926
# std           0.145972
# min        -122.428838
# 25%        -122.275114
# 50%        -122.118312
# 75%        -122.069092
# max        -121.881852
# Name: t_lngDeg, dtype: float64
#
# t_heightAboveWgs84EllipsoidM
# count    131342.000000
# mean         87.028847
# std          56.999876
# min          31.160000
# 25%          37.160000
# 50%          63.520000
# 75%         122.330000
# max         247.850000
# Name: t_heightAboveWgs84EllipsoidM, dtype: float64
#
# utcTimeMillis_y
#        utcTimeMillis_y  utcTimeMillis_y  utcTimeMillis_y
# count     1.137980e+05     1.137980e+05     1.117910e+05
# mean      1.604680e+12     1.604680e+12     1.603703e+12
# std       1.209329e+10     1.209329e+10     1.186885e+10
# min       1.589494e+12     1.589494e+12     1.589494e+12
# 25%       1.591379e+12     1.591379e+12     1.591379e+12
# 50%       1.609798e+12     1.609798e+12     1.599244e+12
# 75%       1.618523e+12     1.618523e+12     1.618522e+12
# max       1.619735e+12     1.619735e+12     1.619735e+12
#
# SignalCount
# count    111791.000000
# mean         39.112460
# std           8.103215
# min           4.000000
# 25%          33.000000
# 50%          41.000000
# 75%          45.000000
# max          56.000000
# Name: SignalCount, dtype: float64
#
# SignalIndex
# count    111791.000000
# mean         18.648827
# std          13.231969
# min           0.000000
# 25%           8.000000
# 50%          17.000000
# 75%          28.000000
# max          55.000000
# Name: SignalIndex, dtype: float64
#
# ConstellationType_y
# count    111791.000000
# mean          3.385120
# std           2.159356
# min           1.000000
# 25%           1.000000
# 50%           3.000000
# 75%           6.000000
# max           6.000000
# Name: ConstellationType_y, dtype: float64
#
# Svid_y
# count    111791.000000
# mean         22.476604
# std          30.017578
# min           1.000000
# 25%           8.000000
# 50%          18.000000
# 75%          27.000000
# max         195.000000
# Name: Svid_y, dtype: float64
#
# CarrierFrequencyHz_y
# count    1.116330e+05
# mean     1.480272e+09
# std      1.749200e+08
# min      1.176450e+09
# 25%      1.561098e+09
# 50%      1.575420e+09
# 75%      1.575420e+09
# max      1.605375e+09
# Name: CarrierFrequencyHz_y, dtype: float64
#
# Cn0DbHz_y
# count    111791.000000
# mean         28.625575
# std          11.995357
# min           0.000000
# 25%          24.050000
# 50%          31.000000
# 75%          36.400000
# max          55.800000
# Name: Cn0DbHz_y, dtype: float64
#
# AzimuthDegrees
# count    111791.000000
# mean        165.555903
# std         109.467490
# min           0.000000
# 25%          59.000000
# 50%         154.000000
# 75%         274.000000
# max         359.000000
# Name: AzimuthDegrees, dtype: float64
#
# ElevationDegrees
# count    111791.000000
# mean         31.939190
# std          23.321118
# min           0.000000
# 25%          11.000000
# 50%          28.000000
# 75%          51.000000
# max          89.000000
# Name: ElevationDegrees, dtype: float64
#
# UsedInFix
# count    111791.000000
# mean          0.619826
# std           0.485432
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           1.000000
# max           1.000000
# Name: UsedInFix, dtype: float64
#
# HasAlmanacData
# count    111791.000000
# mean          0.976519
# std           0.151427
# min           0.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max           1.000000
# Name: HasAlmanacData, dtype: float64
#
# HasEphemerisData
# count    111791.000000
# mean          0.620345
# std           0.485303
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           1.000000
# max           1.000000
# Name: HasEphemerisData, dtype: float64
#
# BasebandCn0DbHz_y
# count    20262.000000
# mean        26.494277
# std         10.566247
# min          0.000000
# 25%         21.722660
# 50%         28.300000
# 75%         34.126602
# max         46.211950
# Name: BasebandCn0DbHz_y, dtype: float64
#
# constellationType
# count    131342.000000
# mean          3.378744
# std           2.176913
# min           1.000000
# 25%           1.000000
# 50%           3.000000
# 75%           6.000000
# max           6.000000
# Name: constellationType, dtype: float64
#
# svid
# count    131342.000000
# mean         17.188843
# std           9.761156
# min           1.000000
# 25%           9.000000
# 50%          17.000000
# 75%          25.000000
# max          37.000000
# Name: svid, dtype: float64
#
# signalType
# count     131342
# unique         8
# top       GPS_L1
# freq       39906
# Name: signalType, dtype: object
#
# receivedSvTimeInGpsNanos
# count    1.313420e+05
# mean     1.287913e+18
# std      1.162110e+16
# min      1.273529e+18
# 25%      1.275424e+18
# 50%      1.283279e+18
# 75%      1.302558e+18
# max      1.303771e+18
# Name: receivedSvTimeInGpsNanos, dtype: float64
#
# xSatPosM
# count    1.313420e+05
# mean    -8.429426e+06
# std      1.260199e+07
# min     -3.141789e+07
# 25%     -1.805893e+07
# 50%     -1.105838e+07
# 75%      9.958046e+05
# max      2.314026e+07
# Name: xSatPosM, dtype: float64
#
# ySatPosM
# count    1.313420e+05
# mean    -1.240430e+07
# std      1.120919e+07
# min     -2.959319e+07
# 25%     -2.090822e+07
# 50%     -1.413953e+07
# 75%     -6.013359e+06
# max      2.661825e+07
# Name: ySatPosM, dtype: float64
#
# zSatPosM
# count    1.313420e+05
# mean     1.258066e+07
# std      1.068349e+07
# min     -1.836208e+07
# 25%      4.774167e+06
# 50%      1.597202e+07
# 75%      2.138985e+07
# max      3.513852e+07
# Name: zSatPosM, dtype: float64
#
# xSatVelMps
# count    131342.000000
# mean        557.524943
# std        1207.930715
# min       -3025.790000
# 25%        -223.555750
# 50%         408.957000
# 75%        1467.172000
# max        3195.491000
# Name: xSatVelMps, dtype: float64
#
# ySatVelMps
# count    131342.000000
# mean       -330.371870
# std        1317.304775
# min       -3143.622000
# 25%       -1323.738250
# 50%        -258.714000
# 75%         546.261250
# max        3124.382000
# Name: ySatVelMps, dtype: float64
#
# zSatVelMps
# count    131342.000000
# mean         37.523551
# std        2272.328628
# min       -3580.628000
# 25%       -2253.343250
# 50%          35.172000
# 75%        2299.073000
# max        3617.957000
# Name: zSatVelMps, dtype: float64
#
# satClkBiasM
# count    1.313420e+05
# mean     1.061657e+05
# std      4.170421e+05
# min     -3.288018e+05
# 25%     -6.885599e+04
# 50%      1.668736e+03
# 75%      7.918819e+04
# max      1.865378e+06
# Name: satClkBiasM, dtype: float64
#
# satClkDriftMps
# count    131342.000000
# mean          0.000092
# std           0.007456
# min          -0.014000
# 25%          -0.002000
# 50%          -0.000000
# 75%           0.001000
# max           0.075000
# Name: satClkDriftMps, dtype: float64
#
# rawPrM
# count    1.313420e+05
# mean     2.361523e+07
# std      3.328288e+06
# min      1.907225e+07
# 25%      2.180702e+07
# 50%      2.337290e+07
# 75%      2.458459e+07
# max      4.416339e+07
# Name: rawPrM, dtype: float64
#
# rawPrUncM
# count    131342.000000
# mean          4.881786
# std           4.913111
# min           0.600000
# 25%           2.099000
# 50%           3.298000
# 75%           5.696000
# max         149.896000
# Name: rawPrUncM, dtype: float64
#
# isrbM
# count    131342.000000
# mean       -310.665604
# std        1056.395342
# min       -6085.269000
# 25%        -228.997750
# 50%           0.000000
# 75%           0.000000
# max        9281.743000
# Name: isrbM, dtype: float64
#
# ionoDelayM
# count    131342.000000
# mean          5.713940
# std           2.862756
# min           0.000000
# 25%           3.710000
# 50%           4.895000
# 75%           7.285000
# max          25.876000
# Name: ionoDelayM, dtype: float64
#
# tropoDelayM
# count    131342.000000
# mean          6.304804
# std           5.712669
# min           0.000000
# 25%           3.029000
# 50%           4.196500
# 75%           7.109000
# max          47.439000
# Name: tropoDelayM, dtype: float64
#
# meter
# count    131342.000000
# mean          4.261468
# std          35.475422
# min           0.001579
# 25%           1.335918
# 50%           2.284470
# 75%           3.944131
# max        9597.674736
# Name: meter, dtype: float64

# %%
for col in df_train.columns:
    print(col)
# Out:
# collectionName
# phoneName
# millisSinceGpsEpoch
# latDeg
# lngDeg
# heightAboveWgs84EllipsoidM
# phone
# utcTimeMillis_x
# elapsedRealtimeNanos_x
# UncalGyroXRadPerSec
# UncalGyroYRadPerSec
# UncalGyroZRadPerSec
# DriftXRadPerSec
# DriftYRadPerSec
# DriftZRadPerSec
# utcTimeMillis_y
# elapsedRealtimeNanos_y
# UncalMagXMicroT
# UncalMagYMicroT
# UncalMagZMicroT
# BiasXMicroT
# BiasYMicroT
# BiasZMicroT
# utcTimeMillis_x
# TimeNanos
# LeapSecond
# TimeUncertaintyNanos
# FullBiasNanos
# BiasNanos
# BiasUncertaintyNanos
# DriftNanosPerSecond
# DriftUncertaintyNanosPerSecond
# HardwareClockDiscontinuityCount
# Svid_x
# TimeOffsetNanos
# State
# ReceivedSvTimeNanos
# ReceivedSvTimeUncertaintyNanos
# Cn0DbHz_x
# PseudorangeRateMetersPerSecond
# PseudorangeRateUncertaintyMetersPerSecond
# AccumulatedDeltaRangeState
# AccumulatedDeltaRangeMeters
# AccumulatedDeltaRangeUncertaintyMeters
# CarrierFrequencyHz_x
# CarrierCycles
# CarrierPhase
# CarrierPhaseUncertainty
# MultipathIndicator
# SnrInDb
# ConstellationType_x
# AgcDb
# BasebandCn0DbHz_x
# FullInterSignalBiasNanos
# FullInterSignalBiasUncertaintyNanos
# SatelliteInterSignalBiasNanos
# SatelliteInterSignalBiasUncertaintyNanos
# CodeType
# ChipsetElapsedRealtimeNanos
# utcTimeMillis_y
# elapsedRealtimeNanos_x
# UncalAccelXMps2
# UncalAccelYMps2
# UncalAccelZMps2
# BiasXMps2
# BiasYMps2
# BiasZMps2
# utcTimeMillis_x
# elapsedRealtimeNanos_y
# yawDeg
# rollDeg
# pitchDeg
# timeSinceFirstFixSeconds
# hDop
# vDop
# speedMps
# courseDegree
# t_latDeg
# t_lngDeg
# t_heightAboveWgs84EllipsoidM
# utcTimeMillis_y
# SignalCount
# SignalIndex
# ConstellationType_y
# Svid_y
# CarrierFrequencyHz_y
# Cn0DbHz_y
# AzimuthDegrees
# ElevationDegrees
# UsedInFix
# HasAlmanacData
# HasEphemerisData
# BasebandCn0DbHz_y
# constellationType
# svid
# signalType
# receivedSvTimeInGpsNanos
# xSatPosM
# ySatPosM
# zSatPosM
# xSatVelMps
# ySatVelMps
# zSatVelMps
# satClkBiasM
# satClkDriftMps
# rawPrM
# rawPrUncM
# isrbM
# ionoDelayM
# tropoDelayM
# meter

# %%
df_train[['latDeg', 'lngDeg', 'heightAboveWgs84EllipsoidM',
             'xSatVelMps', 'ySatVelMps', 'zSatVelMps', 
             'xSatPosM', 'ySatPosM', 'zSatPosM',
            'UncalGyroXRadPerSec', 'UncalGyroYRadPerSec', 'UncalGyroZRadPerSec',
         'DriftXRadPerSec' , 'DriftYRadPerSec', 'DriftZRadPerSec',
         'UncalMagXMicroT', 'UncalMagYMicroT', 'UncalMagZMicroT',
         'UncalAccelXMps2', 'UncalAccelYMps2', 'UncalAccelZMps2']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 131342 entries, 0 to 131341
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   latDeg                      131342 non-null  float64
#  1   lngDeg                      131342 non-null  float64
#  2   heightAboveWgs84EllipsoidM  131342 non-null  float64
#  3   xSatVelMps                  131342 non-null  float64
#  4   ySatVelMps                  131342 non-null  float64
#  5   zSatVelMps                  131342 non-null  float64
#  6   xSatPosM                    131342 non-null  float64
#  7   ySatPosM                    131342 non-null  float64
#  8   zSatPosM                    131342 non-null  float64
#  9   UncalGyroXRadPerSec         113798 non-null  float64
#  10  UncalGyroYRadPerSec         113798 non-null  float64
#  11  UncalGyroZRadPerSec         113798 non-null  float64
#  12  DriftXRadPerSec             74725 non-null   float64
#  13  DriftYRadPerSec             74725 non-null   float64
#  14  DriftZRadPerSec             74725 non-null   float64
#  15  UncalMagXMicroT             113780 non-null  float64
#  16  UncalMagYMicroT             113780 non-null  float64
#  17  UncalMagZMicroT             113762 non-null  float64
#  18  UncalAccelXMps2             113798 non-null  float64
#  19  UncalAccelYMps2             113798 non-null  float64
#  20  UncalAccelZMps2             113798 non-null  float64
# dtypes: float64(21)
# memory usage: 22.0 MB

# %%
df_train = df_train.fillna(method = 'pad')
df_train = df_train.fillna(0)

# %%
df_train[['latDeg', 'lngDeg', 'heightAboveWgs84EllipsoidM',
             'xSatVelMps', 'ySatVelMps', 'zSatVelMps', 
             'xSatPosM', 'ySatPosM', 'zSatPosM',
            'UncalGyroXRadPerSec', 'UncalGyroYRadPerSec', 'UncalGyroZRadPerSec',
         'DriftXRadPerSec' , 'DriftYRadPerSec', 'DriftZRadPerSec',
         'UncalMagXMicroT', 'UncalMagYMicroT', 'UncalMagZMicroT',
         'UncalAccelXMps2', 'UncalAccelYMps2', 'UncalAccelZMps2']].describe()
# Out:
#               latDeg         lngDeg  heightAboveWgs84EllipsoidM  \
# count  131342.000000  131342.000000               131342.000000
# mean       37.435206    -122.154925                   23.832922
# std         0.082712       0.145974                   72.589312
# min        37.321683    -122.472214                -6157.470000
# 25%        37.371575    -122.275109                  -26.790000
# 50%        37.424360    -122.118311                    3.230000
# 75%        37.469109    -122.069091                   59.410000
# max        37.690836    -121.881855                13701.980000
#
#           xSatVelMps     ySatVelMps     zSatVelMps      xSatPosM  \
# count  131342.000000  131342.000000  131342.000000  1.313420e+05
# mean      557.524943    -330.371870      37.523551 -8.429426e+06
# std      1207.930715    1317.304775    2272.328628  1.260199e+07
# min     -3025.790000   -3143.622000   -3580.628000 -3.141789e+07
# 25%      -223.555750   -1323.738250   -2253.343250 -1.805893e+07
# 50%       408.957000    -258.714000      35.172000 -1.105838e+07
# 75%      1467.172000     546.261250    2299.073000  9.958046e+05
# max      3195.491000    3124.382000    3617.957000  2.314026e+07
#
#            ySatPosM      zSatPosM  UncalGyroXRadPerSec  ...  \
# count  1.313420e+05  1.313420e+05        131342.000000  ...
# mean  -1.240430e+07  1.258066e+07             0.000672  ...
# std    1.120919e+07  1.068349e+07             0.080754  ...
# min   -2.959319e+07 -1.836208e+07            -1.824679  ...
# 25%   -2.090822e+07  4.774167e+06            -0.020616  ...
# 50%   -1.413953e+07  1.597202e+07            -0.000484  ...
# 75%   -6.013359e+06  2.138985e+07             0.025197  ...
# max    2.661825e+07  3.513852e+07             1.769790  ...
#
#        UncalGyroZRadPerSec  DriftXRadPerSec  DriftYRadPerSec  DriftZRadPerSec  \
# count        131342.000000    131342.000000    131342.000000    131342.000000
# mean             -0.003519         0.000072         0.001559         0.001583
# std               0.049145         0.001528         0.003905         0.004282
# min              -2.436228        -0.004125        -0.002094        -0.005965
# 25%              -0.018631        -0.000391        -0.000044        -0.001070
# 50%              -0.000153         0.000000         0.000000         0.000000
# 75%               0.013166         0.000137         0.000479         0.002808
# max               2.277408         0.009721         0.015419         0.014271
#
#        UncalMagXMicroT  UncalMagYMicroT  UncalMagZMicroT  UncalAccelXMps2  \
# count    131342.000000    131342.000000    131342.000000    131342.000000
# mean         30.100941       -49.640727       -14.971980        -0.152489
# std          38.442916        38.802910        91.740602         1.068431
# min        -116.700000      -188.475000      -218.495760       -19.929222
# 25%           7.536778       -56.362500       -45.450000        -0.645714
# 50%          27.583504       -41.585327        -4.256250        -0.200438
# 75%          47.100000       -28.360832        18.494448         0.407807
# max         157.912500       126.753975       260.025000         9.878537
#
#        UncalAccelYMps2  UncalAccelZMps2
# count    131342.000000    131342.000000
# mean          9.210476        -0.172470
# std           2.313976         2.582447
# min          -5.511575       -16.254417
# 25%           9.351194        -1.127020
# 50%           9.701699        -0.271248
# 75%           9.984120         0.649944
# max          26.434612        14.864664
#
# [8 rows x 21 columns]

# %%
def data_slice_by_phone(df:pd.DataFrame, 
                        xCols = ['latDeg', 'lngDeg', 'heightAboveWgs84EllipsoidM'], 
                        yCols = ['t_latDeg', 't_lngDeg', 't_heightAboveWgs84EllipsoidM', 'speedMps', 'courseDegree']):
    indexCols = ['collectionName', 'phoneName', 'millisSinceGpsEpoch']
    
    indx = []
    data = []
    true = []
    for i, phone in enumerate(df['phone'].unique()):
        temp = df[df['phone'] == phone]
        indx.append(temp[indexCols])
        data.append(temp[xCols])
        true.append(temp[yCols])
        
    return indx, data, true

def data_merge_by_index(df:pd.DataFrame, index:pd.DataFrame, src:pd.DataFrame, srcCols = ['latDeg', 'lngDeg', 'heightAboveWgs84EllipsoidM']):
    indexCols = ['collectionName', 'phoneName', 'millisSinceGpsEpoch']
    output = df.copy()
    
    listFrame = []
    for i in range(len(index)):
        idxFrame = index[i]
        srcFrame = src[i]
        temp = pd.concat([idxFrame, srcFrame], axis = 1)
        listFrame.append(temp)
    
    dataFrame = pd.concat(listFrame, axis = 0)
    output = output.merge(dataFrame,
              on=["collectionName", "phoneName", "millisSinceGpsEpoch"])
    
    return output


features = ['latDeg', 'lngDeg', 'heightAboveWgs84EllipsoidM',
             'xSatVelMps', 'ySatVelMps', 'zSatVelMps', 
             'xSatPosM', 'ySatPosM', 'zSatPosM',
            'UncalGyroXRadPerSec', 'UncalGyroYRadPerSec', 'UncalGyroZRadPerSec',
         'DriftXRadPerSec' , 'DriftYRadPerSec', 'DriftZRadPerSec',
         'UncalMagXMicroT', 'UncalMagYMicroT', 'UncalMagZMicroT',
         'UncalAccelXMps2', 'UncalAccelYMps2', 'UncalAccelZMps2']
labels = ['t_latDeg', 't_lngDeg', 't_heightAboveWgs84EllipsoidM', 'speedMps', 'courseDegree']

idxFrame, dataFrame, trueFrame = data_slice_by_phone(df_train, xCols=features, yCols = labels)

# data_merge_by_index(df_train[["collectionName", "phoneName", "millisSinceGpsEpoch"]], idxFrame, dataFrame)

# %% [markdown]
# # Check!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# slide window 기반은 때려치고, 데이터프레임에서 직접 읽어오는 방식으로 변경할 필요가 있음
# collectionName, phoneName기반으로 데이터를 잘라서 시계열 데이터처럼 쓸 예정 우선적으로 필요한 것은 lstm으로 돌려보기(baseline을 그렇게 하자!)

# %% [markdown]
# # Modeling

# %%
# build model
class ConvBlock(nn.Module):
    def __init__(self, input_features, output_features, kernel_size = 3):
        super().__init__()
        
        self.convK = nn.Conv1d(input_features, output_features, kernel_size = kernel_size, padding = kernel_size//2)
        self.conv = nn.Conv1d(input_features, output_features, 1)
        self.bn = nn.BatchNorm1d(output_features)
        
    def forward(self, inputs):
        x = self.convK(inputs)
        inputs = self.conv(inputs)
        x = self.bn(x)
        x = F.relu(x)
        outputs = x + inputs
        return outputs
    
class BigConv(nn.Module):
    def __init__(self, input_size, output_size):
        super().__init__()
        self.conv1 = ConvBlock(input_size, 2*input_size)
        self.conv2 = ConvBlock(2*input_size, 4*input_size)
        self.conv3 = ConvBlock(4*input_size, 4*input_size)
        self.conv4 = ConvBlock(4*input_size, 4*input_size)
        self.conv5 = ConvBlock(4*input_size, output_size)
        
    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.conv5(x)
        return x
    
    
    
class ConvolutionNetwork(nn.Module):
    def __init__(self, input_size, output_size):
        super().__init__()
        
#         self.conv = nn.Conv1d(input_size, output_size, 1)
        self.conv1 = BigConv(input_size, 64)
        self.conv2 = BigConv(64, 64)
        self.conv3 = BigConv(64, 64)
        self.conv4 = BigConv(64, output_size)
        
#         self.lstm = nn.LSTM(input_size = 512 + output_size, hidden_size = output_size, num_layers = 3, dropout = 0.3)
    
    def forward(self, x):
#         x1 = self.conv(x)
        
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        
#         x = torch.cat([x1, x], axis = 1)
#         x, hidden = self.lstm(x)
        
        return x
    
model = ConvolutionNetwork(len(features), len(labels))
model.to(device)

# loss_func = nn.SmoothL1Loss()
loss_func = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr = lr)
scheduler = optim.lr_scheduler.LambdaLR(optimizer=optimizer,
                                lr_lambda=lambda epoch: 0.90 ** epoch,
                                last_epoch=-1,
                                verbose=True)
# Out:
# Adjusting learning rate of group 0 to 5.0000e-03.

# %%
class CustomDataloader(torch.utils.data.Dataset):
    def __init__(self, data, true = None):
        self.data = data
        self.true = true
        self.len = len(data)
        
    
    def __len__(self):
        return self.len
    
    def __shuffle__(self):
        index = np.array(range(self.len), dtype = 'int')
        index = np.random.permutation(index)
        data = []
        true = []
        for i in range(self.len):
            data.append(self.data[index[i]])
            true.append(self.true[index[i]])
            
        self.data = data
        self.true = true
    
    def __getitem__(self, idx):
        data = self.data[idx]
        if self.true is None:
            true = []
        else:
            true = self.true[idx]
            
        data = torch.Tensor(np.expand_dims(np.array(data), 0)).transpose(2, 1)
        true = torch.Tensor(np.expand_dims(np.array(true), 0)).transpose(2, 1)
        
        return data, true

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(dataFrame, trueFrame, test_size = 1/10)

loader_train = CustomDataloader(Xtrain, ytrain)
loader_test = CustomDataloader(Xtest, ytest)

# %%
def train(epoch):
    model.train()  # 신경망을 학습 모드로 전환

    # 데이터로더에서 미니배치를 하나씩 꺼내 학습을 수행
    predict = []
    ground = []
    
    loader_train.__shuffle__()
    
    for data, targets in loader_train:
        
        data = data.to(device)
        targets = targets.to(device)
        
        optimizer.zero_grad()  # 경사를 0으로 초기화
        outputs = model(data)  # 데이터를 입력하고 출력을 계산
        loss = loss_func(outputs, targets)  # 출력과 훈련 데이터 정답 간의 오차를 계산
        loss.backward()  # 오차를 역전파 계산
        optimizer.step()  # 역전파 계산한 값으로 가중치를 수정
        
        predict.append(outputs.squeeze(dim = 0).transpose(1,0))
        ground.append(targets.squeeze(dim = 0).transpose(1,0))
    scheduler.step()

    # 정확도 출력
    predict = torch.cat(predict,axis = 0)
    ground = torch.cat(ground,axis = 0)
    
    loss = loss_func(predict, ground)
    meas = check_score_np(predict.to('cpu'), ground.to('cpu'))
    return loss, meas

# %%
def test():
    model.eval()  # 신경망을 추론 모드로 전환

    # 데이터로더에서 미니배치를 하나씩 꺼내 추론을 수행
    predict = []
    ground = []
    with torch.no_grad():  # 추론 과정에는 미분이 필요없음
        for data, targets in loader_test:
            data = data.to(device)
            targets = targets.to(device)
            
            outputs = model(data)  # 데이터를 입력하고 출력을 계산
            predict.append(outputs.squeeze(dim = 0).transpose(1,0))
            ground.append(targets.squeeze(dim = 0).transpose(1,0))

    # 정확도 출력
    predict = torch.cat(predict,axis = 0)
    ground = torch.cat(ground,axis = 0)
    
    loss = loss_func(predict, ground)
    meas = check_score_np(predict.to('cpu'), ground.to('cpu'))
    return loss, meas

# %%
test()
# Out:
# D:\Sangwons_Room\00_SoftWares\Anaconda\envs\torch\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning:
#
# invalid value encountered in arcsin
#
# D:\Sangwons_Room\00_SoftWares\Anaconda\envs\torch\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning:
#
# invalid value encountered in double_scalars
# (tensor(29514368., device='cuda:0'), nan)

# %%
history = []
train_loss, train_meas = 0,0
test_loss, test_meas = 0,0

check_meas = np.inf
check_loss = np.inf
check_epoch = 0

for epoch in range(EPOCH_NUM+1):
    if epoch != 0:
        train_loss, train_meas = train(epoch)
    test_loss, test_meas = test()
    
    history.append({'epoch':epoch, 'train_loss':train_loss, 'train_meas':train_meas, 'test_loss':test_loss, 'test_meas':test_meas})
    
    if (test_meas < check_meas):
        print("")
        print(f"/***CHECK_POINT***/ ")
        print(f"TRAIN - {train_loss}, {train_meas}")
        print(f"TEST - {test_loss}, {test_meas}")
        print("")
        check_meas = test_meas
        check_loss = test_loss
        check_epoch = epoch
        torch.save(model.state_dict(), checkpoint_path)
    
    print(f"/*** EPOCH : {epoch}/{EPOCH_NUM} ***/")
    print(f"TRAIN - {train_loss}, {train_meas}")
    print(f"TEST - {test_loss}, {test_meas}")
    print("")
    
df_history = pd.DataFrame(history)
# Out:
# D:\Sangwons_Room\00_SoftWares\Anaconda\envs\torch\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning:
#
# invalid value encountered in arcsin
#
# D:\Sangwons_Room\00_SoftWares\Anaconda\envs\torch\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning:
#
# invalid value encountered in double_scalars
# /*** EPOCH : 0/1000 ***/
# TRAIN - 0, 0
# TEST - 29514368.0, nan
#
# Adjusting learning rate of group 0 to 4.5000e-03.
# Adjusting learning rate of group 0 to 4.0500e-03.
# Adjusting learning rate of group 0 to 3.6450e-03.
# Adjusting learning rate of group 0 to 3.2805e-03.
# Adjusting learning rate of group 0 to 2.9525e-03.
# Adjusting learning rate of group 0 to 2.6572e-03.
# Adjusting learning rate of group 0 to 2.3915e-03.
# Adjusting learning rate of group 0 to 2.1523e-03.
# Adjusting learning rate of group 0 to 1.9371e-03.
# Adjusting learning rate of group 0 to 1.7434e-03.
# Adjusting learning rate of group 0 to 1.5691e-03.
# Adjusting learning rate of group 0 to 1.4121e-03.
# Adjusting learning rate of group 0 to 1.2709e-03.
# Adjusting learning rate of group 0 to 1.1438e-03.
# Adjusting learning rate of group 0 to 1.0295e-03.
# Adjusting learning rate of group 0 to 9.2651e-04.
# Adjusting learning rate of group 0 to 8.3386e-04.
# Adjusting learning rate of group 0 to 7.5047e-04.
# Adjusting learning rate of group 0 to 6.7543e-04.
# Adjusting learning rate of group 0 to 6.0788e-04.
# Adjusting learning rate of group 0 to 5.4709e-04.
# Adjusting learning rate of group 0 to 4.9239e-04.
# Adjusting learning rate of group 0 to 4.4315e-04.
# Adjusting learning rate of group 0 to 3.9883e-04.
# Adjusting learning rate of group 0 to 3.5895e-04.
# Adjusting learning rate of group 0 to 3.2305e-04.
# Adjusting learning rate of group 0 to 2.9075e-04.
# Adjusting learning rate of group 0 to 2.6167e-04.
# Adjusting learning rate of group 0 to 2.3551e-04.
# Adjusting learning rate of group 0 to 2.1196e-04.
# Adjusting learning rate of group 0 to 1.9076e-04.
# Adjusting learning rate of group 0 to 1.7168e-04.
# Adjusting learning rate of group 0 to 1.5452e-04.
# Adjusting learning rate of group 0 to 1.3906e-04.
# Adjusting learning rate of group 0 to 1.2516e-04.
# Adjusting learning rate of group 0 to 1.1264e-04.
# Adjusting learning rate of group 0 to 1.0138e-04.
# Adjusting learning rate of group 0 to 9.1240e-05.
# Adjusting learning rate of group 0 to 8.2116e-05.
# Adjusting learning rate of group 0 to 7.3904e-05.
# Adjusting learning rate of group 0 to 6.6514e-05.
# Adjusting learning rate of group 0 to 5.9863e-05.
# Adjusting learning rate of group 0 to 5.3876e-05.
# Adjusting learning rate of group 0 to 4.8489e-05.
# Adjusting learning rate of group 0 to 4.3640e-05.
# Adjusting learning rate of group 0 to 3.9276e-05.
# Adjusting learning rate of group 0 to 3.5348e-05.
# Adjusting learning rate of group 0 to 3.1813e-05.
# Adjusting learning rate of group 0 to 2.8632e-05.
# Adjusting learning rate of group 0 to 2.5769e-05.
# Adjusting learning rate of group 0 to 2.3192e-05.
# Adjusting learning rate of group 0 to 2.0873e-05.
# Adjusting learning rate of group 0 to 1.8786e-05.
# Adjusting learning rate of group 0 to 1.6907e-05.
# Adjusting learning rate of group 0 to 1.5216e-05.
# Adjusting learning rate of group 0 to 1.3695e-05.
# Adjusting learning rate of group 0 to 1.2325e-05.
# Adjusting learning rate of group 0 to 1.1093e-05.
# Adjusting learning rate of group 0 to 9.9834e-06.
# Adjusting learning rate of group 0 to 8.9851e-06.
# Adjusting learning rate of group 0 to 8.0865e-06.
# Adjusting learning rate of group 0 to 7.2779e-06.
# Adjusting learning rate of group 0 to 6.5501e-06.
# Adjusting learning rate of group 0 to 5.8951e-06.
# Adjusting learning rate of group 0 to 5.3056e-06.
# /*** EPOCH : 1/1000 ***/
# TRAIN - 138522624.0, nan
# TEST - 1411227.375, nan
#
# Adjusting learning rate of group 0 to 4.7750e-06.
# Adjusting learning rate of group 0 to 4.2975e-06.
# Adjusting learning rate of group 0 to 3.8678e-06.
# Adjusting learning rate of group 0 to 3.4810e-06.
# Adjusting learning rate of group 0 to 3.1329e-06.
# Adjusting learning rate of group 0 to 2.8196e-06.
# Adjusting learning rate of group 0 to 2.5376e-06.
# Adjusting learning rate of group 0 to 2.2839e-06.
# Adjusting learning rate of group 0 to 2.0555e-06.
# Adjusting learning rate of group 0 to 1.8499e-06.
# Adjusting learning rate of group 0 to 1.6649e-06.
# Adjusting learning rate of group 0 to 1.4985e-06.
# Adjusting learning rate of group 0 to 1.3486e-06.
# Adjusting learning rate of group 0 to 1.2137e-06.
# Adjusting learning rate of group 0 to 1.0924e-06.
# Adjusting learning rate of group 0 to 9.8314e-07.
# Adjusting learning rate of group 0 to 8.8482e-07.
# Adjusting learning rate of group 0 to 7.9634e-07.
# Adjusting learning rate of group 0 to 7.1671e-07.
# Adjusting learning rate of group 0 to 6.4504e-07.
# Adjusting learning rate of group 0 to 5.8053e-07.
# Adjusting learning rate of group 0 to 5.2248e-07.
# Adjusting learning rate of group 0 to 4.7023e-07.
# Adjusting learning rate of group 0 to 4.2321e-07.
# Adjusting learning rate of group 0 to 3.8089e-07.
# Adjusting learning rate of group 0 to 3.4280e-07.
# Adjusting learning rate of group 0 to 3.0852e-07.
# Adjusting learning rate of group 0 to 2.7767e-07.
# Adjusting learning rate of group 0 to 2.4990e-07.
# Adjusting learning rate of group 0 to 2.2491e-07.
# Adjusting learning rate of group 0 to 2.0242e-07.
# Adjusting learning rate of group 0 to 1.8218e-07.
# Adjusting learning rate of group 0 to 1.6396e-07.
# Adjusting learning rate of group 0 to 1.4756e-07.
# Adjusting learning rate of group 0 to 1.3281e-07.
# Adjusting learning rate of group 0 to 1.1953e-07.
# Adjusting learning rate of group 0 to 1.0757e-07.
# Adjusting learning rate of group 0 to 9.6816e-08.
# Adjusting learning rate of group 0 to 8.7135e-08.
# Adjusting learning rate of group 0 to 7.8421e-08.
# Adjusting learning rate of group 0 to 7.0579e-08.
# Adjusting learning rate of group 0 to 6.3521e-08.
# Adjusting learning rate of group 0 to 5.7169e-08.
# Adjusting learning rate of group 0 to 5.1452e-08.
# Adjusting learning rate of group 0 to 4.6307e-08.
# Adjusting learning rate of group 0 to 4.1676e-08.
# Adjusting learning rate of group 0 to 3.7509e-08.
# Adjusting learning rate of group 0 to 3.3758e-08.
# Adjusting learning rate of group 0 to 3.0382e-08.
# Adjusting learning rate of group 0 to 2.7344e-08.
# Adjusting learning rate of group 0 to 2.4609e-08.
# Adjusting learning rate of group 0 to 2.2148e-08.
# Adjusting learning rate of group 0 to 1.9934e-08.
# Adjusting learning rate of group 0 to 1.7940e-08.
# Adjusting learning rate of group 0 to 1.6146e-08.
# Adjusting learning rate of group 0 to 1.4532e-08.
# Adjusting learning rate of group 0 to 1.3078e-08.
# Adjusting learning rate of group 0 to 1.1771e-08.
# Adjusting learning rate of group 0 to 1.0594e-08.
# Adjusting learning rate of group 0 to 9.5342e-09.
# Adjusting learning rate of group 0 to 8.5808e-09.
# Adjusting learning rate of group 0 to 7.7227e-09.
# Adjusting learning rate of group 0 to 6.9504e-09.
# Adjusting learning rate of group 0 to 6.2554e-09.
# Adjusting learning rate of group 0 to 5.6298e-09.
# /*** EPOCH : 2/1000 ***/
# TRAIN - 1470480.0, nan
# TEST - 1394762.5, nan
#
# Adjusting learning rate of group 0 to 5.0669e-09.
# Adjusting learning rate of group 0 to 4.5602e-09.
# Adjusting learning rate of group 0 to 4.1042e-09.
# Adjusting learning rate of group 0 to 3.6937e-09.
# Adjusting learning rate of group 0 to 3.3244e-09.
# Adjusting learning rate of group 0 to 2.9919e-09.
# Adjusting learning rate of group 0 to 2.6927e-09.
# Adjusting learning rate of group 0 to 2.4235e-09.
# Adjusting learning rate of group 0 to 2.1811e-09.
# Adjusting learning rate of group 0 to 1.9630e-09.
# Adjusting learning rate of group 0 to 1.7667e-09.
# Adjusting learning rate of group 0 to 1.5900e-09.
# Adjusting learning rate of group 0 to 1.4310e-09.
# Adjusting learning rate of group 0 to 1.2879e-09.
# Adjusting learning rate of group 0 to 1.1591e-09.
# Adjusting learning rate of group 0 to 1.0432e-09.
# Adjusting learning rate of group 0 to 9.3890e-10.
# Adjusting learning rate of group 0 to 8.4501e-10.
# Adjusting learning rate of group 0 to 7.6051e-10.
# Adjusting learning rate of group 0 to 6.8446e-10.
# Adjusting learning rate of group 0 to 6.1601e-10.
# Adjusting learning rate of group 0 to 5.5441e-10.
# Adjusting learning rate of group 0 to 4.9897e-10.
# Adjusting learning rate of group 0 to 4.4907e-10.
# Adjusting learning rate of group 0 to 4.0417e-10.
# Adjusting learning rate of group 0 to 3.6375e-10.
# Adjusting learning rate of group 0 to 3.2737e-10.
# Adjusting learning rate of group 0 to 2.9464e-10.
# Adjusting learning rate of group 0 to 2.6517e-10.
# Adjusting learning rate of group 0 to 2.3866e-10.
# Adjusting learning rate of group 0 to 2.1479e-10.
# Adjusting learning rate of group 0 to 1.9331e-10.
# Adjusting learning rate of group 0 to 1.7398e-10.
# Adjusting learning rate of group 0 to 1.5658e-10.
# Adjusting learning rate of group 0 to 1.4092e-10.
# Adjusting learning rate of group 0 to 1.2683e-10.
# Adjusting learning rate of group 0 to 1.1415e-10.
# Adjusting learning rate of group 0 to 1.0273e-10.
# Adjusting learning rate of group 0 to 9.2460e-11.
# Adjusting learning rate of group 0 to 8.3214e-11.
# Adjusting learning rate of group 0 to 7.4893e-11.
# Adjusting learning rate of group 0 to 6.7403e-11.
# Adjusting learning rate of group 0 to 6.0663e-11.
# Adjusting learning rate of group 0 to 5.4597e-11.
# Adjusting learning rate of group 0 to 4.9137e-11.
# Adjusting learning rate of group 0 to 4.4223e-11.
# Adjusting learning rate of group 0 to 3.9801e-11.
# Adjusting learning rate of group 0 to 3.5821e-11.
# Adjusting learning rate of group 0 to 3.2239e-11.
# Adjusting learning rate of group 0 to 2.9015e-11.
# Adjusting learning rate of group 0 to 2.6113e-11.
# Adjusting learning rate of group 0 to 2.3502e-11.
# Adjusting learning rate of group 0 to 2.1152e-11.
# Adjusting learning rate of group 0 to 1.9037e-11.
# Adjusting learning rate of group 0 to 1.7133e-11.
# Adjusting learning rate of group 0 to 1.5420e-11.
# Adjusting learning rate of group 0 to 1.3878e-11.
# Adjusting learning rate of group 0 to 1.2490e-11.
# Adjusting learning rate of group 0 to 1.1241e-11.
# Adjusting learning rate of group 0 to 1.0117e-11.
# Adjusting learning rate of group 0 to 9.1052e-12.
# Adjusting learning rate of group 0 to 8.1947e-12.
# Adjusting learning rate of group 0 to 7.3752e-12.
# Adjusting learning rate of group 0 to 6.6377e-12.
# Adjusting learning rate of group 0 to 5.9739e-12.
# /*** EPOCH : 3/1000 ***/
# TRAIN - 1467794.125, nan
# TEST - 1394746.5, nan
#
# Adjusting learning rate of group 0 to 5.3765e-12.
# Adjusting learning rate of group 0 to 4.8389e-12.
# Adjusting learning rate of group 0 to 4.3550e-12.
# Adjusting learning rate of group 0 to 3.9195e-12.
# Adjusting learning rate of group 0 to 3.5275e-12.
# Adjusting learning rate of group 0 to 3.1748e-12.
# Adjusting learning rate of group 0 to 2.8573e-12.
# Adjusting learning rate of group 0 to 2.5716e-12.
# Adjusting learning rate of group 0 to 2.3144e-12.
# Adjusting learning rate of group 0 to 2.0830e-12.
# Adjusting learning rate of group 0 to 1.8747e-12.
# Adjusting learning rate of group 0 to 1.6872e-12.
# Adjusting learning rate of group 0 to 1.5185e-12.
# Adjusting learning rate of group 0 to 1.3666e-12.
# Adjusting learning rate of group 0 to 1.2300e-12.
# Adjusting learning rate of group 0 to 1.1070e-12.
# Adjusting learning rate of group 0 to 9.9628e-13.
# Adjusting learning rate of group 0 to 8.9665e-13.
# Adjusting learning rate of group 0 to 8.0699e-13.
# Adjusting learning rate of group 0 to 7.2629e-13.
# Adjusting learning rate of group 0 to 6.5366e-13.
# Adjusting learning rate of group 0 to 5.8829e-13.
# Adjusting learning rate of group 0 to 5.2946e-13.
# Adjusting learning rate of group 0 to 4.7652e-13.
# Adjusting learning rate of group 0 to 4.2887e-13.
# Adjusting learning rate of group 0 to 3.8598e-13.
# Adjusting learning rate of group 0 to 3.4738e-13.
# Adjusting learning rate of group 0 to 3.1264e-13.
# Adjusting learning rate of group 0 to 2.8138e-13.
# Adjusting learning rate of group 0 to 2.5324e-13.
# Adjusting learning rate of group 0 to 2.2792e-13.
# Adjusting learning rate of group 0 to 2.0513e-13.
# Adjusting learning rate of group 0 to 1.8461e-13.
# Adjusting learning rate of group 0 to 1.6615e-13.
# Adjusting learning rate of group 0 to 1.4954e-13.
# Adjusting learning rate of group 0 to 1.3458e-13.
# Adjusting learning rate of group 0 to 1.2112e-13.
# Adjusting learning rate of group 0 to 1.0901e-13.
# Adjusting learning rate of group 0 to 9.8111e-14.
# Adjusting learning rate of group 0 to 8.8300e-14.
# Adjusting learning rate of group 0 to 7.9470e-14.
# Adjusting learning rate of group 0 to 7.1523e-14.
# Adjusting learning rate of group 0 to 6.4371e-14.
# Adjusting learning rate of group 0 to 5.7933e-14.
# Adjusting learning rate of group 0 to 5.2140e-14.
# Adjusting learning rate of group 0 to 4.6926e-14.
# Adjusting learning rate of group 0 to 4.2234e-14.
# Adjusting learning rate of group 0 to 3.8010e-14.
# Adjusting learning rate of group 0 to 3.4209e-14.
# Adjusting learning rate of group 0 to 3.0788e-14.
# Adjusting learning rate of group 0 to 2.7709e-14.
# Adjusting learning rate of group 0 to 2.4938e-14.
# Adjusting learning rate of group 0 to 2.2445e-14.
# Adjusting learning rate of group 0 to 2.0200e-14.
# Adjusting learning rate of group 0 to 1.8180e-14.
# Adjusting learning rate of group 0 to 1.6362e-14.
# Adjusting learning rate of group 0 to 1.4726e-14.
# Adjusting learning rate of group 0 to 1.3253e-14.
# Adjusting learning rate of group 0 to 1.1928e-14.
# Adjusting learning rate of group 0 to 1.0735e-14.
# Adjusting learning rate of group 0 to 9.6617e-15.
# Adjusting learning rate of group 0 to 8.6955e-15.
# Adjusting learning rate of group 0 to 7.8260e-15.
# Adjusting learning rate of group 0 to 7.0434e-15.
# Adjusting learning rate of group 0 to 6.3390e-15.
# /*** EPOCH : 4/1000 ***/
# TRAIN - 1467794.0, nan
# TEST - 1394760.625, nan
#
# Adjusting learning rate of group 0 to 5.7051e-15.
# Adjusting learning rate of group 0 to 5.1346e-15.
# Adjusting learning rate of group 0 to 4.6211e-15.
# Adjusting learning rate of group 0 to 4.1590e-15.
# Adjusting learning rate of group 0 to 3.7431e-15.
# Adjusting learning rate of group 0 to 3.3688e-15.
# Adjusting learning rate of group 0 to 3.0319e-15.
# Adjusting learning rate of group 0 to 2.7287e-15.
# Adjusting learning rate of group 0 to 2.4559e-15.
# Adjusting learning rate of group 0 to 2.2103e-15.
# Adjusting learning rate of group 0 to 1.9893e-15.
# Adjusting learning rate of group 0 to 1.7903e-15.
# Adjusting learning rate of group 0 to 1.6113e-15.
# Adjusting learning rate of group 0 to 1.4502e-15.
# Adjusting learning rate of group 0 to 1.3051e-15.
# Adjusting learning rate of group 0 to 1.1746e-15.
# Adjusting learning rate of group 0 to 1.0572e-15.
# Adjusting learning rate of group 0 to 9.5145e-16.
# Adjusting learning rate of group 0 to 8.5631e-16.
# Adjusting learning rate of group 0 to 7.7068e-16.
# Adjusting learning rate of group 0 to 6.9361e-16.
# Adjusting learning rate of group 0 to 6.2425e-16.
# Adjusting learning rate of group 0 to 5.6182e-16.
# Adjusting learning rate of group 0 to 5.0564e-16.
# Adjusting learning rate of group 0 to 4.5508e-16.
# Adjusting learning rate of group 0 to 4.0957e-16.
# Adjusting learning rate of group 0 to 3.6861e-16.
# Adjusting learning rate of group 0 to 3.3175e-16.
# Adjusting learning rate of group 0 to 2.9858e-16.
# Adjusting learning rate of group 0 to 2.6872e-16.
# Adjusting learning rate of group 0 to 2.4185e-16.
# Adjusting learning rate of group 0 to 2.1766e-16.
# Adjusting learning rate of group 0 to 1.9590e-16.
# Adjusting learning rate of group 0 to 1.7631e-16.
# Adjusting learning rate of group 0 to 1.5868e-16.
# Adjusting learning rate of group 0 to 1.4281e-16.
# Adjusting learning rate of group 0 to 1.2853e-16.
# Adjusting learning rate of group 0 to 1.1567e-16.
# Adjusting learning rate of group 0 to 1.0411e-16.
# Adjusting learning rate of group 0 to 9.3696e-17.
# Adjusting learning rate of group 0 to 8.4327e-17.
# Adjusting learning rate of group 0 to 7.5894e-17.
# Adjusting learning rate of group 0 to 6.8305e-17.
# Adjusting learning rate of group 0 to 6.1474e-17.
# Adjusting learning rate of group 0 to 5.5327e-17.
# Adjusting learning rate of group 0 to 4.9794e-17.
# Adjusting learning rate of group 0 to 4.4815e-17.
# Adjusting learning rate of group 0 to 4.0333e-17.
# Adjusting learning rate of group 0 to 3.6300e-17.
# Adjusting learning rate of group 0 to 3.2670e-17.
# Adjusting learning rate of group 0 to 2.9403e-17.
# Adjusting learning rate of group 0 to 2.6463e-17.
# Adjusting learning rate of group 0 to 2.3816e-17.
# Adjusting learning rate of group 0 to 2.1435e-17.
# Adjusting learning rate of group 0 to 1.9291e-17.
# Adjusting learning rate of group 0 to 1.7362e-17.
# Adjusting learning rate of group 0 to 1.5626e-17.
# Adjusting learning rate of group 0 to 1.4063e-17.
# Adjusting learning rate of group 0 to 1.2657e-17.
# Adjusting learning rate of group 0 to 1.1391e-17.
# Adjusting learning rate of group 0 to 1.0252e-17.
# Adjusting learning rate of group 0 to 9.2269e-18.
# Adjusting learning rate of group 0 to 8.3043e-18.
# Adjusting learning rate of group 0 to 7.4738e-18.
# Adjusting learning rate of group 0 to 6.7264e-18.
# /*** EPOCH : 5/1000 ***/
# TRAIN - 1467793.875, nan
# TEST - 1394770.0, nan
#
# Adjusting learning rate of group 0 to 6.0538e-18.
# Adjusting learning rate of group 0 to 5.4484e-18.
# Adjusting learning rate of group 0 to 4.9036e-18.
# Adjusting learning rate of group 0 to 4.4132e-18.
# Adjusting learning rate of group 0 to 3.9719e-18.
# Adjusting learning rate of group 0 to 3.5747e-18.
# Adjusting learning rate of group 0 to 3.2172e-18.
# Adjusting learning rate of group 0 to 2.8955e-18.
# Adjusting learning rate of group 0 to 2.6060e-18.
# Adjusting learning rate of group 0 to 2.3454e-18.
# Adjusting learning rate of group 0 to 2.1108e-18.
# Adjusting learning rate of group 0 to 1.8997e-18.
# Adjusting learning rate of group 0 to 1.7098e-18.
# Adjusting learning rate of group 0 to 1.5388e-18.
# Adjusting learning rate of group 0 to 1.3849e-18.
# Adjusting learning rate of group 0 to 1.2464e-18.
# Adjusting learning rate of group 0 to 1.1218e-18.
# Adjusting learning rate of group 0 to 1.0096e-18.
# Adjusting learning rate of group 0 to 9.0864e-19.
# Adjusting learning rate of group 0 to 8.1778e-19.
# Adjusting learning rate of group 0 to 7.3600e-19.
# Adjusting learning rate of group 0 to 6.6240e-19.
# Adjusting learning rate of group 0 to 5.9616e-19.
# Adjusting learning rate of group 0 to 5.3654e-19.
# Adjusting learning rate of group 0 to 4.8289e-19.
# Adjusting learning rate of group 0 to 4.3460e-19.
# Adjusting learning rate of group 0 to 3.9114e-19.
# Adjusting learning rate of group 0 to 3.5203e-19.
# Adjusting learning rate of group 0 to 3.1682e-19.
# Adjusting learning rate of group 0 to 2.8514e-19.
# Adjusting learning rate of group 0 to 2.5663e-19.
# Adjusting learning rate of group 0 to 2.3096e-19.
# Adjusting learning rate of group 0 to 2.0787e-19.
# Adjusting learning rate of group 0 to 1.8708e-19.
# Adjusting learning rate of group 0 to 1.6837e-19.
# Adjusting learning rate of group 0 to 1.5154e-19.
# Adjusting learning rate of group 0 to 1.3638e-19.
# Adjusting learning rate of group 0 to 1.2274e-19.
# Adjusting learning rate of group 0 to 1.1047e-19.
# Adjusting learning rate of group 0 to 9.9423e-20.
# Adjusting learning rate of group 0 to 8.9481e-20.
# Adjusting learning rate of group 0 to 8.0532e-20.
# Adjusting learning rate of group 0 to 7.2479e-20.
# Adjusting learning rate of group 0 to 6.5231e-20.
# Adjusting learning rate of group 0 to 5.8708e-20.
# Adjusting learning rate of group 0 to 5.2837e-20.
# Adjusting learning rate of group 0 to 4.7554e-20.
# Adjusting learning rate of group 0 to 4.2798e-20.
# Adjusting learning rate of group 0 to 3.8518e-20.
# Adjusting learning rate of group 0 to 3.4667e-20.
# Adjusting learning rate of group 0 to 3.1200e-20.
# Adjusting learning rate of group 0 to 2.8080e-20.
# Adjusting learning rate of group 0 to 2.5272e-20.
# Adjusting learning rate of group 0 to 2.2745e-20.
# Adjusting learning rate of group 0 to 2.0470e-20.
# Adjusting learning rate of group 0 to 1.8423e-20.
# Adjusting learning rate of group 0 to 1.6581e-20.
# Adjusting learning rate of group 0 to 1.4923e-20.
# Adjusting learning rate of group 0 to 1.3431e-20.
# Adjusting learning rate of group 0 to 1.2087e-20.
# Adjusting learning rate of group 0 to 1.0879e-20.
# Adjusting learning rate of group 0 to 9.7909e-21.
# Adjusting learning rate of group 0 to 8.8118e-21.
# Adjusting learning rate of group 0 to 7.9306e-21.
# Adjusting learning rate of group 0 to 7.1375e-21.
# /*** EPOCH : 6/1000 ***/
# TRAIN - 1467793.875, nan
# TEST - 1394748.625, nan
#
# Adjusting learning rate of group 0 to 6.4238e-21.
# Adjusting learning rate of group 0 to 5.7814e-21.
# Adjusting learning rate of group 0 to 5.2033e-21.
# Adjusting learning rate of group 0 to 4.6829e-21.
# Adjusting learning rate of group 0 to 4.2146e-21.
# Adjusting learning rate of group 0 to 3.7932e-21.
# Adjusting learning rate of group 0 to 3.4139e-21.
# Adjusting learning rate of group 0 to 3.0725e-21.
# Adjusting learning rate of group 0 to 2.7652e-21.
# Adjusting learning rate of group 0 to 2.4887e-21.
# Adjusting learning rate of group 0 to 2.2398e-21.
# Adjusting learning rate of group 0 to 2.0159e-21.
# Adjusting learning rate of group 0 to 1.8143e-21.
# Adjusting learning rate of group 0 to 1.6328e-21.
# Adjusting learning rate of group 0 to 1.4696e-21.
# Adjusting learning rate of group 0 to 1.3226e-21.
# Adjusting learning rate of group 0 to 1.1903e-21.
# Adjusting learning rate of group 0 to 1.0713e-21.
# Adjusting learning rate of group 0 to 9.6418e-22.
# Adjusting learning rate of group 0 to 8.6776e-22.
# Adjusting learning rate of group 0 to 7.8098e-22.
# Adjusting learning rate of group 0 to 7.0288e-22.
# Adjusting learning rate of group 0 to 6.3260e-22.
# Adjusting learning rate of group 0 to 5.6934e-22.
# Adjusting learning rate of group 0 to 5.1240e-22.
# Adjusting learning rate of group 0 to 4.6116e-22.
# Adjusting learning rate of group 0 to 4.1505e-22.
# Adjusting learning rate of group 0 to 3.7354e-22.
# Adjusting learning rate of group 0 to 3.3619e-22.
# Adjusting learning rate of group 0 to 3.0257e-22.
# Adjusting learning rate of group 0 to 2.7231e-22.
# Adjusting learning rate of group 0 to 2.4508e-22.
# Adjusting learning rate of group 0 to 2.2057e-22.
# Adjusting learning rate of group 0 to 1.9852e-22.
# Adjusting learning rate of group 0 to 1.7866e-22.
# Adjusting learning rate of group 0 to 1.6080e-22.
# Adjusting learning rate of group 0 to 1.4472e-22.
# Adjusting learning rate of group 0 to 1.3025e-22.
# Adjusting learning rate of group 0 to 1.1722e-22.
# Adjusting learning rate of group 0 to 1.0550e-22.
# Adjusting learning rate of group 0 to 9.4949e-23.
# Adjusting learning rate of group 0 to 8.5454e-23.
# Adjusting learning rate of group 0 to 7.6909e-23.
# Adjusting learning rate of group 0 to 6.9218e-23.
# Adjusting learning rate of group 0 to 6.2296e-23.
# Adjusting learning rate of group 0 to 5.6067e-23.
# Adjusting learning rate of group 0 to 5.0460e-23.
# Adjusting learning rate of group 0 to 4.5414e-23.
# Adjusting learning rate of group 0 to 4.0873e-23.
# Adjusting learning rate of group 0 to 3.6785e-23.
# Adjusting learning rate of group 0 to 3.3107e-23.
# Adjusting learning rate of group 0 to 2.9796e-23.
# Adjusting learning rate of group 0 to 2.6816e-23.
# Adjusting learning rate of group 0 to 2.4135e-23.
# Adjusting learning rate of group 0 to 2.1721e-23.
# Adjusting learning rate of group 0 to 1.9549e-23.
# Adjusting learning rate of group 0 to 1.7594e-23.
# Adjusting learning rate of group 0 to 1.5835e-23.
# Adjusting learning rate of group 0 to 1.4251e-23.
# Adjusting learning rate of group 0 to 1.2826e-23.
# Adjusting learning rate of group 0 to 1.1544e-23.
# Adjusting learning rate of group 0 to 1.0389e-23.
# Adjusting learning rate of group 0 to 9.3503e-24.
# Adjusting learning rate of group 0 to 8.4153e-24.
# Adjusting learning rate of group 0 to 7.5738e-24.
# /*** EPOCH : 7/1000 ***/
# TRAIN - 1467793.875, nan
# TEST - 1394763.375, nan
#
# Adjusting learning rate of group 0 to 6.8164e-24.
# Adjusting learning rate of group 0 to 6.1347e-24.
# Adjusting learning rate of group 0 to 5.5213e-24.
# Adjusting learning rate of group 0 to 4.9691e-24.
# Adjusting learning rate of group 0 to 4.4722e-24.
# Adjusting learning rate of group 0 to 4.0250e-24.
# Adjusting learning rate of group 0 to 3.6225e-24.
# Adjusting learning rate of group 0 to 3.2603e-24.
# Adjusting learning rate of group 0 to 2.9342e-24.
# Adjusting learning rate of group 0 to 2.6408e-24.
# Adjusting learning rate of group 0 to 2.3767e-24.
# Adjusting learning rate of group 0 to 2.1391e-24.
# Adjusting learning rate of group 0 to 1.9251e-24.
# Adjusting learning rate of group 0 to 1.7326e-24.
# Adjusting learning rate of group 0 to 1.5594e-24.
# Adjusting learning rate of group 0 to 1.4034e-24.
# Adjusting learning rate of group 0 to 1.2631e-24.
# Adjusting learning rate of group 0 to 1.1368e-24.
# Adjusting learning rate of group 0 to 1.0231e-24.
# Adjusting learning rate of group 0 to 9.2079e-25.
# Adjusting learning rate of group 0 to 8.2871e-25.
# Adjusting learning rate of group 0 to 7.4584e-25.
# Adjusting learning rate of group 0 to 6.7126e-25.
# Adjusting learning rate of group 0 to 6.0413e-25.
# Adjusting learning rate of group 0 to 5.4372e-25.
# Adjusting learning rate of group 0 to 4.8935e-25.
# Adjusting learning rate of group 0 to 4.4041e-25.
# Adjusting learning rate of group 0 to 3.9637e-25.
# Adjusting learning rate of group 0 to 3.5673e-25.
# Adjusting learning rate of group 0 to 3.2106e-25.
# Adjusting learning rate of group 0 to 2.8895e-25.
# Adjusting learning rate of group 0 to 2.6006e-25.
# Adjusting learning rate of group 0 to 2.3405e-25.
# Adjusting learning rate of group 0 to 2.1065e-25.
# Adjusting learning rate of group 0 to 1.8958e-25.
# Adjusting learning rate of group 0 to 1.7062e-25.
# Adjusting learning rate of group 0 to 1.5356e-25.
# Adjusting learning rate of group 0 to 1.3821e-25.
# Adjusting learning rate of group 0 to 1.2439e-25.
# Adjusting learning rate of group 0 to 1.1195e-25.
# Adjusting learning rate of group 0 to 1.0075e-25.
# Adjusting learning rate of group 0 to 9.0677e-26.
# Adjusting learning rate of group 0 to 8.1609e-26.
# Adjusting learning rate of group 0 to 7.3448e-26.
# Adjusting learning rate of group 0 to 6.6104e-26.
# Adjusting learning rate of group 0 to 5.9493e-26.
# Adjusting learning rate of group 0 to 5.3544e-26.
# Adjusting learning rate of group 0 to 4.8189e-26.
# Adjusting learning rate of group 0 to 4.3371e-26.
# Adjusting learning rate of group 0 to 3.9033e-26.
# Adjusting learning rate of group 0 to 3.5130e-26.
# Adjusting learning rate of group 0 to 3.1617e-26.
# Adjusting learning rate of group 0 to 2.8455e-26.
# Adjusting learning rate of group 0 to 2.5610e-26.
# Adjusting learning rate of group 0 to 2.3049e-26.
# Adjusting learning rate of group 0 to 2.0744e-26.
# Adjusting learning rate of group 0 to 1.8670e-26.
# Adjusting learning rate of group 0 to 1.6803e-26.
# Adjusting learning rate of group 0 to 1.5122e-26.
# Adjusting learning rate of group 0 to 1.3610e-26.
# Adjusting learning rate of group 0 to 1.2249e-26.
# Adjusting learning rate of group 0 to 1.1024e-26.
# Adjusting learning rate of group 0 to 9.9218e-27.
# Adjusting learning rate of group 0 to 8.9296e-27.
# Adjusting learning rate of group 0 to 8.0366e-27.
# /*** EPOCH : 8/1000 ***/
# TRAIN - 1467794.0, nan
# TEST - 1394781.75, nan
#
# Adjusting learning rate of group 0 to 7.2330e-27.
# Adjusting learning rate of group 0 to 6.5097e-27.
# Adjusting learning rate of group 0 to 5.8587e-27.
# Adjusting learning rate of group 0 to 5.2728e-27.
# Adjusting learning rate of group 0 to 4.7456e-27.
# Adjusting learning rate of group 0 to 4.2710e-27.
# Adjusting learning rate of group 0 to 3.8439e-27.
# Adjusting learning rate of group 0 to 3.4595e-27.
# Adjusting learning rate of group 0 to 3.1136e-27.
# Adjusting learning rate of group 0 to 2.8022e-27.
# Adjusting learning rate of group 0 to 2.5220e-27.
# Adjusting learning rate of group 0 to 2.2698e-27.
# Adjusting learning rate of group 0 to 2.0428e-27.
# Adjusting learning rate of group 0 to 1.8385e-27.
# Adjusting learning rate of group 0 to 1.6547e-27.
# Adjusting learning rate of group 0 to 1.4892e-27.
# Adjusting learning rate of group 0 to 1.3403e-27.
# Adjusting learning rate of group 0 to 1.2063e-27.
# Adjusting learning rate of group 0 to 1.0856e-27.
# Adjusting learning rate of group 0 to 9.7707e-28.
# Adjusting learning rate of group 0 to 8.7936e-28.
# Adjusting learning rate of group 0 to 7.9143e-28.
# Adjusting learning rate of group 0 to 7.1228e-28.
# Adjusting learning rate of group 0 to 6.4105e-28.
# Adjusting learning rate of group 0 to 5.7695e-28.
# Adjusting learning rate of group 0 to 5.1925e-28.
# Adjusting learning rate of group 0 to 4.6733e-28.
# Adjusting learning rate of group 0 to 4.2060e-28.
# Adjusting learning rate of group 0 to 3.7854e-28.
# Adjusting learning rate of group 0 to 3.4068e-28.
# Adjusting learning rate of group 0 to 3.0661e-28.
# Adjusting learning rate of group 0 to 2.7595e-28.
# Adjusting learning rate of group 0 to 2.4836e-28.
# Adjusting learning rate of group 0 to 2.2352e-28.
# Adjusting learning rate of group 0 to 2.0117e-28.
# Adjusting learning rate of group 0 to 1.8105e-28.
# Adjusting learning rate of group 0 to 1.6295e-28.
# Adjusting learning rate of group 0 to 1.4665e-28.
# Adjusting learning rate of group 0 to 1.3199e-28.
# Adjusting learning rate of group 0 to 1.1879e-28.
# Adjusting learning rate of group 0 to 1.0691e-28.
# Adjusting learning rate of group 0 to 9.6219e-29.
# Adjusting learning rate of group 0 to 8.6597e-29.
# Adjusting learning rate of group 0 to 7.7937e-29.
# Adjusting learning rate of group 0 to 7.0144e-29.
# Adjusting learning rate of group 0 to 6.3129e-29.
# Adjusting learning rate of group 0 to 5.6816e-29.
# Adjusting learning rate of group 0 to 5.1135e-29.
# Adjusting learning rate of group 0 to 4.6021e-29.
# Adjusting learning rate of group 0 to 4.1419e-29.
# Adjusting learning rate of group 0 to 3.7277e-29.
# Adjusting learning rate of group 0 to 3.3549e-29.
# Adjusting learning rate of group 0 to 3.0195e-29.
# Adjusting learning rate of group 0 to 2.7175e-29.
# Adjusting learning rate of group 0 to 2.4458e-29.
# Adjusting learning rate of group 0 to 2.2012e-29.
# Adjusting learning rate of group 0 to 1.9811e-29.
# Adjusting learning rate of group 0 to 1.7830e-29.
# Adjusting learning rate of group 0 to 1.6047e-29.
# Adjusting learning rate of group 0 to 1.4442e-29.
# Adjusting learning rate of group 0 to 1.2998e-29.
# Adjusting learning rate of group 0 to 1.1698e-29.
# Adjusting learning rate of group 0 to 1.0528e-29.
# Adjusting learning rate of group 0 to 9.4754e-30.
# Adjusting learning rate of group 0 to 8.5278e-30.
# /*** EPOCH : 9/1000 ***/
# TRAIN - 1467794.0, nan
# TEST - 1394754.625, nan
#
# Adjusting learning rate of group 0 to 7.6750e-30.
# Adjusting learning rate of group 0 to 6.9075e-30.
# Adjusting learning rate of group 0 to 6.2168e-30.
# Adjusting learning rate of group 0 to 5.5951e-30.
# Adjusting learning rate of group 0 to 5.0356e-30.
# Adjusting learning rate of group 0 to 4.5320e-30.
# Adjusting learning rate of group 0 to 4.0788e-30.
# Adjusting learning rate of group 0 to 3.6709e-30.
# Adjusting learning rate of group 0 to 3.3039e-30.
# Adjusting learning rate of group 0 to 2.9735e-30.
# Adjusting learning rate of group 0 to 2.6761e-30.
# Adjusting learning rate of group 0 to 2.4085e-30.
# Adjusting learning rate of group 0 to 2.1677e-30.
# Adjusting learning rate of group 0 to 1.9509e-30.
# Adjusting learning rate of group 0 to 1.7558e-30.
# Adjusting learning rate of group 0 to 1.5802e-30.
# Adjusting learning rate of group 0 to 1.4222e-30.
# Adjusting learning rate of group 0 to 1.2800e-30.
# Adjusting learning rate of group 0 to 1.1520e-30.
# Adjusting learning rate of group 0 to 1.0368e-30.
# Adjusting learning rate of group 0 to 9.3311e-31.
# Adjusting learning rate of group 0 to 8.3979e-31.
# Adjusting learning rate of group 0 to 7.5582e-31.
# Adjusting learning rate of group 0 to 6.8023e-31.
# Adjusting learning rate of group 0 to 6.1221e-31.
# Adjusting learning rate of group 0 to 5.5099e-31.
# Adjusting learning rate of group 0 to 4.9589e-31.
# Adjusting learning rate of group 0 to 4.4630e-31.
# Adjusting learning rate of group 0 to 4.0167e-31.
# Adjusting learning rate of group 0 to 3.6150e-31.
# Adjusting learning rate of group 0 to 3.2535e-31.
# Adjusting learning rate of group 0 to 2.9282e-31.
# Adjusting learning rate of group 0 to 2.6354e-31.
# Adjusting learning rate of group 0 to 2.3718e-31.
# Adjusting learning rate of group 0 to 2.1346e-31.
# Adjusting learning rate of group 0 to 1.9212e-31.
# Adjusting learning rate of group 0 to 1.7291e-31.
# Adjusting learning rate of group 0 to 1.5562e-31.
# Adjusting learning rate of group 0 to 1.4005e-31.
# Adjusting learning rate of group 0 to 1.2605e-31.
# Adjusting learning rate of group 0 to 1.1344e-31.
# Adjusting learning rate of group 0 to 1.0210e-31.
# Adjusting learning rate of group 0 to 9.1890e-32.
# Adjusting learning rate of group 0 to 8.2701e-32.
# Adjusting learning rate of group 0 to 7.4431e-32.
# Adjusting learning rate of group 0 to 6.6987e-32.
# Adjusting learning rate of group 0 to 6.0289e-32.
# Adjusting learning rate of group 0 to 5.4260e-32.
# Adjusting learning rate of group 0 to 4.8834e-32.
# Adjusting learning rate of group 0 to 4.3950e-32.
# Adjusting learning rate of group 0 to 3.9555e-32.
# Adjusting learning rate of group 0 to 3.5600e-32.
# Adjusting learning rate of group 0 to 3.2040e-32.
# Adjusting learning rate of group 0 to 2.8836e-32.
# Adjusting learning rate of group 0 to 2.5952e-32.
# Adjusting learning rate of group 0 to 2.3357e-32.
# Adjusting learning rate of group 0 to 2.1021e-32.
# Adjusting learning rate of group 0 to 1.8919e-32.
# Adjusting learning rate of group 0 to 1.7027e-32.
# Adjusting learning rate of group 0 to 1.5325e-32.
# Adjusting learning rate of group 0 to 1.3792e-32.
# Adjusting learning rate of group 0 to 1.2413e-32.
# Adjusting learning rate of group 0 to 1.1172e-32.
# Adjusting learning rate of group 0 to 1.0054e-32.
# Adjusting learning rate of group 0 to 9.0490e-33.
# /*** EPOCH : 10/1000 ***/
# TRAIN - 1467794.0, nan
# TEST - 1394736.0, nan
#
# Adjusting learning rate of group 0 to 8.1441e-33.
# Adjusting learning rate of group 0 to 7.3297e-33.
# Adjusting learning rate of group 0 to 6.5967e-33.
# Adjusting learning rate of group 0 to 5.9371e-33.
# Adjusting learning rate of group 0 to 5.3434e-33.
# Adjusting learning rate of group 0 to 4.8090e-33.
# Adjusting learning rate of group 0 to 4.3281e-33.
# Adjusting learning rate of group 0 to 3.8953e-33.
# Adjusting learning rate of group 0 to 3.5058e-33.
# Adjusting learning rate of group 0 to 3.1552e-33.
# Adjusting learning rate of group 0 to 2.8397e-33.
# Adjusting learning rate of group 0 to 2.5557e-33.
# Adjusting learning rate of group 0 to 2.3001e-33.
# Adjusting learning rate of group 0 to 2.0701e-33.
# Adjusting learning rate of group 0 to 1.8631e-33.
# Adjusting learning rate of group 0 to 1.6768e-33.
# Adjusting learning rate of group 0 to 1.5091e-33.
# Adjusting learning rate of group 0 to 1.3582e-33.
# Adjusting learning rate of group 0 to 1.2224e-33.
# Adjusting learning rate of group 0 to 1.1001e-33.
# Adjusting learning rate of group 0 to 9.9013e-34.
# Adjusting learning rate of group 0 to 8.9112e-34.
# Adjusting learning rate of group 0 to 8.0201e-34.
# Adjusting learning rate of group 0 to 7.2181e-34.
# Adjusting learning rate of group 0 to 6.4963e-34.
# Adjusting learning rate of group 0 to 5.8466e-34.
# Adjusting learning rate of group 0 to 5.2620e-34.
# Adjusting learning rate of group 0 to 4.7358e-34.
# Adjusting learning rate of group 0 to 4.2622e-34.
# Adjusting learning rate of group 0 to 3.8360e-34.
# Adjusting learning rate of group 0 to 3.4524e-34.
# Adjusting learning rate of group 0 to 3.1071e-34.
# Adjusting learning rate of group 0 to 2.7964e-34.
# Adjusting learning rate of group 0 to 2.5168e-34.
# Adjusting learning rate of group 0 to 2.2651e-34.
# Adjusting learning rate of group 0 to 2.0386e-34.
# Adjusting learning rate of group 0 to 1.8347e-34.
# Adjusting learning rate of group 0 to 1.6513e-34.
# Adjusting learning rate of group 0 to 1.4861e-34.
# Adjusting learning rate of group 0 to 1.3375e-34.
# Adjusting learning rate of group 0 to 1.2038e-34.
# Adjusting learning rate of group 0 to 1.0834e-34.
# Adjusting learning rate of group 0 to 9.7505e-35.
# Adjusting learning rate of group 0 to 8.7755e-35.
# Adjusting learning rate of group 0 to 7.8979e-35.
# Adjusting learning rate of group 0 to 7.1081e-35.
# Adjusting learning rate of group 0 to 6.3973e-35.
# Adjusting learning rate of group 0 to 5.7576e-35.
# Adjusting learning rate of group 0 to 5.1818e-35.
# Adjusting learning rate of group 0 to 4.6637e-35.
# Adjusting learning rate of group 0 to 4.1973e-35.
# Adjusting learning rate of group 0 to 3.7776e-35.
# Adjusting learning rate of group 0 to 3.3998e-35.
# Adjusting learning rate of group 0 to 3.0598e-35.
# Adjusting learning rate of group 0 to 2.7538e-35.
# Adjusting learning rate of group 0 to 2.4785e-35.
# Adjusting learning rate of group 0 to 2.2306e-35.
# Adjusting learning rate of group 0 to 2.0076e-35.
# Adjusting learning rate of group 0 to 1.8068e-35.
# Adjusting learning rate of group 0 to 1.6261e-35.
# Adjusting learning rate of group 0 to 1.4635e-35.
# Adjusting learning rate of group 0 to 1.3172e-35.
# Adjusting learning rate of group 0 to 1.1854e-35.
# Adjusting learning rate of group 0 to 1.0669e-35.
# Adjusting learning rate of group 0 to 9.6021e-36.
# /*** EPOCH : 11/1000 ***/
# TRAIN - 1467794.125, nan
# TEST - 1394760.875, nan
#
# Adjusting learning rate of group 0 to 8.6419e-36.
# Adjusting learning rate of group 0 to 7.7777e-36.
# Adjusting learning rate of group 0 to 6.9999e-36.
# Adjusting learning rate of group 0 to 6.2999e-36.
# Adjusting learning rate of group 0 to 5.6699e-36.
# Adjusting learning rate of group 0 to 5.1029e-36.
# Adjusting learning rate of group 0 to 4.5926e-36.
# Adjusting learning rate of group 0 to 4.1334e-36.
# Adjusting learning rate of group 0 to 3.7200e-36.
# Adjusting learning rate of group 0 to 3.3480e-36.
# Adjusting learning rate of group 0 to 3.0132e-36.
# Adjusting learning rate of group 0 to 2.7119e-36.
# Adjusting learning rate of group 0 to 2.4407e-36.
# Adjusting learning rate of group 0 to 2.1966e-36.
# Adjusting learning rate of group 0 to 1.9770e-36.
# Adjusting learning rate of group 0 to 1.7793e-36.
# Adjusting learning rate of group 0 to 1.6014e-36.
# Adjusting learning rate of group 0 to 1.4412e-36.
# Adjusting learning rate of group 0 to 1.2971e-36.
# Adjusting learning rate of group 0 to 1.1674e-36.
# Adjusting learning rate of group 0 to 1.0506e-36.
# Adjusting learning rate of group 0 to 9.4558e-37.
# Adjusting learning rate of group 0 to 8.5102e-37.
# Adjusting learning rate of group 0 to 7.6592e-37.
# Adjusting learning rate of group 0 to 6.8933e-37.
# Adjusting learning rate of group 0 to 6.2040e-37.
# Adjusting learning rate of group 0 to 5.5836e-37.
# Adjusting learning rate of group 0 to 5.0252e-37.
# Adjusting learning rate of group 0 to 4.5227e-37.
# Adjusting learning rate of group 0 to 4.0704e-37.
# Adjusting learning rate of group 0 to 3.6634e-37.
# Adjusting learning rate of group 0 to 3.2970e-37.
# Adjusting learning rate of group 0 to 2.9673e-37.
# Adjusting learning rate of group 0 to 2.6706e-37.
# Adjusting learning rate of group 0 to 2.4035e-37.
# Adjusting learning rate of group 0 to 2.1632e-37.
# Adjusting learning rate of group 0 to 1.9469e-37.
# Adjusting learning rate of group 0 to 1.7522e-37.
# Adjusting learning rate of group 0 to 1.5770e-37.
# Adjusting learning rate of group 0 to 1.4193e-37.
# Adjusting learning rate of group 0 to 1.2773e-37.
# Adjusting learning rate of group 0 to 1.1496e-37.
# Adjusting learning rate of group 0 to 1.0346e-37.
# Adjusting learning rate of group 0 to 9.3118e-38.
# Adjusting learning rate of group 0 to 8.3806e-38.
# Adjusting learning rate of group 0 to 7.5426e-38.
# Adjusting learning rate of group 0 to 6.7883e-38.
# Adjusting learning rate of group 0 to 6.1095e-38.
# Adjusting learning rate of group 0 to 5.4985e-38.
# Adjusting learning rate of group 0 to 4.9487e-38.
# Adjusting learning rate of group 0 to 4.4538e-38.
# Adjusting learning rate of group 0 to 4.0084e-38.
# Adjusting learning rate of group 0 to 3.6076e-38.
# Adjusting learning rate of group 0 to 3.2468e-38.
# Adjusting learning rate of group 0 to 2.9221e-38.
# Adjusting learning rate of group 0 to 2.6299e-38.
# Adjusting learning rate of group 0 to 2.3669e-38.
# Adjusting learning rate of group 0 to 2.1302e-38.
# Adjusting learning rate of group 0 to 1.9172e-38.
# Adjusting learning rate of group 0 to 1.7255e-38.
# Adjusting learning rate of group 0 to 1.5529e-38.
# Adjusting learning rate of group 0 to 1.3977e-38.
# Adjusting learning rate of group 0 to 1.2579e-38.
# Adjusting learning rate of group 0 to 1.1321e-38.
# Adjusting learning rate of group 0 to 1.0189e-38.
# /*** EPOCH : 12/1000 ***/
# TRAIN - 1467794.0, nan
# TEST - 1394760.875, nan
#
# Adjusting learning rate of group 0 to 9.1700e-39.
# Adjusting learning rate of group 0 to 8.2530e-39.
# Adjusting learning rate of group 0 to 7.4277e-39.
# Adjusting learning rate of group 0 to 6.6849e-39.
# Adjusting learning rate of group 0 to 6.0164e-39.
# Adjusting learning rate of group 0 to 5.4148e-39.
# Adjusting learning rate of group 0 to 4.8733e-39.
# Adjusting learning rate of group 0 to 4.3860e-39.
# Adjusting learning rate of group 0 to 3.9474e-39.
# Adjusting learning rate of group 0 to 3.5527e-39.
# Adjusting learning rate of group 0 to 3.1974e-39.
# Adjusting learning rate of group 0 to 2.8776e-39.
# Adjusting learning rate of group 0 to 2.5899e-39.
# Adjusting learning rate of group 0 to 2.3309e-39.
# Adjusting learning rate of group 0 to 2.0978e-39.
# Adjusting learning rate of group 0 to 1.8880e-39.
# Adjusting learning rate of group 0 to 1.6992e-39.
# Adjusting learning rate of group 0 to 1.5293e-39.
# Adjusting learning rate of group 0 to 1.3764e-39.
# Adjusting learning rate of group 0 to 1.2387e-39.
# Adjusting learning rate of group 0 to 1.1149e-39.
# Adjusting learning rate of group 0 to 1.0034e-39.
# Adjusting learning rate of group 0 to 9.0304e-40.
# Adjusting learning rate of group 0 to 8.1273e-40.
# Adjusting learning rate of group 0 to 7.3146e-40.
# Adjusting learning rate of group 0 to 6.5831e-40.
# Adjusting learning rate of group 0 to 5.9248e-40.
# Adjusting learning rate of group 0 to 5.3323e-40.
# Adjusting learning rate of group 0 to 4.7991e-40.
# Adjusting learning rate of group 0 to 4.3192e-40.
# Adjusting learning rate of group 0 to 3.8873e-40.
# Adjusting learning rate of group 0 to 3.4985e-40.
# Adjusting learning rate of group 0 to 3.1487e-40.
# Adjusting learning rate of group 0 to 2.8338e-40.
# Adjusting learning rate of group 0 to 2.5504e-40.
# Adjusting learning rate of group 0 to 2.2954e-40.
# Adjusting learning rate of group 0 to 2.0659e-40.
# Adjusting learning rate of group 0 to 1.8593e-40.
# Adjusting learning rate of group 0 to 1.6733e-40.
# Adjusting learning rate of group 0 to 1.5060e-40.
# Adjusting learning rate of group 0 to 1.3554e-40.
# Adjusting learning rate of group 0 to 1.2199e-40.
# Adjusting learning rate of group 0 to 1.0979e-40.
# Adjusting learning rate of group 0 to 9.8809e-41.
# Adjusting learning rate of group 0 to 8.8928e-41.
# Adjusting learning rate of group 0 to 8.0036e-41.
# Adjusting learning rate of group 0 to 7.2032e-41.
# Adjusting learning rate of group 0 to 6.4829e-41.
# Adjusting learning rate of group 0 to 5.8346e-41.
# Adjusting learning rate of group 0 to 5.2511e-41.
# Adjusting learning rate of group 0 to 4.7260e-41.
# Adjusting learning rate of group 0 to 4.2534e-41.
# Adjusting learning rate of group 0 to 3.8281e-41.
# Adjusting learning rate of group 0 to 3.4453e-41.
# Adjusting learning rate of group 0 to 3.1007e-41.
# Adjusting learning rate of group 0 to 2.7907e-41.
# Adjusting learning rate of group 0 to 2.5116e-41.
# Adjusting learning rate of group 0 to 2.2604e-41.
# Adjusting learning rate of group 0 to 2.0344e-41.
# Adjusting learning rate of group 0 to 1.8310e-41.
# Adjusting learning rate of group 0 to 1.6479e-41.
# Adjusting learning rate of group 0 to 1.4831e-41.
# Adjusting learning rate of group 0 to 1.3348e-41.
# Adjusting learning rate of group 0 to 1.2013e-41.
# Adjusting learning rate of group 0 to 1.0812e-41.
# /*** EPOCH : 13/1000 ***/
# TRAIN - 1467794.0, nan
# TEST - 1394741.375, nan
#
# Adjusting learning rate of group 0 to 9.7305e-42.
# Adjusting learning rate of group 0 to 8.7574e-42.
# Adjusting learning rate of group 0 to 7.8817e-42.
# Adjusting learning rate of group 0 to 7.0935e-42.
# Adjusting learning rate of group 0 to 6.3841e-42.
# Adjusting learning rate of group 0 to 5.7457e-42.
# Adjusting learning rate of group 0 to 5.1712e-42.
# Adjusting learning rate of group 0 to 4.6540e-42.
# Adjusting learning rate of group 0 to 4.1886e-42.
# Adjusting learning rate of group 0 to 3.7698e-42.
# Adjusting learning rate of group 0 to 3.3928e-42.
# Adjusting learning rate of group 0 to 3.0535e-42.
# Adjusting learning rate of group 0 to 2.7482e-42.
# Adjusting learning rate of group 0 to 2.4734e-42.
# Adjusting learning rate of group 0 to 2.2260e-42.
# Adjusting learning rate of group 0 to 2.0034e-42.
# Adjusting learning rate of group 0 to 1.8031e-42.
# Adjusting learning rate of group 0 to 1.6228e-42.
# Adjusting learning rate of group 0 to 1.4605e-42.
# Adjusting learning rate of group 0 to 1.3144e-42.
# Adjusting learning rate of group 0 to 1.1830e-42.
# Adjusting learning rate of group 0 to 1.0647e-42.
# Adjusting learning rate of group 0 to 9.5823e-43.
# Adjusting learning rate of group 0 to 8.6240e-43.
# Adjusting learning rate of group 0 to 7.7616e-43.
# Adjusting learning rate of group 0 to 6.9855e-43.
# Adjusting learning rate of group 0 to 6.2869e-43.
# Adjusting learning rate of group 0 to 5.6582e-43.
# Adjusting learning rate of group 0 to 5.0924e-43.
# Adjusting learning rate of group 0 to 4.5832e-43.
# Adjusting learning rate of group 0 to 4.1249e-43.
# Adjusting learning rate of group 0 to 3.7124e-43.
# Adjusting learning rate of group 0 to 3.3411e-43.
# Adjusting learning rate of group 0 to 3.0070e-43.
# Adjusting learning rate of group 0 to 2.7063e-43.
# Adjusting learning rate of group 0 to 2.4357e-43.
# Adjusting learning rate of group 0 to 2.1921e-43.
# Adjusting learning rate of group 0 to 1.9729e-43.
# Adjusting learning rate of group 0 to 1.7756e-43.
# Adjusting learning rate of group 0 to 1.5981e-43.
# Adjusting learning rate of group 0 to 1.4382e-43.
# Adjusting learning rate of group 0 to 1.2944e-43.
# Adjusting learning rate of group 0 to 1.1650e-43.
# Adjusting learning rate of group 0 to 1.0485e-43.
# Adjusting learning rate of group 0 to 9.4363e-44.
# Adjusting learning rate of group 0 to 8.4927e-44.
# Adjusting learning rate of group 0 to 7.6434e-44.
# Adjusting learning rate of group 0 to 6.8791e-44.
# Adjusting learning rate of group 0 to 6.1912e-44.
# Adjusting learning rate of group 0 to 5.5721e-44.
# Adjusting learning rate of group 0 to 5.0149e-44.
# Adjusting learning rate of group 0 to 4.5134e-44.
# Adjusting learning rate of group 0 to 4.0620e-44.
# Adjusting learning rate of group 0 to 3.6558e-44.
# Adjusting learning rate of group 0 to 3.2902e-44.
# Adjusting learning rate of group 0 to 2.9612e-44.
# Adjusting learning rate of group 0 to 2.6651e-44.
# Adjusting learning rate of group 0 to 2.3986e-44.
# Adjusting learning rate of group 0 to 2.1587e-44.
# Adjusting learning rate of group 0 to 1.9429e-44.
# Adjusting learning rate of group 0 to 1.7486e-44.
# Adjusting learning rate of group 0 to 1.5737e-44.
# Adjusting learning rate of group 0 to 1.4163e-44.
# Adjusting learning rate of group 0 to 1.2747e-44.
# Adjusting learning rate of group 0 to 1.1472e-44.
# /*** EPOCH : 14/1000 ***/
# TRAIN - 1467794.0, nan
# TEST - 1394754.75, nan
#
# Adjusting learning rate of group 0 to 1.0325e-44.
# Adjusting learning rate of group 0 to 9.2926e-45.
# Adjusting learning rate of group 0 to 8.3634e-45.
# Adjusting learning rate of group 0 to 7.5270e-45.
# Adjusting learning rate of group 0 to 6.7743e-45.
# Adjusting learning rate of group 0 to 6.0969e-45.
# Adjusting learning rate of group 0 to 5.4872e-45.
# Adjusting learning rate of group 0 to 4.9385e-45.
# Adjusting learning rate of group 0 to 4.4446e-45.
# Adjusting learning rate of group 0 to 4.0002e-45.
# Adjusting learning rate of group 0 to 3.6002e-45.
# Adjusting learning rate of group 0 to 3.2401e-45.
# Adjusting learning rate of group 0 to 2.9161e-45.
# Adjusting learning rate of group 0 to 2.6245e-45.
# Adjusting learning rate of group 0 to 2.3621e-45.
# Adjusting learning rate of group 0 to 2.1259e-45.
# Adjusting learning rate of group 0 to 1.9133e-45.
# Adjusting learning rate of group 0 to 1.7219e-45.
# Adjusting learning rate of group 0 to 1.5497e-45.
# Adjusting learning rate of group 0 to 1.3948e-45.
# Adjusting learning rate of group 0 to 1.2553e-45.
# Adjusting learning rate of group 0 to 1.1298e-45.
# ...
# /*** EPOCH : 83/1000 ***/
# TRAIN - 1467793.875, nan
# TEST - 1394770.0, nan
#
# Adjusting learning rate of group 0 to 6.1880e-250.
# Adjusting learning rate of group 0 to 5.5692e-250.
# Adjusting learning rate of group 0 to 5.0123e-250.
# Adjusting learning rate of group 0 to 4.5111e-250.
# Adjusting learning rate of group 0 to 4.0600e-250.
# Adjusting learning rate of group 0 to 3.6540e-250.
# Adjusting learning rate of group 0 to 3.2886e-250.
# Adjusting learning rate of group 0 to 2.9597e-250.
# Adjusting learning rate of group 0 to 2.6637e-250.
# Adjusting learning rate of group 0 to 2.3974e-250.
# Adjusting learning rate of group 0 to 2.1576e-250.
# Adjusting learning rate of group 0 to 1.9419e-250.
# Adjusting learning rate of group 0 to 1.7477e-250.
# Adjusting learning rate of group 0 to 1.5729e-250.
# Adjusting learning rate of group 0 to 1.4156e-250.
# Adjusting learning rate of group 0 to 1.2741e-250.
# Adjusting learning rate of group 0 to 1.1467e-250.
# Adjusting learning rate of group 0 to 1.0320e-250.
# Adjusting learning rate of group 0 to 9.2879e-251.
# Adjusting learning rate of group 0 to 8.3591e-251.
# Adjusting learning rate of group 0 to 7.5232e-251.
# Adjusting learning rate of group 0 to 6.7709e-251.
# Adjusting learning rate of group 0 to 6.0938e-251.
# Adjusting learning rate of group 0 to 5.4844e-251.
# Adjusting learning rate of group 0 to 4.9360e-251.
# Adjusting learning rate of group 0 to 4.4424e-251.
# Adjusting learning rate of group 0 to 3.9981e-251.
# Adjusting learning rate of group 0 to 3.5983e-251.
# Adjusting learning rate of group 0 to 3.2385e-251.
# Adjusting learning rate of group 0 to 2.9146e-251.
# Adjusting learning rate of group 0 to 2.6232e-251.
# Adjusting learning rate of group 0 to 2.3609e-251.
# Adjusting learning rate of group 0 to 2.1248e-251.
# Adjusting learning rate of group 0 to 1.9123e-251.
# Adjusting learning rate of group 0 to 1.7211e-251.
# Adjusting learning rate of group 0 to 1.5490e-251.
# Adjusting learning rate of group 0 to 1.3941e-251.
# Adjusting learning rate of group 0 to 1.2547e-251.
# Adjusting learning rate of group 0 to 1.1292e-251.
# Adjusting learning rate of group 0 to 1.0163e-251.
# Adjusting learning rate of group 0 to 9.1464e-252.
# Adjusting learning rate of group 0 to 8.2318e-252.
# Adjusting learning rate of group 0 to 7.4086e-252.
# Adjusting learning rate of group 0 to 6.6677e-252.
# Adjusting learning rate of group 0 to 6.0010e-252.
# Adjusting learning rate of group 0 to 5.4009e-252.
# Adjusting learning rate of group 0 to 4.8608e-252.
# Adjusting learning rate of group 0 to 4.3747e-252.
# Adjusting learning rate of group 0 to 3.9372e-252.
# Adjusting learning rate of group 0 to 3.5435e-252.
# Adjusting learning rate of group 0 to 3.1892e-252.
# Adjusting learning rate of group 0 to 2.8702e-252.
# Adjusting learning rate of group 0 to 2.5832e-252.
# Adjusting learning rate of group 0 to 2.3249e-252.
# Adjusting learning rate of group 0 to 2.0924e-252.
# Adjusting learning rate of group 0 to 1.8832e-252.
# Adjusting learning rate of group 0 to 1.6949e-252.
# Adjusting learning rate of group 0 to 1.5254e-252.
# Adjusting learning rate of group 0 to 1.3728e-252.
# Adjusting learning rate of group 0 to 1.2355e-252.
# Adjusting learning rate of group 0 to 1.1120e-252.
# Adjusting learning rate of group 0 to 1.0008e-252.
# Adjusting learning rate of group 0 to 9.0071e-253.
# Adjusting learning rate of group 0 to 8.1064e-253.
# Adjusting learning rate of group 0 to 7.2958e-253.
# /*** EPOCH : 84/1000 ***/
# TRAIN - 1467794.125, nan
# TEST - 1394751.625, nan
#
# Adjusting learning rate of group 0 to 6.5662e-253.
# Adjusting learning rate of group 0 to 5.9096e-253.
# Adjusting learning rate of group 0 to 5.3186e-253.
# Adjusting learning rate of group 0 to 4.7868e-253.
# Adjusting learning rate of group 0 to 4.3081e-253.
# Adjusting learning rate of group 0 to 3.8773e-253.
# Adjusting learning rate of group 0 to 3.4895e-253.
# Adjusting learning rate of group 0 to 3.1406e-253.
# Adjusting learning rate of group 0 to 2.8265e-253.
# Adjusting learning rate of group 0 to 2.5439e-253.
# Adjusting learning rate of group 0 to 2.2895e-253.
# Adjusting learning rate of group 0 to 2.0605e-253.
# Adjusting learning rate of group 0 to 1.8545e-253.
# Adjusting learning rate of group 0 to 1.6690e-253.
# Adjusting learning rate of group 0 to 1.5021e-253.
# Adjusting learning rate of group 0 to 1.3519e-253.
# Adjusting learning rate of group 0 to 1.2167e-253.
# Adjusting learning rate of group 0 to 1.0951e-253.
# Adjusting learning rate of group 0 to 9.8555e-254.
# Adjusting learning rate of group 0 to 8.8700e-254.
# Adjusting learning rate of group 0 to 7.9830e-254.
# Adjusting learning rate of group 0 to 7.1847e-254.
# Adjusting learning rate of group 0 to 6.4662e-254.
# Adjusting learning rate of group 0 to 5.8196e-254.
# Adjusting learning rate of group 0 to 5.2376e-254.
# Adjusting learning rate of group 0 to 4.7139e-254.
# Adjusting learning rate of group 0 to 4.2425e-254.
# Adjusting learning rate of group 0 to 3.8182e-254.
# Adjusting learning rate of group 0 to 3.4364e-254.
# Adjusting learning rate of group 0 to 3.0928e-254.
# Adjusting learning rate of group 0 to 2.7835e-254.
# Adjusting learning rate of group 0 to 2.5051e-254.
# Adjusting learning rate of group 0 to 2.2546e-254.
# Adjusting learning rate of group 0 to 2.0292e-254.
# Adjusting learning rate of group 0 to 1.8262e-254.
# Adjusting learning rate of group 0 to 1.6436e-254.
# Adjusting learning rate of group 0 to 1.4793e-254.
# Adjusting learning rate of group 0 to 1.3313e-254.
# Adjusting learning rate of group 0 to 1.1982e-254.
# Adjusting learning rate of group 0 to 1.0784e-254.
# Adjusting learning rate of group 0 to 9.7054e-255.
# Adjusting learning rate of group 0 to 8.7349e-255.
# Adjusting learning rate of group 0 to 7.8614e-255.
# Adjusting learning rate of group 0 to 7.0753e-255.
# Adjusting learning rate of group 0 to 6.3677e-255.
# Adjusting learning rate of group 0 to 5.7310e-255.
# Adjusting learning rate of group 0 to 5.1579e-255.
# Adjusting learning rate of group 0 to 4.6421e-255.
# Adjusting learning rate of group 0 to 4.1779e-255.
# Adjusting learning rate of group 0 to 3.7601e-255.
# Adjusting learning rate of group 0 to 3.3841e-255.
# Adjusting learning rate of group 0 to 3.0457e-255.
# Adjusting learning rate of group 0 to 2.7411e-255.
# Adjusting learning rate of group 0 to 2.4670e-255.
# Adjusting learning rate of group 0 to 2.2203e-255.
# Adjusting learning rate of group 0 to 1.9983e-255.
# Adjusting learning rate of group 0 to 1.7984e-255.
# Adjusting learning rate of group 0 to 1.6186e-255.
# Adjusting learning rate of group 0 to 1.4567e-255.
# Adjusting learning rate of group 0 to 1.3111e-255.
# Adjusting learning rate of group 0 to 1.1800e-255.
# Adjusting learning rate of group 0 to 1.0620e-255.
# Adjusting learning rate of group 0 to 9.5576e-256.
# Adjusting learning rate of group 0 to 8.6019e-256.
# Adjusting learning rate of group 0 to 7.7417e-256.
# /*** EPOCH : 85/1000 ***/
# TRAIN - 1467794.0, nan
# TEST - 1394762.75, nan
#
# Adjusting learning rate of group 0 to 6.9675e-256.
# Adjusting learning rate of group 0 to 6.2708e-256.
# Adjusting learning rate of group 0 to 5.6437e-256.
# Adjusting learning rate of group 0 to 5.0793e-256.
# Adjusting learning rate of group 0 to 4.5714e-256.
# Adjusting learning rate of group 0 to 4.1142e-256.
# Adjusting learning rate of group 0 to 3.7028e-256.
# Adjusting learning rate of group 0 to 3.3325e-256.
# Adjusting learning rate of group 0 to 2.9993e-256.
# Adjusting learning rate of group 0 to 2.6994e-256.
# Adjusting learning rate of group 0 to 2.4294e-256.
# Adjusting learning rate of group 0 to 2.1865e-256.
# Adjusting learning rate of group 0 to 1.9678e-256.
# Adjusting learning rate of group 0 to 1.7710e-256.
# Adjusting learning rate of group 0 to 1.5939e-256.
# Adjusting learning rate of group 0 to 1.4345e-256.
# Adjusting learning rate of group 0 to 1.2911e-256.
# Adjusting learning rate of group 0 to 1.1620e-256.
# Adjusting learning rate of group 0 to 1.0458e-256.
# Adjusting learning rate of group 0 to 9.4121e-257.
# Adjusting learning rate of group 0 to 8.4709e-257.
# Adjusting learning rate of group 0 to 7.6238e-257.
# Adjusting learning rate of group 0 to 6.8614e-257.
# Adjusting learning rate of group 0 to 6.1753e-257.
# Adjusting learning rate of group 0 to 5.5577e-257.
# Adjusting learning rate of group 0 to 5.0020e-257.
# Adjusting learning rate of group 0 to 4.5018e-257.
# Adjusting learning rate of group 0 to 4.0516e-257.
# Adjusting learning rate of group 0 to 3.6464e-257.
# Adjusting learning rate of group 0 to 3.2818e-257.
# Adjusting learning rate of group 0 to 2.9536e-257.
# Adjusting learning rate of group 0 to 2.6582e-257.
# Adjusting learning rate of group 0 to 2.3924e-257.
# Adjusting learning rate of group 0 to 2.1532e-257.
# Adjusting learning rate of group 0 to 1.9379e-257.
# Adjusting learning rate of group 0 to 1.7441e-257.
# Adjusting learning rate of group 0 to 1.5697e-257.
# Adjusting learning rate of group 0 to 1.4127e-257.
# Adjusting learning rate of group 0 to 1.2714e-257.
# Adjusting learning rate of group 0 to 1.1443e-257.
# Adjusting learning rate of group 0 to 1.0299e-257.
# Adjusting learning rate of group 0 to 9.2687e-258.
# Adjusting learning rate of group 0 to 8.3419e-258.
# Adjusting learning rate of group 0 to 7.5077e-258.
# Adjusting learning rate of group 0 to 6.7569e-258.
# Adjusting learning rate of group 0 to 6.0812e-258.
# Adjusting learning rate of group 0 to 5.4731e-258.
# Adjusting learning rate of group 0 to 4.9258e-258.
# Adjusting learning rate of group 0 to 4.4332e-258.
# Adjusting learning rate of group 0 to 3.9899e-258.
# Adjusting learning rate of group 0 to 3.5909e-258.
# Adjusting learning rate of group 0 to 3.2318e-258.
# Adjusting learning rate of group 0 to 2.9086e-258.
# Adjusting learning rate of group 0 to 2.6178e-258.
# Adjusting learning rate of group 0 to 2.3560e-258.
# Adjusting learning rate of group 0 to 2.1204e-258.
# Adjusting learning rate of group 0 to 1.9083e-258.
# Adjusting learning rate of group 0 to 1.7175e-258.
# Adjusting learning rate of group 0 to 1.5458e-258.
# Adjusting learning rate of group 0 to 1.3912e-258.
# Adjusting learning rate of group 0 to 1.2521e-258.
# Adjusting learning rate of group 0 to 1.1269e-258.
# Adjusting learning rate of group 0 to 1.0142e-258.
# Adjusting learning rate of group 0 to 9.1276e-259.
# Adjusting learning rate of group 0 to 8.2148e-259.
# /*** EPOCH : 86/1000 ***/
# TRAIN - 1467794.0, nan
# TEST - 1394730.5, nan
#
# Adjusting learning rate of group 0 to 7.3933e-259.
# Adjusting learning rate of group 0 to 6.6540e-259.
# Adjusting learning rate of group 0 to 5.9886e-259.
# Adjusting learning rate of group 0 to 5.3897e-259.
# Adjusting learning rate of group 0 to 4.8508e-259.
# Adjusting learning rate of group 0 to 4.3657e-259.
# Adjusting learning rate of group 0 to 3.9291e-259.
# Adjusting learning rate of group 0 to 3.5362e-259.
# Adjusting learning rate of group 0 to 3.1826e-259.
# Adjusting learning rate of group 0 to 2.8643e-259.
# Adjusting learning rate of group 0 to 2.5779e-259.
# Adjusting learning rate of group 0 to 2.3201e-259.
# Adjusting learning rate of group 0 to 2.0881e-259.
# Adjusting learning rate of group 0 to 1.8793e-259.
# Adjusting learning rate of group 0 to 1.6914e-259.
# Adjusting learning rate of group 0 to 1.5222e-259.
# Adjusting learning rate of group 0 to 1.3700e-259.
# Adjusting learning rate of group 0 to 1.2330e-259.
# Adjusting learning rate of group 0 to 1.1097e-259.
# Adjusting learning rate of group 0 to 9.9873e-260.
# Adjusting learning rate of group 0 to 8.9886e-260.
# Adjusting learning rate of group 0 to 8.0897e-260.
# Adjusting learning rate of group 0 to 7.2807e-260.
# Adjusting learning rate of group 0 to 6.5527e-260.
# Adjusting learning rate of group 0 to 5.8974e-260.
# Adjusting learning rate of group 0 to 5.3077e-260.
# Adjusting learning rate of group 0 to 4.7769e-260.
# Adjusting learning rate of group 0 to 4.2992e-260.
# Adjusting learning rate of group 0 to 3.8693e-260.
# Adjusting learning rate of group 0 to 3.4824e-260.
# Adjusting learning rate of group 0 to 3.1341e-260.
# Adjusting learning rate of group 0 to 2.8207e-260.
# Adjusting learning rate of group 0 to 2.5386e-260.
# Adjusting learning rate of group 0 to 2.2848e-260.
# Adjusting learning rate of group 0 to 2.0563e-260.
# Adjusting learning rate of group 0 to 1.8507e-260.
# Adjusting learning rate of group 0 to 1.6656e-260.
# Adjusting learning rate of group 0 to 1.4990e-260.
# Adjusting learning rate of group 0 to 1.3491e-260.
# Adjusting learning rate of group 0 to 1.2142e-260.
# Adjusting learning rate of group 0 to 1.0928e-260.
# Adjusting learning rate of group 0 to 9.8352e-261.
# Adjusting learning rate of group 0 to 8.8517e-261.
# Adjusting learning rate of group 0 to 7.9665e-261.
# Adjusting learning rate of group 0 to 7.1699e-261.
# Adjusting learning rate of group 0 to 6.4529e-261.
# Adjusting learning rate of group 0 to 5.8076e-261.
# Adjusting learning rate of group 0 to 5.2268e-261.
# Adjusting learning rate of group 0 to 4.7041e-261.
# Adjusting learning rate of group 0 to 4.2337e-261.
# Adjusting learning rate of group 0 to 3.8104e-261.
# Adjusting learning rate of group 0 to 3.4293e-261.
# Adjusting learning rate of group 0 to 3.0864e-261.
# Adjusting learning rate of group 0 to 2.7778e-261.
# Adjusting learning rate of group 0 to 2.5000e-261.
# Adjusting learning rate of group 0 to 2.2500e-261.
# Adjusting learning rate of group 0 to 2.0250e-261.
# Adjusting learning rate of group 0 to 1.8225e-261.
# Adjusting learning rate of group 0 to 1.6402e-261.
# Adjusting learning rate of group 0 to 1.4762e-261.
# Adjusting learning rate of group 0 to 1.3286e-261.
# Adjusting learning rate of group 0 to 1.1957e-261.
# Adjusting learning rate of group 0 to 1.0762e-261.
# Adjusting learning rate of group 0 to 9.6854e-262.
# Adjusting learning rate of group 0 to 8.7169e-262.
# /*** EPOCH : 87/1000 ***/
# TRAIN - 1467794.0, nan
# TEST - 1394746.25, nan
#
# Adjusting learning rate of group 0 to 7.8452e-262.
# Adjusting learning rate of group 0 to 7.0607e-262.
# Adjusting learning rate of group 0 to 6.3546e-262.
# Adjusting learning rate of group 0 to 5.7191e-262.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-4fe3d1215df1> in <module>
#       9 for epoch in range(EPOCH_NUM+1):
#      10     if epoch != 0:
# ---> 11         train_loss, train_meas = train(epoch)
#      12     test_loss, test_meas = test()
#      13
#
# <ipython-input-22-64b65eb1978c> in train(epoch)
#      17         loss = loss_func(outputs, targets)  # 출력과 훈련 데이터 정답 간의 오차를 계산
#      18         loss.backward()  # 오차를 역전파 계산
# ---> 19         optimizer.step()  # 역전파 계산한 값으로 가중치를 수정
#      20         scheduler.step()
#      21
#
# D:\Sangwons_Room\00_SoftWares\Anaconda\envs\torch\lib\site-packages\torch\optim\lr_scheduler.py in wrapper(*args, **kwargs)
#      65                 instance._step_count += 1
#      66                 wrapped = func.__get__(instance, cls)
# ---> 67                 return wrapped(*args, **kwargs)
#      68
#      69             # Note that the returned function here is no longer a bound method,
#
# D:\Sangwons_Room\00_SoftWares\Anaconda\envs\torch\lib\site-packages\torch\autograd\grad_mode.py in decorate_context(*args, **kwargs)
#      24         def decorate_context(*args, **kwargs):
#      25             with self.__class__():
# ---> 26                 return func(*args, **kwargs)
#      27         return cast(F, decorate_context)
#      28
#
# D:\Sangwons_Room\00_SoftWares\Anaconda\envs\torch\lib\site-packages\torch\optim\adam.py in step(self, closure)
#     117                    group['lr'],
#     118                    group['weight_decay'],
# --> 119                    group['eps']
#     120                    )
#     121         return loss
#
# D:\Sangwons_Room\00_SoftWares\Anaconda\envs\torch\lib\site-packages\torch\optim\functional.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps)
#      84
#      85         # Decay the first and second moment running average coefficient
# ---> 86         exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1)
#      87         exp_avg_sq.mul_(beta2).addcmul_(grad, grad, value=1 - beta2)
#      88         if amsgrad:
#
# KeyboardInterrupt:

# %%
df_history = pd.DataFrame(history)

fig, axes = plt.subplots(2,1,figsize = (8,12))

axes[0].plot(df_history['epoch'], df_history['train_loss'])
axes[0].plot(df_history['epoch'], df_history['test_loss'])
axes[0].axvline(x = check_epoch, ymin = 0, ymax = df_history['test_loss'].max(), color = 'r')
axes[0].axhline(y = default_loss, xmin = 0, xmax = df_history['epoch'].max(), color = 'k')

axes[1].plot(df_history['epoch'], df_history['train_meas'])
axes[1].plot(df_history['epoch'], df_history['test_meas'])
axes[1].axvline(x = check_epoch, ymin = 0, ymax = df_history['test_meas'].max(), color = 'r')
axes[1].axhline(y = default_meas, xmin = 0, xmax = df_history['epoch'].max(), color = 'k')

# %%
del X_train, X_test, y_train, y_test

# %% [markdown]
# # Submission

# %%
df_test = pd.read_pickle(str(data_dir / "gsdc_test.pkl.gzip"))

print(df_test.shape)
df_test.head()

# %%
model.load_state_dict(torch.load(checkpoint_path))
torch.save(model.state_dict(), model_path)

# %%
# Load submission sample
submission = pd.read_csv(str(data_dir / "sample_submission.csv"))
print(submission.shape)

# %%
model = SimpleNetwork(X.shape[1] * X.shape[2], y.shape[1])
model = model.to(device)
model.load_state_dict(torch.load(model_path))

# %%
X, _ = extract_features(df_test, train = False)

X = torch.Tensor(X)

loader_test = DataLoader(X, batch_size = batch_size, shuffle = False)

# %%
model.eval()  # 신경망을 추론 모드로 전환

# 데이터로더에서 미니배치를 하나씩 꺼내 추론을 수행
predict = []
with torch.no_grad():  # 추론 과정에는 미분이 필요없음
    for data in loader_test:
        data = data.to(device)

        outputs = model(data)  # 데이터를 입력하고 출력을 계산
        predict.append(outputs)
predict = torch.cat(predict, axis = 0).to('cpu')

# %%
predict.shape

# %%
print(submission.shape)
submission.columns

# %%
submission['latDeg'] = predict[:,1]
submission['lngDeg'] = predict[:,2]

# %%
submission.to_csv(f"./models/{notebookName}/{num_files} - result.csv", index = False)
pd.DataFrame([]).to_csv(dummy_path)

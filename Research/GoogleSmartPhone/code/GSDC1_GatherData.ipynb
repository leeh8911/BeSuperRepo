# %% [markdown]
# # Reference
# 1. https://www.kaggle.com/rohanrao/tutorial-on-reading-large-datasets
# 1. https://www.kaggle.com/asobod11138/gsdc-neuralnet-keras (multi-threading)

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
from glob import glob
import os
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from pathlib import Path
import plotly.express as px
from multiprocessing import Pool
import multiprocessing as multi
import gc

from utils.gsdc_parser import ground_truth_file_open, derived_file_open, gnsslog_file_open, gnss_log_to_dataframes

split_charater = "\\"

# %% [markdown]
# # Help Function

# %%
def UTC2GpsEpoch(df):
    '''UTC to GpsEpoch
    
    utcTimeMillis         : UTC epoch (1970/1/1)
    millisSinceGpsEpoch   : GPS epoch(1980/1/6 midnight 12:00 UTC)
    
    Ref: https://www.kaggle.com/c/google-smartphone-decimeter-challenge/discussion/239187
    '''
    dt_offset = pd.to_datetime('1980-01-06 00:00:00') 
    dt_offset_in_ms = int(dt_offset.value / 1e6)
    df['millisSinceGpsEpoch'] = df['utcTimeMillis'] - dt_offset_in_ms + 18000
    df['millisSinceGpsEpoch'] = df['millisSinceGpsEpoch'].astype('int64')
    return df

# %% [markdown]
# # Set Path and Load Dataset

# %%
PATH = Path("../input/google-smartphone-decimeter-challenge")
train_df = pd.read_csv(PATH / "baseline_locations_train.csv")
test_df = pd.read_csv(PATH / "baseline_locations_test.csv")

# %%
print(train_df.shape)
train_df.head()
# Out:
# (131342, 7)
#         collectionName phoneName  millisSinceGpsEpoch     latDeg      lngDeg  \
# 0  2020-05-14-US-MTV-1    Pixel4        1273529463442  37.423575 -122.094091
# 1  2020-05-14-US-MTV-1    Pixel4        1273529464442  37.423578 -122.094101
# 2  2020-05-14-US-MTV-1    Pixel4        1273529465442  37.423573 -122.094111
# 3  2020-05-14-US-MTV-1    Pixel4        1273529466442  37.423583 -122.094121
# 4  2020-05-14-US-MTV-1    Pixel4        1273529467442  37.423579 -122.094114
#
#    heightAboveWgs84EllipsoidM                       phone
# 0                      -34.06  2020-05-14-US-MTV-1_Pixel4
# 1                      -33.29  2020-05-14-US-MTV-1_Pixel4
# 2                      -30.99  2020-05-14-US-MTV-1_Pixel4
# 3                      -32.83  2020-05-14-US-MTV-1_Pixel4
# 4                      -34.49  2020-05-14-US-MTV-1_Pixel4

# %%
print(test_df.shape)
test_df.head()
# Out:
# (91486, 7)
#         collectionName phoneName  millisSinceGpsEpoch     latDeg      lngDeg  \
# 0  2020-05-15-US-MTV-1    Pixel4        1273608785432  37.416628 -122.082053
# 1  2020-05-15-US-MTV-1    Pixel4        1273608786432  37.416646 -122.082040
# 2  2020-05-15-US-MTV-1    Pixel4        1273608787432  37.416653 -122.082039
# 3  2020-05-15-US-MTV-1    Pixel4        1273608788432  37.416607 -122.082063
# 4  2020-05-15-US-MTV-1    Pixel4        1273608789432  37.416609 -122.082073
#
#    heightAboveWgs84EllipsoidM                       phone
# 0                      -30.69  2020-05-15-US-MTV-1_Pixel4
# 1                      -31.76  2020-05-15-US-MTV-1_Pixel4
# 2                      -31.65  2020-05-15-US-MTV-1_Pixel4
# 3                      -31.52  2020-05-15-US-MTV-1_Pixel4
# 4                      -28.95  2020-05-15-US-MTV-1_Pixel4

# %% [markdown]
# # Load All Data Function

# %%
gnss_section_names = {'Raw','UncalAccel', 'UncalGyro', 'UncalMag', 'Fix', 'Status', 'OrientationDeg'}
section_names = {'GroundTruth', 'Derived', 'Raw','UncalAccel', 'UncalGyro', 'UncalMag', 'Fix', 'Status', 'OrientationDeg'}
_columns = ['latDeg', 'lngDeg', 'heightAboveWgs84EllipsoidM']

# %%
thread_num = 4

# %%
def merge_data(df_, truth, derived, gnss):
    df = df_.copy()
    
    print('Truth Data Start')
    if truth is not None:
        df = pd.merge_asof(df.sort_values('millisSinceGpsEpoch'), 
              truth.sort_values('millisSinceGpsEpoch'), 
              on="millisSinceGpsEpoch", by=["collectionName", "phoneName"], 
              direction='nearest',tolerance=100000)
    print('Truth Data Fin')

    print('Derived Data Start')
    df = pd.merge_asof(df.sort_values('millisSinceGpsEpoch'), 
          derived.sort_values('millisSinceGpsEpoch'), 
          on="millisSinceGpsEpoch", by=["collectionName", "phoneName"], 
          direction='nearest',tolerance=100000)
    print('Derived Data Fin')


    print('Gnss Log Data Start')
    for key, value in tqdm(gnss.items()):
        if value.shape[0] == 0:
            continue
        df = pd.merge_asof(df.sort_values('millisSinceGpsEpoch'), 
              value.sort_values('millisSinceGpsEpoch'), 
              on="millisSinceGpsEpoch", by=["collectionName", "phoneName"], 
              direction='nearest',tolerance=100000, suffixes = ['', "_" + key])
    print('Gnss Log Data Fin')
        
    return df

# %% [markdown]
# ## Train
# ### For Multi Processing Code

# %%
path_list = list(glob(str(PATH / "train" / "*/*/*")))

get_ground_truth = lambda x:x.split(split_charater)[-1].find("ground_truth")>= 0
get_derived = lambda x:x.split(split_charater)[-1].find("derived.csv")>= 0
get_gnsslog = lambda x:x.split(split_charater)[-1].find("GnssLog.txt")>= 0

ground_truth_path_list = list(filter(get_ground_truth, path_list))
derived_path_list = list(filter(get_derived, path_list))
gnsslog_path_list = list(filter(get_gnsslog, path_list))

# %%
output = dict()
for section in section_names:
    output[section] = pd.DataFrame()

# %%
with Pool(thread_num) as pool:
    imap = pool.imap(gnsslog_file_open, gnsslog_path_list)
    gnss_logs = list(tqdm(imap, total=len(gnsslog_path_list), desc="load gnss log"))
    
gnss_dict = {}
for key in gnss_section_names:
    list_temp = []
    for gnss_log in gnss_logs:
        list_temp.append(gnss_log[key])
    df_temp = pd.concat(list_temp)
    gnss_dict[key] = df_temp
    if (key == "Status") or (key == "Fix"):  
        gnss_dict[key].rename(columns = {'UnixTimeMillis':'utcTimeMillis'}, inplace = True)
    
    gnss_dict[key] = UTC2GpsEpoch(gnss_dict[key])
    print(gnss_dict[key]['utcTimeMillis'].dtype)
    print(gnss_dict[key].shape)
    print(gnss_dict[key].head())

del gnss_logs
# Out:
# load gnss log:   0%|          | 0/73 [00:00<?, ?it/s]
# float64
# (2825564, 8)
#         collectionName phoneName  utcTimeMillis  elapsedRealtimeNanos  yawDeg  \
# 0  2021-03-10-US-SVL-1  Pixel4XL   1.615418e+12          1.035191e+13    61.0
# 1  2021-03-10-US-SVL-1  Pixel4XL   1.615418e+12          1.035193e+13    61.0
# 2  2021-03-10-US-SVL-1  Pixel4XL   1.615418e+12          1.035195e+13    61.0
# 3  2021-03-10-US-SVL-1  Pixel4XL   1.615418e+12          1.035196e+13    61.0
# 4  2021-03-10-US-SVL-1  Pixel4XL   1.615418e+12          1.035198e+13    61.0
#
#    rollDeg  pitchDeg  millisSinceGpsEpoch
# 0   -165.0     -83.0        1299453166737
# 1   -165.0     -83.0        1299453166753
# 2   -165.0     -83.0        1299453166769
# 3   -165.0     -83.0        1299453166785
# 4   -165.0     -83.0        1299453166801
# int64
# (4285508, 16)
#    utcTimeMillis  SignalCount  SignalIndex  ConstellationType  Svid  \
# 0  1589494244403           37            0                  1     2
# 1  1589494244403           37            1                  1     5
# 2  1589494244403           37            2                  1     6
# 3  1589494244403           37            3                  1    12
# 4  1589494244403           37            4                  1    19
#
#    CarrierFrequencyHz  Cn0DbHz  AzimuthDegrees  ElevationDegrees  UsedInFix  \
# 0        1.575420e+09     37.9            52.0              72.0          1
# 1        1.575420e+09     30.0           144.0              25.0          1
# 2        1.575420e+09     36.9            43.0              37.0          0
# 3        1.575420e+09     25.2           340.0              78.0          1
# 4        1.575420e+09     28.0            70.0              14.0          1
#
#    HasAlmanacData  HasEphemerisData       collectionName phoneName  \
# 0               1                 1  2020-05-14-US-MTV-1    Pixel4
# 1               1                 1  2020-05-14-US-MTV-1    Pixel4
# 2               1                 1  2020-05-14-US-MTV-1    Pixel4
# 3               1                 1  2020-05-14-US-MTV-1    Pixel4
# 4               1                 1  2020-05-14-US-MTV-1    Pixel4
#
#    BasebandCn0DbHz  millisSinceGpsEpoch
# 0              NaN        1273529462403
# 1              NaN        1273529462403
# 2              NaN        1273529462403
# 3              NaN        1273529462403
# 4              NaN        1273529462403
# int64
# (11237068, 11)
#    utcTimeMillis  elapsedRealtimeNanos  UncalMagXMicroT  UncalMagYMicroT  \
# 0  1589494244849        19637944305324        25.068630       -48.203823
# 1  1589494244860        19637954245636        25.011307       -48.403454
# 2  1589494244869        19637964187407        25.010984       -48.398920
# 3  1589494244879        19637974118709        25.042374       -49.233658
# 4  1589494244889        19637984054907        24.980007       -48.764900
#
#    UncalMagZMicroT       collectionName phoneName  BiasXMicroT  BiasYMicroT  \
# 0       -17.910692  2020-05-14-US-MTV-1    Pixel4          NaN          NaN
# 1       -17.473583  2020-05-14-US-MTV-1    Pixel4          NaN          NaN
# 2       -17.320847  2020-05-14-US-MTV-1    Pixel4          NaN          NaN
# 3       -17.507921  2020-05-14-US-MTV-1    Pixel4          NaN          NaN
# 4       -15.564432  2020-05-14-US-MTV-1    Pixel4          NaN          NaN
#
#    BiasZMicroT  millisSinceGpsEpoch
# 0          NaN        1273529462849
# 1          NaN        1273529462860
# 2          NaN        1273529462869
# 3          NaN        1273529462879
# 4          NaN        1273529462889
# int64
# (20523372, 11)
#    utcTimeMillis  elapsedRealtimeNanos  UncalAccelXMps2  UncalAccelYMps2  \
# 0  1589494244845        19637940404074         0.177860        10.159246
# 1  1589494244847        19637942846782        -0.002934        10.351667
# 2  1589494244850        19637945289491        -0.114138        10.099208
# 3  1589494244853        19637947732199        -0.089033         9.789539
# 4  1589494244856        19637950174907        -0.123533         9.586480
#
#    UncalAccelZMps2       collectionName phoneName  BiasXMps2  BiasYMps2  \
# 0         1.052928  2020-05-14-US-MTV-1    Pixel4        NaN        NaN
# 1         0.934190  2020-05-14-US-MTV-1    Pixel4        NaN        NaN
# 2         0.751948  2020-05-14-US-MTV-1    Pixel4        NaN        NaN
# 3         0.821809  2020-05-14-US-MTV-1    Pixel4        NaN        NaN
# 4         0.996857  2020-05-14-US-MTV-1    Pixel4        NaN        NaN
#
#    BiasZMps2  millisSinceGpsEpoch
# 0        NaN        1273529462845
# 1        NaN        1273529462847
# 2        NaN        1273529462850
# 3        NaN        1273529462853
# 4        NaN        1273529462856
# int64
# (20534266, 11)
#    utcTimeMillis  elapsedRealtimeNanos  UncalGyroXRadPerSec  \
# 0  1589494244844        19637939874074            -0.003550
# 1  1589494244847        19637942316782            -0.003370
# 2  1589494244849        19637944759491            -0.004533
# 3  1589494244852        19637947202199            -0.008254
# 4  1589494244855        19637949644907            -0.008272
#
#    UncalGyroYRadPerSec  UncalGyroZRadPerSec       collectionName phoneName  \
# 0             0.023597            -0.082773  2020-05-14-US-MTV-1    Pixel4
# 1             0.030998            -0.080377  2020-05-14-US-MTV-1    Pixel4
# 2             0.028622            -0.074239  2020-05-14-US-MTV-1    Pixel4
# 3             0.017697            -0.065580  2020-05-14-US-MTV-1    Pixel4
# 4             0.010407            -0.058197  2020-05-14-US-MTV-1    Pixel4
#
#    DriftXRadPerSec  DriftYRadPerSec  DriftZRadPerSec  millisSinceGpsEpoch
# 0              NaN              NaN              NaN        1273529462844
# 1              NaN              NaN              NaN        1273529462847
# 2              NaN              NaN              NaN        1273529462849
# 3              NaN              NaN              NaN        1273529462852
# 4              NaN              NaN              NaN        1273529462855
# int64
# (4386205, 39)
#    utcTimeMillis       TimeNanos  LeapSecond  TimeUncertaintyNanos  \
# 0  1589494245442  21091250000000         NaN                   NaN
# 1  1589494245442  21091250000000         NaN                   NaN
# 2  1589494245442  21091250000000         NaN                   NaN
# 3  1589494245442  21091250000000         NaN                   NaN
# 4  1589494245442  21091250000000         NaN                   NaN
#
#          FullBiasNanos  BiasNanos  BiasUncertaintyNanos  DriftNanosPerSecond  \
# 0 -1273508372192433379  -0.173279             25.084462            -0.129289
# 1 -1273508372192433379  -0.173279             25.084462            -0.129289
# 2 -1273508372192433379  -0.173279             25.084462            -0.129289
# 3 -1273508372192433379  -0.173279             25.084462            -0.129289
# 4 -1273508372192433379  -0.173279             25.084462            -0.129289
#
#    DriftUncertaintyNanosPerSecond  HardwareClockDiscontinuityCount  ...  \
# 0                       10.603476                             2593  ...
# 1                       10.603476                             2593  ...
# 2                       10.603476                             2593  ...
# 3                       10.603476                             2593  ...
# 4                       10.603476                             2593  ...
#
#         collectionName  phoneName  BasebandCn0DbHz  FullInterSignalBiasNanos  \
# 0  2020-05-14-US-MTV-1     Pixel4              NaN                       NaN
# 1  2020-05-14-US-MTV-1     Pixel4              NaN                       NaN
# 2  2020-05-14-US-MTV-1     Pixel4              NaN                       NaN
# 3  2020-05-14-US-MTV-1     Pixel4              NaN                       NaN
# 4  2020-05-14-US-MTV-1     Pixel4              NaN                       NaN
#
#    FullInterSignalBiasUncertaintyNanos  SatelliteInterSignalBiasNanos  \
# 0                                  NaN                            NaN
# 1                                  NaN                            NaN
# 2                                  NaN                            NaN
# 3                                  NaN                            NaN
# 4                                  NaN                            NaN
#
#    SatelliteInterSignalBiasUncertaintyNanos  CodeType  \
# 0                                       NaN       NaN
# 1                                       NaN       NaN
# 2                                       NaN       NaN
# 3                                       NaN       NaN
# 4                                       NaN       NaN
#
#    ChipsetElapsedRealtimeNanos  millisSinceGpsEpoch
# 0                          NaN        1273529463442
# 1                          NaN        1273529463442
# 2                          NaN        1273529463442
# 3                          NaN        1273529463442
# 4                          NaN        1273529463442
#
# [5 rows x 39 columns]
# int64
# (0, 14)
# Empty DataFrame
# Columns: [Provider, LatitudeDegrees, LongitudeDegrees, AltitudeMeters, SpeedMps, AccuracyMeters, BearingDegrees, utcTimeMillis, SpeedAccuracyMps, BearingAccuracyDegrees, collectionName, phoneName, elapsedRealtimeNanos, millisSinceGpsEpoch]
# Index: []

# %%
with Pool(thread_num) as pool:
    imap = pool.imap(ground_truth_file_open, ground_truth_path_list)
    ground_truth = list(tqdm(imap, total=len(ground_truth_path_list), desc="load ground truth"))
    
df_truth = pd.concat(ground_truth)
print(df_truth.shape)
df_truth.head()

del ground_truth
# Out:
# load ground truth:   0%|          | 0/73 [00:00<?, ?it/s]
# (131342, 11)

# %%
with Pool(thread_num) as pool:
    imap = pool.imap(derived_file_open, derived_path_list)
    derived = list(tqdm(imap, total=len(derived_path_list), desc="load derived data"))
    
df_derived = pd.concat(derived)
print(df_derived.shape)
df_derived.head()

del derived
# Out:
# load derived data:   0%|          | 0/73 [00:00<?, ?it/s]
# (3834542, 20)

# %% [markdown]
# ### Tiny Data Issue Solve

# %%
raw_timestamps = gnss_dict['Raw']['millisSinceGpsEpoch'].unique()
derived_timestamps = df_derived['millisSinceGpsEpoch'].unique()

# The timestamps in derived are one epoch ahead. We need to map each epoch
# in derived to the prior one (in Raw).
indexes = np.searchsorted(raw_timestamps, derived_timestamps)
from_t_to_fix_derived = dict(zip(derived_timestamps, raw_timestamps[indexes-1]))
df_derived['millisSinceGpsEpoch'] = np.array(list(map(lambda v: from_t_to_fix_derived[v], df_derived['millisSinceGpsEpoch'])))

# %%
delta_millis = df_derived['millisSinceGpsEpoch'] - df_derived['receivedSvTimeInGpsNanos']/1e6
good_signals = (delta_millis > 0) & (delta_millis < 300)
df_derived = df_derived[good_signals].copy()

# %% [markdown]
# ### Save To Pickle File

# %%
output = merge_data(train_df, df_truth, df_derived, gnss_dict)
output.to_pickle(str(PATH / "gsdc_train.pkl.gzip"))
print(output.shape)
output.head()
# Out:
# Truth Data Start
# Truth Data Fin
# Derived Data Start
# Derived Data Fin
# Gnss Log Data Start
#   0%|          | 0/7 [00:00<?, ?it/s]
# Gnss Log Data Fin
# (131342, 110)
#         collectionName       phoneName  millisSinceGpsEpoch     latDeg  \
# 0  2020-05-14-US-MTV-1          Pixel4        1273529463442  37.423575
# 1  2020-05-14-US-MTV-1          Pixel4        1273529464442  37.423578
# 2  2020-05-14-US-MTV-1          Pixel4        1273529465442  37.423573
# 3  2020-05-14-US-MTV-1          Pixel4        1273529466442  37.423583
# 4  2020-05-14-US-MTV-1  Pixel4XLModded        1273529466449  37.423574
#
#        lngDeg  heightAboveWgs84EllipsoidM                               phone  \
# 0 -122.094091                      -34.06          2020-05-14-US-MTV-1_Pixel4
# 1 -122.094101                      -33.29          2020-05-14-US-MTV-1_Pixel4
# 2 -122.094111                      -30.99          2020-05-14-US-MTV-1_Pixel4
# 3 -122.094121                      -32.83          2020-05-14-US-MTV-1_Pixel4
# 4 -122.094137                      -33.20  2020-05-14-US-MTV-1_Pixel4XLModded
#
#    timeSinceFirstFixSeconds  hDop  vDop  ...  SnrInDb  ConstellationType_Raw  \
# 0                    551.44   1.1   0.0  ...      NaN                      1
# 1                    552.44   1.1   0.0  ...      NaN                      1
# 2                    553.44   1.1   0.0  ...      NaN                      1
# 3                    554.44   1.1   0.0  ...      NaN                      1
# 4                    554.45   1.2   0.0  ...      NaN                      1
#
#    AgcDb  BasebandCn0DbHz_Raw  FullInterSignalBiasNanos  \
# 0  -0.61                  NaN                       NaN
# 1  -0.12                  NaN                       NaN
# 2   0.02                  NaN                       NaN
# 3   0.07                  NaN                       NaN
# 4   0.99                  NaN                       NaN
#
#    FullInterSignalBiasUncertaintyNanos  SatelliteInterSignalBiasNanos  \
# 0                                  NaN                            NaN
# 1                                  NaN                            NaN
# 2                                  NaN                            NaN
# 3                                  NaN                            NaN
# 4                                  NaN                            NaN
#
#   SatelliteInterSignalBiasUncertaintyNanos  CodeType  \
# 0                                      NaN       NaN
# 1                                      NaN       NaN
# 2                                      NaN       NaN
# 3                                      NaN       NaN
# 4                                      NaN       NaN
#
#    ChipsetElapsedRealtimeNanos
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
# [5 rows x 110 columns]

# %%
output.info(verbose = True, memory_usage= True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 131342 entries, 0 to 131341
# Data columns (total 110 columns):
#  #   Column                                     Non-Null Count   Dtype
# ---  ------                                     --------------   -----
#  0   collectionName                             131342 non-null  object
#  1   phoneName                                  131342 non-null  object
#  2   millisSinceGpsEpoch                        131342 non-null  int64
#  3   latDeg                                     131342 non-null  float64
#  4   lngDeg                                     131342 non-null  float64
#  5   heightAboveWgs84EllipsoidM                 131342 non-null  float64
#  6   phone                                      131342 non-null  object
#  7   timeSinceFirstFixSeconds                   131342 non-null  float64
#  8   hDop                                       131342 non-null  float64
#  9   vDop                                       131342 non-null  float64
#  10  speedMps                                   131342 non-null  float64
#  11  courseDegree                               131342 non-null  float64
#  12  t_latDeg                                   131342 non-null  float64
#  13  t_lngDeg                                   131342 non-null  float64
#  14  t_heightAboveWgs84EllipsoidM               131342 non-null  float64
#  15  constellationType                          69268 non-null   float64
#  16  svid                                       69268 non-null   float64
#  17  signalType                                 69268 non-null   object
#  18  receivedSvTimeInGpsNanos                   69268 non-null   float64
#  19  xSatPosM                                   69268 non-null   float64
#  20  ySatPosM                                   69268 non-null   float64
#  21  zSatPosM                                   69268 non-null   float64
#  22  xSatVelMps                                 69268 non-null   float64
#  23  ySatVelMps                                 69268 non-null   float64
#  24  zSatVelMps                                 69268 non-null   float64
#  25  satClkBiasM                                69268 non-null   float64
#  26  satClkDriftMps                             69268 non-null   float64
#  27  rawPrM                                     69268 non-null   float64
#  28  rawPrUncM                                  69268 non-null   float64
#  29  isrbM                                      69268 non-null   float64
#  30  ionoDelayM                                 69268 non-null   float64
#  31  tropoDelayM                                69268 non-null   float64
#  32  utcTimeMillis                              36607 non-null   float64
#  33  elapsedRealtimeNanos                       36607 non-null   float64
#  34  yawDeg                                     36607 non-null   float64
#  35  rollDeg                                    36607 non-null   float64
#  36  pitchDeg                                   36607 non-null   float64
#  37  utcTimeMillis_Status                       112002 non-null  float64
#  38  SignalCount                                112002 non-null  float64
#  39  SignalIndex                                112002 non-null  float64
#  40  ConstellationType                          112002 non-null  float64
#  41  Svid                                       112002 non-null  float64
#  42  CarrierFrequencyHz                         111826 non-null  float64
#  43  Cn0DbHz                                    112002 non-null  float64
#  44  AzimuthDegrees                             112002 non-null  float64
#  45  ElevationDegrees                           112002 non-null  float64
#  46  UsedInFix                                  112002 non-null  float64
#  47  HasAlmanacData                             112002 non-null  float64
#  48  HasEphemerisData                           112002 non-null  float64
#  49  BasebandCn0DbHz                            20406 non-null   float64
#  50  utcTimeMillis_UncalMag                     113834 non-null  float64
#  51  elapsedRealtimeNanos_UncalMag              113834 non-null  float64
#  52  UncalMagXMicroT                            113834 non-null  float64
#  53  UncalMagYMicroT                            113834 non-null  float64
#  54  UncalMagZMicroT                            113834 non-null  float64
#  55  BiasXMicroT                                74779 non-null   float64
#  56  BiasYMicroT                                74779 non-null   float64
#  57  BiasZMicroT                                74779 non-null   float64
#  58  utcTimeMillis_UncalAccel                   113834 non-null  float64
#  59  elapsedRealtimeNanos_UncalAccel            113834 non-null  float64
#  60  UncalAccelXMps2                            113834 non-null  float64
#  61  UncalAccelYMps2                            113834 non-null  float64
#  62  UncalAccelZMps2                            113834 non-null  float64
#  63  BiasXMps2                                  74779 non-null   float64
#  64  BiasYMps2                                  74779 non-null   float64
#  65  BiasZMps2                                  74779 non-null   float64
#  66  utcTimeMillis_UncalGyro                    113834 non-null  float64
#  67  elapsedRealtimeNanos_UncalGyro             113834 non-null  float64
#  68  UncalGyroXRadPerSec                        113834 non-null  float64
#  69  UncalGyroYRadPerSec                        113834 non-null  float64
#  70  UncalGyroZRadPerSec                        113834 non-null  float64
#  71  DriftXRadPerSec                            74779 non-null   float64
#  72  DriftYRadPerSec                            74779 non-null   float64
#  73  DriftZRadPerSec                            74779 non-null   float64
#  74  utcTimeMillis_Raw                          131342 non-null  int64
#  75  TimeNanos                                  131342 non-null  int64
#  76  LeapSecond                                 45928 non-null   float64
#  77  TimeUncertaintyNanos                       0 non-null       float64
#  78  FullBiasNanos                              131342 non-null  int64
#  79  BiasNanos                                  131342 non-null  float64
#  80  BiasUncertaintyNanos                       131342 non-null  float64
#  81  DriftNanosPerSecond                        117173 non-null  float64
#  82  DriftUncertaintyNanosPerSecond             117173 non-null  float64
#  83  HardwareClockDiscontinuityCount            131342 non-null  int64
#  84  Svid_Raw                                   131342 non-null  int64
#  85  TimeOffsetNanos                            131342 non-null  float64
#  86  State                                      131342 non-null  int64
#  87  ReceivedSvTimeNanos                        131342 non-null  int64
#  88  ReceivedSvTimeUncertaintyNanos             131342 non-null  int64
#  89  Cn0DbHz_Raw                                131342 non-null  float64
#  90  PseudorangeRateMetersPerSecond             131342 non-null  float64
#  91  PseudorangeRateUncertaintyMetersPerSecond  131342 non-null  float64
#  92  AccumulatedDeltaRangeState                 131342 non-null  int64
#  93  AccumulatedDeltaRangeMeters                131342 non-null  float64
#  94  AccumulatedDeltaRangeUncertaintyMeters     131342 non-null  float64
#  95  CarrierFrequencyHz_Raw                     131342 non-null  float64
#  96  CarrierCycles                              0 non-null       float64
#  97  CarrierPhase                               0 non-null       float64
#  98  CarrierPhaseUncertainty                    0 non-null       float64
#  99  MultipathIndicator                         131342 non-null  int64
#  100 SnrInDb                                    0 non-null       float64
#  101 ConstellationType_Raw                      131342 non-null  int64
#  102 AgcDb                                      123461 non-null  float64
#  103 BasebandCn0DbHz_Raw                        25995 non-null   float64
#  104 FullInterSignalBiasNanos                   25995 non-null   float64
#  105 FullInterSignalBiasUncertaintyNanos        25995 non-null   float64
#  106 SatelliteInterSignalBiasNanos              14204 non-null   float64
#  107 SatelliteInterSignalBiasUncertaintyNanos   14204 non-null   float64
#  108 CodeType                                   83102 non-null   object
#  109 ChipsetElapsedRealtimeNanos                48613 non-null   float64
# dtypes: float64(93), int64(12), object(5)
# memory usage: 111.2+ MB

# %%
del df_truth, df_derived, gnss_dict, output
gc.collect()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-268b98048577> in <module>
# ----> 1 del df_truth, df_derived, gnss_dict, output
#       2 gc.collect()
#
# NameError: name 'df_truth' is not defined

# %% [markdown]
# ## Test
# ### For Multi Processing Code

# %%
path_list = list(glob(str(PATH / "test" / "*/*/*")))

get_ground_truth = lambda x:x.split(split_charater)[-1].find("ground_truth")>= 0
get_derived = lambda x:x.split(split_charater)[-1].find("derived.csv")>= 0
get_gnsslog = lambda x:x.split(split_charater)[-1].find("GnssLog.txt")>= 0

ground_truth_path_list = list(filter(get_ground_truth, path_list))
derived_path_list = list(filter(get_derived, path_list))
gnsslog_path_list = list(filter(get_gnsslog, path_list))

# %%
output = dict()
for section in section_names:
    output[section] = pd.DataFrame()

# %%
with Pool(thread_num) as pool:
    imap = pool.imap(gnsslog_file_open, gnsslog_path_list)
    gnss_logs = list(tqdm(imap, total=len(gnsslog_path_list), desc="load gnss log"))
    
gnss_dict = {}
for key in gnss_section_names:
    list_temp = []
    for gnss_log in gnss_logs:
        list_temp.append(gnss_log[key])
    df_temp = pd.concat(list_temp)
    gnss_dict[key] = df_temp
    if (key == "Status") or (key == "Fix"):  
        gnss_dict[key].rename(columns = {'UnixTimeMillis':'utcTimeMillis'}, inplace = True)
    
    gnss_dict[key] = UTC2GpsEpoch(gnss_dict[key])
    print(gnss_dict[key]['utcTimeMillis'].dtype)
    print(gnss_dict[key].shape)
    print(gnss_dict[key].head())

del gnss_logs
# Out:
# load gnss log:   0%|          | 0/48 [00:00<?, ?it/s]
# float64
# (3583787, 8)
#         collectionName     phoneName  utcTimeMillis  elapsedRealtimeNanos  \
# 0  2021-03-16-US-MTV-2  Pixel4Modded   1.615921e+12          7.160950e+12
# 1  2021-03-16-US-MTV-2  Pixel4Modded   1.615921e+12          7.160966e+12
# 2  2021-03-16-US-MTV-2  Pixel4Modded   1.615921e+12          7.160982e+12
# 3  2021-03-16-US-MTV-2  Pixel4Modded   1.615921e+12          7.160998e+12
# 4  2021-03-16-US-MTV-2  Pixel4Modded   1.615921e+12          7.161014e+12
#
#    yawDeg  rollDeg  pitchDeg  millisSinceGpsEpoch
# 0    55.0    137.0     -82.0        1299956516428
# 1    57.0    139.0     -82.0        1299956516444
# 2    58.0    139.0     -82.0        1299956516460
# 3    57.0    139.0     -82.0        1299956516476
# 4    56.0    138.0     -82.0        1299956516492
# int64
# (2936055, 16)
#    utcTimeMillis  SignalCount  SignalIndex  ConstellationType  Svid  \
# 0              0           33            0                  1     2
# 1              0           33            1                  1     6
# 2              0           33            2                  1    12
# 3              0           33            3                  1    17
# 4              0           33            4                  1    19
#
#    CarrierFrequencyHz  Cn0DbHz  AzimuthDegrees  ElevationDegrees  UsedInFix  \
# 0        1.575420e+09     30.6           177.0              45.0          1
# 1        1.575420e+09     31.0           123.0              60.0          1
# 2        1.575420e+09     26.5           303.0              30.0          1
# 3        1.575420e+09     38.3            46.0              35.0          1
# 4        1.575420e+09     32.8            35.0              56.0          1
#
#    HasAlmanacData  HasEphemerisData       collectionName phoneName  \
# 0               1                 1  2020-05-15-US-MTV-1    Pixel4
# 1               1                 1  2020-05-15-US-MTV-1    Pixel4
# 2               1                 1  2020-05-15-US-MTV-1    Pixel4
# 3               1                 1  2020-05-15-US-MTV-1    Pixel4
# 4               1                 1  2020-05-15-US-MTV-1    Pixel4
#
#    BasebandCn0DbHz  millisSinceGpsEpoch
# 0              NaN        -315964782000
# 1              NaN        -315964782000
# 2              NaN        -315964782000
# 3              NaN        -315964782000
# 4              NaN        -315964782000
# int64
# (7987551, 11)
#    utcTimeMillis  elapsedRealtimeNanos  UncalMagXMicroT  UncalMagYMicroT  \
# 0  1589573567183          8.843774e+12        -3.996058       -79.446210
# 1  1589573567194          8.843784e+12        -3.970562       -79.003136
# 2  1589573567203          8.843794e+12        -3.710957       -79.621560
# 3  1589573567213          8.843804e+12        -3.908953       -80.058640
# 4  1589573567223          8.843814e+12        -4.020702       -80.498720
#
#    UncalMagZMicroT       collectionName phoneName  BiasXMicroT  BiasYMicroT  \
# 0       -17.910206  2020-05-15-US-MTV-1    Pixel4          NaN          NaN
# 1       -17.070097  2020-05-15-US-MTV-1    Pixel4          NaN          NaN
# 2       -17.610000  2020-05-15-US-MTV-1    Pixel4          NaN          NaN
# 3       -17.770708  2020-05-15-US-MTV-1    Pixel4          NaN          NaN
# 4       -18.271114  2020-05-15-US-MTV-1    Pixel4          NaN          NaN
#
#    BiasZMicroT  millisSinceGpsEpoch
# 0          NaN        1273608785183
# 1          NaN        1273608785194
# 2          NaN        1273608785203
# 3          NaN        1273608785213
# 4          NaN        1273608785223
# int64
# (15161426, 11)
#    utcTimeMillis  elapsedRealtimeNanos  UncalAccelXMps2  UncalAccelYMps2  \
# 0  1589573567183         8843773381996        -0.240767         9.742706
# 1  1589573567186         8843775824912        -0.273790         9.696383
# 2  1589573567189         8843778267777        -0.298204         9.653967
# 3  1589573567191         8843780710693        -0.298566         9.682033
# 4  1589573567194         8843783153610        -0.285433         9.747028
#
#    UncalAccelZMps2       collectionName phoneName  BiasXMps2  BiasYMps2  \
# 0        -0.099626  2020-05-15-US-MTV-1    Pixel4        NaN        NaN
# 1         0.006728  2020-05-15-US-MTV-1    Pixel4        NaN        NaN
# 2         0.021937  2020-05-15-US-MTV-1    Pixel4        NaN        NaN
# 3        -0.045378  2020-05-15-US-MTV-1    Pixel4        NaN        NaN
# 4        -0.237778  2020-05-15-US-MTV-1    Pixel4        NaN        NaN
#
#    BiasZMps2  millisSinceGpsEpoch
# 0        NaN        1273608785183
# 1        NaN        1273608785186
# 2        NaN        1273608785189
# 3        NaN        1273608785191
# 4        NaN        1273608785194
# int64
# (15161423, 11)
#    utcTimeMillis  elapsedRealtimeNanos  UncalGyroXRadPerSec  \
# 0  1589573567182         8843772851996            -0.012492
# 1  1589573567186         8843775294912            -0.007893
# 2  1589573567188         8843777737777             0.003079
# 3  1589573567191         8843780180693             0.015324
# 4  1589573567193         8843782623610             0.025200
#
#    UncalGyroYRadPerSec  UncalGyroZRadPerSec       collectionName phoneName  \
# 0            -0.017060             0.015538  2020-05-15-US-MTV-1    Pixel4
# 1            -0.020935             0.003299  2020-05-15-US-MTV-1    Pixel4
# 2            -0.017404            -0.000481  2020-05-15-US-MTV-1    Pixel4
# 3            -0.007783            -0.007979  2020-05-15-US-MTV-1    Pixel4
# 4             0.004334            -0.014250  2020-05-15-US-MTV-1    Pixel4
#
#   DriftXRadPerSec  DriftYRadPerSec  DriftZRadPerSec  millisSinceGpsEpoch
# 0             NaN              NaN              NaN        1273608785182
# 1             NaN              NaN              NaN        1273608785186
# 2             NaN              NaN              NaN        1273608785188
# 3             NaN              NaN              NaN        1273608785191
# 4             NaN              NaN              NaN        1273608785193
# int64
# (2956220, 39)
#    utcTimeMillis      TimeNanos  LeapSecond  TimeUncertaintyNanos  \
# 0  1589573567431  8881264000000         NaN                   NaN
# 1  1589573567431  8881264000000         NaN                   NaN
# 2  1589573567431  8881264000000         NaN                   NaN
# 3  1589573567431  8881264000000         NaN                   NaN
# 4  1589573567431  8881264000000         NaN                   NaN
#
#          FullBiasNanos  BiasNanos  BiasUncertaintyNanos  DriftNanosPerSecond  \
# 0 -1273599904167740172   0.358889             32.053304             2.640615
# 1 -1273599904167740172   0.358889             32.053304             2.640615
# 2 -1273599904167740172   0.358889             32.053304             2.640615
# 3 -1273599904167740172   0.358889             32.053304             2.640615
# 4 -1273599904167740172   0.358889             32.053304             2.640615
#
#    DriftUncertaintyNanosPerSecond  HardwareClockDiscontinuityCount  ...  \
# 0                        9.812771                              290  ...
# 1                        9.812771                              290  ...
# 2                        9.812771                              290  ...
# 3                        9.812771                              290  ...
# 4                        9.812771                              290  ...
#
#         collectionName  phoneName  BasebandCn0DbHz  FullInterSignalBiasNanos  \
# 0  2020-05-15-US-MTV-1     Pixel4              NaN                       NaN
# 1  2020-05-15-US-MTV-1     Pixel4              NaN                       NaN
# 2  2020-05-15-US-MTV-1     Pixel4              NaN                       NaN
# 3  2020-05-15-US-MTV-1     Pixel4              NaN                       NaN
# 4  2020-05-15-US-MTV-1     Pixel4              NaN                       NaN
#
#    FullInterSignalBiasUncertaintyNanos  SatelliteInterSignalBiasNanos  \
# 0                                  NaN                            NaN
# 1                                  NaN                            NaN
# 2                                  NaN                            NaN
# 3                                  NaN                            NaN
# 4                                  NaN                            NaN
#
#    SatelliteInterSignalBiasUncertaintyNanos  CodeType  \
# 0                                       NaN       NaN
# 1                                       NaN       NaN
# 2                                       NaN       NaN
# 3                                       NaN       NaN
# 4                                       NaN       NaN
#
#    ChipsetElapsedRealtimeNanos  millisSinceGpsEpoch
# 0                          NaN        1273608785431
# 1                          NaN        1273608785431
# 2                          NaN        1273608785431
# 3                          NaN        1273608785431
# 4                          NaN        1273608785431
#
# [5 rows x 39 columns]
# int64
# (0, 14)
# Empty DataFrame
# Columns: [Provider, LatitudeDegrees, LongitudeDegrees, AltitudeMeters, SpeedMps, AccuracyMeters, BearingDegrees, utcTimeMillis, SpeedAccuracyMps, BearingAccuracyDegrees, collectionName, phoneName, elapsedRealtimeNanos, millisSinceGpsEpoch]
# Index: []

# %%
with Pool(thread_num) as pool:
    imap = pool.imap(derived_file_open, derived_path_list)
    derived = list(tqdm(imap, total=len(derived_path_list), desc="load derived data"))
    
df_derived = pd.concat(derived)
print(df_derived.shape)
df_derived.head()

del derived
# Out:
# load derived data:   0%|          | 0/48 [00:00<?, ?it/s]
# (2523199, 20)

# %% [markdown]
# ### Tiny Data Issue Solve

# %%
raw_timestamps = gnss_dict['Raw']['millisSinceGpsEpoch'].unique()
derived_timestamps = df_derived['millisSinceGpsEpoch'].unique()

# The timestamps in derived are one epoch ahead. We need to map each epoch
# in derived to the prior one (in Raw).
indexes = np.searchsorted(raw_timestamps, derived_timestamps)
from_t_to_fix_derived = dict(zip(derived_timestamps, raw_timestamps[indexes-1]))
df_derived['millisSinceGpsEpoch'] = np.array(list(map(lambda v: from_t_to_fix_derived[v], df_derived['millisSinceGpsEpoch'])))

# %%
delta_millis = df_derived['millisSinceGpsEpoch'] - df_derived['receivedSvTimeInGpsNanos']/1e6
good_signals = (delta_millis > 0) & (delta_millis < 300)
df_derived = df_derived[good_signals].copy()

# %% [markdown]
# ### Save To Pickle File

# %%
output = merge_data(test_df, None, df_derived, gnss_dict)
output.to_pickle(str(PATH / "gsdc_test.pkl.gzip"))
print(output.shape)
output.head()
# Out:
# Truth Data Start
# Truth Data Fin
# Derived Data Start
# Derived Data Fin
# Gnss Log Data Start
#   0%|          | 0/7 [00:00<?, ?it/s]
# Gnss Log Data Fin
# (91486, 102)
#         collectionName phoneName  millisSinceGpsEpoch     latDeg      lngDeg  \
# 0  2020-05-15-US-MTV-1  Pixel4XL        1273608752446  37.416623 -122.082055
# 1  2020-05-15-US-MTV-1  Pixel4XL        1273608753446  37.416590 -122.082073
# 2  2020-05-15-US-MTV-1  Pixel4XL        1273608754446  37.416593 -122.082084
# 3  2020-05-15-US-MTV-1  Pixel4XL        1273608755446  37.416580 -122.082067
# 4  2020-05-15-US-MTV-1  Pixel4XL        1273608756446  37.416594 -122.082065
#
#    heightAboveWgs84EllipsoidM                         phone  \
# 0                      -24.21  2020-05-15-US-MTV-1_Pixel4XL
# 1                      -29.97  2020-05-15-US-MTV-1_Pixel4XL
# 2                      -29.85  2020-05-15-US-MTV-1_Pixel4XL
# 3                      -28.53  2020-05-15-US-MTV-1_Pixel4XL
# 4                      -27.70  2020-05-15-US-MTV-1_Pixel4XL
#
#    constellationType  svid signalType  ...  SnrInDb  ConstellationType_Raw  \
# 0                3.0  21.0     GLO_G1  ...      NaN                      1
# 1                3.0  21.0     GLO_G1  ...      NaN                      1
# 2                3.0  21.0     GLO_G1  ...      NaN                      1
# 3                3.0  21.0     GLO_G1  ...      NaN                      6
# 4                3.0  21.0     GLO_G1  ...      NaN                      1
#
#    AgcDb  BasebandCn0DbHz_Raw  FullInterSignalBiasNanos  \
# 0   1.88                  NaN                       NaN
# 1   2.33                  NaN                       NaN
# 2   1.99                  NaN                       NaN
# 3   1.74                  NaN                       NaN
# 4   2.08                  NaN                       NaN
#
#    FullInterSignalBiasUncertaintyNanos  SatelliteInterSignalBiasNanos  \
# 0                                  NaN                            NaN
# 1                                  NaN                            NaN
# 2                                  NaN                            NaN
# 3                                  NaN                            NaN
# 4                                  NaN                            NaN
#
#    SatelliteInterSignalBiasUncertaintyNanos  CodeType  \
# 0                                       NaN       NaN
# 1                                       NaN       NaN
# 2                                       NaN       NaN
# 3                                       NaN       NaN
# 4                                       NaN       NaN
#
#    ChipsetElapsedRealtimeNanos
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
# [5 rows x 102 columns]

# %%
output.info(verbose = True, memory_usage= True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 91486 entries, 0 to 91485
# Data columns (total 102 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   collectionName                             91486 non-null  object
#  1   phoneName                                  91486 non-null  object
#  2   millisSinceGpsEpoch                        91486 non-null  int64
#  3   latDeg                                     91486 non-null  float64
#  4   lngDeg                                     91486 non-null  float64
#  5   heightAboveWgs84EllipsoidM                 91486 non-null  float64
#  6   phone                                      91486 non-null  object
#  7   constellationType                          55504 non-null  float64
#  8   svid                                       55504 non-null  float64
#  9   signalType                                 55504 non-null  object
#  10  receivedSvTimeInGpsNanos                   55504 non-null  float64
#  11  xSatPosM                                   55504 non-null  float64
#  12  ySatPosM                                   55504 non-null  float64
#  13  zSatPosM                                   55504 non-null  float64
#  14  xSatVelMps                                 55504 non-null  float64
#  15  ySatVelMps                                 55504 non-null  float64
#  16  zSatVelMps                                 55504 non-null  float64
#  17  satClkBiasM                                55504 non-null  float64
#  18  satClkDriftMps                             55504 non-null  float64
#  19  rawPrM                                     55504 non-null  float64
#  20  rawPrUncM                                  55504 non-null  float64
#  21  isrbM                                      55504 non-null  float64
#  22  ionoDelayM                                 55504 non-null  float64
#  23  tropoDelayM                                55504 non-null  float64
#  24  utcTimeMillis                              46854 non-null  float64
#  25  elapsedRealtimeNanos                       46854 non-null  float64
#  26  yawDeg                                     46854 non-null  float64
#  27  rollDeg                                    46854 non-null  float64
#  28  pitchDeg                                   46854 non-null  float64
#  29  utcTimeMillis_Status                       81190 non-null  float64
#  30  SignalCount                                81190 non-null  float64
#  31  SignalIndex                                81190 non-null  float64
#  32  ConstellationType                          81190 non-null  float64
#  33  Svid                                       81190 non-null  float64
#  34  CarrierFrequencyHz                         81025 non-null  float64
#  35  Cn0DbHz                                    81190 non-null  float64
#  36  AzimuthDegrees                             81190 non-null  float64
#  37  ElevationDegrees                           81190 non-null  float64
#  38  UsedInFix                                  81190 non-null  float64
#  39  HasAlmanacData                             81190 non-null  float64
#  40  HasEphemerisData                           81190 non-null  float64
#  41  BasebandCn0DbHz                            22140 non-null  float64
#  42  utcTimeMillis_UncalMag                     80279 non-null  float64
#  43  elapsedRealtimeNanos_UncalMag              80279 non-null  float64
#  44  UncalMagXMicroT                            80279 non-null  float64
#  45  UncalMagYMicroT                            80279 non-null  float64
#  46  UncalMagZMicroT                            80279 non-null  float64
#  47  BiasXMicroT                                46854 non-null  float64
#  48  BiasYMicroT                                46854 non-null  float64
#  49  BiasZMicroT                                46854 non-null  float64
#  50  utcTimeMillis_UncalAccel                   80279 non-null  float64
#  51  elapsedRealtimeNanos_UncalAccel            80279 non-null  float64
#  52  UncalAccelXMps2                            80279 non-null  float64
#  53  UncalAccelYMps2                            80279 non-null  float64
#  54  UncalAccelZMps2                            80279 non-null  float64
#  55  BiasXMps2                                  46854 non-null  float64
#  56  BiasYMps2                                  46854 non-null  float64
#  57  BiasZMps2                                  46854 non-null  float64
#  58  utcTimeMillis_UncalGyro                    80279 non-null  float64
#  59  elapsedRealtimeNanos_UncalGyro             80279 non-null  float64
#  60  UncalGyroXRadPerSec                        80279 non-null  float64
#  61  UncalGyroYRadPerSec                        80279 non-null  float64
#  62  UncalGyroZRadPerSec                        80279 non-null  float64
#  63  DriftXRadPerSec                            46854 non-null  object
#  64  DriftYRadPerSec                            46854 non-null  float64
#  65  DriftZRadPerSec                            46854 non-null  float64
#  66  utcTimeMillis_Raw                          91486 non-null  int64
#  67  TimeNanos                                  91486 non-null  int64
#  68  LeapSecond                                 29230 non-null  float64
#  69  TimeUncertaintyNanos                       0 non-null      float64
#  70  FullBiasNanos                              91486 non-null  int64
#  71  BiasNanos                                  91486 non-null  float64
#  72  BiasUncertaintyNanos                       91486 non-null  float64
#  73  DriftNanosPerSecond                        85679 non-null  float64
#  74  DriftUncertaintyNanosPerSecond             85679 non-null  float64
#  75  HardwareClockDiscontinuityCount            91486 non-null  int64
#  76  Svid_Raw                                   91486 non-null  int64
#  77  TimeOffsetNanos                            91486 non-null  float64
#  78  State                                      91486 non-null  int64
#  79  ReceivedSvTimeNanos                        91486 non-null  int64
#  80  ReceivedSvTimeUncertaintyNanos             91486 non-null  int64
#  81  Cn0DbHz_Raw                                91486 non-null  float64
#  82  PseudorangeRateMetersPerSecond             91486 non-null  float64
#  83  PseudorangeRateUncertaintyMetersPerSecond  91486 non-null  float64
#  84  AccumulatedDeltaRangeState                 91486 non-null  int64
#  85  AccumulatedDeltaRangeMeters                91486 non-null  float64
#  86  AccumulatedDeltaRangeUncertaintyMeters     91486 non-null  float64
#  87  CarrierFrequencyHz_Raw                     91486 non-null  float64
#  88  CarrierCycles                              0 non-null      float64
#  89  CarrierPhase                               0 non-null      float64
#  90  CarrierPhaseUncertainty                    0 non-null      float64
#  91  MultipathIndicator                         91486 non-null  int64
#  92  SnrInDb                                    0 non-null      float64
#  93  ConstellationType_Raw                      91486 non-null  int64
#  94  AgcDb                                      87200 non-null  float64
#  95  BasebandCn0DbHz_Raw                        26395 non-null  float64
#  96  FullInterSignalBiasNanos                   26395 non-null  float64
#  97  FullInterSignalBiasUncertaintyNanos        26395 non-null  float64
#  98  SatelliteInterSignalBiasNanos              17338 non-null  float64
#  99  SatelliteInterSignalBiasUncertaintyNanos   17338 non-null  float64
#  100 CodeType                                   58061 non-null  object
#  101 ChipsetElapsedRealtimeNanos                42066 non-null  float64
# dtypes: float64(84), int64(12), object(6)
# memory usage: 71.9+ MB

# %%
del df_derived, gnss_dict, output

# %%
# %clear

# %% [markdown]
# # Load Pickle File

# %%
import numpy as np
import pandas as pd
from glob import glob
import os
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from pathlib import Path
import plotly.express as px

# %%
PATH = Path("../input/google-smartphone-decimeter-challenge")

# %%
df_train = pd.read_pickle(str(PATH / "gsdc_train.pkl.gzip"))

# %%
print(df_train.shape)
df_train.head()
# Out:
# (131342, 110)
#         collectionName       phoneName  millisSinceGpsEpoch     latDeg  \
# 0  2020-05-14-US-MTV-1          Pixel4        1273529463442  37.423575
# 1  2020-05-14-US-MTV-1          Pixel4        1273529464442  37.423578
# 2  2020-05-14-US-MTV-1          Pixel4        1273529465442  37.423573
# 3  2020-05-14-US-MTV-1          Pixel4        1273529466442  37.423583
# 4  2020-05-14-US-MTV-1  Pixel4XLModded        1273529466449  37.423574
#
#        lngDeg  heightAboveWgs84EllipsoidM                               phone  \
# 0 -122.094091                      -34.06          2020-05-14-US-MTV-1_Pixel4
# 1 -122.094101                      -33.29          2020-05-14-US-MTV-1_Pixel4
# 2 -122.094111                      -30.99          2020-05-14-US-MTV-1_Pixel4
# 3 -122.094121                      -32.83          2020-05-14-US-MTV-1_Pixel4
# 4 -122.094137                      -33.20  2020-05-14-US-MTV-1_Pixel4XLModded
#
#    timeSinceFirstFixSeconds  hDop  vDop  ...  SnrInDb  ConstellationType_Raw  \
# 0                    551.44   1.1   0.0  ...      NaN                      1
# 1                    552.44   1.1   0.0  ...      NaN                      1
# 2                    553.44   1.1   0.0  ...      NaN                      1
# 3                    554.44   1.1   0.0  ...      NaN                      1
# 4                    554.45   1.2   0.0  ...      NaN                      1
#
#    AgcDb  BasebandCn0DbHz_Raw  FullInterSignalBiasNanos  \
# 0  -0.61                  NaN                       NaN
# 1  -0.12                  NaN                       NaN
# 2   0.02                  NaN                       NaN
# 3   0.07                  NaN                       NaN
# 4   0.99                  NaN                       NaN
#
#    FullInterSignalBiasUncertaintyNanos  SatelliteInterSignalBiasNanos  \
# 0                                  NaN                            NaN
# 1                                  NaN                            NaN
# 2                                  NaN                            NaN
# 3                                  NaN                            NaN
# 4                                  NaN                            NaN
#
#   SatelliteInterSignalBiasUncertaintyNanos  CodeType  \
# 0                                      NaN       NaN
# 1                                      NaN       NaN
# 2                                      NaN       NaN
# 3                                      NaN       NaN
# 4                                      NaN       NaN
#
#    ChipsetElapsedRealtimeNanos
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
# [5 rows x 110 columns]

# %%
df_train.info(verbose = True, memory_usage= True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 131342 entries, 0 to 131341
# Data columns (total 110 columns):
#  #   Column                                     Non-Null Count   Dtype
# ---  ------                                     --------------   -----
#  0   collectionName                             131342 non-null  object
#  1   phoneName                                  131342 non-null  object
#  2   millisSinceGpsEpoch                        131342 non-null  int64
#  3   latDeg                                     131342 non-null  float64
#  4   lngDeg                                     131342 non-null  float64
#  5   heightAboveWgs84EllipsoidM                 131342 non-null  float64
#  6   phone                                      131342 non-null  object
#  7   timeSinceFirstFixSeconds                   131342 non-null  float64
#  8   hDop                                       131342 non-null  float64
#  9   vDop                                       131342 non-null  float64
#  10  speedMps                                   131342 non-null  float64
#  11  courseDegree                               131342 non-null  float64
#  12  t_latDeg                                   131342 non-null  float64
#  13  t_lngDeg                                   131342 non-null  float64
#  14  t_heightAboveWgs84EllipsoidM               131342 non-null  float64
#  15  constellationType                          69268 non-null   float64
#  16  svid                                       69268 non-null   float64
#  17  signalType                                 69268 non-null   object
#  18  receivedSvTimeInGpsNanos                   69268 non-null   float64
#  19  xSatPosM                                   69268 non-null   float64
#  20  ySatPosM                                   69268 non-null   float64
#  21  zSatPosM                                   69268 non-null   float64
#  22  xSatVelMps                                 69268 non-null   float64
#  23  ySatVelMps                                 69268 non-null   float64
#  24  zSatVelMps                                 69268 non-null   float64
#  25  satClkBiasM                                69268 non-null   float64
#  26  satClkDriftMps                             69268 non-null   float64
#  27  rawPrM                                     69268 non-null   float64
#  28  rawPrUncM                                  69268 non-null   float64
#  29  isrbM                                      69268 non-null   float64
#  30  ionoDelayM                                 69268 non-null   float64
#  31  tropoDelayM                                69268 non-null   float64
#  32  utcTimeMillis                              36607 non-null   float64
#  33  elapsedRealtimeNanos                       36607 non-null   float64
#  34  yawDeg                                     36607 non-null   float64
#  35  rollDeg                                    36607 non-null   float64
#  36  pitchDeg                                   36607 non-null   float64
#  37  utcTimeMillis_Status                       112002 non-null  float64
#  38  SignalCount                                112002 non-null  float64
#  39  SignalIndex                                112002 non-null  float64
#  40  ConstellationType                          112002 non-null  float64
#  41  Svid                                       112002 non-null  float64
#  42  CarrierFrequencyHz                         111826 non-null  float64
#  43  Cn0DbHz                                    112002 non-null  float64
#  44  AzimuthDegrees                             112002 non-null  float64
#  45  ElevationDegrees                           112002 non-null  float64
#  46  UsedInFix                                  112002 non-null  float64
#  47  HasAlmanacData                             112002 non-null  float64
#  48  HasEphemerisData                           112002 non-null  float64
#  49  BasebandCn0DbHz                            20406 non-null   float64
#  50  utcTimeMillis_UncalMag                     113834 non-null  float64
#  51  elapsedRealtimeNanos_UncalMag              113834 non-null  float64
#  52  UncalMagXMicroT                            113834 non-null  float64
#  53  UncalMagYMicroT                            113834 non-null  float64
#  54  UncalMagZMicroT                            113834 non-null  float64
#  55  BiasXMicroT                                74779 non-null   float64
#  56  BiasYMicroT                                74779 non-null   float64
#  57  BiasZMicroT                                74779 non-null   float64
#  58  utcTimeMillis_UncalAccel                   113834 non-null  float64
#  59  elapsedRealtimeNanos_UncalAccel            113834 non-null  float64
#  60  UncalAccelXMps2                            113834 non-null  float64
#  61  UncalAccelYMps2                            113834 non-null  float64
#  62  UncalAccelZMps2                            113834 non-null  float64
#  63  BiasXMps2                                  74779 non-null   float64
#  64  BiasYMps2                                  74779 non-null   float64
#  65  BiasZMps2                                  74779 non-null   float64
#  66  utcTimeMillis_UncalGyro                    113834 non-null  float64
#  67  elapsedRealtimeNanos_UncalGyro             113834 non-null  float64
#  68  UncalGyroXRadPerSec                        113834 non-null  float64
#  69  UncalGyroYRadPerSec                        113834 non-null  float64
#  70  UncalGyroZRadPerSec                        113834 non-null  float64
#  71  DriftXRadPerSec                            74779 non-null   float64
#  72  DriftYRadPerSec                            74779 non-null   float64
#  73  DriftZRadPerSec                            74779 non-null   float64
#  74  utcTimeMillis_Raw                          131342 non-null  int64
#  75  TimeNanos                                  131342 non-null  int64
#  76  LeapSecond                                 45928 non-null   float64
#  77  TimeUncertaintyNanos                       0 non-null       float64
#  78  FullBiasNanos                              131342 non-null  int64
#  79  BiasNanos                                  131342 non-null  float64
#  80  BiasUncertaintyNanos                       131342 non-null  float64
#  81  DriftNanosPerSecond                        117173 non-null  float64
#  82  DriftUncertaintyNanosPerSecond             117173 non-null  float64
#  83  HardwareClockDiscontinuityCount            131342 non-null  int64
#  84  Svid_Raw                                   131342 non-null  int64
#  85  TimeOffsetNanos                            131342 non-null  float64
#  86  State                                      131342 non-null  int64
#  87  ReceivedSvTimeNanos                        131342 non-null  int64
#  88  ReceivedSvTimeUncertaintyNanos             131342 non-null  int64
#  89  Cn0DbHz_Raw                                131342 non-null  float64
#  90  PseudorangeRateMetersPerSecond             131342 non-null  float64
#  91  PseudorangeRateUncertaintyMetersPerSecond  131342 non-null  float64
#  92  AccumulatedDeltaRangeState                 131342 non-null  int64
#  93  AccumulatedDeltaRangeMeters                131342 non-null  float64
#  94  AccumulatedDeltaRangeUncertaintyMeters     131342 non-null  float64
#  95  CarrierFrequencyHz_Raw                     131342 non-null  float64
#  96  CarrierCycles                              0 non-null       float64
#  97  CarrierPhase                               0 non-null       float64
#  98  CarrierPhaseUncertainty                    0 non-null       float64
#  99  MultipathIndicator                         131342 non-null  int64
#  100 SnrInDb                                    0 non-null       float64
#  101 ConstellationType_Raw                      131342 non-null  int64
#  102 AgcDb                                      123461 non-null  float64
#  103 BasebandCn0DbHz_Raw                        25995 non-null   float64
#  104 FullInterSignalBiasNanos                   25995 non-null   float64
#  105 FullInterSignalBiasUncertaintyNanos        25995 non-null   float64
#  106 SatelliteInterSignalBiasNanos              14204 non-null   float64
#  107 SatelliteInterSignalBiasUncertaintyNanos   14204 non-null   float64
#  108 CodeType                                   83102 non-null   object
#  109 ChipsetElapsedRealtimeNanos                48613 non-null   float64
# dtypes: float64(93), int64(12), object(5)
# memory usage: 111.2+ MB

# %%
df_test = pd.read_pickle(str(PATH / "gsdc_test.pkl.gzip"))

# %%
print(df_test.shape)
df_test.head()
# Out:
# (91486, 102)
#         collectionName phoneName  millisSinceGpsEpoch     latDeg      lngDeg  \
# 0  2020-05-15-US-MTV-1  Pixel4XL        1273608752446  37.416623 -122.082055
# 1  2020-05-15-US-MTV-1  Pixel4XL        1273608753446  37.416590 -122.082073
# 2  2020-05-15-US-MTV-1  Pixel4XL        1273608754446  37.416593 -122.082084
# 3  2020-05-15-US-MTV-1  Pixel4XL        1273608755446  37.416580 -122.082067
# 4  2020-05-15-US-MTV-1  Pixel4XL        1273608756446  37.416594 -122.082065
#
#    heightAboveWgs84EllipsoidM                         phone  \
# 0                      -24.21  2020-05-15-US-MTV-1_Pixel4XL
# 1                      -29.97  2020-05-15-US-MTV-1_Pixel4XL
# 2                      -29.85  2020-05-15-US-MTV-1_Pixel4XL
# 3                      -28.53  2020-05-15-US-MTV-1_Pixel4XL
# 4                      -27.70  2020-05-15-US-MTV-1_Pixel4XL
#
#    constellationType  svid signalType  ...  SnrInDb  ConstellationType_Raw  \
# 0                3.0  21.0     GLO_G1  ...      NaN                      1
# 1                3.0  21.0     GLO_G1  ...      NaN                      1
# 2                3.0  21.0     GLO_G1  ...      NaN                      1
# 3                3.0  21.0     GLO_G1  ...      NaN                      6
# 4                3.0  21.0     GLO_G1  ...      NaN                      1
#
#    AgcDb  BasebandCn0DbHz_Raw  FullInterSignalBiasNanos  \
# 0   1.88                  NaN                       NaN
# 1   2.33                  NaN                       NaN
# 2   1.99                  NaN                       NaN
# 3   1.74                  NaN                       NaN
# 4   2.08                  NaN                       NaN
#
#    FullInterSignalBiasUncertaintyNanos  SatelliteInterSignalBiasNanos  \
# 0                                  NaN                            NaN
# 1                                  NaN                            NaN
# 2                                  NaN                            NaN
# 3                                  NaN                            NaN
# 4                                  NaN                            NaN
#
#    SatelliteInterSignalBiasUncertaintyNanos  CodeType  \
# 0                                       NaN       NaN
# 1                                       NaN       NaN
# 2                                       NaN       NaN
# 3                                       NaN       NaN
# 4                                       NaN       NaN
#
#    ChipsetElapsedRealtimeNanos
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
# [5 rows x 102 columns]

# %%
df_test.info(verbose = True, memory_usage= True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 91486 entries, 0 to 91485
# Data columns (total 102 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   collectionName                             91486 non-null  object
#  1   phoneName                                  91486 non-null  object
#  2   millisSinceGpsEpoch                        91486 non-null  int64
#  3   latDeg                                     91486 non-null  float64
#  4   lngDeg                                     91486 non-null  float64
#  5   heightAboveWgs84EllipsoidM                 91486 non-null  float64
#  6   phone                                      91486 non-null  object
#  7   constellationType                          55504 non-null  float64
#  8   svid                                       55504 non-null  float64
#  9   signalType                                 55504 non-null  object
#  10  receivedSvTimeInGpsNanos                   55504 non-null  float64
#  11  xSatPosM                                   55504 non-null  float64
#  12  ySatPosM                                   55504 non-null  float64
#  13  zSatPosM                                   55504 non-null  float64
#  14  xSatVelMps                                 55504 non-null  float64
#  15  ySatVelMps                                 55504 non-null  float64
#  16  zSatVelMps                                 55504 non-null  float64
#  17  satClkBiasM                                55504 non-null  float64
#  18  satClkDriftMps                             55504 non-null  float64
#  19  rawPrM                                     55504 non-null  float64
#  20  rawPrUncM                                  55504 non-null  float64
#  21  isrbM                                      55504 non-null  float64
#  22  ionoDelayM                                 55504 non-null  float64
#  23  tropoDelayM                                55504 non-null  float64
#  24  utcTimeMillis                              46854 non-null  float64
#  25  elapsedRealtimeNanos                       46854 non-null  float64
#  26  yawDeg                                     46854 non-null  float64
#  27  rollDeg                                    46854 non-null  float64
#  28  pitchDeg                                   46854 non-null  float64
#  29  utcTimeMillis_Status                       81190 non-null  float64
#  30  SignalCount                                81190 non-null  float64
#  31  SignalIndex                                81190 non-null  float64
#  32  ConstellationType                          81190 non-null  float64
#  33  Svid                                       81190 non-null  float64
#  34  CarrierFrequencyHz                         81025 non-null  float64
#  35  Cn0DbHz                                    81190 non-null  float64
#  36  AzimuthDegrees                             81190 non-null  float64
#  37  ElevationDegrees                           81190 non-null  float64
#  38  UsedInFix                                  81190 non-null  float64
#  39  HasAlmanacData                             81190 non-null  float64
#  40  HasEphemerisData                           81190 non-null  float64
#  41  BasebandCn0DbHz                            22140 non-null  float64
#  42  utcTimeMillis_UncalMag                     80279 non-null  float64
#  43  elapsedRealtimeNanos_UncalMag              80279 non-null  float64
#  44  UncalMagXMicroT                            80279 non-null  float64
#  45  UncalMagYMicroT                            80279 non-null  float64
#  46  UncalMagZMicroT                            80279 non-null  float64
#  47  BiasXMicroT                                46854 non-null  float64
#  48  BiasYMicroT                                46854 non-null  float64
#  49  BiasZMicroT                                46854 non-null  float64
#  50  utcTimeMillis_UncalAccel                   80279 non-null  float64
#  51  elapsedRealtimeNanos_UncalAccel            80279 non-null  float64
#  52  UncalAccelXMps2                            80279 non-null  float64
#  53  UncalAccelYMps2                            80279 non-null  float64
#  54  UncalAccelZMps2                            80279 non-null  float64
#  55  BiasXMps2                                  46854 non-null  float64
#  56  BiasYMps2                                  46854 non-null  float64
#  57  BiasZMps2                                  46854 non-null  float64
#  58  utcTimeMillis_UncalGyro                    80279 non-null  float64
#  59  elapsedRealtimeNanos_UncalGyro             80279 non-null  float64
#  60  UncalGyroXRadPerSec                        80279 non-null  float64
#  61  UncalGyroYRadPerSec                        80279 non-null  float64
#  62  UncalGyroZRadPerSec                        80279 non-null  float64
#  63  DriftXRadPerSec                            46854 non-null  object
#  64  DriftYRadPerSec                            46854 non-null  float64
#  65  DriftZRadPerSec                            46854 non-null  float64
#  66  utcTimeMillis_Raw                          91486 non-null  int64
#  67  TimeNanos                                  91486 non-null  int64
#  68  LeapSecond                                 29230 non-null  float64
#  69  TimeUncertaintyNanos                       0 non-null      float64
#  70  FullBiasNanos                              91486 non-null  int64
#  71  BiasNanos                                  91486 non-null  float64
#  72  BiasUncertaintyNanos                       91486 non-null  float64
#  73  DriftNanosPerSecond                        85679 non-null  float64
#  74  DriftUncertaintyNanosPerSecond             85679 non-null  float64
#  75  HardwareClockDiscontinuityCount            91486 non-null  int64
#  76  Svid_Raw                                   91486 non-null  int64
#  77  TimeOffsetNanos                            91486 non-null  float64
#  78  State                                      91486 non-null  int64
#  79  ReceivedSvTimeNanos                        91486 non-null  int64
#  80  ReceivedSvTimeUncertaintyNanos             91486 non-null  int64
#  81  Cn0DbHz_Raw                                91486 non-null  float64
#  82  PseudorangeRateMetersPerSecond             91486 non-null  float64
#  83  PseudorangeRateUncertaintyMetersPerSecond  91486 non-null  float64
#  84  AccumulatedDeltaRangeState                 91486 non-null  int64
#  85  AccumulatedDeltaRangeMeters                91486 non-null  float64
#  86  AccumulatedDeltaRangeUncertaintyMeters     91486 non-null  float64
#  87  CarrierFrequencyHz_Raw                     91486 non-null  float64
#  88  CarrierCycles                              0 non-null      float64
#  89  CarrierPhase                               0 non-null      float64
#  90  CarrierPhaseUncertainty                    0 non-null      float64
#  91  MultipathIndicator                         91486 non-null  int64
#  92  SnrInDb                                    0 non-null      float64
#  93  ConstellationType_Raw                      91486 non-null  int64
#  94  AgcDb                                      87200 non-null  float64
#  95  BasebandCn0DbHz_Raw                        26395 non-null  float64
#  96  FullInterSignalBiasNanos                   26395 non-null  float64
#  97  FullInterSignalBiasUncertaintyNanos        26395 non-null  float64
#  98  SatelliteInterSignalBiasNanos              17338 non-null  float64
#  99  SatelliteInterSignalBiasUncertaintyNanos   17338 non-null  float64
#  100 CodeType                                   58061 non-null  object
#  101 ChipsetElapsedRealtimeNanos                42066 non-null  float64
# dtypes: float64(84), int64(12), object(6)
# memory usage: 71.9+ MB

# %%
submission = pd.read_csv("../input/google-smartphone-decimeter-challenge/sample_submission.csv")
submission.shape
# Out:
# (91486, 4)

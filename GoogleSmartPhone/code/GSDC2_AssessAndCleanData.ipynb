# %% [markdown]
# # Load Libraries

# %%
import numpy as np
import pandas as pd
from glob import glob
import os
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from pathlib import Path
import plotly.express as px

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %% [markdown]
# # Set Path

# %%
data_dir = Path("../input/google-smartphone-decimeter-challenge")

# %% [markdown]
# # Load Data

# %%
df_train = pd.read_pickle(str(data_dir / "gsdc_train.pkl.gzip"))

# %% [markdown]
# # Check Dataset

# %%
print(df_train.shape)
df_train.head()
# Out:
# (131342, 110)
#         collectionName       phoneName  millisSinceGpsEpoch     latDeg  \
# 0  2020-05-14-US-MTV-1          Pixel4        1273529463442  37.423575
# 1  2020-05-14-US-MTV-1          Pixel4        1273529464442  37.423578
# 2  2020-05-14-US-MTV-1          Pixel4        1273529465442  37.423573
# 3  2020-05-14-US-MTV-1          Pixel4        1273529466442  37.423583
# 4  2020-05-14-US-MTV-1  Pixel4XLModded        1273529466449  37.423574
#
#        lngDeg  heightAboveWgs84EllipsoidM                               phone  \
# 0 -122.094091                      -34.06          2020-05-14-US-MTV-1_Pixel4
# 1 -122.094101                      -33.29          2020-05-14-US-MTV-1_Pixel4
# 2 -122.094111                      -30.99          2020-05-14-US-MTV-1_Pixel4
# 3 -122.094121                      -32.83          2020-05-14-US-MTV-1_Pixel4
# 4 -122.094137                      -33.20  2020-05-14-US-MTV-1_Pixel4XLModded
#
#    timeSinceFirstFixSeconds  hDop  vDop  ...  HasEphemerisData  \
# 0                    551.44   1.1   0.0  ...               NaN
# 1                    552.44   1.1   0.0  ...               NaN
# 2                    553.44   1.1   0.0  ...               NaN
# 3                    554.44   1.1   0.0  ...               NaN
# 4                    554.45   1.2   0.0  ...               NaN
#
#    BasebandCn0DbHz_y  utcTimeMillis_y  elapsedRealtimeNanos_y  \
# 0                NaN              NaN                     NaN
# 1                NaN              NaN                     NaN
# 2                NaN              NaN                     NaN
# 3                NaN              NaN                     NaN
# 4                NaN              NaN                     NaN
#
#    UncalMagXMicroT  UncalMagYMicroT  UncalMagZMicroT BiasXMicroT  BiasYMicroT  \
# 0              NaN              NaN              NaN         NaN          NaN
# 1              NaN              NaN              NaN         NaN          NaN
# 2              NaN              NaN              NaN         NaN          NaN
# 3              NaN              NaN              NaN         NaN          NaN
# 4              NaN              NaN              NaN         NaN          NaN
#
#    BiasZMicroT
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 110 columns]

# %%
df_train.info(verbose = True, memory_usage= True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 131342 entries, 0 to 131341
# Data columns (total 110 columns):
#  #   Column                                     Non-Null Count   Dtype
# ---  ------                                     --------------   -----
#  0   collectionName                             131342 non-null  object
#  1   phoneName                                  131342 non-null  object
#  2   millisSinceGpsEpoch                        131342 non-null  int64
#  3   latDeg                                     131342 non-null  float64
#  4   lngDeg                                     131342 non-null  float64
#  5   heightAboveWgs84EllipsoidM                 131342 non-null  float64
#  6   phone                                      131342 non-null  object
#  7   timeSinceFirstFixSeconds                   131342 non-null  float64
#  8   hDop                                       131342 non-null  float64
#  9   vDop                                       131342 non-null  float64
#  10  speedMps                                   131342 non-null  float64
#  11  courseDegree                               131342 non-null  float64
#  12  t_latDeg                                   131342 non-null  float64
#  13  t_lngDeg                                   131342 non-null  float64
#  14  t_heightAboveWgs84EllipsoidM               131342 non-null  float64
#  15  constellationType                          131342 non-null  int64
#  16  svid                                       131342 non-null  int64
#  17  signalType                                 131342 non-null  object
#  18  receivedSvTimeInGpsNanos                   131342 non-null  int64
#  19  xSatPosM                                   131342 non-null  float64
#  20  ySatPosM                                   131342 non-null  float64
#  21  zSatPosM                                   131342 non-null  float64
#  22  xSatVelMps                                 131342 non-null  float64
#  23  ySatVelMps                                 131342 non-null  float64
#  24  zSatVelMps                                 131342 non-null  float64
#  25  satClkBiasM                                131342 non-null  float64
#  26  satClkDriftMps                             131342 non-null  float64
#  27  rawPrM                                     131342 non-null  float64
#  28  rawPrUncM                                  131342 non-null  float64
#  29  isrbM                                      131342 non-null  float64
#  30  ionoDelayM                                 131342 non-null  float64
#  31  tropoDelayM                                131342 non-null  float64
#  32  utcTimeMillis_x                            0 non-null       float64
#  33  elapsedRealtimeNanos_x                     0 non-null       float64
#  34  UncalGyroXRadPerSec                        0 non-null       float64
#  35  UncalGyroYRadPerSec                        0 non-null       float64
#  36  UncalGyroZRadPerSec                        0 non-null       float64
#  37  DriftXRadPerSec                            0 non-null       float64
#  38  DriftYRadPerSec                            0 non-null       float64
#  39  DriftZRadPerSec                            0 non-null       float64
#  40  utcTimeMillis_y                            0 non-null       float64
#  41  elapsedRealtimeNanos_y                     0 non-null       float64
#  42  UncalAccelXMps2                            0 non-null       float64
#  43  UncalAccelYMps2                            0 non-null       float64
#  44  UncalAccelZMps2                            0 non-null       float64
#  45  BiasXMps2                                  0 non-null       float64
#  46  BiasYMps2                                  0 non-null       float64
#  47  BiasZMps2                                  0 non-null       float64
#  48  utcTimeMillis_x                            0 non-null       float64
#  49  elapsedRealtimeNanos_x                     0 non-null       float64
#  50  yawDeg                                     0 non-null       float64
#  51  rollDeg                                    0 non-null       float64
#  52  pitchDeg                                   0 non-null       float64
#  53  utcTimeMillis_y                            0 non-null       float64
#  54  TimeNanos                                  0 non-null       float64
#  55  LeapSecond                                 0 non-null       float64
#  56  TimeUncertaintyNanos                       0 non-null       float64
#  57  FullBiasNanos                              0 non-null       float64
#  58  BiasNanos                                  0 non-null       float64
#  59  BiasUncertaintyNanos                       0 non-null       float64
#  60  DriftNanosPerSecond                        0 non-null       float64
#  61  DriftUncertaintyNanosPerSecond             0 non-null       float64
#  62  HardwareClockDiscontinuityCount            0 non-null       float64
#  63  Svid_x                                     0 non-null       float64
#  64  TimeOffsetNanos                            0 non-null       float64
#  65  State                                      0 non-null       float64
#  66  ReceivedSvTimeNanos                        0 non-null       float64
#  67  ReceivedSvTimeUncertaintyNanos             0 non-null       float64
#  68  Cn0DbHz_x                                  0 non-null       float64
#  69  PseudorangeRateMetersPerSecond             0 non-null       float64
#  70  PseudorangeRateUncertaintyMetersPerSecond  0 non-null       float64
#  71  AccumulatedDeltaRangeState                 0 non-null       float64
#  72  AccumulatedDeltaRangeMeters                0 non-null       float64
#  73  AccumulatedDeltaRangeUncertaintyMeters     0 non-null       float64
#  74  CarrierFrequencyHz_x                       0 non-null       float64
#  75  CarrierCycles                              0 non-null       float64
#  76  CarrierPhase                               0 non-null       float64
#  77  CarrierPhaseUncertainty                    0 non-null       float64
#  78  MultipathIndicator                         0 non-null       float64
#  79  SnrInDb                                    0 non-null       float64
#  80  ConstellationType_x                        0 non-null       float64
#  81  AgcDb                                      0 non-null       float64
#  82  BasebandCn0DbHz_x                          0 non-null       float64
#  83  FullInterSignalBiasNanos                   0 non-null       float64
#  84  FullInterSignalBiasUncertaintyNanos        0 non-null       float64
#  85  SatelliteInterSignalBiasNanos              0 non-null       float64
#  86  SatelliteInterSignalBiasUncertaintyNanos   0 non-null       float64
#  87  CodeType                                   0 non-null       object
#  88  ChipsetElapsedRealtimeNanos                0 non-null       float64
#  89  utcTimeMillis_x                            0 non-null       float64
#  90  SignalCount                                0 non-null       float64
#  91  SignalIndex                                0 non-null       float64
#  92  ConstellationType_y                        0 non-null       float64
#  93  Svid_y                                     0 non-null       float64
#  94  CarrierFrequencyHz_y                       0 non-null       float64
#  95  Cn0DbHz_y                                  0 non-null       float64
#  96  AzimuthDegrees                             0 non-null       float64
#  97  ElevationDegrees                           0 non-null       float64
#  98  UsedInFix                                  0 non-null       float64
#  99  HasAlmanacData                             0 non-null       float64
#  100 HasEphemerisData                           0 non-null       float64
#  101 BasebandCn0DbHz_y                          0 non-null       float64
#  102 utcTimeMillis_y                            0 non-null       float64
#  103 elapsedRealtimeNanos_y                     0 non-null       float64
#  104 UncalMagXMicroT                            0 non-null       float64
#  105 UncalMagYMicroT                            0 non-null       float64
#  106 UncalMagZMicroT                            0 non-null       float64
#  107 BiasXMicroT                                0 non-null       float64
#  108 BiasYMicroT                                0 non-null       float64
#  109 BiasZMicroT                                0 non-null       float64
# dtypes: float64(101), int64(4), object(5)
# memory usage: 111.2+ MB

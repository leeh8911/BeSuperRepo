# %% [markdown]
# # references
# 1. https://www.kaggle.com/columbia2131/device-eda-interpolate-by-removing-device-en-ja

# %% [markdown]
# # Load Libraries

# %%
import numpy as np
import pandas as pd
from glob import glob
import os
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from pathlib import Path
import plotly.express as px
import seaborn as sns

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
notebookName = 'Baseline'
PATH = Path(f"./models/{notebookName}")

# %%
if os.path.isdir(PATH):
    dir_list = os.listdir(PATH)
    num_files = 0
    while True:
        if os.path.isfile(str(PATH / f"{num_files}")):
            print(num_files)
            num_files += 1
        else:
            break
else:
    os.mkdir(PATH)
    num_files = 0
# Out:
# 0
# 1
# 2
# 3

# %%
num_files
# Out:
# 4

# %%
RANDOM_STATE = 1990
lr = 0.0005
batch_size = 128
EPOCH_NUM = 1000

torch.manual_seed(RANDOM_STATE)

experience_name = f"{num_files}"
checkpoint_name = "check_point"
model_name = str("model - " + experience_name)
param_name = str("param - " + experience_name)
result_name = str("result - " + experience_name)

dummy_path = str(PATH / f"{num_files}")
checkpoint_path = str(PATH / f"{checkpoint_name}.pth")
model_path = str(PATH / f"{model_name}.pth")
param_path = str(PATH / f"{param_name}.pth")
result_path = str(PATH / f"{result_name}.csv")
model_path, param_path, result_path
# Out:
# ('models\\Baseline\\model - 4.pth',
#  'models\\Baseline\\param - 4.pth',
#  'models\\Baseline\\result - 4.csv')

# %% [markdown]
# # Useful Functions

# %%
def calc_haversine(lat1, lon1, lat2, lon2):
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat / 2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2.0)**2
    
    c = 2 * np.arcsin(a ** 0.5)
    dist = 6_367_000 * c
    return dist

# %%
def check_score(input_df: pd.DataFrame) -> pd.DataFrame:
    output_df = input_df.copy()
    
    output_df['meter'] = input_df.apply(
        lambda r: calc_haversine(
            r.latDeg, r.lngDeg, r.t_latDeg, r.t_lngDeg
        ),
        axis=1
    )

    meter_score = output_df['meter'].mean()
    print(f'error meter: {meter_score}')

    scores = []
    for phone in output_df['phone'].unique():
        _index = output_df['phone']==phone
        p_50 = np.percentile(output_df.loc[_index, 'meter'], 50)
        p_95 = np.percentile(output_df.loc[_index, 'meter'], 95)
        scores.append(p_50)
        scores.append(p_95)

    score = sum(scores) / len(scores)
    print(f'score: {score}')
    
    return output_df, meter_score , score

# %%
def check_score_np(predict:torch.Tensor, target:torch.Tensor):
    m = []
    predict = predict.detach().numpy()
    target = target.detach().numpy()
    for i in range(predict.shape[0]):
        temp = calc_haversine(predict[i,0], predict[i,1], target[i,0], target[i,1])
        m.append(temp)
    
    m = np.array(m)
    score = (np.percentile(m, 50) + np.percentile(m, 95))/2
    
    return score

# %% [markdown]
# # Load Datasets

# %%
data_dir = Path("../input/google-smartphone-decimeter-challenge")
df_train = pd.read_pickle(str(data_dir / "gsdc_train.pkl.gzip"))

# %%
# check score
df_train, default_loss, default_meas = check_score(df_train)
# Out:
# error meter: 3.84684837499064
# score: 5.2879706490841585

# %% [markdown]
# # Feature Engineering
# ## Simple view, what is in data frame.

# %%
print(df_train.shape)
df_train.head()
# Out:
# (131342, 111)
#         collectionName       phoneName  millisSinceGpsEpoch     latDeg  \
# 0  2020-05-14-US-MTV-1          Pixel4        1273529463442  37.423575
# 1  2020-05-14-US-MTV-1          Pixel4        1273529464442  37.423578
# 2  2020-05-14-US-MTV-1          Pixel4        1273529465442  37.423573
# 3  2020-05-14-US-MTV-1          Pixel4        1273529466442  37.423583
# 4  2020-05-14-US-MTV-1  Pixel4XLModded        1273529466449  37.423574
#
#        lngDeg  heightAboveWgs84EllipsoidM                               phone  \
# 0 -122.094091                      -34.06          2020-05-14-US-MTV-1_Pixel4
# 1 -122.094101                      -33.29          2020-05-14-US-MTV-1_Pixel4
# 2 -122.094111                      -30.99          2020-05-14-US-MTV-1_Pixel4
# 3 -122.094121                      -32.83          2020-05-14-US-MTV-1_Pixel4
# 4 -122.094137                      -33.20  2020-05-14-US-MTV-1_Pixel4XLModded
#
#    utcTimeMillis_x  elapsedRealtimeNanos_x  UncalGyroXRadPerSec  ...  \
# 0     1.589494e+12            1.965654e+13            -0.000502  ...
# 1     1.589494e+12            1.965754e+13            -0.003537  ...
# 2     1.589494e+12            1.965854e+13             0.002028  ...
# 3     1.589494e+12            1.965954e+13            -0.015753  ...
# 4     1.589494e+12            1.734189e+13             0.875268  ...
#
#    ySatVelMps  zSatVelMps  satClkBiasM  satClkDriftMps        rawPrM  \
# 0     156.040    3559.757     -468.084           0.001  2.379498e+07
# 1     411.162   -3013.649    65954.431          -0.002  2.592442e+07
# 2   -2776.605    -434.445     1223.261           0.000  2.131445e+07
# 3     411.755   -3013.528    65954.426          -0.002  2.592544e+07
# 4     -81.334   -3057.885    -3909.257           0.001  2.318871e+07
#
#    rawPrUncM     isrbM  ionoDelayM  tropoDelayM     meter
# 0     11.992  1134.758      10.866       16.647  3.586842
# 1      3.897  -222.675       7.111        5.174  2.745901
# 2      1.499     0.000       4.777        3.371  1.888409
# 3      3.598  -220.611       7.113        5.183  1.213483
# 4     10.493     0.000       7.313        5.311  0.664080
#
# [5 rows x 111 columns]

# %%
for col in df_train.columns:
    print(col)
# Out:
# collectionName
# phoneName
# millisSinceGpsEpoch
# latDeg
# lngDeg
# heightAboveWgs84EllipsoidM
# phone
# utcTimeMillis_x
# elapsedRealtimeNanos_x
# UncalGyroXRadPerSec
# UncalGyroYRadPerSec
# UncalGyroZRadPerSec
# DriftXRadPerSec
# DriftYRadPerSec
# DriftZRadPerSec
# utcTimeMillis_y
# elapsedRealtimeNanos_y
# UncalMagXMicroT
# UncalMagYMicroT
# UncalMagZMicroT
# BiasXMicroT
# BiasYMicroT
# BiasZMicroT
# utcTimeMillis_x
# TimeNanos
# LeapSecond
# TimeUncertaintyNanos
# FullBiasNanos
# BiasNanos
# BiasUncertaintyNanos
# DriftNanosPerSecond
# DriftUncertaintyNanosPerSecond
# HardwareClockDiscontinuityCount
# Svid_x
# TimeOffsetNanos
# State
# ReceivedSvTimeNanos
# ReceivedSvTimeUncertaintyNanos
# Cn0DbHz_x
# PseudorangeRateMetersPerSecond
# PseudorangeRateUncertaintyMetersPerSecond
# AccumulatedDeltaRangeState
# AccumulatedDeltaRangeMeters
# AccumulatedDeltaRangeUncertaintyMeters
# CarrierFrequencyHz_x
# CarrierCycles
# CarrierPhase
# CarrierPhaseUncertainty
# MultipathIndicator
# SnrInDb
# ConstellationType_x
# AgcDb
# BasebandCn0DbHz_x
# FullInterSignalBiasNanos
# FullInterSignalBiasUncertaintyNanos
# SatelliteInterSignalBiasNanos
# SatelliteInterSignalBiasUncertaintyNanos
# CodeType
# ChipsetElapsedRealtimeNanos
# utcTimeMillis_y
# elapsedRealtimeNanos_x
# UncalAccelXMps2
# UncalAccelYMps2
# UncalAccelZMps2
# BiasXMps2
# BiasYMps2
# BiasZMps2
# utcTimeMillis_x
# elapsedRealtimeNanos_y
# yawDeg
# rollDeg
# pitchDeg
# timeSinceFirstFixSeconds
# hDop
# vDop
# speedMps
# courseDegree
# t_latDeg
# t_lngDeg
# t_heightAboveWgs84EllipsoidM
# utcTimeMillis_y
# SignalCount
# SignalIndex
# ConstellationType_y
# Svid_y
# CarrierFrequencyHz_y
# Cn0DbHz_y
# AzimuthDegrees
# ElevationDegrees
# UsedInFix
# HasAlmanacData
# HasEphemerisData
# BasebandCn0DbHz_y
# constellationType
# svid
# signalType
# receivedSvTimeInGpsNanos
# xSatPosM
# ySatPosM
# zSatPosM
# xSatVelMps
# ySatVelMps
# zSatVelMps
# satClkBiasM
# satClkDriftMps
# rawPrM
# rawPrUncM
# isrbM
# ionoDelayM
# tropoDelayM
# meter

# %% [markdown]
# WTF.. 총 컬럼의 개수가 총 111개나 된다. 물론 이는 중복된 값도 여럿 존재하고, 의미없는 수치가 포함된 결과이기도 해서 온전히 받아들일 수 없긴 하지만.. 그래도 너무 많다.
#
# ## Is There Null?
# 데이터 사이의 공백이 얼마나 있는지 우선 확인해보자.

# %%
df_train.info(verbose = True, null_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 131342 entries, 0 to 131341
# Data columns (total 111 columns):
#  #   Column                                     Non-Null Count   Dtype
# ---  ------                                     --------------   -----
#  0   collectionName                             131342 non-null  object
#  1   phoneName                                  131342 non-null  object
#  2   millisSinceGpsEpoch                        131342 non-null  int64
#  3   latDeg                                     131342 non-null  float64
#  4   lngDeg                                     131342 non-null  float64
#  5   heightAboveWgs84EllipsoidM                 131342 non-null  float64
#  6   phone                                      131342 non-null  object
#  7   utcTimeMillis_x                            113798 non-null  float64
#  8   elapsedRealtimeNanos_x                     113798 non-null  float64
#  9   UncalGyroXRadPerSec                        113798 non-null  float64
#  10  UncalGyroYRadPerSec                        113798 non-null  float64
#  11  UncalGyroZRadPerSec                        113798 non-null  float64
#  12  DriftXRadPerSec                            74725 non-null   float64
#  13  DriftYRadPerSec                            74725 non-null   float64
#  14  DriftZRadPerSec                            74725 non-null   float64
#  15  utcTimeMillis_y                            113798 non-null  float64
#  16  elapsedRealtimeNanos_y                     113798 non-null  float64
#  17  UncalMagXMicroT                            113780 non-null  float64
#  18  UncalMagYMicroT                            113780 non-null  float64
#  19  UncalMagZMicroT                            113762 non-null  float64
#  20  BiasXMicroT                                74693 non-null   float64
#  21  BiasYMicroT                                74693 non-null   float64
#  22  BiasZMicroT                                74675 non-null   float64
#  23  utcTimeMillis_x                            131342 non-null  int64
#  24  TimeNanos                                  131342 non-null  int64
#  25  LeapSecond                                 45928 non-null   float64
#  26  TimeUncertaintyNanos                       0 non-null       float64
#  27  FullBiasNanos                              131342 non-null  int64
#  28  BiasNanos                                  131342 non-null  float64
#  29  BiasUncertaintyNanos                       131342 non-null  float64
#  30  DriftNanosPerSecond                        117173 non-null  float64
#  31  DriftUncertaintyNanosPerSecond             117173 non-null  float64
#  32  HardwareClockDiscontinuityCount            131342 non-null  int64
#  33  Svid_x                                     131342 non-null  int64
#  34  TimeOffsetNanos                            131342 non-null  float64
#  35  State                                      131342 non-null  int64
#  36  ReceivedSvTimeNanos                        131342 non-null  int64
#  37  ReceivedSvTimeUncertaintyNanos             131342 non-null  int64
#  38  Cn0DbHz_x                                  131342 non-null  float64
#  39  PseudorangeRateMetersPerSecond             131342 non-null  float64
#  40  PseudorangeRateUncertaintyMetersPerSecond  131342 non-null  float64
#  41  AccumulatedDeltaRangeState                 131342 non-null  int64
#  42  AccumulatedDeltaRangeMeters                131342 non-null  float64
#  43  AccumulatedDeltaRangeUncertaintyMeters     131342 non-null  float64
#  44  CarrierFrequencyHz_x                       131342 non-null  float64
#  45  CarrierCycles                              0 non-null       float64
#  46  CarrierPhase                               0 non-null       float64
#  47  CarrierPhaseUncertainty                    0 non-null       float64
#  48  MultipathIndicator                         131342 non-null  int64
#  49  SnrInDb                                    0 non-null       float64
#  50  ConstellationType_x                        131342 non-null  int64
#  51  AgcDb                                      123464 non-null  float64
#  52  BasebandCn0DbHz_x                          25995 non-null   float64
#  53  FullInterSignalBiasNanos                   25995 non-null   float64
#  54  FullInterSignalBiasUncertaintyNanos        25995 non-null   float64
#  55  SatelliteInterSignalBiasNanos              14204 non-null   float64
#  56  SatelliteInterSignalBiasUncertaintyNanos   14204 non-null   float64
#  57  CodeType                                   83102 non-null   object
#  58  ChipsetElapsedRealtimeNanos                48614 non-null   float64
#  59  utcTimeMillis_y                            113798 non-null  float64
#  60  elapsedRealtimeNanos_x                     113798 non-null  float64
#  61  UncalAccelXMps2                            113798 non-null  float64
#  62  UncalAccelYMps2                            113798 non-null  float64
#  63  UncalAccelZMps2                            113798 non-null  float64
#  64  BiasXMps2                                  74725 non-null   float64
#  65  BiasYMps2                                  74725 non-null   float64
#  66  BiasZMps2                                  74725 non-null   float64
#  67  utcTimeMillis_x                            36589 non-null   float64
#  68  elapsedRealtimeNanos_y                     36589 non-null   float64
#  69  yawDeg                                     36589 non-null   float64
#  70  rollDeg                                    36572 non-null   float64
#  71  pitchDeg                                   36572 non-null   float64
#  72  timeSinceFirstFixSeconds                   131342 non-null  float64
#  73  hDop                                       131342 non-null  float64
#  74  vDop                                       131342 non-null  float64
#  75  speedMps                                   131342 non-null  float64
#  76  courseDegree                               131342 non-null  float64
#  77  t_latDeg                                   131342 non-null  float64
#  78  t_lngDeg                                   131342 non-null  float64
#  79  t_heightAboveWgs84EllipsoidM               131342 non-null  float64
#  80  utcTimeMillis_y                            111791 non-null  float64
#  81  SignalCount                                111791 non-null  float64
#  82  SignalIndex                                111791 non-null  float64
#  83  ConstellationType_y                        111791 non-null  float64
#  84  Svid_y                                     111791 non-null  float64
#  85  CarrierFrequencyHz_y                       111633 non-null  float64
#  86  Cn0DbHz_y                                  111791 non-null  float64
#  87  AzimuthDegrees                             111791 non-null  float64
#  88  ElevationDegrees                           111791 non-null  float64
#  89  UsedInFix                                  111791 non-null  float64
#  90  HasAlmanacData                             111791 non-null  float64
#  91  HasEphemerisData                           111791 non-null  float64
#  92  BasebandCn0DbHz_y                          20262 non-null   float64
#  93  constellationType                          131342 non-null  int64
#  94  svid                                       131342 non-null  int64
#  95  signalType                                 131342 non-null  object
#  96  receivedSvTimeInGpsNanos                   131342 non-null  int64
#  97  xSatPosM                                   131342 non-null  float64
#  98  ySatPosM                                   131342 non-null  float64
#  99  zSatPosM                                   131342 non-null  float64
#  100 xSatVelMps                                 131342 non-null  float64
#  101 ySatVelMps                                 131342 non-null  float64
#  102 zSatVelMps                                 131342 non-null  float64
#  103 satClkBiasM                                131342 non-null  float64
#  104 satClkDriftMps                             131342 non-null  float64
#  105 rawPrM                                     131342 non-null  float64
#  106 rawPrUncM                                  131342 non-null  float64
#  107 isrbM                                      131342 non-null  float64
#  108 ionoDelayM                                 131342 non-null  float64
#  109 tropoDelayM                                131342 non-null  float64
#  110 meter                                      131342 non-null  float64
# dtypes: float64(91), int64(15), object(5)
# memory usage: 112.2+ MB

# %% [markdown]
# 중간중간 아무것도 존재하지 않는 데이터도 있고, 빈 데이터가 다수 차지하는 것도 많다. 우선 데이터가 하나도 없는 것들은 모두 제거하고, 공백데이터가 몇퍼센트 존재하는지부터 확인해보자.

# %%
df_train = df_train.dropna(axis = 1, how = 'all')
print(df_train.shape)
print(df_train.columns)
df_train.head()
# Out:
# (131342, 106)
# Index(['collectionName', 'phoneName', 'millisSinceGpsEpoch', 'latDeg',
#        'lngDeg', 'heightAboveWgs84EllipsoidM', 'phone', 'utcTimeMillis_x',
#        'elapsedRealtimeNanos_x', 'UncalGyroXRadPerSec',
#        ...
#        'ySatVelMps', 'zSatVelMps', 'satClkBiasM', 'satClkDriftMps', 'rawPrM',
#        'rawPrUncM', 'isrbM', 'ionoDelayM', 'tropoDelayM', 'meter'],
#       dtype='object', length=106)
#         collectionName       phoneName  millisSinceGpsEpoch     latDeg  \
# 0  2020-05-14-US-MTV-1          Pixel4        1273529463442  37.423575
# 1  2020-05-14-US-MTV-1          Pixel4        1273529464442  37.423578
# 2  2020-05-14-US-MTV-1          Pixel4        1273529465442  37.423573
# 3  2020-05-14-US-MTV-1          Pixel4        1273529466442  37.423583
# 4  2020-05-14-US-MTV-1  Pixel4XLModded        1273529466449  37.423574
#
#        lngDeg  heightAboveWgs84EllipsoidM                               phone  \
# 0 -122.094091                      -34.06          2020-05-14-US-MTV-1_Pixel4
# 1 -122.094101                      -33.29          2020-05-14-US-MTV-1_Pixel4
# 2 -122.094111                      -30.99          2020-05-14-US-MTV-1_Pixel4
# 3 -122.094121                      -32.83          2020-05-14-US-MTV-1_Pixel4
# 4 -122.094137                      -33.20  2020-05-14-US-MTV-1_Pixel4XLModded
#
#    utcTimeMillis_x  elapsedRealtimeNanos_x  UncalGyroXRadPerSec  ...  \
# 0     1.589494e+12            1.965654e+13            -0.000502  ...
# 1     1.589494e+12            1.965754e+13            -0.003537  ...
# 2     1.589494e+12            1.965854e+13             0.002028  ...
# 3     1.589494e+12            1.965954e+13            -0.015753  ...
# 4     1.589494e+12            1.734189e+13             0.875268  ...
#
#    ySatVelMps  zSatVelMps  satClkBiasM  satClkDriftMps        rawPrM  \
# 0     156.040    3559.757     -468.084           0.001  2.379498e+07
# 1     411.162   -3013.649    65954.431          -0.002  2.592442e+07
# 2   -2776.605    -434.445     1223.261           0.000  2.131445e+07
# 3     411.755   -3013.528    65954.426          -0.002  2.592544e+07
# 4     -81.334   -3057.885    -3909.257           0.001  2.318871e+07
#
#    rawPrUncM     isrbM  ionoDelayM  tropoDelayM     meter
# 0     11.992  1134.758      10.866       16.647  3.586842
# 1      3.897  -222.675       7.111        5.174  2.745901
# 2      1.499     0.000       4.777        3.371  1.888409
# 3      3.598  -220.611       7.113        5.183  1.213483
# 4     10.493     0.000       7.313        5.311  0.664080
#
# [5 rows x 106 columns]

# %% [markdown]
# 5개의 컬럼들이 missing value로 채워져 있어 제거 되었다.

# %%
fig = plt.figure(figsize = (4, 16))
ax = plt.gca()
df = df_train.isna().mean(axis = 0)
sns.barplot(x = df, y = df.index, ax = ax)
ax.axvline(0.5)

# %% [markdown]
# 꽤 많은 데이터들이 공백 데이터가 있지만, 50%를 넘는 경우는 11개, 30%를 넘는 경우는 22개이다. 30%이상 공백 데이터가 있는 경우는 추정하기 어려울 것으로 생각되어, 모두 제거한다.

# %%
df_train = df_train.drop(df_train.columns[df_train.isna().mean() > 0.5], axis = 1)
print(df_train.shape)
print(df_train.columns)
df_train.head()
# Out:
# (131342, 90)
# Index(['collectionName', 'phoneName', 'millisSinceGpsEpoch', 'latDeg',
#        'lngDeg', 'heightAboveWgs84EllipsoidM', 'phone',
#        'elapsedRealtimeNanos_x', 'UncalGyroXRadPerSec', 'UncalGyroYRadPerSec',
#        'UncalGyroZRadPerSec', 'DriftXRadPerSec', 'DriftYRadPerSec',
#        'DriftZRadPerSec', 'utcTimeMillis_y', 'UncalMagXMicroT',
#        'UncalMagYMicroT', 'UncalMagZMicroT', 'BiasXMicroT', 'BiasYMicroT',
#        'BiasZMicroT', 'TimeNanos', 'FullBiasNanos', 'BiasNanos',
#        'BiasUncertaintyNanos', 'DriftNanosPerSecond',
#        'DriftUncertaintyNanosPerSecond', 'HardwareClockDiscontinuityCount',
#        'Svid_x', 'TimeOffsetNanos', 'State', 'ReceivedSvTimeNanos',
#        'ReceivedSvTimeUncertaintyNanos', 'Cn0DbHz_x',
#        'PseudorangeRateMetersPerSecond',
#        'PseudorangeRateUncertaintyMetersPerSecond',
#        'AccumulatedDeltaRangeState', 'AccumulatedDeltaRangeMeters',
#        'AccumulatedDeltaRangeUncertaintyMeters', 'CarrierFrequencyHz_x',
#        'MultipathIndicator', 'ConstellationType_x', 'AgcDb', 'CodeType',
#        'utcTimeMillis_y', 'elapsedRealtimeNanos_x', 'UncalAccelXMps2',
#        'UncalAccelYMps2', 'UncalAccelZMps2', 'BiasXMps2', 'BiasYMps2',
#        'BiasZMps2', 'timeSinceFirstFixSeconds', 'hDop', 'vDop', 'speedMps',
#        'courseDegree', 't_latDeg', 't_lngDeg', 't_heightAboveWgs84EllipsoidM',
#        'utcTimeMillis_y', 'SignalCount', 'SignalIndex', 'ConstellationType_y',
#        'Svid_y', 'CarrierFrequencyHz_y', 'Cn0DbHz_y', 'AzimuthDegrees',
#        'ElevationDegrees', 'UsedInFix', 'HasAlmanacData', 'HasEphemerisData',
#        'constellationType', 'svid', 'signalType', 'receivedSvTimeInGpsNanos',
#        'xSatPosM', 'ySatPosM', 'zSatPosM', 'xSatVelMps', 'ySatVelMps',
#        'zSatVelMps', 'satClkBiasM', 'satClkDriftMps', 'rawPrM', 'rawPrUncM',
#        'isrbM', 'ionoDelayM', 'tropoDelayM', 'meter'],
#       dtype='object')
#         collectionName       phoneName  millisSinceGpsEpoch     latDeg  \
# 0  2020-05-14-US-MTV-1          Pixel4        1273529463442  37.423575
# 1  2020-05-14-US-MTV-1          Pixel4        1273529464442  37.423578
# 2  2020-05-14-US-MTV-1          Pixel4        1273529465442  37.423573
# 3  2020-05-14-US-MTV-1          Pixel4        1273529466442  37.423583
# 4  2020-05-14-US-MTV-1  Pixel4XLModded        1273529466449  37.423574
#
#        lngDeg  heightAboveWgs84EllipsoidM                               phone  \
# 0 -122.094091                      -34.06          2020-05-14-US-MTV-1_Pixel4
# 1 -122.094101                      -33.29          2020-05-14-US-MTV-1_Pixel4
# 2 -122.094111                      -30.99          2020-05-14-US-MTV-1_Pixel4
# 3 -122.094121                      -32.83          2020-05-14-US-MTV-1_Pixel4
# 4 -122.094137                      -33.20  2020-05-14-US-MTV-1_Pixel4XLModded
#
#    elapsedRealtimeNanos_x  UncalGyroXRadPerSec  UncalGyroYRadPerSec  ...  \
# 0            1.965654e+13            -0.000502            -0.016050  ...
# 1            1.965754e+13            -0.003537             0.013521  ...
# 2            1.965854e+13             0.002028             0.005823  ...
# 3            1.965954e+13            -0.015753             0.016050  ...
# 4            1.734189e+13             0.875268             1.288668  ...
#
#    ySatVelMps  zSatVelMps  satClkBiasM  satClkDriftMps        rawPrM  \
# 0     156.040    3559.757     -468.084           0.001  2.379498e+07
# 1     411.162   -3013.649    65954.431          -0.002  2.592442e+07
# 2   -2776.605    -434.445     1223.261           0.000  2.131445e+07
# 3     411.755   -3013.528    65954.426          -0.002  2.592544e+07
# 4     -81.334   -3057.885    -3909.257           0.001  2.318871e+07
#
#    rawPrUncM     isrbM  ionoDelayM  tropoDelayM     meter
# 0     11.992  1134.758      10.866       16.647  3.586842
# 1      3.897  -222.675       7.111        5.174  2.745901
# 2      1.499     0.000       4.777        3.371  1.888409
# 3      3.598  -220.611       7.113        5.183  1.213483
# 4     10.493     0.000       7.313        5.311  0.664080
#
# [5 rows x 90 columns]

# %% [markdown]
# ... 그래도 80개의 컬럼이 남아있다. 이제부턴 차근차근 하나씩 분석해 보자!
#
# ## `collectionName` & `phoneName`
# `collectionName` 과 `phoneName`은 데이터를 다룰때 하나의 중요한 단서가 될 것 같다. 이 GPS데이터셋은 시계열 데이터일 가능성이 큰데, 날짜와 핸드폰 종류로 구분된 시계열 데이터인 것 같다. 그렇다면, 각 데이터의 길이가 얼마나 되는지 확인해 볼 필요가 있고, 또한 시계열 데이터가 맞는지 확인하기 위해 `millisSinceGpsEpoch`를 확인해서 규칙적으로 분포하는 시계열 데이터인지, 불규칙하게 분포한 시계열 데이터 인지, 시계열 데이터가 아닌지 확인해볼 필요가 있을 것 같다.

# %%
data = df_train.groupby('phone').count()['collectionName']

fig = plt.figure(figsize = (4, 16))
ax = plt.gca()
df = df_train.isna().mean(axis = 0)
sns.barplot(x = data, y = data.index, ax = ax)
ax.axvline(0.5)

# %%
data.describe()
# Out:
# count      73.000000
# mean     1799.205479
# std       383.524552
# min       577.000000
# 25%      1699.000000
# 50%      1791.000000
# 75%      2003.000000
# max      2890.000000
# Name: collectionName, dtype: float64

# %% [markdown]
# Confidence Interval 25% ~ 75%의 값을 기준으로 1700~2000개 정도의 길이인 데이터들로 확인된다. 또한 가장 적은 데이터는 577개이고, 가장 많은 데이터는 2890개이다.

# %%
phones = df_train['phone'].unique()
fig, axes = plt.subplots(len(phones), 1, figsize = (10, 4 * len(phones)))
for i, phone in enumerate(phones):
    temp = df_train[df_train['phone'] == phone]
    
    axes[i].plot(range(temp.shape[0]), temp['millisSinceGpsEpoch'],'o')
    axes[i].set_title(phone)
    
plt.show()

# %% [markdown]
# `2020-05-14-US-MTV-2_Pixel4XLModded` 를 제외한 나머지 데이터들은 순차적으로 획득한 정보로 보인다. 즉, 모든 정보를 순차적으로 획득한 시계열 데이터라고 생각하여도 크게 다르지 않을 것이라는 예상을 할 수 있다.
# 따라서 학습이나 추론을 위해 데이터를 변형을 해야 한다면, `phone` 칼럼으로 구분된 시계열 데이터임을 인지 하고 단위를 잘 쪼개 넣어야 할 것 같다.

# %% [markdown]
# ## `latDeg` & `lngDeg`
# `latDeg`와 `lngDeg`는 GPS신호의 위도와 경도를 의미하는 변수이다. 또한 GoogleSmartphoneDecimalChallenge에서 직접 추정해야 하는 변수이기도 하다. 따라서 이 데이터가 어떻게 되어 있는지 확인하는 작업도 중요할 것으로 보인다.
# 물론 다른 캐글러의 정보를 확인하는 것이 더 빠르기 때문에 우선은 넘어간다!

# %% [markdown]
# ## `UncalGyroXRadPerSec`, `UncalGyroYRadPerSec`, `UncalGyroZRadPerSec`, `DriftXRadPerSec`, `DriftYRadPerSec`, `DriftZRadPerSec`
#
# * `UncalGyro[X/Y/Z]RadPerSec`는 실제 스마트폰 기기의 움직임과 관련이 있는 변수로 캐글 공식 대회에 나온 데이터 설명은 다음과 같다.즉 drift에 대한 보상이 없이 계산된 X, Y, Z축 방향의 각속도를 의미한다. 각속도는 실제 물체의 움직임의 방향을 예측하는데 큰 도움을 줄 수 있는 변수로 예상 된다.
# * `Drift[X/Y/Z]RadPerSec`는 UncalGyro데이터의 드리프트값을 추정한 결과이다. 이 데이터에 포함된 공백 데이터는 이전 날짜에 수집된 정보이다.

# %%
phones = df_train['phone'].unique()

# %%
fig, axes = plt.subplots(8, 1, figsize = (16,80))

count = 0
for i, phone in enumerate(phones):
    if i % 10 != 0:
        continue
    temp = df_train[df_train['phone'] == phone]
    count = i//10
    axes[count].plot(temp['UncalGyroZRadPerSec'])
    axes[count].plot(temp['DriftZRadPerSec'])
    axes[count].set_title(f"{phone} - Drift Estimated Ratio {temp['DriftZRadPerSec'].isna().mean()}")

# %% [markdown]
# 특정 데이터셋에서 데이터가 사라지는 문제가 있는 것으로 확인됨.
# 또한 `DriftXRadPerSec`의 경우에는 특정 시점 데이터 이후에서 나타나는 것으로 보임.

# %%
means = df_train.groupby('phone').mean().reset_index()

fig, axes = plt.subplots(1, 3, figsize = (9, 16))
axes[0].plot(means['UncalGyroXRadPerSec'], means['phone'])
axes[0].plot(means['DriftXRadPerSec']    , means['phone'])
axes[1].plot(means['UncalGyroYRadPerSec'], means['phone'])
axes[1].plot(means['DriftYRadPerSec']    , means['phone'])
axes[2].plot(means['UncalGyroZRadPerSec'], means['phone'])
axes[2].plot(means['DriftZRadPerSec']    , means['phone'])

axes[1].set_yticklabels("")
axes[2].set_yticklabels("")

plt.show()

# %% [markdown]
# `Drift[X/Y/Z]RadPerSec`는 2020-07-08 전후로 처음 생성 되는 것으로 보이고, 모든 데이터는 2020-08-03부터 2020-09-04까지 gyro데이터가 사라지는 것으로 보인다.
# 그렇다면 gyro와 유사한 데이터인 accel, magnetic field 데이터 또한 확인해볼 필요가 있을 것으로 보인다. 각각의 데이터들이 언제 존재하고, 언제 사라지는지 확인해보자

# %%
means = df_train.groupby('phone').mean().reset_index()

'UncalMagXMicroT','UncalMagYMicroT','UncalMagZMicroT', 'BiasXMicroT', 'BiasYMicroT', 'BiasZMicroT']
value_cols = ['UncalGyroXRadPerSec', 'UncalGyroYRadPerSec', 'UncalGyroZRadPerSec',
              'UncalAccelXMps2','UncalAccelYMps2','UncalAccelZMps2',
              'UncalMagXMicroT','UncalMagYMicroT','UncalMagZMicroT']
bias_cols = ['DriftXRadPerSec', 'DriftYRadPerSec', 'DriftZRadPerSec',
             'BiasXMps2', 'BiasYMps2', 'BiasZMps2',
             'BiasXMicroT', 'BiasYMicroT', 'BiasZMicroT']
cols = ['UncalGyroXRadPerSec', 'UncalGyroYRadPerSec', 'UncalGyroZRadPerSec', 'DriftXRadPerSec', 'DriftYRadPerSec', 'DriftZRadPerSec',
'UncalAccelXMps2','UncalAccelYMps2','UncalAccelZMps2', 'BiasXMps2', 'BiasYMps2', 'BiasZMps2',

means[cols].isna().sum()
# Out:
# [['DriftXRadPerSec', 'DriftYRadPerSec', 'DriftZRadPerSec', 'BiasXMps2', 'BiasYMps2', 'BiasZMps2', 'BiasXMicroT', 'BiasYMicroT', 'BiasZMicroT'], ['UncalGyroXRadPerSec', 'UncalGyroYRadPerSec', 'UncalGyroZRadPerSec', 'UncalAccelXMps2', 'UncalAccelYMps2', 'UncalAccelZMps2', 'UncalMagXMicroT', 'UncalMagYMicroT', 'UncalMagZMicroT']]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-b29ff014e08b> in <module>
#      12 print(cols)
#      13
# ---> 14 means[cols].isna().sum()
#
# D:\Sangwons_Room\00_SoftWares\Anaconda\envs\torch\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2910             if is_iterator(key):
#    2911                 key = list(key)
# -> 2912             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2913
#    2914         # take() does not accept boolean indexers
#
# D:\Sangwons_Room\00_SoftWares\Anaconda\envs\torch\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# D:\Sangwons_Room\00_SoftWares\Anaconda\envs\torch\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1296             if missing == len(indexer):
#    1297                 axis_name = self.obj._get_axis_name(axis)
# -> 1298                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1299
#    1300             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index([('DriftXRadPerSec', 'DriftYRadPerSec', 'DriftZRadPerSec', 'BiasXMps2', 'BiasYMps2', 'BiasZMps2', 'BiasXMicroT', 'BiasYMicroT', 'BiasZMicroT'), ('UncalGyroXRadPerSec', 'UncalGyroYRadPerSec', 'UncalGyroZRadPerSec', 'UncalAccelXMps2', 'UncalAccelYMps2', 'UncalAccelZMps2', 'UncalMagXMicroT', 'UncalMagYMicroT', 'UncalMagZMicroT')], dtype='object')] are in the [columns]"

# %%
df_train.ya
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Sangwons_Room\00_SoftWares\Anaconda\envs\torch\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._unpack_bool_indexer()
#
# KeyError: 'rollDeg'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-2823dc80c102> in <module>
# ----> 1 df_train['rollDeg']
#
# D:\Sangwons_Room\00_SoftWares\Anaconda\envs\torch\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# D:\Sangwons_Room\00_SoftWares\Anaconda\envs\torch\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'rollDeg'

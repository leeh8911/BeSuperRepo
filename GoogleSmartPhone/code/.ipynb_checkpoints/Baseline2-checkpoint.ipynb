# %% [markdown]
# # references
# 1. https://www.kaggle.com/columbia2131/device-eda-interpolate-by-removing-device-en-ja

# %% [markdown]
# # Load Libraries

# %%
import numpy as np
import pandas as pd
from glob import glob
import os
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from pathlib import Path
import plotly.express as px

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
notebookName = 'Baseline2'
PATH = Path(f"./models/{notebookName}")

# %%
if os.path.isdir(PATH):
    dir_list = os.listdir(PATH)
    num_files = 0
    while True:
        if os.path.isfile(str(PATH / f"{num_files}")):
            print(num_files)
            num_files += 1
        else:
            break
else:
    os.mkdir(PATH)
    num_files = 0

# %%
num_files
# Out:
# 0

# %% [markdown]
# # Set Hyper Parameters

# %%
RANDOM_STATE = 42
lr = 0.001
batch_size = 4
EPOCH_NUM = 1000


usecols = ['latDeg', 'lngDeg', 'heightAboveWgs84EllipsoidM',
             'xSatVelMps', 'ySatVelMps', 'zSatVelMps', 
             'xSatPosM', 'ySatPosM', 'zSatPosM',
            'UncalGyroXRadPerSec', 'UncalGyroYRadPerSec', 'UncalGyroZRadPerSec',
         'DriftXRadPerSec' , 'DriftYRadPerSec', 'DriftZRadPerSec',
         'UncalMagXMicroT', 'UncalMagYMicroT', 'UncalMagZMicroT',
         'UncalAccelXMps2', 'UncalAccelYMps2', 'UncalAccelZMps2']
scaled_features = ['dlatDeg', 'dlngDeg',
             'xSatVelMps', 'ySatVelMps', 'zSatVelMps', 
             'xSatPosM', 'ySatPosM', 'zSatPosM',
            'UncalGyroXRadPerSec', 'UncalGyroYRadPerSec', 'UncalGyroZRadPerSec',
         'DriftXRadPerSec' , 'DriftYRadPerSec', 'DriftZRadPerSec',
         'UncalMagXMicroT', 'UncalMagYMicroT', 'UncalMagZMicroT',
         'UncalAccelXMps2', 'UncalAccelYMps2', 'UncalAccelZMps2']
features = ['latDeg', 'lngDeg', 'heightAboveWgs84EllipsoidM',
            'dlatDeg', 'dlngDeg',
             'xSatVelMps', 'ySatVelMps', 'zSatVelMps', 
             'xSatPosM', 'ySatPosM', 'zSatPosM',
            'UncalGyroXRadPerSec', 'UncalGyroYRadPerSec', 'UncalGyroZRadPerSec',
         'DriftXRadPerSec' , 'DriftYRadPerSec', 'DriftZRadPerSec',
         'UncalMagXMicroT', 'UncalMagYMicroT', 'UncalMagZMicroT',
         'UncalAccelXMps2', 'UncalAccelYMps2', 'UncalAccelZMps2']
labels = ['t_latDeg', 't_lngDeg', 't_heightAboveWgs84EllipsoidM', 'speedMps', 'courseDegree']

# %%
set(features) - set(usecols)
# Out:
# {'dlatDeg', 'dlngDeg'}

# %%
torch.manual_seed(RANDOM_STATE)

experience_name = f"{num_files}"
checkpoint_name = "check_point"
model_name = str("model - " + experience_name)
param_name = str("param - " + experience_name)
result_name = str("result - " + experience_name)

dummy_path = str(PATH / f"{num_files}")
checkpoint_path = str(PATH / f"{checkpoint_name}.pth")
model_path = str(PATH / f"{model_name}.pth")
param_path = str(PATH / f"{param_name}.pth")
result_path = str(PATH / f"{result_name}.csv")
model_path, param_path, result_path
# Out:
# ('models\\Baseline2\\model - 0.pth',
#  'models\\Baseline2\\param - 0.pth',
#  'models\\Baseline2\\result - 0.csv')

# %% [markdown]
# # Useful Functions

# %%
def calc_haversine(lat1, lon1, lat2, lon2):
    dlat = (lat2 - lat1) % 360
    dlon = (lon2 - lon1) % 360 
    
    dlat, dlon = map(np.radians, [dlat, dlon])
    a = np.sin(dlat / 2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2.0)**2
    c = 2 * np.arcsin(a ** 0.5)
        
    dist = 6_367_000 * c
    return dist

# %%
def check_score(input_df: pd.DataFrame) -> pd.DataFrame:
    output_df = input_df.copy()
    
    output_df['meter'] = input_df.apply(
        lambda r: calc_haversine(
            r.latDeg, r.lngDeg, r.t_latDeg, r.t_lngDeg
        ),
        axis=1
    )

    meter_score = output_df['meter'].mean()
    print(f'error meter: {meter_score}')

    scores = []
    for phone in output_df['phone'].unique():
        _index = output_df['phone']==phone
        p_50 = np.percentile(output_df.loc[_index, 'meter'], 50)
        p_95 = np.percentile(output_df.loc[_index, 'meter'], 95)
        scores.append(p_50)
        scores.append(p_95)

    score = sum(scores) / len(scores)
    print(f'score: {score}')
    
    return output_df, meter_score , score

# %%
def check_score_np(predict:torch.Tensor, target:torch.Tensor):
    m = []
    predict = predict.detach().numpy()
    target = target.detach().numpy()
    for i in range(predict.shape[0]):
        temp = calc_haversine(predict[i,0], predict[i,1], target[i,0], target[i,1])
        m.append(temp)
    
    m = np.array(m)
    score = (np.percentile(m, 50) + np.percentile(m, 95))/2
    
    return score

# %% [markdown]
# # Load Datasets

# %%
data_dir = Path("../input/google-smartphone-decimeter-challenge")
df_train = pd.read_pickle(str(data_dir / "gsdc_train.pkl.gzip"))

# %%
# check score
df_train, default_loss, default_meas = check_score(df_train)
# Out:
# error meter: 4.261468362435763
# score: 5.812326742270749

# %% [markdown]
# # Feature Engineering
# ## Simple view, what is in data frame.

# %%
print(df_train.shape)
df_train.head()
# Out:
# (131342, 111)
#         collectionName       phoneName  millisSinceGpsEpoch     latDeg  \
# 0  2020-05-14-US-MTV-1          Pixel4        1273529463442  37.423575
# 1  2020-05-14-US-MTV-1          Pixel4        1273529464442  37.423578
# 2  2020-05-14-US-MTV-1          Pixel4        1273529465442  37.423573
# 3  2020-05-14-US-MTV-1          Pixel4        1273529466442  37.423583
# 4  2020-05-14-US-MTV-1  Pixel4XLModded        1273529466449  37.423574
#
#        lngDeg  heightAboveWgs84EllipsoidM                               phone  \
# 0 -122.094091                      -34.06          2020-05-14-US-MTV-1_Pixel4
# 1 -122.094101                      -33.29          2020-05-14-US-MTV-1_Pixel4
# 2 -122.094111                      -30.99          2020-05-14-US-MTV-1_Pixel4
# 3 -122.094121                      -32.83          2020-05-14-US-MTV-1_Pixel4
# 4 -122.094137                      -33.20  2020-05-14-US-MTV-1_Pixel4XLModded
#
#    utcTimeMillis_x  elapsedRealtimeNanos_x  UncalGyroXRadPerSec  ...  \
# 0     1.589494e+12            1.965654e+13            -0.000502  ...
# 1     1.589494e+12            1.965754e+13            -0.003537  ...
# 2     1.589494e+12            1.965854e+13             0.002028  ...
# 3     1.589494e+12            1.965954e+13            -0.015753  ...
# 4     1.589494e+12            1.734189e+13             0.875268  ...
#
#    ySatVelMps  zSatVelMps  satClkBiasM  satClkDriftMps        rawPrM  \
# 0     156.040    3559.757     -468.084           0.001  2.379498e+07
# 1     411.162   -3013.649    65954.431          -0.002  2.592442e+07
# 2   -2776.605    -434.445     1223.261           0.000  2.131445e+07
# 3     411.755   -3013.528    65954.426          -0.002  2.592544e+07
# 4     -81.334   -3057.885    -3909.257           0.001  2.318871e+07
#
#    rawPrUncM     isrbM  ionoDelayM  tropoDelayM     meter
# 0     11.992  1134.758      10.866       16.647  4.345847
# 1      3.897  -222.675       7.111        5.174  3.324526
# 2      1.499     0.000       4.777        3.371  2.279173
# 3      3.598  -220.611       7.113        5.183  1.381411
# 4     10.493     0.000       7.313        5.311  0.794351
#
# [5 rows x 111 columns]

# %%
for c in df_train.columns:
    print(c)
    print(df_train[c].describe())
    print()
# Out:
# collectionName
# count                  131342
# unique                     29
# top       2021-01-04-US-RWC-1
# freq                     8293
# Name: collectionName, dtype: object
#
# phoneName
# count     131342
# unique         7
# top       Pixel4
# freq       48153
# Name: phoneName, dtype: object
#
# millisSinceGpsEpoch
# count    1.313420e+05
# mean     1.287913e+12
# std      1.162110e+10
# min      1.273529e+12
# 25%      1.275424e+12
# 50%      1.283279e+12
# 75%      1.302558e+12
# max      1.303771e+12
# Name: millisSinceGpsEpoch, dtype: float64
#
# latDeg
# count    131342.000000
# mean         37.435206
# std           0.082712
# min          37.321683
# 25%          37.371575
# 50%          37.424360
# 75%          37.469109
# max          37.690836
# Name: latDeg, dtype: float64
#
# lngDeg
# count    131342.000000
# mean       -122.154925
# std           0.145974
# min        -122.472214
# 25%        -122.275109
# 50%        -122.118311
# 75%        -122.069091
# max        -121.881855
# Name: lngDeg, dtype: float64
#
# heightAboveWgs84EllipsoidM
# count    131342.000000
# mean         23.832922
# std          72.589312
# min       -6157.470000
# 25%         -26.790000
# 50%           3.230000
# 75%          59.410000
# max       13701.980000
# Name: heightAboveWgs84EllipsoidM, dtype: float64
#
# phone
# count                         131342
# unique                            73
# top       2021-04-22-US-SJC-1_Pixel4
# freq                            2890
# Name: phone, dtype: object
#
# utcTimeMillis_x
#        utcTimeMillis_x  utcTimeMillis_x  utcTimeMillis_x
# count     1.137980e+05     1.313420e+05     3.658900e+04
# mean      1.604680e+12     1.603878e+12     1.619017e+12
# std       1.209329e+10     1.162110e+10     1.172510e+09
# min       1.589494e+12     1.589494e+12     1.615418e+12
# 25%       1.591379e+12     1.591389e+12     1.618523e+12
# 50%       1.609798e+12     1.599243e+12     1.619641e+12
# 75%       1.618523e+12     1.618522e+12     1.619723e+12
# max       1.619735e+12     1.619735e+12     1.619735e+12
#
# elapsedRealtimeNanos_x
#        elapsedRealtimeNanos_x  elapsedRealtimeNanos_x
# count            1.137980e+05            1.137980e+05
# mean             4.735094e+13            4.735094e+13
# std              1.075541e+14            1.075541e+14
# min              2.282485e+11            2.282544e+11
# 25%              8.036286e+12            8.036287e+12
# 50%              1.387414e+13            1.387414e+13
# 75%              6.816902e+13            6.816902e+13
# max              6.041912e+14            6.041912e+14
#
# UncalGyroXRadPerSec
# count    113798.000000
# mean          0.000923
# std           0.084996
# min          -1.824679
# 25%          -0.025551
# 50%           0.000916
# 75%           0.027488
# max           1.769790
# Name: UncalGyroXRadPerSec, dtype: float64
#
# UncalGyroYRadPerSec
# count    113798.000000
# mean         -0.001575
# std           0.092559
# min          -3.528166
# 25%          -0.019481
# 50%           0.000799
# 75%           0.018816
# max           1.880860
# Name: UncalGyroYRadPerSec, dtype: float64
#
# UncalGyroZRadPerSec
# count    113798.000000
# mean          0.000977
# std           0.050096
# min          -2.436228
# 25%          -0.011459
# 50%           0.001222
# 75%           0.014946
# max           2.277408
# Name: UncalGyroZRadPerSec, dtype: float64
#
# DriftXRadPerSec
# count    74725.000000
# mean         0.000195
# std          0.001996
# min         -0.004125
# 25%         -0.000503
# 50%          0.000009
# 75%          0.000837
# max          0.009721
# Name: DriftXRadPerSec, dtype: float64
#
# DriftYRadPerSec
# count    74725.000000
# mean         0.002355
# std          0.004949
# min         -0.002094
# 25%         -0.000251
# 50%          0.000075
# 75%          0.000577
# max          0.015419
# Name: DriftYRadPerSec, dtype: float64
#
# DriftZRadPerSec
# count    74725.000000
# mean         0.002363
# std          0.005364
# min         -0.005965
# 25%         -0.001627
# 50%          0.000601
# 75%          0.004007
# max          0.014271
# Name: DriftZRadPerSec, dtype: float64
#
# utcTimeMillis_y
#        utcTimeMillis_y  utcTimeMillis_y  utcTimeMillis_y
# count     1.137980e+05     1.137980e+05     1.117910e+05
# mean      1.604680e+12     1.604680e+12     1.603703e+12
# std       1.209329e+10     1.209329e+10     1.186885e+10
# min       1.589494e+12     1.589494e+12     1.589494e+12
# 25%       1.591379e+12     1.591379e+12     1.591379e+12
# 50%       1.609798e+12     1.609798e+12     1.599244e+12
# 75%       1.618523e+12     1.618523e+12     1.618522e+12
# max       1.619735e+12     1.619735e+12     1.619735e+12
#
# elapsedRealtimeNanos_y
#        elapsedRealtimeNanos_y  elapsedRealtimeNanos_y
# count            1.137980e+05            3.658900e+04
# mean             4.734853e+13            3.053199e+13
# std              1.075550e+14            2.743854e+13
# min              1.000000e+00            4.003852e+12
# 25%              8.034477e+12            1.176684e+13
# 50%              1.386814e+13            1.740758e+13
# 75%              6.816902e+13            6.710127e+13
# max              6.041912e+14            8.309815e+13
#
# UncalMagXMicroT
# count    113780.000000
# mean         29.201133
# std          39.605883
# min        -116.700000
# 25%           4.980000
# 50%          28.740000
# 75%          48.731492
# max         157.912500
# Name: UncalMagXMicroT, dtype: float64
#
# UncalMagYMicroT
# count    113780.000000
# mean        -52.356617
# std          37.173081
# min        -188.475000
# 25%         -57.937500
# 50%         -43.409250
# 75%         -34.369005
# max         126.753975
# Name: UncalMagYMicroT, dtype: float64
#
# UncalMagZMicroT
# count    113762.000000
# mean          4.066886
# std          67.743703
# min        -218.495760
# 25%         -24.240000
# 50%           0.803906
# 75%          20.510125
# max         260.025000
# Name: UncalMagZMicroT, dtype: float64
#
# BiasXMicroT
# count    74693.000000
# mean        16.093315
# std         42.486049
# min       -117.600000
# 25%         -4.390179
# 50%         13.256575
# 75%         30.476776
# max        135.506530
# Name: BiasXMicroT, dtype: float64
#
# BiasYMicroT
# count    74693.000000
# mean       -14.527748
# std         55.477841
# min       -123.855360
# 25%        -42.649117
# 50%         -9.150366
# 75%          3.924739
# max        202.620000
# Name: BiasYMicroT, dtype: float64
#
# BiasZMicroT
# count    74675.000000
# mean        15.456419
# std         80.564831
# min       -217.118040
# 25%        -37.862960
# 50%          2.663509
# 75%         35.045803
# max        234.596240
# Name: BiasZMicroT, dtype: float64
#
# utcTimeMillis_x
#        utcTimeMillis_x  utcTimeMillis_x  utcTimeMillis_x
# count     1.137980e+05     1.313420e+05     3.658900e+04
# mean      1.604680e+12     1.603878e+12     1.619017e+12
# std       1.209329e+10     1.162110e+10     1.172510e+09
# min       1.589494e+12     1.589494e+12     1.615418e+12
# 25%       1.591379e+12     1.591389e+12     1.618523e+12
# 50%       1.609798e+12     1.599243e+12     1.619641e+12
# 75%       1.618523e+12     1.618522e+12     1.619723e+12
# max       1.619735e+12     1.619735e+12     1.619735e+12
#
# TimeNanos
# count    1.313420e+05
# mean     1.871161e+14
# std      7.720866e+14
# min      4.993900e+10
# 25%      2.326058e+12
# 50%      1.078879e+13
# 75%      3.760431e+13
# max      4.261706e+15
# Name: TimeNanos, dtype: float64
#
# LeapSecond
# count    45928.0
# mean        18.0
# std          0.0
# min         18.0
# 25%         18.0
# 50%         18.0
# 75%         18.0
# max         18.0
# Name: LeapSecond, dtype: float64
#
# TimeUncertaintyNanos
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: TimeUncertaintyNanos, dtype: float64
#
# FullBiasNanos
# count    1.313420e+05
# mean    -1.287726e+18
# std      1.153714e+16
# min     -1.303769e+18
# 25%     -1.299453e+18
# 50%     -1.283273e+18
# 75%     -1.275339e+18
# max     -1.273508e+18
# Name: FullBiasNanos, dtype: float64
#
# BiasNanos
# count    131342.000000
# mean         -0.034683
# std           0.509370
# min          -0.999985
# 25%          -0.413013
# 50%           0.000000
# 75%           0.297781
# max           0.999979
# Name: BiasNanos, dtype: float64
#
# BiasUncertaintyNanos
# count    131342.000000
# mean        138.882081
# std         323.337851
# min           4.410778
# 25%          14.575101
# 50%          17.903321
# 75%          24.439189
# max        1010.203618
# Name: BiasUncertaintyNanos, dtype: float64
#
# DriftNanosPerSecond
# count    117173.000000
# mean         45.715046
# std         139.770830
# min        -133.764974
# 25%         -15.050240
# 50%          -1.192627
# 75%          16.070364
# max         445.000000
# Name: DriftNanosPerSecond, dtype: float64
#
# DriftUncertaintyNanosPerSecond
# count    117173.000000
# mean          9.264991
# std           3.707014
# min           0.743675
# 25%           8.952852
# 50%           9.697816
# 75%          10.821678
# max          41.865084
# Name: DriftUncertaintyNanosPerSecond, dtype: float64
#
# HardwareClockDiscontinuityCount
# count    131342.000000
# mean        904.863547
# std        2067.940289
# min           0.000000
# 25%           1.000000
# 50%           8.000000
# 75%         932.000000
# max       12484.000000
# Name: HardwareClockDiscontinuityCount, dtype: float64
#
# Svid_x
# count    131342.000000
# mean         21.857091
# std          26.931186
# min           1.000000
# 25%           9.000000
# 50%          19.000000
# 75%          27.000000
# max         195.000000
# Name: Svid_x, dtype: float64
#
# TimeOffsetNanos
# count    131342.0
# mean          0.0
# std           0.0
# min           0.0
# 25%           0.0
# 50%           0.0
# 75%           0.0
# max           0.0
# Name: TimeOffsetNanos, dtype: float64
#
# State
# count    131342.000000
# mean      37819.338597
# std       27131.543312
# min           4.000000
# 25%       16399.000000
# 50%       23567.000000
# 75%       49359.000000
# max       85034.000000
# Name: State, dtype: float64
#
# ReceivedSvTimeNanos
# count    1.313420e+05
# mean     3.121059e+14
# std      1.732955e+14
# min      1.328100e+04
# 25%      1.667148e+14
# 50%      4.112899e+14
# 75%      4.270754e+14
# max      5.184634e+14
# Name: ReceivedSvTimeNanos, dtype: float64
#
# ReceivedSvTimeUncertaintyNanos
# count    1.313420e+05
# mean     5.091290e+07
# std      2.198207e+08
# min      2.000000e+00
# 25%      7.000000e+00
# 50%      1.200000e+01
# 75%      2.100000e+01
# max      1.000000e+09
# Name: ReceivedSvTimeUncertaintyNanos, dtype: float64
#
# Cn0DbHz_x
# count    131342.000000
# mean         31.992947
# std           7.658805
# min           7.000000
# 25%          27.300000
# 50%          32.400000
# 75%          37.100000
# max          56.600000
# Name: Cn0DbHz_x, dtype: float64
#
# PseudorangeRateMetersPerSecond
# count    131342.000000
# mean         26.339512
# std        3565.671982
# min     -524008.318948
# 25%        -359.270341
# 50%          22.610368
# 75%         416.577360
# max      524170.529641
# Name: PseudorangeRateMetersPerSecond, dtype: float64
#
# PseudorangeRateUncertaintyMetersPerSecond
# count    1.313420e+05
# mean     1.525417e+07
# std      6.588192e+07
# min      9.465822e-04
# 25%      3.740000e-02
# 50%      6.120000e-02
# 75%      3.065000e-01
# max      2.997925e+08
# Name: PseudorangeRateUncertaintyMetersPerSecond, dtype: float64
#
# AccumulatedDeltaRangeState
# count    131342.000000
# mean         20.949102
# std           6.050364
# min           1.000000
# 25%          17.000000
# 50%          21.000000
# 75%          25.000000
# max          29.000000
# Name: AccumulatedDeltaRangeState, dtype: float64
#
# AccumulatedDeltaRangeMeters
# count    1.313420e+05
# mean    -5.972150e+03
# std      5.628474e+05
# min     -3.910771e+06
# 25%     -7.343367e+04
# 50%      0.000000e+00
# 75%      6.822980e+04
# max      3.896353e+06
# Name: AccumulatedDeltaRangeMeters, dtype: float64
#
# AccumulatedDeltaRangeUncertaintyMeters
# count    1.313420e+05
# mean     3.680766e+37
# std      1.056895e+38
# min     -6.921125e+18
# 25%      1.008556e-03
# 50%      2.354611e-03
# 75%      7.212130e-03
# max      3.402823e+38
# Name: AccumulatedDeltaRangeUncertaintyMeters, dtype: float64
#
# CarrierFrequencyHz_x
# count    1.313420e+05
# mean     1.484393e+09
# std      1.719319e+08
# min      1.176450e+09
# 25%      1.561098e+09
# 50%      1.575420e+09
# 75%      1.575420e+09
# max      1.605375e+09
# Name: CarrierFrequencyHz_x, dtype: float64
#
# CarrierCycles
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: CarrierCycles, dtype: float64
#
# CarrierPhase
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: CarrierPhase, dtype: float64
#
# CarrierPhaseUncertainty
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: CarrierPhaseUncertainty, dtype: float64
#
# MultipathIndicator
# count    131342.00000
# mean          0.03133
# std           0.17421
# min           0.00000
# 25%           0.00000
# 50%           0.00000
# 75%           0.00000
# max           1.00000
# Name: MultipathIndicator, dtype: float64
#
# SnrInDb
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: SnrInDb, dtype: float64
#
# ConstellationType_x
# count    131342.000000
# mean          3.337265
# std           2.166505
# min           1.000000
# 25%           1.000000
# 50%           3.000000
# 75%           6.000000
# max           6.000000
# Name: ConstellationType_x, dtype: float64
#
# AgcDb
# count    123464.000000
# mean         -1.916208
# std          29.264287
# min         -76.000000
# 25%          -1.150000
# 50%           0.380000
# 75%           3.890000
# max          64.818840
# Name: AgcDb, dtype: float64
#
# BasebandCn0DbHz_x
# count    25995.000000
# mean        26.892116
# std          8.898908
# min          6.900000
# 25%         21.437767
# 50%         28.038876
# 75%         33.668024
# max         46.022934
# Name: BasebandCn0DbHz_x, dtype: float64
#
# FullInterSignalBiasNanos
# count    25995.000000
# mean      -703.613103
# std       2609.491071
# min      -7876.281738
# 25%         -6.829505
# 50%          0.000000
# 75%          2.379855
# max       3817.982422
# Name: FullInterSignalBiasNanos, dtype: float64
#
# FullInterSignalBiasUncertaintyNanos
# count    25995.000000
# mean         8.037853
# std        215.055299
# min          0.000000
# 25%          1.000000
# 50%          2.082444
# 75%          6.126178
# max      20000.000000
# Name: FullInterSignalBiasUncertaintyNanos, dtype: float64
#
# SatelliteInterSignalBiasNanos
# count    14204.000000
# mean         5.548503
# std         10.726767
# min         -8.412334
# 25%         -1.235865
# 50%          0.000000
# 75%         10.681106
# max         35.390258
# Name: SatelliteInterSignalBiasNanos, dtype: float64
#
# SatelliteInterSignalBiasUncertaintyNanos
# count    14204.000000
# mean         1.346381
# std          0.292879
# min          1.000000
# 25%          1.000000
# 50%          1.500000
# 75%          1.500000
# max          2.000000
# Name: SatelliteInterSignalBiasUncertaintyNanos, dtype: float64
#
# CodeType
# count     83102
# unique        4
# top           C
# freq      53965
# Name: CodeType, dtype: object
#
# ChipsetElapsedRealtimeNanos
# count    4.861400e+04
# mean     3.429301e+13
# std      3.153181e+13
# min      6.236340e+12
# 25%      1.136069e+13
# 50%      1.715725e+13
# 75%      7.316578e+13
# max      9.553389e+13
# Name: ChipsetElapsedRealtimeNanos, dtype: float64
#
# utcTimeMillis_y
#        utcTimeMillis_y  utcTimeMillis_y  utcTimeMillis_y
# count     1.137980e+05     1.137980e+05     1.117910e+05
# mean      1.604680e+12     1.604680e+12     1.603703e+12
# std       1.209329e+10     1.209329e+10     1.186885e+10
# min       1.589494e+12     1.589494e+12     1.589494e+12
# 25%       1.591379e+12     1.591379e+12     1.591379e+12
# 50%       1.609798e+12     1.609798e+12     1.599244e+12
# 75%       1.618523e+12     1.618523e+12     1.618522e+12
# max       1.619735e+12     1.619735e+12     1.619735e+12
#
# elapsedRealtimeNanos_x
#        elapsedRealtimeNanos_x  elapsedRealtimeNanos_x
# count            1.137980e+05            1.137980e+05
# mean             4.735094e+13            4.735094e+13
# std              1.075541e+14            1.075541e+14
# min              2.282485e+11            2.282544e+11
# 25%              8.036286e+12            8.036287e+12
# 50%              1.387414e+13            1.387414e+13
# 75%              6.816902e+13            6.816902e+13
# max              6.041912e+14            6.041912e+14
#
# UncalAccelXMps2
# count    113798.000000
# mean         -0.206611
# std           1.108711
# min         -19.929222
# 25%          -0.705284
# 50%          -0.244068
# 75%           0.238684
# max           9.878537
# Name: UncalAccelXMps2, dtype: float64
#
# UncalAccelYMps2
# count    113798.000000
# mean          9.156857
# std           2.472644
# min          -5.511575
# 25%           9.318250
# 50%           9.737592
# 75%          10.037734
# max          26.434612
# Name: UncalAccelYMps2, dtype: float64
#
# UncalAccelZMps2
# count    113798.000000
# mean         -0.208391
# std           2.750507
# min         -16.254417
# 25%          -1.201197
# 50%          -0.407976
# 75%           0.822626
# max          14.864664
# Name: UncalAccelZMps2, dtype: float64
#
# BiasXMps2
# count    74725.0
# mean         0.0
# std          0.0
# min          0.0
# 25%          0.0
# 50%          0.0
# 75%          0.0
# max          0.0
# Name: BiasXMps2, dtype: float64
#
# BiasYMps2
# count    74725.0
# mean         0.0
# std          0.0
# min          0.0
# 25%          0.0
# 50%          0.0
# 75%          0.0
# max          0.0
# Name: BiasYMps2, dtype: float64
#
# BiasZMps2
# count    74725.000000
# mean        -0.000455
# std          0.000939
# min         -0.002394
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          0.000000
# Name: BiasZMps2, dtype: float64
#
# utcTimeMillis_x
#        utcTimeMillis_x  utcTimeMillis_x  utcTimeMillis_x
# count     1.137980e+05     1.313420e+05     3.658900e+04
# mean      1.604680e+12     1.603878e+12     1.619017e+12
# std       1.209329e+10     1.162110e+10     1.172510e+09
# min       1.589494e+12     1.589494e+12     1.615418e+12
# 25%       1.591379e+12     1.591389e+12     1.618523e+12
# 50%       1.609798e+12     1.599243e+12     1.619641e+12
# 75%       1.618523e+12     1.618522e+12     1.619723e+12
# max       1.619735e+12     1.619735e+12     1.619735e+12
#
# elapsedRealtimeNanos_y
#        elapsedRealtimeNanos_y  elapsedRealtimeNanos_y
# count            1.137980e+05            3.658900e+04
# mean             4.734853e+13            3.053199e+13
# std              1.075550e+14            2.743854e+13
# min              1.000000e+00            4.003852e+12
# 25%              8.034477e+12            1.176684e+13
# 50%              1.386814e+13            1.740758e+13
# 75%              6.816902e+13            6.710127e+13
# max              6.041912e+14            8.309815e+13
#
# yawDeg
# count    36589.000000
# mean       141.763891
# std         89.888553
# min          0.000000
# 25%         73.000000
# 50%        127.000000
# 75%        180.000000
# max        359.000000
# Name: yawDeg, dtype: float64
#
# rollDeg
# count    36572.000000
# mean        44.125834
# std        152.973663
# min       -180.000000
# 25%       -174.000000
# 50%        146.000000
# 75%        164.000000
# max        179.000000
# Name: rollDeg, dtype: float64
#
# pitchDeg
# count    36572.000000
# mean       -61.415017
# std         34.612914
# min        -89.000000
# 25%        -84.000000
# 50%        -81.000000
# 75%        -45.000000
# max         21.000000
# Name: pitchDeg, dtype: float64
#
# timeSinceFirstFixSeconds
# count    131342.000000
# mean       1213.986316
# std         609.145524
# min          47.430000
# 25%         718.430000
# 50%        1174.430000
# 75%        1659.440000
# max        3216.450000
# Name: timeSinceFirstFixSeconds, dtype: float64
#
# hDop
# count    131342.000000
# mean         10.146238
# std          56.707267
# min           0.000000
# 25%           0.900000
# 50%           1.300000
# 75%           2.500000
# max         655.300000
# Name: hDop, dtype: float64
#
# vDop
# count    131342.0
# mean          0.0
# std           0.0
# min           0.0
# 25%           0.0
# 50%           0.0
# 75%           0.0
# max           0.0
# Name: vDop, dtype: float64
#
# speedMps
# count    131342.000000
# mean         18.220691
# std          12.698756
# min           0.000000
# 25%           5.260000
# 50%          22.020000
# 75%          29.310000
# max          45.010000
# Name: speedMps, dtype: float64
#
# courseDegree
# count    131342.000000
# mean        210.534792
# std         101.127548
# min           0.000000
# 25%         129.000000
# 50%         209.100000
# 75%         309.600000
# max         360.000000
# Name: courseDegree, dtype: float64
#
# t_latDeg
# count    131342.000000
# mean         37.435201
# std           0.082713
# min          37.322839
# 25%          37.371573
# 50%          37.424355
# 75%          37.469097
# max          37.690794
# Name: t_latDeg, dtype: float64
#
# t_lngDeg
# count    131342.000000
# mean       -122.154926
# std           0.145972
# min        -122.428838
# 25%        -122.275114
# 50%        -122.118312
# 75%        -122.069092
# max        -121.881852
# Name: t_lngDeg, dtype: float64
#
# t_heightAboveWgs84EllipsoidM
# count    131342.000000
# mean         87.028847
# std          56.999876
# min          31.160000
# 25%          37.160000
# 50%          63.520000
# 75%         122.330000
# max         247.850000
# Name: t_heightAboveWgs84EllipsoidM, dtype: float64
#
# utcTimeMillis_y
#        utcTimeMillis_y  utcTimeMillis_y  utcTimeMillis_y
# count     1.137980e+05     1.137980e+05     1.117910e+05
# mean      1.604680e+12     1.604680e+12     1.603703e+12
# std       1.209329e+10     1.209329e+10     1.186885e+10
# min       1.589494e+12     1.589494e+12     1.589494e+12
# 25%       1.591379e+12     1.591379e+12     1.591379e+12
# 50%       1.609798e+12     1.609798e+12     1.599244e+12
# 75%       1.618523e+12     1.618523e+12     1.618522e+12
# max       1.619735e+12     1.619735e+12     1.619735e+12
#
# SignalCount
# count    111791.000000
# mean         39.112460
# std           8.103215
# min           4.000000
# 25%          33.000000
# 50%          41.000000
# 75%          45.000000
# max          56.000000
# Name: SignalCount, dtype: float64
#
# SignalIndex
# count    111791.000000
# mean         18.648827
# std          13.231969
# min           0.000000
# 25%           8.000000
# 50%          17.000000
# 75%          28.000000
# max          55.000000
# Name: SignalIndex, dtype: float64
#
# ConstellationType_y
# count    111791.000000
# mean          3.385120
# std           2.159356
# min           1.000000
# 25%           1.000000
# 50%           3.000000
# 75%           6.000000
# max           6.000000
# Name: ConstellationType_y, dtype: float64
#
# Svid_y
# count    111791.000000
# mean         22.476604
# std          30.017578
# min           1.000000
# 25%           8.000000
# 50%          18.000000
# 75%          27.000000
# max         195.000000
# Name: Svid_y, dtype: float64
#
# CarrierFrequencyHz_y
# count    1.116330e+05
# mean     1.480272e+09
# std      1.749200e+08
# min      1.176450e+09
# 25%      1.561098e+09
# 50%      1.575420e+09
# 75%      1.575420e+09
# max      1.605375e+09
# Name: CarrierFrequencyHz_y, dtype: float64
#
# Cn0DbHz_y
# count    111791.000000
# mean         28.625575
# std          11.995357
# min           0.000000
# 25%          24.050000
# 50%          31.000000
# 75%          36.400000
# max          55.800000
# Name: Cn0DbHz_y, dtype: float64
#
# AzimuthDegrees
# count    111791.000000
# mean        165.555903
# std         109.467490
# min           0.000000
# 25%          59.000000
# 50%         154.000000
# 75%         274.000000
# max         359.000000
# Name: AzimuthDegrees, dtype: float64
#
# ElevationDegrees
# count    111791.000000
# mean         31.939190
# std          23.321118
# min           0.000000
# 25%          11.000000
# 50%          28.000000
# 75%          51.000000
# max          89.000000
# Name: ElevationDegrees, dtype: float64
#
# UsedInFix
# count    111791.000000
# mean          0.619826
# std           0.485432
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           1.000000
# max           1.000000
# Name: UsedInFix, dtype: float64
#
# HasAlmanacData
# count    111791.000000
# mean          0.976519
# std           0.151427
# min           0.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max           1.000000
# Name: HasAlmanacData, dtype: float64
#
# HasEphemerisData
# count    111791.000000
# mean          0.620345
# std           0.485303
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           1.000000
# max           1.000000
# Name: HasEphemerisData, dtype: float64
#
# BasebandCn0DbHz_y
# count    20262.000000
# mean        26.494277
# std         10.566247
# min          0.000000
# 25%         21.722660
# 50%         28.300000
# 75%         34.126602
# max         46.211950
# Name: BasebandCn0DbHz_y, dtype: float64
#
# constellationType
# count    131342.000000
# mean          3.378744
# std           2.176913
# min           1.000000
# 25%           1.000000
# 50%           3.000000
# 75%           6.000000
# max           6.000000
# Name: constellationType, dtype: float64
#
# svid
# count    131342.000000
# mean         17.188843
# std           9.761156
# min           1.000000
# 25%           9.000000
# 50%          17.000000
# 75%          25.000000
# max          37.000000
# Name: svid, dtype: float64
#
# signalType
# count     131342
# unique         8
# top       GPS_L1
# freq       39906
# Name: signalType, dtype: object
#
# receivedSvTimeInGpsNanos
# count    1.313420e+05
# mean     1.287913e+18
# std      1.162110e+16
# min      1.273529e+18
# 25%      1.275424e+18
# 50%      1.283279e+18
# 75%      1.302558e+18
# max      1.303771e+18
# Name: receivedSvTimeInGpsNanos, dtype: float64
#
# xSatPosM
# count    1.313420e+05
# mean    -8.429426e+06
# std      1.260199e+07
# min     -3.141789e+07
# 25%     -1.805893e+07
# 50%     -1.105838e+07
# 75%      9.958046e+05
# max      2.314026e+07
# Name: xSatPosM, dtype: float64
#
# ySatPosM
# count    1.313420e+05
# mean    -1.240430e+07
# std      1.120919e+07
# min     -2.959319e+07
# 25%     -2.090822e+07
# 50%     -1.413953e+07
# 75%     -6.013359e+06
# max      2.661825e+07
# Name: ySatPosM, dtype: float64
#
# zSatPosM
# count    1.313420e+05
# mean     1.258066e+07
# std      1.068349e+07
# min     -1.836208e+07
# 25%      4.774167e+06
# 50%      1.597202e+07
# 75%      2.138985e+07
# max      3.513852e+07
# Name: zSatPosM, dtype: float64
#
# xSatVelMps
# count    131342.000000
# mean        557.524943
# std        1207.930715
# min       -3025.790000
# 25%        -223.555750
# 50%         408.957000
# 75%        1467.172000
# max        3195.491000
# Name: xSatVelMps, dtype: float64
#
# ySatVelMps
# count    131342.000000
# mean       -330.371870
# std        1317.304775
# min       -3143.622000
# 25%       -1323.738250
# 50%        -258.714000
# 75%         546.261250
# max        3124.382000
# Name: ySatVelMps, dtype: float64
#
# zSatVelMps
# count    131342.000000
# mean         37.523551
# std        2272.328628
# min       -3580.628000
# 25%       -2253.343250
# 50%          35.172000
# 75%        2299.073000
# max        3617.957000
# Name: zSatVelMps, dtype: float64
#
# satClkBiasM
# count    1.313420e+05
# mean     1.061657e+05
# std      4.170421e+05
# min     -3.288018e+05
# 25%     -6.885599e+04
# 50%      1.668736e+03
# 75%      7.918819e+04
# max      1.865378e+06
# Name: satClkBiasM, dtype: float64
#
# satClkDriftMps
# count    131342.000000
# mean          0.000092
# std           0.007456
# min          -0.014000
# 25%          -0.002000
# 50%          -0.000000
# 75%           0.001000
# max           0.075000
# Name: satClkDriftMps, dtype: float64
#
# rawPrM
# count    1.313420e+05
# mean     2.361523e+07
# std      3.328288e+06
# min      1.907225e+07
# 25%      2.180702e+07
# 50%      2.337290e+07
# 75%      2.458459e+07
# max      4.416339e+07
# Name: rawPrM, dtype: float64
#
# rawPrUncM
# count    131342.000000
# mean          4.881786
# std           4.913111
# min           0.600000
# 25%           2.099000
# 50%           3.298000
# 75%           5.696000
# max         149.896000
# Name: rawPrUncM, dtype: float64
#
# isrbM
# count    131342.000000
# mean       -310.665604
# std        1056.395342
# min       -6085.269000
# 25%        -228.997750
# 50%           0.000000
# 75%           0.000000
# max        9281.743000
# Name: isrbM, dtype: float64
#
# ionoDelayM
# count    131342.000000
# mean          5.713940
# std           2.862756
# min           0.000000
# 25%           3.710000
# 50%           4.895000
# 75%           7.285000
# max          25.876000
# Name: ionoDelayM, dtype: float64
#
# tropoDelayM
# count    131342.000000
# mean          6.304804
# std           5.712669
# min           0.000000
# 25%           3.029000
# 50%           4.196500
# 75%           7.109000
# max          47.439000
# Name: tropoDelayM, dtype: float64
#
# meter
# count    131342.000000
# mean          4.261468
# std          35.475422
# min           0.001579
# 25%           1.335918
# 50%           2.284470
# 75%           3.944131
# max        9597.674736
# Name: meter, dtype: float64

# %%
for col in df_train.columns:
    print(col)
# Out:
# collectionName
# phoneName
# millisSinceGpsEpoch
# latDeg
# lngDeg
# heightAboveWgs84EllipsoidM
# phone
# utcTimeMillis_x
# elapsedRealtimeNanos_x
# UncalGyroXRadPerSec
# UncalGyroYRadPerSec
# UncalGyroZRadPerSec
# DriftXRadPerSec
# DriftYRadPerSec
# DriftZRadPerSec
# utcTimeMillis_y
# elapsedRealtimeNanos_y
# UncalMagXMicroT
# UncalMagYMicroT
# UncalMagZMicroT
# BiasXMicroT
# BiasYMicroT
# BiasZMicroT
# utcTimeMillis_x
# TimeNanos
# LeapSecond
# TimeUncertaintyNanos
# FullBiasNanos
# BiasNanos
# BiasUncertaintyNanos
# DriftNanosPerSecond
# DriftUncertaintyNanosPerSecond
# HardwareClockDiscontinuityCount
# Svid_x
# TimeOffsetNanos
# State
# ReceivedSvTimeNanos
# ReceivedSvTimeUncertaintyNanos
# Cn0DbHz_x
# PseudorangeRateMetersPerSecond
# PseudorangeRateUncertaintyMetersPerSecond
# AccumulatedDeltaRangeState
# AccumulatedDeltaRangeMeters
# AccumulatedDeltaRangeUncertaintyMeters
# CarrierFrequencyHz_x
# CarrierCycles
# CarrierPhase
# CarrierPhaseUncertainty
# MultipathIndicator
# SnrInDb
# ConstellationType_x
# AgcDb
# BasebandCn0DbHz_x
# FullInterSignalBiasNanos
# FullInterSignalBiasUncertaintyNanos
# SatelliteInterSignalBiasNanos
# SatelliteInterSignalBiasUncertaintyNanos
# CodeType
# ChipsetElapsedRealtimeNanos
# utcTimeMillis_y
# elapsedRealtimeNanos_x
# UncalAccelXMps2
# UncalAccelYMps2
# UncalAccelZMps2
# BiasXMps2
# BiasYMps2
# BiasZMps2
# utcTimeMillis_x
# elapsedRealtimeNanos_y
# yawDeg
# rollDeg
# pitchDeg
# timeSinceFirstFixSeconds
# hDop
# vDop
# speedMps
# courseDegree
# t_latDeg
# t_lngDeg
# t_heightAboveWgs84EllipsoidM
# utcTimeMillis_y
# SignalCount
# SignalIndex
# ConstellationType_y
# Svid_y
# CarrierFrequencyHz_y
# Cn0DbHz_y
# AzimuthDegrees
# ElevationDegrees
# UsedInFix
# HasAlmanacData
# HasEphemerisData
# BasebandCn0DbHz_y
# constellationType
# svid
# signalType
# receivedSvTimeInGpsNanos
# xSatPosM
# ySatPosM
# zSatPosM
# xSatVelMps
# ySatVelMps
# zSatVelMps
# satClkBiasM
# satClkDriftMps
# rawPrM
# rawPrUncM
# isrbM
# ionoDelayM
# tropoDelayM
# meter

# %% [markdown]
# ## Feature Extractor

# %%
def FeatureExtraction(df:pd.DataFrame, use_cols, features) -> pd.DataFrame:
    output = df.copy()
    need_create_features = set(features) - set(use_cols)
    
    for needy in need_create_features:
        if needy in ['dlatDeg', 'dlngDeg']:
            output[needy] = DeltaLatLong(df, needy)
        elif needy == 'DriftXRadPerSec':
            output[needy] = WrongDataTypeStrDriftXRadPerSec(df, needy)
    
    return output

def WrongDataTypeStrDriftXRadPerSec(df:pd.DataFrame, col):
    output = df.copy()
    output[col] = output[col].apply(lambda x: x + '-4' if type(x) == str and x[-1] == 'E' else x)
    output[col] = output[col].apply(lambda x: x if type(x) == float else float(x))
    return output[col]
    
def DeltaLatLong(df:pd.DataFrame, col):
    output = df.copy()
    output[col] = 0
    if col == 'dlatDeg':
        target = 'latDeg'
    else:
        target = 'lngDeg'
        
    for phone in output['phone'].unique():
        temp = output[output['phone'] == phone]
        origin = temp.reset_index().iloc[0][target]
        output.loc[output['phone'] == phone,col] = temp[target] - origin
    
    return output[col]

df_train = FeatureExtraction(df_train, usecols, features)
print(df_train.columns)
df_train.head()
# Out:
# Index(['collectionName', 'phoneName', 'millisSinceGpsEpoch', 'latDeg',
#        'lngDeg', 'heightAboveWgs84EllipsoidM', 'phone', 'utcTimeMillis_x',
#        'elapsedRealtimeNanos_x', 'UncalGyroXRadPerSec',
#        ...
#        'satClkBiasM', 'satClkDriftMps', 'rawPrM', 'rawPrUncM', 'isrbM',
#        'ionoDelayM', 'tropoDelayM', 'meter', 'dlngDeg', 'dlatDeg'],
#       dtype='object', length=113)
#         collectionName       phoneName  millisSinceGpsEpoch     latDeg  \
# 0  2020-05-14-US-MTV-1          Pixel4        1273529463442  37.423575
# 1  2020-05-14-US-MTV-1          Pixel4        1273529464442  37.423578
# 2  2020-05-14-US-MTV-1          Pixel4        1273529465442  37.423573
# 3  2020-05-14-US-MTV-1          Pixel4        1273529466442  37.423583
# 4  2020-05-14-US-MTV-1  Pixel4XLModded        1273529466449  37.423574
#
#        lngDeg  heightAboveWgs84EllipsoidM                               phone  \
# 0 -122.094091                      -34.06          2020-05-14-US-MTV-1_Pixel4
# 1 -122.094101                      -33.29          2020-05-14-US-MTV-1_Pixel4
# 2 -122.094111                      -30.99          2020-05-14-US-MTV-1_Pixel4
# 3 -122.094121                      -32.83          2020-05-14-US-MTV-1_Pixel4
# 4 -122.094137                      -33.20  2020-05-14-US-MTV-1_Pixel4XLModded
#
#    utcTimeMillis_x  elapsedRealtimeNanos_x  UncalGyroXRadPerSec  ...  \
# 0     1.589494e+12            1.965654e+13             0.507496  ...
# 1     1.589494e+12            1.965754e+13             0.506651  ...
# 2     1.589494e+12            1.965854e+13             0.508199  ...
# 3     1.589494e+12            1.965954e+13             0.503253  ...
# 4     1.589494e+12            1.734189e+13             0.751139  ...
#
#    satClkBiasM  satClkDriftMps        rawPrM  rawPrUncM     isrbM  ionoDelayM  \
# 0     -468.084           0.001  2.379498e+07     11.992  1134.758      10.866
# 1    65954.431          -0.002  2.592442e+07      3.897  -222.675       7.111
# 2     1223.261           0.000  2.131445e+07      1.499     0.000       4.777
# 3    65954.426          -0.002  2.592544e+07      3.598  -220.611       7.113
# 4    -3909.257           0.001  2.318871e+07     10.493     0.000       7.313
#
#    tropoDelayM     meter  dlngDeg   dlatDeg
# 0       16.647  4.345847  0.00000  0.000000
# 1        5.174  3.324526 -0.00001  0.000002
# 2        3.371  2.279173 -0.00002 -0.000002
# 3        5.183  1.381411 -0.00003  0.000007
# 4        5.311  0.794351  0.00000  0.000000
#
# [5 rows x 113 columns]

# %%
df_ = FeatureExtraction(df_test, usecols, features)
for v in df_['DriftXRadPerSec']:
    if  type(v) == float or  type(v) == int:
        pass
    else:
        print(type(v), v)
# Out:
# <class 'str'> -7.093253E-4
# <class 'str'> -7.088188E-4
# <class 'str'> -7.074449E-4
# <class 'str'> -7.067865E-4
# <class 'str'> -7.0526707E-4
# <class 'str'> -7.050138E-4
# <class 'str'> -7.0511515E-4
# <class 'str'> -7.0511515E-4
# <class 'str'> -7.062294E-4
# <class 'str'> -7.0648274E-4
# <class 'str'> -7.068879E-4
# <class 'str'> -7.0703984E-4
# <class 'str'> -7.06432E-4
# <class 'str'> -7.067866E-4
# <class 'str'> -7.06584E-4
# <class 'str'> -7.0638146E-4
# <class 'str'> -7.0638146E-4
# <class 'str'> -7.0724246E-4
# <class 'str'> -7.0754637E-4
# <class 'str'> -7.076477E-4
# <class 'str'> -7.0805923E-4
# <class 'str'> -7.076477E-4
# <class 'str'> -7.0795795E-4
# <class 'str'> -7.076477E-4
# <class 'str'> -7.076477E-4
# <class 'str'> -7.0795795E-4
# <class 'str'> -7.0744514E-4
# <class 'str'> -7.0734386E-4
# <class 'str'> -7.0703996E-4
# <class 'str'> -7.0714124E-4
# <class 'str'> -7.0744514E-4
# <class 'str'> -7.0703996E-4
# <class 'str'> -7.06888E-4
# <class 'str'> -7.065841E-4
# <class 'str'> -7.054698E-4
# <class 'str'> -7.0450746E-4
# <class 'str'> -7.04001E-4
# <class 'str'> -7.03083E-4
# <class 'str'> -7.023233E-4
# <class 'str'> -7.023233E-4
# <class 'str'> -7.014116E-4
# <class 'str'> -7.01361E-4
# <class 'str'> -7.010571E-4
# <class 'str'> -7.007532E-4
# <class 'str'> -6.9948065E-4
# <class 'str'> -6.9973385E-4
# <class 'str'> -6.993793E-4
# <class 'str'> -6.9851824E-4
# <class 'str'> -6.9841696E-4
# <class 'str'> -6.980118E-4
# <class 'str'> -6.979105E-4
# <class 'str'> -6.976066E-4
# <class 'str'> -6.976066E-4
# <class 'str'> -6.973027E-4
# <class 'str'> -6.964923E-4
# <class 'str'> -6.967962E-4
# <class 'str'> -6.964923E-4
# <class 'str'> -6.961378E-4
# <class 'str'> -6.961378E-4
# <class 'str'> -6.9593516E-4
# <class 'str'> -6.9552363E-4
# <class 'str'> -6.9521967E-4
# <class 'str'> -6.9491577E-4
# <class 'str'> -6.945612E-4
# <class 'str'> -6.9405476E-4
# <class 'str'> -6.9390284E-4
# <class 'str'> -6.933963E-4
# <class 'str'> -6.923833E-4
# <class 'str'> -6.916679E-4
# <class 'str'> -6.91516E-4
# <class 'str'> -6.91516E-4
# <class 'str'> -6.914147E-4
# <class 'str'> -6.911108E-4
# <class 'str'> -6.910095E-4
# <class 'str'> -6.906043E-4
# <class 'str'> -6.904017E-4
# <class 'str'> -6.901485E-4
# <class 'str'> -6.899459E-4
# <class 'str'> -6.894394E-4
# <class 'str'> -6.8873033E-4
# <class 'str'> -6.885277E-4
# <class 'str'> -6.8817317E-4
# <class 'str'> -6.87559E-4
# <class 'str'> -6.878629E-4
# <class 'str'> -6.8745774E-4
# <class 'str'> -6.873564E-4
# <class 'str'> -6.872551E-4
# <class 'str'> -6.867993E-4
# <class 'str'> -6.867993E-4
# <class 'str'> -6.858876E-4
# <class 'str'> -6.855837E-4
# <class 'str'> -6.8548234E-4
# <class 'str'> -6.8548234E-4
# <class 'str'> -6.851278E-4
# <class 'str'> -6.8639405E-4
# <class 'str'> -6.8700186E-4
# <class 'str'> -6.877616E-4
# <class 'str'> -6.8847695E-4
# <class 'str'> -6.8933796E-4
# <class 'str'> -6.8964186E-4
# <class 'str'> -6.894393E-4
# <class 'str'> -6.8862893E-4
# <class 'str'> -6.8923674E-4
# <class 'str'> -6.8943936E-4
# <class 'str'> -6.8943936E-4
# <class 'str'> -6.8984454E-4
# <class 'str'> -6.8974326E-4
# <class 'str'> -6.899458E-4
# <class 'str'> -6.90351E-4
# <class 'str'> -6.90351E-4
# <class 'str'> -6.900471E-4
# <class 'str'> -6.897432E-4
# <class 'str'> -6.891354E-4
# <class 'str'> -6.888315E-4
# <class 'str'> -6.8847695E-4
# <class 'str'> -6.8817305E-4
# <class 'str'> -6.8878086E-4
# <class 'str'> -6.882744E-4
# <class 'str'> -6.8796414E-4
# <class 'str'> -6.8786286E-4
# <class 'str'> -6.877616E-4
# <class 'str'> -6.876603E-4
# <class 'str'> -6.876603E-4
# <class 'str'> -6.873564E-4
# <class 'str'> -6.878629E-4
# <class 'str'> -6.876603E-4
# <class 'str'> -6.87559E-4
# <class 'str'> -6.880718E-4
# <class 'str'> -6.8837573E-4
# <class 'str'> -6.8817317E-4
# <class 'str'> -6.88781E-4
# <class 'str'> -6.8913546E-4
# <class 'str'> -6.8954064E-4
# <class 'str'> -6.889329E-4
# <class 'str'> -6.8933814E-4
# <class 'str'> -6.901992E-4
# <class 'str'> -6.907057E-4
# <class 'str'> -6.915161E-4
# <class 'str'> -6.9213024E-4
# <class 'str'> -6.9202896E-4
# <class 'str'> -6.930926E-4
# <class 'str'> -6.934978E-4
# <class 'str'> -6.9496664E-4
# <class 'str'> -6.95253E-4
# <class 'str'> -6.9533486E-4
# <class 'str'> -6.951711E-4
# <class 'str'> -6.9558027E-4
# <class 'str'> -6.966083E-4
# <class 'str'> -6.96281E-4
# <class 'str'> -6.9709925E-4
# <class 'str'> -6.9640373E-4
# <class 'str'> -6.96772E-4
# <class 'str'> -6.97263E-4
# <class 'str'> -6.9767213E-4
# <class 'str'> -6.971812E-4
# <class 'str'> -6.973449E-4
# <class 'str'> -6.971812E-4
# <class 'str'> -6.971812E-4
# <class 'str'> -6.969357E-4
# <class 'str'> -6.9701753E-4
# <class 'str'> -6.9701753E-4
# <class 'str'> -6.9701753E-4
# <class 'str'> -6.969357E-4
# <class 'str'> -6.9685385E-4
# <class 'str'> -6.969357E-4
# <class 'str'> -6.9669023E-4
# <class 'str'> -6.963629E-4
# <class 'str'> -6.96322E-4
# <class 'str'> -6.9660845E-4
# <class 'str'> -6.9660845E-4
# <class 'str'> -6.968539E-4
# <class 'str'> -6.9693575E-4
# <class 'str'> -6.9726305E-4
# <class 'str'> -6.9709937E-4
# <class 'str'> -6.9709937E-4
# <class 'str'> -6.973449E-4
# <class 'str'> -6.9718127E-4
# <class 'str'> -6.9718127E-4
# <class 'str'> -6.9718127E-4
# <class 'str'> -6.970994E-4
# <class 'str'> -6.9734495E-4
# <class 'str'> -6.9734495E-4
# <class 'str'> -6.9734495E-4
# <class 'str'> -6.975904E-4
# <class 'str'> -6.9771317E-4
# <class 'str'> -6.9767225E-4
# <class 'str'> -6.984497E-4
# <class 'str'> -6.976723E-4
# <class 'str'> -6.977541E-4
# <class 'str'> -6.984497E-4
# <class 'str'> -6.986952E-4
# <class 'str'> -6.9812237E-4
# <class 'str'> -6.9861335E-4
# <class 'str'> -6.9795863E-4
# <class 'str'> -6.984496E-4
# <class 'str'> -6.9767225E-4
# <class 'str'> -6.977541E-4
# <class 'str'> -6.9795863E-4
# <class 'str'> -6.9767225E-4
# <class 'str'> -6.979587E-4
# <class 'str'> -6.979996E-4
# <class 'str'> -6.977132E-4
# <class 'str'> -6.977132E-4
# <class 'str'> -6.9759047E-4
# <class 'str'> -6.979587E-4
# <class 'str'> -6.979587E-4
# <class 'str'> -6.9775415E-4
# <class 'str'> -6.9754955E-4
# <class 'str'> -6.976314E-4
# <class 'str'> -6.985315E-4
# <class 'str'> -6.985315E-4
# <class 'str'> -6.97836E-4
# <class 'str'> -6.9844973E-4
# <class 'str'> -6.985315E-4
# <class 'str'> -6.9861335E-4
# <class 'str'> -6.986952E-4
# <class 'str'> -6.9857243E-4
# <class 'str'> -6.987361E-4
# <class 'str'> -6.993141E-4
# <class 'str'> -6.9939595E-4
# <class 'str'> -6.9939595E-4
# <class 'str'> -6.994778E-4
# <class 'str'> -6.9955963E-4
# <class 'str'> -6.9980515E-4
# <class 'str'> -6.997233E-4
# <class 'str'> -6.9964153E-4
# <class 'str'> -6.9947785E-4
# <class 'str'> -6.999688E-4
# <class 'str'> -6.999688E-4
# <class 'str'> -6.999688E-4
# <class 'str'> -6.99887E-4
# <class 'str'> -7.001325E-4
# <class 'str'> -7.001325E-4
# <class 'str'> -7.0095086E-4
# <class 'str'> -7.0082815E-4
# <class 'str'> -7.016055E-4
# <class 'str'> -7.018919E-4
# <class 'str'> -7.0127816E-4
# <class 'str'> -7.0189184E-4
# <class 'str'> -7.02347E-4
# <class 'str'> -7.025925E-4
# <class 'str'> -7.025925E-4
# <class 'str'> -7.031244E-4
# <class 'str'> -7.029198E-4
# <class 'str'> -7.0353353E-4
# <class 'str'> -7.0377905E-4
# <class 'str'> -7.0390175E-4
# <class 'str'> -7.0410635E-4
# <class 'str'> -7.0459733E-4
# <class 'str'> -7.043518E-4
# <class 'str'> -7.046382E-4
# <class 'str'> -7.044336E-4
# <class 'str'> -7.048837E-4
# <class 'str'> -7.045973E-4
# <class 'str'> -7.0504734E-4
# <class 'str'> -7.049655E-4
# <class 'str'> -7.053797E-4
# <class 'str'> -7.059934E-4
# <class 'str'> -7.0648437E-4
# <class 'str'> -7.064025E-4
# <class 'str'> -7.067708E-4
# <class 'str'> -7.0767093E-4
# <class 'str'> -7.080801E-4
# <class 'str'> -7.0865796E-4
# <class 'str'> -7.084074E-4
# <class 'str'> -7.0886256E-4
# <class 'str'> -7.089444E-4
# <class 'str'> -7.102946E-4
# <class 'str'> -7.105401E-4
# <class 'str'> -7.1078556E-4
# <class 'str'> -7.1078556E-4
# <class 'str'> -7.1078556E-4
# <class 'str'> -7.1111287E-4
# <class 'str'> -7.1111287E-4
# <class 'str'> -7.1111287E-4
# <class 'str'> -7.1099016E-4
# <class 'str'> -7.1062194E-4
# <class 'str'> -7.1013096E-4
# <class 'str'> -7.105401E-4
# <class 'str'> -7.1013096E-4
# <class 'str'> -7.103764E-4
# <class 'str'> -7.1004906E-4
# <class 'str'> -7.0963986E-4
# <class 'str'> -7.093534E-4
# <class 'str'> -7.0918974E-4
# <class 'str'> -7.091079E-4
# <class 'str'> -7.087806E-4
# <class 'str'> -7.0816174E-4
# <class 'str'> -7.083254E-4
# <class 'str'> -7.0848904E-4
# <class 'str'> -7.0832536E-4
# <class 'str'> -7.0848904E-4
# <class 'str'> -7.0886244E-4
# <class 'str'> -7.0848904E-4
# <class 'str'> -7.0848904E-4
# <class 'str'> -7.091896E-4
# <class 'str'> -7.096397E-4
# <class 'str'> -7.1053987E-4
# <class 'str'> -7.1086717E-4
# <class 'str'> -7.111945E-4
# <class 'str'> -7.118952E-4
# <class 'str'> -7.12468E-4
# <class 'str'> -7.131635E-4
# <class 'str'> -7.1324536E-4
# <class 'str'> -7.136545E-4
# <class 'str'> -7.142682E-4
# <class 'str'> -7.144728E-4
# <class 'str'> -7.155416E-4
# <class 'str'> -7.155416E-4
# <class 'str'> -7.158689E-4
# <class 'str'> -7.160735E-4
# <class 'str'> -7.164417E-4
# <class 'str'> -7.160326E-4
# <class 'str'> -7.162372E-4
# <class 'str'> -7.150098E-4
# <class 'str'> -7.1459555E-4
# <class 'str'> -7.1459555E-4
# <class 'str'> -7.138182E-4
# <class 'str'> -7.138182E-4
# <class 'str'> -7.138182E-4
# <class 'str'> -7.135727E-4
# <class 'str'> -7.134909E-4
# <class 'str'> -7.134909E-4
# <class 'str'> -7.1340904E-4
# <class 'str'> -7.131636E-4
# <class 'str'> -7.131636E-4
# <class 'str'> -7.1291806E-4
# <class 'str'> -7.127135E-4
# <class 'str'> -7.1324536E-4
# <class 'str'> -7.1324536E-4
# <class 'str'> -7.1246794E-4
# <class 'str'> -7.1291794E-4
# <class 'str'> -7.1324524E-4
# <class 'str'> -7.1344984E-4
# <class 'str'> -7.1332714E-4
# <class 'str'> -7.1332714E-4
# <class 'str'> -7.130816E-4
# <class 'str'> -7.1332714E-4
# <class 'str'> -7.1332714E-4
# <class 'str'> -7.13368E-4
# <class 'str'> -7.1381807E-4
# <class 'str'> -7.136544E-4
# <class 'str'> -7.138999E-4
# <class 'str'> -7.1381807E-4
# <class 'str'> -7.138999E-4
# <class 'str'> -7.141863E-4
# <class 'str'> -7.136544E-4
# <class 'str'> -7.145136E-4
# <class 'str'> -7.143499E-4
# <class 'str'> -7.145954E-4
# <class 'str'> -7.14268E-4
# <class 'str'> -7.141862E-4
# <class 'str'> -7.14718E-4
# <class 'str'> -7.150505E-4
# <class 'str'> -7.148408E-4
# <class 'str'> -7.157051E-4
# <class 'str'> -7.157051E-4
# <class 'str'> -7.157051E-4
# <class 'str'> -7.160324E-4
# <class 'str'> -7.1623694E-4
# <class 'str'> -7.161142E-4
# <class 'str'> -7.163597E-4
# <class 'str'> -7.1660517E-4
# <class 'str'> -7.1676885E-4
# <class 'str'> -7.16687E-4
# <class 'str'> -7.1730075E-4
# <class 'str'> -7.173825E-4
# <class 'str'> -7.17137E-4
# <class 'str'> -7.1721885E-4
# <class 'str'> -7.1705517E-4
# <class 'str'> -7.1705517E-4
# <class 'str'> -7.173416E-4
# <class 'str'> -7.1705517E-4
# <class 'str'> -7.178735E-4
# <class 'str'> -7.182469E-4
# <class 'str'> -7.185333E-4
# <class 'str'> -7.184924E-4
# <class 'str'> -7.193925E-4
# <class 'str'> -7.196789E-4
# <class 'str'> -7.1926974E-4
# <class 'str'> -7.193925E-4
# <class 'str'> -7.199653E-4
# <class 'str'> -7.204154E-4
# <class 'str'> -7.2033354E-4
# <class 'str'> -7.20579E-4
# <class 'str'> -7.207427E-4
# <class 'str'> -7.204972E-4
# <class 'str'> -7.213206E-4
# <class 'str'> -7.21607E-4
# <class 'str'> -7.21607E-4
# <class 'str'> -7.213615E-4
# <class 'str'> -7.213615E-4
# <class 'str'> -7.216888E-4
# <class 'str'> -7.2193425E-4
# <class 'str'> -7.216888E-4
# <class 'str'> -7.216888E-4
# <class 'str'> -7.216479E-4
# <class 'str'> -7.2102906E-4
# <class 'str'> -7.204972E-4
# <class 'str'> -7.20579E-4
# <class 'str'> -7.199653E-4
# <class 'str'> -7.202517E-4
# <class 'str'> -7.206609E-4
# <class 'str'> -7.199653E-4
# <class 'str'> -7.20579E-4
# <class 'str'> -7.194743E-4
# <class 'str'> -7.2016986E-4
# <class 'str'> -7.1976066E-4
# <class 'str'> -7.1890146E-4
# <class 'str'> -7.1857416E-4
# <class 'str'> -7.1890146E-4
# <class 'str'> -7.181241E-4
# <class 'str'> -7.1779167E-4
# <class 'str'> -7.173825E-4
# <class 'str'> -7.17178E-4
# <class 'str'> -7.1660517E-4
# <class 'str'> -7.177099E-4
# <class 'str'> -7.183287E-4
# <class 'str'> -7.1873784E-4
# <class 'str'> -7.1873784E-4
# <class 'str'> -7.180372E-4
# <class 'str'> -7.182469E-4
# <class 'str'> -7.1824685E-4
# <class 'str'> -7.177916E-4
# <class 'str'> -7.1775075E-4
# <class 'str'> -7.173416E-4
# <class 'str'> -7.1721885E-4
# <class 'str'> -7.179144E-4
# <class 'str'> -7.175461E-4
# <class 'str'> -7.1795523E-4
# <class 'str'> -7.1857416E-4
# <class 'str'> -7.1824685E-4
# <class 'str'> -7.1824685E-4
# <class 'str'> -7.184924E-4
# <class 'str'> -7.1795535E-4
# <class 'str'> -7.184924E-4
# <class 'str'> -7.184924E-4
# <class 'str'> -7.187379E-4
# <class 'str'> -7.1869703E-4
# <class 'str'> -7.189016E-4
# <class 'str'> -7.189016E-4
# <class 'str'> -7.189016E-4
# <class 'str'> -7.192289E-4
# <class 'str'> -7.1906525E-4
# <class 'str'> -7.191471E-4
# <class 'str'> -7.1939256E-4
# <class 'str'> -7.1890163E-4
# <class 'str'> -7.193108E-4
# <class 'str'> -7.188198E-4
# <class 'str'> -7.191471E-4
# <class 'str'> -7.193107E-4
# <class 'str'> -7.1939256E-4
# <class 'str'> -7.208246E-4
# <class 'str'> -7.207427E-4
# <class 'str'> -7.204153E-4
# <class 'str'> -7.200062E-4
# <class 'str'> -7.1931066E-4
# <class 'str'> -7.190652E-4
# <class 'str'> -7.1881973E-4
# <class 'str'> -7.190652E-4
# <class 'str'> -7.1824697E-4
# <class 'str'> -7.1824697E-4
# <class 'str'> -7.171372E-4
# <class 'str'> -7.171372E-4
# <class 'str'> -7.165235E-4
# <class 'str'> -7.1611436E-4
# <class 'str'> -7.160735E-4
# <class 'str'> -7.158689E-4
# <class 'str'> -7.157052E-4
# <class 'str'> -7.15337E-4
# <class 'str'> -7.152552E-4
# <class 'str'> -7.151734E-4
# <class 'str'> -7.1500975E-4
# <class 'str'> -7.1475917E-4
# <class 'str'> -7.1554165E-4
# <class 'str'> -7.157053E-4
# <class 'str'> -7.147591E-4
# <class 'str'> -7.152552E-4
# <class 'str'> -7.146773E-4
# <class 'str'> -7.142682E-4
# <class 'str'> -7.1389996E-4
# <class 'str'> -7.1365444E-4
# <class 'str'> -7.1336806E-4
# <class 'str'> -7.13409E-4
# <class 'str'> -7.132044E-4
# <class 'str'> -7.132044E-4
# <class 'str'> -7.128362E-4
# <class 'str'> -7.133272E-4
# <class 'str'> -7.1332726E-4
# <class 'str'> -7.133682E-4
# <class 'str'> -7.1316364E-4
# <class 'str'> -7.126317E-4
# <class 'str'> -7.12509E-4
# <class 'str'> -7.1197713E-4
# <class 'str'> -7.1197713E-4
# <class 'str'> -7.1135827E-4
# <class 'str'> -7.1209983E-4
# <class 'str'> -7.1263174E-4
# <class 'str'> -7.1299996E-4
# <class 'str'> -7.1308174E-4
# <class 'str'> -7.126317E-4
# <class 'str'> -7.1291806E-4
# <class 'str'> -7.1324536E-4
# <class 'str'> -7.133272E-4
# <class 'str'> -7.1344996E-4
# <class 'str'> -7.1324536E-4
# <class 'str'> -7.1324536E-4
# <class 'str'> -7.139818E-4
# <class 'str'> -7.1430916E-4
# <class 'str'> -7.1418646E-4
# <class 'str'> -7.143501E-4
# <class 'str'> -7.139818E-4
# <class 'str'> -7.149279E-4
# <class 'str'> -7.148001E-4
# <class 'str'> -7.142682E-4
# <class 'str'> -7.139818E-4
# <class 'str'> -7.1389996E-4
# <class 'str'> -7.13409E-4
# <class 'str'> -7.1349076E-4
# <class 'str'> -7.1316346E-4
# <class 'str'> -7.127134E-4
# <class 'str'> -7.126725E-4
# <class 'str'> -7.120997E-4
# <class 'str'> -7.1164453E-4
# <class 'str'> -7.1156275E-4
# <class 'str'> -7.1103085E-4
# <class 'str'> -7.1103085E-4
# <class 'str'> -7.107036E-4
# <class 'str'> -7.106627E-4
# <class 'str'> -7.106627E-4
# <class 'str'> -7.101308E-4
# <class 'str'> -7.10008E-4
# <class 'str'> -7.0992624E-4
# <class 'str'> -7.096808E-4
# <class 'str'> -7.101309E-4
# <class 'str'> -7.099263E-4
# <class 'str'> -7.098854E-4
# <class 'str'> -7.0992636E-4
# <class 'str'> -7.0980354E-4
# <class 'str'> -7.098444E-4
# <class 'str'> -7.0959894E-4
# <class 'str'> -7.0927164E-4
# <class 'str'> -7.0927164E-4
# <class 'str'> -7.0857606E-4
# <class 'str'> -7.087806E-4
# <class 'str'> -7.0865784E-4
# <class 'str'> -7.088624E-4
# <class 'str'> -7.0832536E-4
# <class 'str'> -7.0832536E-4
# <class 'str'> -7.0832536E-4
# <class 'str'> -7.0832536E-4
# <class 'str'> -7.08039E-4
# <class 'str'> -7.082436E-4
# <class 'str'> -7.0816174E-4
# <class 'str'> -7.0783444E-4
# <class 'str'> -7.082436E-4
# <class 'str'> -7.0799806E-4
# <class 'str'> -7.0799806E-4
# <class 'str'> -7.077526E-4
# <class 'str'> -7.0828444E-4
# <class 'str'> -7.081617E-4
# <class 'str'> -7.079162E-4
# <class 'str'> -7.079162E-4
# <class 'str'> -7.082026E-4
# <class 'str'> -7.081617E-4
# <class 'str'> -7.081208E-4
# <class 'str'> -7.081208E-4
# <class 'str'> -7.078344E-4
# <class 'str'> -7.080799E-4
# <class 'str'> -7.078344E-4
# <class 'str'> -7.082026E-4
# <class 'str'> -7.07507E-4
# <class 'str'> -7.076707E-4
# <class 'str'> -7.0791616E-4
# <class 'str'> -7.0791616E-4
# <class 'str'> -7.081616E-4
# <class 'str'> -7.082844E-4
# <class 'str'> -7.091897E-4
# <class 'str'> -7.098443E-4
# <class 'str'> -7.1021257E-4
# <class 'str'> -7.1000797E-4
# <class 'str'> -7.095988E-4
# <class 'str'> -7.098443E-4
# <class 'str'> -7.0947607E-4
# <class 'str'> -7.088624E-4
# <class 'str'> -7.091897E-4
# <class 'str'> -7.09026E-4
# <class 'str'> -7.0832536E-4
# <class 'str'> -7.086578E-4
# <class 'str'> -7.0832536E-4
# <class 'str'> -7.0832536E-4
# <class 'str'> -7.082026E-4
# <class 'str'> -7.0807984E-4
# <class 'str'> -7.0820254E-4
# <class 'str'> -7.081616E-4
# <class 'str'> -7.078343E-4
# <class 'str'> -7.078343E-4
# <class 'str'> -7.078343E-4
# <class 'str'> -7.0758886E-4
# <class 'str'> -7.078343E-4
# <class 'str'> -7.0742524E-4
# <class 'str'> -7.072207E-4
# <class 'str'> -7.07057E-4
# <class 'str'> -7.0709793E-4
# <class 'str'> -7.064433E-4
# <class 'str'> -7.0693425E-4
# <class 'str'> -7.068525E-4
# <class 'str'> -7.067297E-4
# <class 'str'> -7.0648425E-4
# <class 'str'> -7.0709793E-4
# <class 'str'> -7.0730253E-4
# <class 'str'> -7.073026E-4
# <class 'str'> -7.07589E-4
# <class 'str'> -7.079163E-4
# <class 'str'> -7.070571E-4
# <class 'str'> -7.079163E-4
# <class 'str'> -7.079163E-4
# <class 'str'> -7.079981E-4
# <class 'str'> -7.0857606E-4
# <class 'str'> -7.0816185E-4
# <class 'str'> -7.0828456E-4
# <class 'str'> -7.0828456E-4
# <class 'str'> -7.09108E-4
# <class 'str'> -7.0939446E-4
# <class 'str'> -7.094354E-4
# <class 'str'> -7.0980366E-4
# <class 'str'> -7.1045826E-4
# <class 'str'> -7.1029464E-4
# <class 'str'> -7.107038E-4
# <class 'str'> -7.107038E-4
# <class 'str'> -7.1062194E-4
# <class 'str'> -7.1062194E-4
# <class 'str'> -7.1062194E-4
# <class 'str'> -7.1148115E-4
# <class 'str'> -7.1189547E-4
# <class 'str'> -7.114812E-4
# <class 'str'> -7.114812E-4
# <class 'str'> -7.1127666E-4
# <class 'str'> -7.1173185E-4
# <class 'str'> -7.1127666E-4
# <class 'str'> -7.11113E-4
# <class 'str'> -7.1135844E-4
# <class 'str'> -7.114812E-4
# <class 'str'> -7.114812E-4
# <class 'str'> -7.114812E-4
# <class 'str'> -7.114812E-4
# <class 'str'> -7.116449E-4
# <class 'str'> -7.116449E-4
# <class 'str'> -7.116448E-4
# <class 'str'> -7.116448E-4
# <class 'str'> -7.1189535E-4
# <class 'str'> -7.1189535E-4
# <class 'str'> -7.113583E-4
# <class 'str'> -7.113583E-4
# <class 'str'> -7.109492E-4
# <class 'str'> -7.111128E-4
# <class 'str'> -7.111128E-4
# <class 'str'> -7.1086735E-4
# <class 'str'> -7.106218E-4
# <class 'str'> -7.106218E-4
# <class 'str'> -7.109082E-4
# <class 'str'> -7.103763E-4
# <class 'str'> -7.1082637E-4
# <class 'str'> -7.1054E-4
# <class 'str'> -7.1078545E-4
# <class 'str'> -7.1045815E-4
# <class 'str'> -7.1037636E-4
# <class 'str'> -7.106218E-4
# <class 'str'> -7.106218E-4
# <class 'str'> -7.1037636E-4
# <class 'str'> -7.102126E-4
# <class 'str'> -7.10008E-4
# <class 'str'> -7.099262E-4
# <class 'str'> -7.094761E-4
# <class 'str'> -7.0984435E-4
# <class 'str'> -7.0968067E-4
# <class 'str'> -7.1000797E-4
# <class 'str'> -7.09517E-4
# <class 'str'> -7.090669E-4
# <class 'str'> -7.091897E-4
# <class 'str'> -7.0943515E-4
# <class 'str'> -7.088623E-4
# <class 'str'> -7.087806E-4
# <class 'str'> -7.0902606E-4
# <class 'str'> -7.089443E-4
# <class 'str'> -7.090261E-4
# <class 'str'> -7.089443E-4
# <class 'str'> -7.093534E-4
# <class 'str'> -7.094352E-4
# <class 'str'> -7.0984435E-4
# <class 'str'> -7.0939434E-4
# <class 'str'> -7.0918974E-4
# <class 'str'> -7.09517E-4
# <class 'str'> -7.1000797E-4
# <class 'str'> -7.098852E-4
# <class 'str'> -7.1037625E-4
# <class 'str'> -7.102944E-4
# <class 'str'> -7.1037625E-4
# <class 'str'> -7.10008E-4
# <class 'str'> -7.101308E-4
# <class 'str'> -7.099262E-4
# <class 'str'> -7.10008E-4
# <class 'str'> -7.0976256E-4
# <class 'str'> -7.0992624E-4
# <class 'str'> -7.0984435E-4
# <class 'str'> -7.097625E-4
# <class 'str'> -7.088623E-4
# <class 'str'> -7.0955785E-4
# <class 'str'> -7.0906687E-4
# <class 'str'> -7.0902595E-4
# <class 'str'> -7.085758E-4
# <class 'str'> -7.0902595E-4
# <class 'str'> -7.0902595E-4
# <class 'str'> -7.085758E-4
# <class 'str'> -7.0894405E-4
# <class 'str'> -7.0910767E-4
# <class 'str'> -7.0955773E-4
# <class 'str'> -7.0976233E-4
# <class 'str'> -7.0951687E-4
# <class 'str'> -7.098442E-4
# <class 'str'> -7.102124E-4
# <class 'str'> -7.103761E-4
# <class 'str'> -7.1021245E-4
# <class 'str'> -7.1070343E-4
# <class 'str'> -7.1070343E-4
# <class 'str'> -7.1074435E-4
# <class 'str'> -7.109489E-4
# <class 'str'> -7.109489E-4
# <class 'str'> -7.109489E-4
# <class 'str'> -7.116444E-4
# <class 'str'> -7.1156264E-4
# <class 'str'> -7.120996E-4
# <class 'str'> -7.120587E-4
# <class 'str'> -7.12386E-4
# <class 'str'> -7.1250874E-4
# <class 'str'> -7.132452E-4
# <class 'str'> -7.1340887E-4
# <class 'str'> -7.139817E-4
# <class 'str'> -7.152552E-4
# <class 'str'> -7.1509153E-4
# <class 'str'> -7.1500975E-4
# <class 'str'> -7.1554165E-4
# <class 'str'> -7.1570533E-4
# <class 'str'> -7.1636E-4
# <class 'str'> -7.1660546E-4
# <class 'str'> -7.165237E-4
# <class 'str'> -7.165237E-4
# <class 'str'> -7.176284E-4
# <class 'str'> -7.1857456E-4
# <class 'str'> -7.182881E-4
# <class 'str'> -7.1832904E-4
# <class 'str'> -7.184109E-4
# <class 'str'> -7.192292E-4
# <class 'str'> -7.191474E-4
# <class 'str'> -7.19311E-4
# <class 'str'> -7.1906555E-4
# <class 'str'> -7.191474E-4
# <class 'str'> -7.1906555E-4
# <class 'str'> -7.1906555E-4
# <class 'str'> -7.1906555E-4
# <class 'str'> -7.19311E-4
# <class 'str'> -7.1906555E-4
# <class 'str'> -7.1873824E-4
# <class 'str'> -7.1873824E-4
# <class 'str'> -7.1873824E-4
# <class 'str'> -7.186564E-4
# <class 'str'> -7.186564E-4
# <class 'str'> -7.1841094E-4
# <class 'str'> -7.18861E-4
# <class 'str'> -7.185337E-4
# <class 'str'> -7.185337E-4
# <class 'str'> -7.188201E-4
# <class 'str'> -7.188201E-4
# <class 'str'> -7.189019E-4
# <class 'str'> -7.1898376E-4
# <class 'str'> -7.192292E-4
# <class 'str'> -7.1865646E-4
# <class 'str'> -7.187383E-4
# <class 'str'> -7.190656E-4
# <class 'str'> -7.193929E-4
# <class 'str'> -7.190656E-4
# <class 'str'> -7.190656E-4
# <class 'str'> -7.197202E-4
# <class 'str'> -7.196793E-4
# <class 'str'> -7.200884E-4
# <class 'str'> -7.2000653E-4
# <class 'str'> -7.20252E-4
# <class 'str'> -7.209476E-4
# <class 'str'> -7.208248E-4
# <class 'str'> -7.2066113E-4
# <class 'str'> -7.211112E-4
# <class 'str'> -7.211112E-4
# <class 'str'> -7.214436E-4
# <class 'str'> -7.216891E-4
# <class 'str'> -7.217709E-4
# <class 'str'> -7.2218006E-4
# <class 'str'> -7.300626E-4
# <class 'str'> -7.3047174E-4
# <class 'str'> -7.3096267E-4
# <class 'str'> -7.307581E-4
# <class 'str'> -7.3096267E-4
# <class 'str'> -7.3096267E-4
# <class 'str'> -7.3133095E-4
# <class 'str'> -7.3133095E-4
# <class 'str'> -7.314946E-4
# <class 'str'> -7.321083E-4
# <class 'str'> -7.3239475E-4
# <class 'str'> -7.323538E-4
# <class 'str'> -7.325993E-4
# <class 'str'> -7.325175E-4
# <class 'str'> -7.32763E-4
# <class 'str'> -7.324356E-4
# <class 'str'> -7.32763E-4
# <class 'str'> -7.32763E-4
# <class 'str'> -7.328448E-4
# <class 'str'> -7.330954E-4
# <class 'str'> -7.334636E-4
# <class 'str'> -7.334636E-4
# <class 'str'> -7.3403644E-4
# <class 'str'> -7.3387276E-4
# <class 'str'> -7.3387276E-4
# <class 'str'> -7.3387276E-4
# <class 'str'> -7.3403644E-4
# <class 'str'> -7.342001E-4
# <class 'str'> -7.343638E-4
# <class 'str'> -7.341183E-4
# <class 'str'> -7.3403644E-4
# <class 'str'> -7.3403644E-4
# <class 'str'> -7.3370914E-4
# <class 'str'> -7.341183E-4
# <class 'str'> -7.342001E-4
# <class 'str'> -7.3403644E-4
# <class 'str'> -7.3403644E-4
# <class 'str'> -7.3481386E-4
# <class 'str'> -7.3481386E-4
# <class 'str'> -7.350593E-4
# <class 'str'> -7.353867E-4
# <class 'str'> -7.353867E-4
# <class 'str'> -7.360873E-4
# <class 'str'> -7.3633285E-4
# <class 'str'> -7.3600037E-4
# <class 'str'> -7.3666015E-4
# <class 'str'> -7.368238E-4
# <class 'str'> -7.374376E-4
# <class 'str'> -7.374376E-4
# <class 'str'> -7.3801033E-4
# <class 'str'> -7.377648E-4
# <class 'str'> -7.3801033E-4
# <class 'str'> -7.377648E-4
# <class 'str'> -7.380922E-4
# <class 'str'> -7.3784665E-4
# <class 'str'> -7.3784665E-4
# <class 'str'> -7.3784665E-4
# <class 'str'> -7.376012E-4
# <class 'str'> -7.379285E-4
# <class 'str'> -7.38174E-4
# <class 'str'> -7.38174E-4
# <class 'str'> -7.388287E-4
# <class 'str'> -7.391969E-4
# <class 'str'> -7.394475E-4
# <class 'str'> -7.390332E-4
# <class 'str'> -7.395293E-4
# <class 'str'> -7.405113E-4
# <class 'str'> -7.407977E-4
# <class 'str'> -7.41125E-4
# <class 'str'> -7.407977E-4
# <class 'str'> -7.419433E-4
# <class 'str'> -7.417387E-4
# <class 'str'> -7.429304E-4
# <class 'str'> -7.4333954E-4
# <class 'str'> -7.4325775E-4
# <class 'str'> -7.4325775E-4
# <class 'str'> -7.440351E-4
# <class 'str'> -7.4518076E-4
# <class 'str'> -7.455899E-4
# <class 'str'> -7.458814E-4
# <class 'str'> -7.456308E-4
# <class 'str'> -7.455899E-4
# <class 'str'> -7.453444E-4
# <class 'str'> -7.460451E-4
# <class 'str'> -7.458405E-4
# <class 'str'> -7.4518076E-4
# <class 'str'> -7.453853E-4
# <class 'str'> -7.45058E-4
# <class 'str'> -7.4567687E-4
# <class 'str'> -7.4518076E-4
# <class 'str'> -7.4518076E-4
# <class 'str'> -7.450171E-4
# <class 'str'> -7.457178E-4
# <class 'str'> -7.457996E-4
# <class 'str'> -7.462087E-4
# <class 'str'> -7.461269E-4
# <class 'str'> -7.4653607E-4
# <class 'str'> -7.460451E-4
# <class 'str'> -7.4629055E-4
# <class 'str'> -7.4731343E-4
# <class 'str'> -7.478044E-4
# <class 'str'> -7.4858184E-4
# <class 'str'> -7.492825E-4
# <class 'str'> -7.497735E-4
# <class 'str'> -7.497735E-4
# <class 'str'> -7.4960984E-4
# <class 'str'> -7.4977346E-4
# <class 'str'> -7.494051E-4
# <class 'str'> -7.4911874E-4
# <class 'str'> -7.49487E-4
# <class 'str'> -7.492825E-4
# <class 'str'> -7.489961E-4
# <class 'str'> -7.489961E-4
# <class 'str'> -7.4841816E-4
# <class 'str'> -7.486636E-4
# <class 'str'> -7.486636E-4
# <class 'str'> -7.486636E-4
# <class 'str'> -7.488273E-4
# <class 'str'> -7.4891426E-4
# <class 'str'> -7.4891426E-4
# <class 'str'> -7.490779E-4
# <class 'str'> -7.4899604E-4
# <class 'str'> -7.4911874E-4
# <class 'str'> -7.494051E-4
# <class 'str'> -7.4948696E-4
# <class 'str'> -7.499371E-4
# <class 'str'> -7.494052E-4
# <class 'str'> -7.496916E-4
# <class 'str'> -7.5010076E-4
# <class 'str'> -7.5055077E-4
# <class 'str'> -7.5018255E-4
# <class 'str'> -7.502644E-4
# <class 'str'> -7.5010076E-4
# <class 'str'> -7.504281E-4
# <class 'str'> -7.5071456E-4
# <class 'str'> -7.509601E-4
# <class 'str'> -7.509601E-4
# <class 'str'> -7.5153285E-4
# <class 'str'> -7.518193E-4
# <class 'str'> -7.5239723E-4
# <class 'str'> -7.527245E-4
# <class 'str'> -7.528882E-4
# <class 'str'> -7.523154E-4
# <class 'str'> -7.5219263E-4
# <class 'str'> -7.5202377E-4
# <class 'str'> -7.527245E-4
# <class 'str'> -7.5264263E-4
# <class 'str'> -7.529699E-4
# <class 'str'> -7.5321534E-4
# <class 'str'> -7.529699E-4
# <class 'str'> -7.5256074E-4
# <class 'str'> -7.533381E-4
# <class 'str'> -7.519009E-4
# <class 'str'> -7.525606E-4
# <class 'str'> -7.5231516E-4
# <class 'str'> -7.521106E-4
# <class 'str'> -7.5202365E-4
# <class 'str'> -7.5202365E-4
# <class 'str'> -7.523971E-4
# <class 'str'> -7.519419E-4
# <class 'str'> -7.520236E-4
# <class 'str'> -7.525607E-4
# <class 'str'> -7.5247884E-4
# <class 'str'> -7.5247884E-4
# <class 'str'> -7.5313356E-4
# <class 'str'> -7.5366546E-4
# <class 'str'> -7.535427E-4
# <class 'str'> -7.528472E-4
# <class 'str'> -7.532971E-4
# <class 'str'> -7.532971E-4
# <class 'str'> -7.525607E-4
# <class 'str'> -7.5272436E-4
# <class 'str'> -7.528471E-4
# <class 'str'> -7.5341994E-4
# <class 'str'> -7.532154E-4
# <class 'str'> -7.5321534E-4
# <class 'str'> -7.533381E-4
# <class 'str'> -7.5374724E-4
# <class 'str'> -7.53379E-4
# <class 'str'> -7.539518E-4
# <class 'str'> -7.53829E-4
# <class 'str'> -7.5440184E-4
# <class 'str'> -7.545246E-4
# <class 'str'> -7.5575715E-4
# <class 'str'> -7.5526617E-4
# <class 'str'> -7.55348E-4
# <class 'str'> -7.5645273E-4
# <class 'str'> -7.565346E-4
# <class 'str'> -7.569437E-4
# <class 'str'> -7.569437E-4
# <class 'str'> -7.5624813E-4
# <class 'str'> -7.5747556E-4
# <class 'str'> -7.58212E-4
# <class 'str'> -7.580484E-4
# <class 'str'> -7.580484E-4
# <class 'str'> -7.57803E-4
# <class 'str'> -7.586673E-4
# <class 'str'> -7.5948564E-4
# <class 'str'> -7.596493E-4
# <class 'str'> -7.5940386E-4
# <class 'str'> -7.5854466E-4
# <class 'str'> -7.5854466E-4
# <class 'str'> -7.5804855E-4
# <class 'str'> -7.574349E-4
# <class 'str'> -7.572712E-4
# <class 'str'> -7.566984E-4
# <class 'str'> -7.566984E-4
# <class 'str'> -7.565348E-4
# <class 'str'> -7.564939E-4
# <class 'str'> -7.563711E-4
# <class 'str'> -7.561666E-4
# <class 'str'> -7.5608474E-4
# <class 'str'> -7.5588014E-4
# <class 'str'> -7.560438E-4
# <class 'str'> -7.5567554E-4
# <class 'str'> -7.5543E-4
# <class 'str'> -7.5517944E-4
# <class 'str'> -7.5489306E-4
# <class 'str'> -7.550976E-4
# <class 'str'> -7.548112E-4
# <class 'str'> -7.5464754E-4
# <class 'str'> -7.5456576E-4
# <class 'str'> -7.545248E-4
# <class 'str'> -7.542384E-4
# <class 'str'> -7.54443E-4
# <class 'str'> -7.5456576E-4
# <class 'str'> -7.5456576E-4
# <class 'str'> -7.5423846E-4
# <class 'str'> -7.543203E-4
# <class 'str'> -7.543203E-4
# <class 'str'> -7.543203E-4
# <class 'str'> -7.5444306E-4
# <class 'str'> -7.543203E-4
# <class 'str'> -7.54484E-4
# <class 'str'> -7.548113E-4
# <class 'str'> -7.5472944E-4
# <class 'str'> -7.546886E-4
# <class 'str'> -7.545658E-4
# <class 'str'> -7.546476E-4
# <class 'str'> -7.546476E-4
# <class 'str'> -7.5444306E-4
# <class 'str'> -7.5444306E-4
# <class 'str'> -7.546067E-4
# <class 'str'> -6.9744623E-4
# <class 'str'> -6.9720077E-4
# <class 'str'> -6.9720077E-4
# <class 'str'> -6.9720077E-4
# <class 'str'> -6.9695525E-4
# <class 'str'> -6.964642E-4
# <class 'str'> -6.9642335E-4
# <class 'str'> -6.961778E-4
# <class 'str'> -6.961778E-4
# <class 'str'> -6.955232E-4
# <class 'str'> -6.955232E-4
# <class 'str'> -6.9540046E-4
# <class 'str'> -6.953186E-4
# <class 'str'> -6.951499E-4
# <class 'str'> -6.9486344E-4
# <class 'str'> -6.950271E-4
# <class 'str'> -6.943316E-4
# <class 'str'> -6.947407E-4
# <class 'str'> -6.9457706E-4
# <class 'str'> -6.944133E-4
# <class 'str'> -6.941679E-4
# <class 'str'> -6.940451E-4
# <class 'str'> -6.937587E-4
# <class 'str'> -6.941679E-4
# <class 'str'> -6.9396326E-4
# <class 'str'> -6.938815E-4
# <class 'str'> -6.937587E-4
# <class 'str'> -6.9384056E-4
# <class 'str'> -6.9424976E-4
# <class 'str'> -6.935542E-4
# <class 'str'> -6.9424976E-4
# <class 'str'> -6.951089E-4
# <class 'str'> -6.959323E-4
# <class 'str'> -6.9625967E-4
# <class 'str'> -6.955232E-4
# <class 'str'> -6.958505E-4
# <class 'str'> -6.9568685E-4
# <class 'str'> -6.9535954E-4
# <class 'str'> -6.9490436E-4
# <class 'str'> -6.951089E-4
# <class 'str'> -6.951089E-4
# <class 'str'> -6.9457706E-4
# <class 'str'> -6.9465884E-4
# <class 'str'> -6.947407E-4
# <class 'str'> -6.9449516E-4
# <class 'str'> -6.938815E-4
# <class 'str'> -6.9359504E-4
# <class 'str'> -6.935542E-4
# <class 'str'> -6.9347234E-4
# <class 'str'> -6.940861E-4
# <class 'str'> -6.9379964E-4
# <class 'str'> -6.933905E-4
# <class 'str'> -6.93145E-4
# <class 'str'> -6.9330866E-4
# <class 'str'> -6.928177E-4
# <class 'str'> -6.923267E-4
# <class 'str'> -6.928995E-4
# <class 'str'> -6.928995E-4
# <class 'str'> -6.937178E-4
# <class 'str'> -6.941679E-4
# <class 'str'> -6.938815E-4
# <class 'str'> -6.941679E-4
# <class 'str'> -6.943316E-4
# <class 'str'> -6.9465884E-4
# <class 'str'> -6.9490436E-4
# <class 'str'> -6.951089E-4
# <class 'str'> -6.946998E-4
# <class 'str'> -6.9449516E-4
# <class 'str'> -6.9506804E-4
# <class 'str'> -6.955232E-4
# <class 'str'> -6.9560506E-4
# <class 'str'> -6.9523166E-4
# <class 'str'> -6.9523166E-4
# <class 'str'> -6.958505E-4
# <class 'str'> -6.9630065E-4
# <class 'str'> -6.9638237E-4
# <class 'str'> -6.961778E-4
# <class 'str'> -6.957687E-4
# <class 'str'> -6.953186E-4
# <class 'str'> -6.948225E-4
# <class 'str'> -6.9490436E-4
# <class 'str'> -6.948225E-4
# <class 'str'> -6.9457706E-4
# <class 'str'> -6.937587E-4
# <class 'str'> -6.934314E-4
# <class 'str'> -6.939224E-4
# <class 'str'> -6.939224E-4
# <class 'str'> -6.9400424E-4
# <class 'str'> -6.928177E-4
# <class 'str'> -6.9363596E-4
# <class 'str'> -6.928177E-4
# <class 'str'> -6.928995E-4
# <class 'str'> -6.926131E-4
# <class 'str'> -6.926949E-4
# <class 'str'> -6.9244945E-4
# <class 'str'> -6.9224485E-4
# <class 'str'> -6.923676E-4
# <class 'str'> -6.925722E-4
# <class 'str'> -6.923676E-4
# <class 'str'> -6.923676E-4
# <class 'str'> -6.922858E-4
# <class 'str'> -6.922858E-4
# <class 'str'> -6.922858E-4
# <class 'str'> -6.918715E-4
# <class 'str'> -6.920352E-4
# <class 'str'> -6.922858E-4
# <class 'str'> -6.922858E-4
# <class 'str'> -6.920352E-4
# <class 'str'> -6.923676E-4
# <class 'str'> -6.9212215E-4
# <class 'str'> -6.9212215E-4
# <class 'str'> -6.923676E-4
# <class 'str'> -6.918715E-4
# <class 'str'> -6.92204E-4
# <class 'str'> -6.9244945E-4
# <class 'str'> -6.9212215E-4
# <class 'str'> -6.9212215E-4
# <class 'str'> -6.9212215E-4
# <class 'str'> -6.9212215E-4
# <class 'str'> -6.923676E-4
# <class 'str'> -6.9212215E-4
# <class 'str'> -6.9212215E-4
# <class 'str'> -6.9212215E-4
# <class 'str'> -6.9212215E-4
# <class 'str'> -6.9244945E-4
# <class 'str'> -6.920352E-4
# <class 'str'> -6.9212215E-4
# <class 'str'> -6.9212215E-4
# <class 'str'> -6.9212215E-4
# <class 'str'> -6.92204E-4
# <class 'str'> -6.9195335E-4
# <class 'str'> -6.920352E-4
# <class 'str'> -6.9178967E-4
# <class 'str'> -6.9212215E-4
# <class 'str'> -6.9212215E-4
# <class 'str'> -6.920352E-4
# <class 'str'> -6.9178967E-4
# <class 'str'> -6.9154415E-4
# <class 'str'> -6.918715E-4
# <class 'str'> -6.918715E-4
# <class 'str'> -6.917078E-4
# <class 'str'> -6.91626E-4
# <class 'str'> -6.918715E-4
# <class 'str'> -6.918715E-4
# <class 'str'> -6.9212215E-4
# <class 'str'> -6.917078E-4
# <class 'str'> -6.9178967E-4
# <class 'str'> -6.9178967E-4
# <class 'str'> -6.9178967E-4
# <class 'str'> -6.91626E-4
# <class 'str'> -6.920352E-4
# <class 'str'> -6.920352E-4
# <class 'str'> -6.9195335E-4
# <class 'str'> -6.91626E-4
# <class 'str'> -6.917078E-4
# <class 'str'> -6.9195335E-4
# <class 'str'> -6.9178967E-4
# <class 'str'> -6.9178967E-4
# <class 'str'> -6.913396E-4
# <class 'str'> -6.914623E-4
# <class 'str'> -6.918715E-4
# <class 'str'> -6.9212215E-4
# <class 'str'> -6.9178967E-4
# <class 'str'> -6.920352E-4
# <class 'str'> -6.9178967E-4
# <class 'str'> -6.9178967E-4
# <class 'str'> -6.918715E-4
# <class 'str'> -6.918715E-4
# <class 'str'> -6.923676E-4
# <class 'str'> -6.922858E-4
# <class 'str'> -6.92204E-4
# <class 'str'> -6.918715E-4
# <class 'str'> -6.9212215E-4
# <class 'str'> -6.920352E-4
# <class 'str'> -6.920352E-4
# <class 'str'> -6.920352E-4
# <class 'str'> -6.920352E-4
# <class 'str'> -6.923676E-4
# <class 'str'> -6.9298135E-4
# <class 'str'> -6.937587E-4
# <class 'str'> -6.938815E-4
# <class 'str'> -6.938815E-4
# <class 'str'> -6.938815E-4
# <class 'str'> -6.9457706E-4
# <class 'str'> -6.951089E-4
# <class 'str'> -6.953186E-4
# <class 'str'> -6.953186E-4
# <class 'str'> -6.9523166E-4
# <class 'str'> -6.959323E-4
# <class 'str'> -6.96096E-4
# <class 'str'> -6.965052E-4
# <class 'str'> -6.971189E-4
# <class 'str'> -6.9781445E-4
# <class 'str'> -6.977326E-4
# <class 'str'> -6.9752807E-4
# <class 'str'> -6.9728255E-4
# <class 'str'> -6.970371E-4
# <class 'str'> -6.970371E-4
# <class 'str'> -6.96587E-4
# <class 'str'> -6.966279E-4
# <class 'str'> -6.96096E-4
# <class 'str'> -6.9642335E-4
# <class 'str'> -6.9540046E-4
# <class 'str'> -6.951499E-4
# <class 'str'> -6.951499E-4
# <class 'str'> -6.9560506E-4
# <class 'str'> -6.953186E-4
# <class 'str'> -6.950271E-4
# <class 'str'> -6.954414E-4
# <class 'str'> -6.9519074E-4
# <class 'str'> -6.952777E-4
# <class 'str'> -6.949453E-4
# <class 'str'> -6.949453E-4
# <class 'str'> -6.949453E-4
# <class 'str'> -6.949862E-4
# <class 'str'> -6.951089E-4
# <class 'str'> -6.9457706E-4
# <class 'str'> -6.9478166E-4
# <class 'str'> -6.951089E-4
# <class 'str'> -6.947407E-4
# <class 'str'> -6.947407E-4
# <class 'str'> -6.952777E-4
# <class 'str'> -6.948225E-4
# <class 'str'> -6.9457706E-4
# <class 'str'> -6.947407E-4
# <class 'str'> -6.949862E-4
# <class 'str'> -6.947407E-4
# <class 'str'> -6.947407E-4
# <class 'str'> -6.947407E-4
# <class 'str'> -6.947407E-4
# <class 'str'> -6.948225E-4
# <class 'str'> -6.9465884E-4
# <class 'str'> -6.949862E-4
# <class 'str'> -6.9465884E-4
# <class 'str'> -6.947407E-4
# <class 'str'> -6.944133E-4
# <class 'str'> -6.947407E-4
# <class 'str'> -6.943316E-4
# <class 'str'> -6.9457706E-4
# <class 'str'> -6.9465884E-4
# <class 'str'> -6.9465884E-4
# <class 'str'> -6.9465884E-4
# <class 'str'> -6.947407E-4
# <class 'str'> -6.9449516E-4
# <class 'str'> -6.944133E-4
# <class 'str'> -6.9465884E-4
# <class 'str'> -6.9490436E-4
# <class 'str'> -6.9449516E-4
# <class 'str'> -6.948225E-4
# <class 'str'> -6.947407E-4
# <class 'str'> -6.947407E-4
# <class 'str'> -6.944133E-4
# <class 'str'> -6.9465884E-4
# <class 'str'> -6.9490436E-4
# <class 'str'> -6.9519074E-4
# <class 'str'> -6.949862E-4
# <class 'str'> -6.9506804E-4
# <class 'str'> -6.951089E-4
# <class 'str'> -6.947407E-4
# <class 'str'> -6.9465884E-4
# <class 'str'> -6.9490436E-4
# <class 'str'> -6.947407E-4
# <class 'str'> -6.947407E-4
# <class 'str'> -6.9449516E-4
# <class 'str'> -6.947407E-4
# <class 'str'> -6.949862E-4
# <class 'str'> -6.949862E-4
# <class 'str'> -6.9519074E-4
# <class 'str'> -6.9457706E-4
# <class 'str'> -6.9465884E-4
# <class 'str'> -6.9465884E-4
# <class 'str'> -6.9465884E-4
# <class 'str'> -6.9449516E-4
# <class 'str'> -6.948225E-4
# <class 'str'> -6.943316E-4
# <class 'str'> -6.944133E-4
# <class 'str'> -6.9424976E-4
# <class 'str'> -6.940451E-4
# <class 'str'> -6.948225E-4
# <class 'str'> -6.9490436E-4
# <class 'str'> -6.9465884E-4
# <class 'str'> -6.948225E-4
# <class 'str'> -6.9506804E-4
# <class 'str'> -6.9457706E-4
# <class 'str'> -6.948225E-4
# <class 'str'> -6.9523166E-4
# <class 'str'> -6.949862E-4
# <class 'str'> -6.9490436E-4
# <class 'str'> -6.9490436E-4
# <class 'str'> -6.949862E-4
# <class 'str'> -6.951499E-4
# <class 'str'> -6.9506804E-4
# <class 'str'> -6.951499E-4
# <class 'str'> -6.951499E-4
# <class 'str'> -6.9486344E-4
# <class 'str'> -6.951089E-4
# <class 'str'> -6.949862E-4
# <class 'str'> -6.949862E-4
# <class 'str'> -6.958505E-4
# <class 'str'> -6.970371E-4
# <class 'str'> -6.9744623E-4
# <class 'str'> -6.9720077E-4
# <class 'str'> -6.9728255E-4
# <class 'str'> -6.9748715E-4
# <class 'str'> -6.979372E-4
# <class 'str'> -6.9777353E-4
# <class 'str'> -6.982236E-4
# <class 'str'> -6.9777353E-4
# <class 'str'> -6.9871976E-4
# <class 'str'> -6.997426E-4
# <class 'str'> -6.998244E-4
# <class 'str'> -6.9990626E-4
# <class 'str'> -6.9990626E-4
# <class 'str'> -7.003154E-4
# <class 'str'> -7.0109277E-4
# <class 'str'> -7.014201E-4
# <class 'str'> -7.0150197E-4
# <class 'str'> -7.0125645E-4
# <class 'str'> -7.0150197E-4
# <class 'str'> -7.013383E-4
# <class 'str'> -7.0109277E-4
# <class 'str'> -7.008064E-4
# <class 'str'> -7.015838E-4
# <class 'str'> -7.014201E-4
# <class 'str'> -7.010109E-4
# <class 'str'> -7.0072454E-4
# <class 'str'> -7.006427E-4
# <class 'str'> -7.006427E-4
# <class 'str'> -7.0039724E-4
# <class 'str'> -7.00479E-4
# <class 'str'> -7.0006994E-4
# <class 'str'> -7.0052E-4
# <class 'str'> -7.0039724E-4
# <class 'str'> -7.003154E-4
# <class 'str'> -7.0019264E-4
# <class 'str'> -7.008064E-4
# <class 'str'> -7.0072454E-4
# <class 'str'> -7.0039724E-4
# <class 'str'> -7.009291E-4
# <class 'str'> -7.0150197E-4
# <class 'str'> -7.0150197E-4
# <class 'str'> -7.0179347E-4
# <class 'str'> -7.0228445E-4
# <class 'str'> -7.0207985E-4
# <class 'str'> -7.025299E-4
# <class 'str'> -7.0167077E-4
# <class 'str'> -7.0228445E-4
# <class 'str'> -7.025299E-4
# <class 'str'> -7.0244813E-4
# <class 'str'> -7.028573E-4
# <class 'str'> -7.0298E-4
# <class 'str'> -7.0371653E-4
# <class 'str'> -7.0461666E-4
# <class 'str'> -7.0486724E-4
# <class 'str'> -7.050718E-4
# <class 'str'> -7.0499E-4
# <class 'str'> -7.042893E-4
# <class 'str'> -7.038801E-4
# <class 'str'> -7.0371653E-4
# <class 'str'> -7.0404384E-4
# <class 'str'> -7.038801E-4
# <class 'str'> -7.036347E-4
# <class 'str'> -7.031846E-4
# <class 'str'> -7.0289813E-4
# <class 'str'> -7.0310273E-4
# <class 'str'> -7.0277543E
# <class 'str'> -7.0277543E
# <class 'str'> -7.0277543E
# <class 'str'> -7.0277543E
# <class 'str'> -7.0277543E
# <class 'str'> -7.0277543E
# <class 'str'> -7.0277543E
# <class 'str'> -7.0277543E
# <class 'str'> -7.0277543E
# <class 'str'> -7.0277543E
# <class 'str'> -7.0277543E
# <class 'str'> -7.0277543E
# <class 'str'> -7.0277543E
# <class 'str'> -7.0277543E
# <class 'str'> -7.0277543E
# <class 'str'> -7.0277543E
# <class 'str'> -7.0277543E
# <class 'str'> -7.0277543E

# %% [markdown]
# ## Create Scaler Class

# %%
class Scaler():
    def __init__(self, data, cols):
        self.scaler = dict()
        for col in cols:
            self.scaler[col] = MinMaxScaler()
            self.scaler[col].fit(self.to_numpy(data[col]))
    def transform(self, data):
        output = data.copy()
        keys = self.scaler.keys()
        for col in output.columns:
            if col in keys:
                temp = self.scaler[col].transform(self.to_numpy(data[col]))
                output[col] = self.to_series(temp, col)
        return output
    
    def inverse_transform(self, data):
        output = data.copy()
        keys = self.scaler.keys()
        for col in output.columns:
            if col in keys:
                output[col] = self.scaler[col].inverse_transform(output[col])
        return output
    def to_numpy(self, series):
        return np.array(series).reshape(-1, 1)
        
    def to_series(self, array, col):
        array = array.reshape(-1)
        return pd.Series(data = array, name = col)
        
        
            
scaler = Scaler(df_train, scaled_features)
df_train = scaler.transform(df_train)
df_train
# Out:
#              collectionName        phoneName  millisSinceGpsEpoch     latDeg  \
# 0       2020-05-14-US-MTV-1           Pixel4        1273529463442  37.423575
# 1       2020-05-14-US-MTV-1           Pixel4        1273529464442  37.423578
# 2       2020-05-14-US-MTV-1           Pixel4        1273529465442  37.423573
# 3       2020-05-14-US-MTV-1           Pixel4        1273529466442  37.423583
# 4       2020-05-14-US-MTV-1   Pixel4XLModded        1273529466449  37.423574
# ...                     ...              ...                  ...        ...
# 131337  2021-04-29-US-MTV-1  SamsungS20Ultra        1303770559000  37.395790
# 131338  2021-04-29-US-MTV-1  SamsungS20Ultra        1303770560000  37.395784
# 131339  2021-04-29-US-MTV-1  SamsungS20Ultra        1303770561000  37.395813
# 131340  2021-04-29-US-MTV-1  SamsungS20Ultra        1303770562000  37.395822
# 131341  2021-04-29-US-MTV-1  SamsungS20Ultra        1303770563000  37.395824
#
#             lngDeg  heightAboveWgs84EllipsoidM  \
# 0      -122.094091                      -34.06
# 1      -122.094101                      -33.29
# 2      -122.094111                      -30.99
# 3      -122.094121                      -32.83
# 4      -122.094137                      -33.20
# ...            ...                         ...
# 131337 -122.103020                       21.70
# 131338 -122.103041                       21.39
# 131339 -122.103052                        9.87
# 131340 -122.103019                       10.75
# 131341 -122.103019                        7.37
#
#                                       phone  utcTimeMillis_x  \
# 0                2020-05-14-US-MTV-1_Pixel4     1.589494e+12
# 1                2020-05-14-US-MTV-1_Pixel4     1.589494e+12
# 2                2020-05-14-US-MTV-1_Pixel4     1.589494e+12
# 3                2020-05-14-US-MTV-1_Pixel4     1.589494e+12
# 4        2020-05-14-US-MTV-1_Pixel4XLModded     1.589494e+12
# ...                                     ...              ...
# 131337  2021-04-29-US-MTV-1_SamsungS20Ultra     1.619735e+12
# 131338  2021-04-29-US-MTV-1_SamsungS20Ultra     1.619735e+12
# 131339  2021-04-29-US-MTV-1_SamsungS20Ultra     1.619735e+12
# 131340  2021-04-29-US-MTV-1_SamsungS20Ultra     1.619735e+12
# 131341  2021-04-29-US-MTV-1_SamsungS20Ultra     1.619735e+12
#
#         elapsedRealtimeNanos_x  UncalGyroXRadPerSec  ...  satClkBiasM  \
# 0                 1.965654e+13             0.507496  ...     -468.084
# 1                 1.965754e+13             0.506651  ...    65954.431
# 2                 1.965854e+13             0.508199  ...     1223.261
# 3                 1.965954e+13             0.503253  ...    65954.426
# 4                 1.734189e+13             0.751139  ...    -3909.257
# ...                        ...                  ...  ...          ...
# 131337            7.922927e+13             0.508145  ...   -10335.849
# 131338            7.923027e+13             0.512054  ...   -33065.690
# 131339            7.923127e+13             0.505426  ...    13606.212
# 131340            7.923227e+13             0.507805  ...   139129.304
# 131341            7.923327e+13             0.510694  ...   -60090.310
#
#         satClkDriftMps        rawPrM  rawPrUncM     isrbM  ionoDelayM  \
# 0                0.001  2.379498e+07     11.992  1134.758      10.866
# 1               -0.002  2.592442e+07      3.897  -222.675       7.111
# 2                0.000  2.131445e+07      1.499     0.000       4.777
# 3               -0.002  2.592544e+07      3.598  -220.611       7.113
# 4                0.001  2.318871e+07     10.493     0.000       7.313
# ...                ...           ...        ...       ...         ...
# 131337          -0.002  2.030376e+07      9.893     0.000       3.765
# 131338          -0.001  2.028822e+07     23.983   -11.032       4.392
# 131339           0.009  2.421064e+07     20.686   -11.760      16.388
# 131340           0.001  2.581079e+07      8.394    19.276      10.223
# 131341          -0.002  2.566759e+07     23.384     5.799       5.543
#
#         tropoDelayM      meter   dlngDeg   dlatDeg
# 0            16.647   4.345847  0.512148  0.569395
# 1             5.174   3.324526  0.512136  0.569399
# 2             3.371   2.279173  0.512123  0.569391
# 3             5.183   1.381411  0.512109  0.569409
# 4             5.311   0.794351  0.512148  0.569395
# ...             ...        ...       ...       ...
# 131337        2.485  11.285731  0.512159  0.569390
# 131338        3.085  13.599167  0.512131  0.569380
# 131339        7.407  14.251517  0.512117  0.569435
# 131340       10.745  10.715989  0.512160  0.569451
# 131341        4.199  10.736952  0.512160  0.569455
#
# [131342 rows x 113 columns]

# %%
df_train[features].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 131342 entries, 0 to 131341
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   latDeg                      131342 non-null  float64
#  1   lngDeg                      131342 non-null  float64
#  2   heightAboveWgs84EllipsoidM  131342 non-null  float64
#  3   dlatDeg                     131342 non-null  float64
#  4   dlngDeg                     131342 non-null  float64
#  5   xSatVelMps                  131342 non-null  float64
#  6   ySatVelMps                  131342 non-null  float64
#  7   zSatVelMps                  131342 non-null  float64
#  8   xSatPosM                    131342 non-null  float64
#  9   ySatPosM                    131342 non-null  float64
#  10  zSatPosM                    131342 non-null  float64
#  11  UncalGyroXRadPerSec         113798 non-null  float64
#  12  UncalGyroYRadPerSec         113798 non-null  float64
#  13  UncalGyroZRadPerSec         113798 non-null  float64
#  14  DriftXRadPerSec             74725 non-null   float64
#  15  DriftYRadPerSec             74725 non-null   float64
#  16  DriftZRadPerSec             74725 non-null   float64
#  17  UncalMagXMicroT             113780 non-null  float64
#  18  UncalMagYMicroT             113780 non-null  float64
#  19  UncalMagZMicroT             113762 non-null  float64
#  20  UncalAccelXMps2             113798 non-null  float64
#  21  UncalAccelYMps2             113798 non-null  float64
#  22  UncalAccelZMps2             113798 non-null  float64
# dtypes: float64(23)
# memory usage: 24.0 MB

# %%
df_train = df_train.fillna(method = 'pad')
df_train = df_train.fillna(0)

# %%
df_train[features].describe()
# Out:
#               latDeg         lngDeg  heightAboveWgs84EllipsoidM  \
# count  131342.000000  131342.000000               131342.000000
# mean       37.435206    -122.154925                   23.832922
# std         0.082712       0.145974                   72.589312
# min        37.321683    -122.472214                -6157.470000
# 25%        37.371575    -122.275109                  -26.790000
# 50%        37.424360    -122.118311                    3.230000
# 75%        37.469109    -122.069091                   59.410000
# max        37.690836    -121.881855                13701.980000
#
#              dlatDeg        dlngDeg     xSatVelMps     ySatVelMps  \
# count  131342.000000  131342.000000  131342.000000  131342.000000
# mean        0.555940       0.497013       0.575977       0.448827
# std         0.165104       0.175158       0.194161       0.210163
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.532389       0.451988       0.450427       0.290345
# 50%         0.567141       0.512504       0.552096       0.460259
# 75%         0.586828       0.532634       0.722192       0.588686
# max         1.000000       1.000000       1.000000       1.000000
#
#           zSatVelMps       xSatPosM       ySatPosM  ...  UncalGyroZRadPerSec  \
# count  131342.000000  131342.000000  131342.000000  ...        131342.000000
# mean        0.502620       0.421357       0.305790  ...             0.516100
# std         0.315663       0.230983       0.199411  ...             0.010426
# min         0.000000       0.000000       0.000000  ...             0.000000
# 25%         0.184381       0.244857       0.154505  ...             0.512894
# 50%         0.502293       0.373171       0.274920  ...             0.516814
# 75%         0.816786       0.594113       0.419485  ...             0.519640
# max         1.000000       1.000000       1.000000  ...             1.000000
#
#        DriftXRadPerSec  DriftYRadPerSec  DriftZRadPerSec  UncalMagXMicroT  \
# count    131342.000000    131342.000000    131342.000000    131342.000000
# mean          0.214558         0.173046         0.285329         0.534575
# std           0.177919         0.242996         0.276831         0.139990
# min           0.000000         0.000000         0.000000         0.000000
# 25%           0.000000         0.000000         0.000000         0.452408
# 50%           0.269665         0.108718         0.222054         0.525408
# 75%           0.307786         0.146917         0.433565         0.596477
# max           1.000000         1.000000         1.000000         1.000000
#
#        UncalMagYMicroT  UncalMagZMicroT  UncalAccelXMps2  UncalAccelYMps2  \
# count    131342.000000    131342.000000    131342.000000    131342.000000
# mean          0.440424         0.425319         0.663476         0.460839
# std           0.123094         0.191717         0.035844         0.072434
# min           0.000000         0.000000         0.000000         0.000000
# 25%           0.419100         0.361626         0.646929         0.465244
# 50%           0.465978         0.447712         0.661867         0.476216
# 75%           0.507930         0.495256         0.682273         0.485056
# max           1.000000         1.000000         1.000000         1.000000
#
#        UncalAccelZMps2
# count    131342.000000
# mean          0.516787
# std           0.082986
# min           0.000000
# 25%           0.486113
# 50%           0.513613
# 75%           0.543215
# max           1.000000
#
# [8 rows x 23 columns]

# %%
def data_slice_by_phone(df:pd.DataFrame, 
                        xCols = ['latDeg', 'lngDeg', 'heightAboveWgs84EllipsoidM'], 
                        yCols = ['t_latDeg', 't_lngDeg', 't_heightAboveWgs84EllipsoidM', 'speedMps', 'courseDegree']):
    indexCols = ['collectionName', 'phoneName', 'millisSinceGpsEpoch']
    
    indx = []
    data = []
    true = []
    for i, phone in enumerate(df['phone'].unique()):
        temp = df[df['phone'] == phone]
        indx.append(temp[indexCols])
        data.append(temp[xCols])
        true.append(temp[yCols])
        
    return indx, data, true

def data_merge_by_index(df:pd.DataFrame, index:pd.DataFrame, src:pd.DataFrame, srcCols = ['latDeg', 'lngDeg', 'heightAboveWgs84EllipsoidM']):
    indexCols = ['collectionName', 'phoneName', 'millisSinceGpsEpoch']
    output = df.copy()
    
    listFrame = []
    for i in range(len(index)):
        idxFrame = index[i]
        srcFrame = src[i]
        temp = pd.concat([idxFrame, srcFrame], axis = 1)
        listFrame.append(temp)
    
    dataFrame = pd.concat(listFrame, axis = 0)
    output = output.merge(dataFrame,
              on=["collectionName", "phoneName", "millisSinceGpsEpoch"])
    
    return output

idxFrame, dataFrame, trueFrame = data_slice_by_phone(df_train, xCols=features, yCols = labels)

# %% [markdown]
# # Check!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# slide window 기반은 때려치고, 데이터프레임에서 직접 읽어오는 방식으로 변경할 필요가 있음
# collectionName, phoneName기반으로 데이터를 잘라서 시계열 데이터처럼 쓸 예정 우선적으로 필요한 것은 lstm으로 돌려보기(baseline을 그렇게 하자!)

# %% [markdown]
# # Modeling

# %%
# build model
class ConvBlock(nn.Module):
    def __init__(self, input_features, output_features, kernel_size = 3):
        super().__init__()
        
        self.convK = nn.Conv1d(input_features, output_features, kernel_size = kernel_size, padding = kernel_size//2)
        self.conv = nn.Conv1d(input_features, output_features, 1)
        self.bn = nn.BatchNorm1d(output_features)
        
    def forward(self, inputs):
        x = self.convK(inputs)
        inputs = self.conv(inputs)
        x = self.bn(x)
        x = F.relu(x)
        outputs = x + inputs
        return outputs
    
class BigConv(nn.Module):
    def __init__(self, input_size, output_size):
        super().__init__()
        self.conv1 = ConvBlock(input_size, 2*input_size)
        self.conv2 = ConvBlock(2*input_size, 4*input_size)
        self.conv3 = ConvBlock(4*input_size, 4*input_size)
        self.conv4 = ConvBlock(4*input_size, 4*input_size)
        self.conv5 = ConvBlock(4*input_size, output_size)
        
    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.conv5(x)
        return x
    
    
    
class ConvolutionNetwork(nn.Module):
    def __init__(self, input_size, output_size):
        super().__init__()
        
#         self.conv = nn.Conv1d(input_size, output_size, 1)
        self.conv1 = BigConv(input_size, 64)
        self.conv2 = BigConv(64, 64)
        self.conv3 = BigConv(64, 64)
        self.conv4 = BigConv(64, output_size)
        
#         self.lstm = nn.LSTM(input_size = 512 + output_size, hidden_size = output_size, num_layers = 3, dropout = 0.3)
    
    def forward(self, x):
#         x1 = self.conv(x)
        
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        
#         x = torch.cat([x1, x], axis = 1)
#         x, hidden = self.lstm(x)
        
        return x
    
model = ConvolutionNetwork(len(features), len(labels))
model.to(device)

# loss_func = nn.SmoothL1Loss()
loss_func = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr = lr)
scheduler = optim.lr_scheduler.LambdaLR(optimizer=optimizer,
                                lr_lambda=lambda epoch: 0.995 ** epoch,
                                last_epoch=-1,
                                verbose=True)
# Out:
# Adjusting learning rate of group 0 to 1.0000e-03.

# %%
class CustomDataloader(torch.utils.data.Dataset):
    def __init__(self, data, true = None):
        self.data = data
        self.true = true
        self.len = len(data)
        
    
    def __len__(self):
        return self.len
    
    def __shuffle__(self):
        index = np.array(range(self.len), dtype = 'int')
        index = np.random.permutation(index)
        data = []
        true = []
        for i in range(self.len):
            data.append(self.data[index[i]])
            true.append(self.true[index[i]])
            
        self.data = data
        self.true = true
    
    def __getitem__(self, idx):
        data = self.data[idx]
        if self.true is None:
            true = []
        else:
            true = self.true[idx]
            
        data = torch.Tensor(np.expand_dims(np.array(data), 0)).transpose(2, 1)
        true = torch.Tensor(np.expand_dims(np.array(true), 0)).transpose(2, 1)
        
        return data, true

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(dataFrame, trueFrame, test_size = 1/10)

loader_train = CustomDataloader(Xtrain, ytrain)
loader_test = CustomDataloader(Xtest, ytest)

# %%
def train(epoch):
    model.train()  # 신경망을 학습 모드로 전환

    # 데이터로더에서 미니배치를 하나씩 꺼내 학습을 수행
    predict = []
    ground = []
    
    loader_train.__shuffle__()
    
    for data, targets in loader_train:
        
        data = data.to(device)
        targets = targets.to(device)
        
        optimizer.zero_grad()  # 경사를 0으로 초기화
        outputs = model(data)  # 데이터를 입력하고 출력을 계산
        loss = loss_func(outputs, targets)  # 출력과 훈련 데이터 정답 간의 오차를 계산
        loss.backward()  # 오차를 역전파 계산
        optimizer.step()  # 역전파 계산한 값으로 가중치를 수정
        
        predict.append(outputs.squeeze(dim = 0).transpose(1,0))
        ground.append(targets.squeeze(dim = 0).transpose(1,0))
    scheduler.step()

    # 정확도 출력
    predict = torch.cat(predict,axis = 0)
    ground = torch.cat(ground,axis = 0)
    
    loss = loss_func(predict, ground)
    meas = check_score_np(predict.to('cpu'), ground.to('cpu'))
    return loss, meas

# %%
def test():
    model.eval()  # 신경망을 추론 모드로 전환

    # 데이터로더에서 미니배치를 하나씩 꺼내 추론을 수행
    predict = []
    ground = []
    with torch.no_grad():  # 추론 과정에는 미분이 필요없음
        for data, targets in loader_test:
            data = data.to(device)
            targets = targets.to(device)
            
            outputs = model(data)  # 데이터를 입력하고 출력을 계산
            predict.append(outputs.squeeze(dim = 0).transpose(1,0))
            ground.append(targets.squeeze(dim = 0).transpose(1,0))

    # 정확도 출력
    predict = torch.cat(predict,axis = 0)
    ground = torch.cat(ground,axis = 0)
    
    loss = loss_func(predict, ground)
    meas = check_score_np(predict.to('cpu'), ground.to('cpu'))
    return loss, meas

# %%
test()
# Out:
# (tensor(15931.0693, device='cuda:0'), 14909720.664014945)

# %%
history = []
train_loss, train_meas = 0,0
test_loss, test_meas = 0,0

check_meas = np.inf
check_loss = np.inf
check_epoch = 0

for epoch in range(EPOCH_NUM+1):
    if epoch != 0:
        train_loss, train_meas = train(epoch)
    test_loss, test_meas = test()
    
    history.append({'epoch':epoch, 'train_loss':train_loss, 'train_meas':train_meas, 'test_loss':test_loss, 'test_meas':test_meas})
    
    if (test_meas < check_meas):
        print("")
        print(f"/***CHECK_POINT***/ ")
        print(f"TRAIN - {train_loss}, {train_meas}")
        print(f"TEST - {test_loss}, {test_meas}")
        print("")
        check_meas = test_meas
        check_loss = test_loss
        check_epoch = epoch
        torch.save(model.state_dict(), checkpoint_path)
    
    print(f"/*** EPOCH : {epoch}/{EPOCH_NUM} ***/")
    print(f"TRAIN - {train_loss}, {train_meas}")
    print(f"TEST - {test_loss}, {test_meas}")
    print("")
    
df_history = pd.DataFrame(history)
# Out:
# /***CHECK_POINT***/
# TRAIN - 0, 0
# TEST - 15931.0693359375, 14909720.664014945
#
# /*** EPOCH : 0/1000 ***/
# TRAIN - 0, 0
# TEST - 15931.0693359375, 14909720.664014945
#
# Adjusting learning rate of group 0 to 9.9500e-04.
# D:\Sangwons_Room\00_SoftWares\Anaconda\envs\torch\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# D:\Sangwons_Room\00_SoftWares\Anaconda\envs\torch\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning:
#
# invalid value encountered in arcsin
# /*** EPOCH : 1/1000 ***/
# TRAIN - 5886.81787109375, nan
# TEST - 2750.77734375, nan
#
# Adjusting learning rate of group 0 to 9.9003e-04.
# /*** EPOCH : 2/1000 ***/
# TRAIN - 3418.171875, nan
# TEST - 2809.639404296875, nan
#
# Adjusting learning rate of group 0 to 9.8507e-04.
# /*** EPOCH : 3/1000 ***/
# TRAIN - 3176.9189453125, nan
# TEST - 2341.22607421875, nan
#
# Adjusting learning rate of group 0 to 9.8015e-04.
# /*** EPOCH : 4/1000 ***/
# TRAIN - 3168.65283203125, nan
# TEST - 2437.28662109375, nan
#
# Adjusting learning rate of group 0 to 9.7525e-04.
# /*** EPOCH : 5/1000 ***/
# TRAIN - 3186.880615234375, nan
# TEST - 2706.9130859375, nan
#
# Adjusting learning rate of group 0 to 9.7037e-04.
# /*** EPOCH : 6/1000 ***/
# TRAIN - 3341.899658203125, nan
# TEST - 2354.6669921875, nan
#
# Adjusting learning rate of group 0 to 9.6552e-04.
# /*** EPOCH : 7/1000 ***/
# TRAIN - 3144.35693359375, nan
# TEST - 2601.30810546875, nan
#
# Adjusting learning rate of group 0 to 9.6069e-04.
# /*** EPOCH : 8/1000 ***/
# TRAIN - 2936.247802734375, nan
# TEST - 2523.030029296875, nan
#
# Adjusting learning rate of group 0 to 9.5589e-04.
# /*** EPOCH : 9/1000 ***/
# TRAIN - 2918.459228515625, nan
# TEST - 2716.116943359375, nan
#
# Adjusting learning rate of group 0 to 9.5111e-04.
# /*** EPOCH : 10/1000 ***/
# TRAIN - 3007.763427734375, nan
# TEST - 2516.633056640625, nan
#
# Adjusting learning rate of group 0 to 9.4635e-04.
# /*** EPOCH : 11/1000 ***/
# TRAIN - 2866.485595703125, nan
# TEST - 2429.34375, nan
#
# Adjusting learning rate of group 0 to 9.4162e-04.
# /*** EPOCH : 12/1000 ***/
# TRAIN - 2823.804443359375, nan
# TEST - 2259.437255859375, nan
#
# Adjusting learning rate of group 0 to 9.3691e-04.
# /*** EPOCH : 13/1000 ***/
# TRAIN - 2773.539306640625, nan
# TEST - 2576.697509765625, nan
#
# Adjusting learning rate of group 0 to 9.3223e-04.
# /*** EPOCH : 14/1000 ***/
# TRAIN - 2896.787353515625, nan
# TEST - 2192.398681640625, nan
#
# Adjusting learning rate of group 0 to 9.2757e-04.
# /*** EPOCH : 15/1000 ***/
# TRAIN - 2869.420166015625, nan
# TEST - 2745.97509765625, nan
#
# Adjusting learning rate of group 0 to 9.2293e-04.
# /*** EPOCH : 16/1000 ***/
# TRAIN - 2847.69189453125, nan
# TEST - 4159.60693359375, nan
#
# Adjusting learning rate of group 0 to 9.1832e-04.
# /*** EPOCH : 17/1000 ***/
# TRAIN - 2857.180908203125, nan
# TEST - 2410.335693359375, nan
#
# Adjusting learning rate of group 0 to 9.1372e-04.
# /*** EPOCH : 18/1000 ***/
# TRAIN - 2768.746826171875, nan
# TEST - 2467.77490234375, nan
#
# Adjusting learning rate of group 0 to 9.0916e-04.
# /*** EPOCH : 19/1000 ***/
# TRAIN - 2788.8486328125, nan
# TEST - 2344.024169921875, nan
#
# Adjusting learning rate of group 0 to 9.0461e-04.
# /*** EPOCH : 20/1000 ***/
# TRAIN - 2670.17236328125, nan
# TEST - 2100.027099609375, nan
#
# Adjusting learning rate of group 0 to 9.0009e-04.
# /*** EPOCH : 21/1000 ***/
# TRAIN - 2779.099853515625, nan
# TEST - 3069.30126953125, nan
#
# Adjusting learning rate of group 0 to 8.9559e-04.
# /*** EPOCH : 22/1000 ***/
# TRAIN - 2639.79345703125, nan
# TEST - 2195.754638671875, nan
#
# Adjusting learning rate of group 0 to 8.9111e-04.
# /*** EPOCH : 23/1000 ***/
# TRAIN - 2673.62255859375, nan
# TEST - 2354.561767578125, nan
#
# Adjusting learning rate of group 0 to 8.8665e-04.
# /*** EPOCH : 24/1000 ***/
# TRAIN - 2454.294677734375, nan
# TEST - 2237.970703125, nan
#
# Adjusting learning rate of group 0 to 8.8222e-04.
# /*** EPOCH : 25/1000 ***/
# TRAIN - 2449.857666015625, nan
# TEST - 3028.842529296875, nan
#
# Adjusting learning rate of group 0 to 8.7781e-04.
# /*** EPOCH : 26/1000 ***/
# TRAIN - 2590.83203125, nan
# TEST - 2465.924560546875, nan
#
# Adjusting learning rate of group 0 to 8.7342e-04.
# /*** EPOCH : 27/1000 ***/
# TRAIN - 2523.4208984375, nan
# TEST - 2805.18994140625, nan
#
# Adjusting learning rate of group 0 to 8.6905e-04.
# /*** EPOCH : 28/1000 ***/
# TRAIN - 2495.36328125, nan
# TEST - 2089.22509765625, nan
#
# Adjusting learning rate of group 0 to 8.6471e-04.
# /*** EPOCH : 29/1000 ***/
# TRAIN - 2455.52001953125, nan
# TEST - 2280.659423828125, nan
#
# Adjusting learning rate of group 0 to 8.6038e-04.
# /*** EPOCH : 30/1000 ***/
# TRAIN - 2534.238525390625, nan
# TEST - 2769.9482421875, nan
#
# Adjusting learning rate of group 0 to 8.5608e-04.
# /*** EPOCH : 31/1000 ***/
# TRAIN - 2485.877685546875, nan
# TEST - 2676.260498046875, nan
#
# Adjusting learning rate of group 0 to 8.5180e-04.
# /*** EPOCH : 32/1000 ***/
# TRAIN - 2624.3994140625, nan
# TEST - 2745.145751953125, nan
#
# Adjusting learning rate of group 0 to 8.4754e-04.
# /*** EPOCH : 33/1000 ***/
# TRAIN - 2516.72998046875, nan
# TEST - 2570.1611328125, nan
#
# Adjusting learning rate of group 0 to 8.4331e-04.
# /*** EPOCH : 34/1000 ***/
# TRAIN - 2262.297119140625, nan
# TEST - 2481.543212890625, nan
#
# Adjusting learning rate of group 0 to 8.3909e-04.
# /*** EPOCH : 35/1000 ***/
# TRAIN - 2239.526611328125, nan
# TEST - 2198.513427734375, nan
#
# Adjusting learning rate of group 0 to 8.3489e-04.
# /*** EPOCH : 36/1000 ***/
# TRAIN - 2156.75146484375, nan
# TEST - 2535.85107421875, nan
#
# Adjusting learning rate of group 0 to 8.3072e-04.
# /*** EPOCH : 37/1000 ***/
# TRAIN - 2003.356689453125, nan
# TEST - 2174.462646484375, nan
#
# Adjusting learning rate of group 0 to 8.2657e-04.
# /*** EPOCH : 38/1000 ***/
# TRAIN - 2054.97998046875, nan
# TEST - 3285.419189453125, nan
#
# Adjusting learning rate of group 0 to 8.2243e-04.
# /*** EPOCH : 39/1000 ***/
# TRAIN - 3249.459716796875, nan
# TEST - 2930.535888671875, nan
#
# Adjusting learning rate of group 0 to 8.1832e-04.
# /*** EPOCH : 40/1000 ***/
# TRAIN - 607585.5, nan
# TEST - 19181.04296875, nan
#
# Adjusting learning rate of group 0 to 8.1423e-04.
# /*** EPOCH : 41/1000 ***/
# TRAIN - 2291339.0, nan
# TEST - 27140.033203125, nan
#
# Adjusting learning rate of group 0 to 8.1016e-04.
# /*** EPOCH : 42/1000 ***/
# TRAIN - 10112.1474609375, nan
# TEST - 4682.89697265625, nan
#
# Adjusting learning rate of group 0 to 8.0611e-04.
# /*** EPOCH : 43/1000 ***/
# TRAIN - 3710.345947265625, nan
# TEST - 3871.085205078125, nan
#
# Adjusting learning rate of group 0 to 8.0208e-04.
# /*** EPOCH : 44/1000 ***/
# TRAIN - 3174.415771484375, nan
# TEST - 3295.84912109375, nan
#
# Adjusting learning rate of group 0 to 7.9807e-04.
# /*** EPOCH : 45/1000 ***/
# TRAIN - 3010.35693359375, nan
# TEST - 3183.13818359375, nan
#
# Adjusting learning rate of group 0 to 7.9408e-04.
# /*** EPOCH : 46/1000 ***/
# TRAIN - 2868.614990234375, nan
# TEST - 3133.289794921875, nan
#
# Adjusting learning rate of group 0 to 7.9010e-04.
# /*** EPOCH : 47/1000 ***/
# TRAIN - 2897.081787109375, nan
# TEST - 2697.393310546875, nan
#
# Adjusting learning rate of group 0 to 7.8615e-04.
# /*** EPOCH : 48/1000 ***/
# TRAIN - 2761.18603515625, nan
# TEST - 2795.6435546875, nan
#
# Adjusting learning rate of group 0 to 7.8222e-04.
# /*** EPOCH : 49/1000 ***/
# TRAIN - 2724.935791015625, nan
# TEST - 2898.3076171875, nan
#
# Adjusting learning rate of group 0 to 7.7831e-04.
# /*** EPOCH : 50/1000 ***/
# TRAIN - 2660.23828125, nan
# TEST - 2680.49462890625, nan
#
# Adjusting learning rate of group 0 to 7.7442e-04.
# /*** EPOCH : 51/1000 ***/
# TRAIN - 2671.85205078125, nan
# TEST - 2689.7275390625, nan
#
# Adjusting learning rate of group 0 to 7.7055e-04.
# /*** EPOCH : 52/1000 ***/
# TRAIN - 2607.078369140625, nan
# TEST - 2607.095458984375, nan
#
# Adjusting learning rate of group 0 to 7.6670e-04.
# /*** EPOCH : 53/1000 ***/
# TRAIN - 2571.812744140625, nan
# TEST - 2958.68798828125, nan
#
# Adjusting learning rate of group 0 to 7.6286e-04.
# /*** EPOCH : 54/1000 ***/
# TRAIN - 2586.72802734375, nan
# TEST - 2542.66259765625, nan
#
# Adjusting learning rate of group 0 to 7.5905e-04.
# /*** EPOCH : 55/1000 ***/
# TRAIN - 2490.731689453125, nan
# TEST - 2587.189453125, nan
#
# Adjusting learning rate of group 0 to 7.5525e-04.
# /*** EPOCH : 56/1000 ***/
# TRAIN - 2483.4697265625, nan
# TEST - 2324.50439453125, nan
#
# Adjusting learning rate of group 0 to 7.5148e-04.
# /*** EPOCH : 57/1000 ***/
# TRAIN - 2427.806884765625, nan
# TEST - 2426.215576171875, nan
#
# Adjusting learning rate of group 0 to 7.4772e-04.
# /*** EPOCH : 58/1000 ***/
# TRAIN - 2380.78173828125, nan
# TEST - 2448.5380859375, nan
#
# Adjusting learning rate of group 0 to 7.4398e-04.
# /*** EPOCH : 59/1000 ***/
# TRAIN - 2392.91552734375, nan
# TEST - 2643.783447265625, nan
#
# Adjusting learning rate of group 0 to 7.4026e-04.
# /*** EPOCH : 60/1000 ***/
# TRAIN - 2326.2509765625, nan
# TEST - 2513.743896484375, nan
#
# Adjusting learning rate of group 0 to 7.3656e-04.
# /*** EPOCH : 61/1000 ***/
# TRAIN - 2286.501220703125, nan
# TEST - 2374.248291015625, nan
# Adjusting learning rate of group 0 to 7.3288e-04.
# /*** EPOCH : 62/1000 ***/
# TRAIN - 2236.335205078125, nan
# TEST - 2671.4814453125, nan
#
# Adjusting learning rate of group 0 to 7.2921e-04.
# /*** EPOCH : 63/1000 ***/
# TRAIN - 2211.072998046875, nan
# TEST - 2279.098876953125, nan
#
# Adjusting learning rate of group 0 to 7.2557e-04.
# /*** EPOCH : 64/1000 ***/
# TRAIN - 2187.217529296875, nan
# TEST - 2690.870361328125, nan
#
# Adjusting learning rate of group 0 to 7.2194e-04.
# /*** EPOCH : 65/1000 ***/
# TRAIN - 2172.88623046875, nan
# TEST - 2480.385986328125, nan
#
# Adjusting learning rate of group 0 to 7.1833e-04.
# /*** EPOCH : 66/1000 ***/
# TRAIN - 2147.93505859375, nan
# TEST - 2564.545166015625, nan
#
# Adjusting learning rate of group 0 to 7.1474e-04.
# /*** EPOCH : 67/1000 ***/
# TRAIN - 2120.713134765625, nan
# TEST - 2434.01025390625, nan
#
# Adjusting learning rate of group 0 to 7.1116e-04.
# /*** EPOCH : 68/1000 ***/
# TRAIN - 2082.36669921875, nan
# TEST - 2425.771728515625, nan
#
# Adjusting learning rate of group 0 to 7.0761e-04.
# /*** EPOCH : 69/1000 ***/
# TRAIN - 2065.87451171875, nan
# TEST - 2281.112548828125, nan
#
# Adjusting learning rate of group 0 to 7.0407e-04.
# /*** EPOCH : 70/1000 ***/
# TRAIN - 2014.9827880859375, nan
# TEST - 2383.875244140625, nan
#
# Adjusting learning rate of group 0 to 7.0055e-04.
# /*** EPOCH : 71/1000 ***/
# TRAIN - 2005.7313232421875, nan
# TEST - 2509.849853515625, nan
#
# Adjusting learning rate of group 0 to 6.9705e-04.
# /*** EPOCH : 72/1000 ***/
# TRAIN - 1961.4296875, nan
# TEST - 2806.62548828125, nan
#
# Adjusting learning rate of group 0 to 6.9356e-04.
# /*** EPOCH : 73/1000 ***/
# TRAIN - 2006.4444580078125, nan
# TEST - 2519.005615234375, nan
#
# Adjusting learning rate of group 0 to 6.9009e-04.
# /*** EPOCH : 74/1000 ***/
# TRAIN - 1911.837158203125, nan
# TEST - 2192.956298828125, nan
#
# Adjusting learning rate of group 0 to 6.8664e-04.
# /*** EPOCH : 75/1000 ***/
# TRAIN - 1900.4456787109375, nan
# TEST - 2569.361328125, nan
#
# Adjusting learning rate of group 0 to 6.8321e-04.
# /*** EPOCH : 76/1000 ***/
# TRAIN - 1884.041015625, nan
# TEST - 2404.070556640625, nan
#
# Adjusting learning rate of group 0 to 6.7979e-04.
# /*** EPOCH : 77/1000 ***/
# TRAIN - 1874.1614990234375, nan
# TEST - 2225.236572265625, nan
#
# Adjusting learning rate of group 0 to 6.7639e-04.
# /*** EPOCH : 78/1000 ***/
# TRAIN - 1891.0264892578125, nan
# TEST - 2258.96826171875, nan
#
# Adjusting learning rate of group 0 to 6.7301e-04.
# /*** EPOCH : 79/1000 ***/
# TRAIN - 1837.564208984375, nan
# TEST - 2969.013427734375, nan
#
# Adjusting learning rate of group 0 to 6.6965e-04.
# /*** EPOCH : 80/1000 ***/
# TRAIN - 1857.02001953125, nan
# TEST - 2416.658447265625, nan
#
# Adjusting learning rate of group 0 to 6.6630e-04.
# /*** EPOCH : 81/1000 ***/
# TRAIN - 1802.114501953125, nan
# TEST - 2420.60107421875, nan
#
# Adjusting learning rate of group 0 to 6.6297e-04.
# /*** EPOCH : 82/1000 ***/
# TRAIN - 1787.90625, nan
# TEST - 2502.186767578125, nan
#
# Adjusting learning rate of group 0 to 6.5965e-04.
# /*** EPOCH : 83/1000 ***/
# TRAIN - 1809.701904296875, nan
# TEST - 2822.919189453125, nan
#
# Adjusting learning rate of group 0 to 6.5635e-04.
# /*** EPOCH : 84/1000 ***/
# TRAIN - 1806.4525146484375, nan
# TEST - 2538.961669921875, nan
#
# Adjusting learning rate of group 0 to 6.5307e-04.
# /*** EPOCH : 85/1000 ***/
# TRAIN - 1808.95751953125, nan
# TEST - 2388.046875, nan
#
# Adjusting learning rate of group 0 to 6.4981e-04.
# /*** EPOCH : 86/1000 ***/
# TRAIN - 1783.6251220703125, nan
# TEST - 2504.761962890625, nan
#
# Adjusting learning rate of group 0 to 6.4656e-04.
# /*** EPOCH : 87/1000 ***/
# TRAIN - 1766.796142578125, nan
# TEST - 2601.2978515625, nan
#
# Adjusting learning rate of group 0 to 6.4333e-04.
# /*** EPOCH : 88/1000 ***/
# TRAIN - 1766.31689453125, nan
# TEST - 2689.60888671875, nan
#
# Adjusting learning rate of group 0 to 6.4011e-04.
# /*** EPOCH : 89/1000 ***/
# TRAIN - 1686.6365966796875, nan
# TEST - 2211.123779296875, nan
#
# Adjusting learning rate of group 0 to 6.3691e-04.
# /*** EPOCH : 90/1000 ***/
# TRAIN - 1687.609619140625, nan
# TEST - 2703.880126953125, nan
#
# Adjusting learning rate of group 0 to 6.3372e-04.
# /*** EPOCH : 91/1000 ***/
# TRAIN - 1708.4876708984375, nan
# TEST - 2501.627685546875, nan
#
# Adjusting learning rate of group 0 to 6.3056e-04.
# /*** EPOCH : 92/1000 ***/
# TRAIN - 1785.8594970703125, nan
# TEST - 2929.380859375, nan
#
# Adjusting learning rate of group 0 to 6.2740e-04.
# /*** EPOCH : 93/1000 ***/
# TRAIN - 1739.564208984375, nan
# TEST - 2406.6572265625, nan
#
# Adjusting learning rate of group 0 to 6.2427e-04.
# /*** EPOCH : 94/1000 ***/
# TRAIN - 1681.59033203125, nan
# TEST - 2318.42822265625, nan
#
# Adjusting learning rate of group 0 to 6.2114e-04.
# /*** EPOCH : 95/1000 ***/
# TRAIN - 1723.4036865234375, nan
# TEST - 2551.000244140625, nan
#
# Adjusting learning rate of group 0 to 6.1804e-04.
# /*** EPOCH : 96/1000 ***/
# TRAIN - 1712.329345703125, nan
# TEST - 3259.606201171875, nan
#
# Adjusting learning rate of group 0 to 6.1495e-04.
# /*** EPOCH : 97/1000 ***/
# TRAIN - 1690.8331298828125, nan
# TEST - 2455.365234375, nan
#
# Adjusting learning rate of group 0 to 6.1187e-04.
# /*** EPOCH : 98/1000 ***/
# TRAIN - 1670.4295654296875, nan
# TEST - 3318.236328125, nan
#
# Adjusting learning rate of group 0 to 6.0881e-04.
# /*** EPOCH : 99/1000 ***/
# TRAIN - 1810.9312744140625, nan
# TEST - 3059.025634765625, nan
#
# Adjusting learning rate of group 0 to 6.0577e-04.
# /*** EPOCH : 100/1000 ***/
# TRAIN - 1695.4879150390625, nan
# TEST - 2362.433349609375, nan
#
# Adjusting learning rate of group 0 to 6.0274e-04.
# /*** EPOCH : 101/1000 ***/
# TRAIN - 1631.376220703125, nan
# TEST - 2961.646240234375, nan
#
# Adjusting learning rate of group 0 to 5.9973e-04.
# /*** EPOCH : 102/1000 ***/
# TRAIN - 1741.7303466796875, nan
# TEST - 2484.384765625, nan
#
# Adjusting learning rate of group 0 to 5.9673e-04.
# /*** EPOCH : 103/1000 ***/
# TRAIN - 1616.1265869140625, nan
# TEST - 2411.552490234375, nan
#
# Adjusting learning rate of group 0 to 5.9375e-04.
# /*** EPOCH : 104/1000 ***/
# TRAIN - 1651.9765625, nan
# TEST - 2876.64990234375, nan
#
# Adjusting learning rate of group 0 to 5.9078e-04.
# /*** EPOCH : 105/1000 ***/
# TRAIN - 1653.1434326171875, nan
# TEST - 3126.434814453125, nan
#
# Adjusting learning rate of group 0 to 5.8782e-04.
# /*** EPOCH : 106/1000 ***/
# TRAIN - 1554.2762451171875, nan
# TEST - 3013.58984375, nan
#
# Adjusting learning rate of group 0 to 5.8488e-04.
# /*** EPOCH : 107/1000 ***/
# TRAIN - 1691.6505126953125, nan
# TEST - 2791.580810546875, nan
#
# Adjusting learning rate of group 0 to 5.8196e-04.
# /*** EPOCH : 108/1000 ***/
# TRAIN - 1795.1844482421875, nan
# TEST - 2591.6162109375, nan
#
# Adjusting learning rate of group 0 to 5.7905e-04.
# /*** EPOCH : 109/1000 ***/
# TRAIN - 1598.9998779296875, nan
# TEST - 2567.606689453125, nan
#
# Adjusting learning rate of group 0 to 5.7615e-04.
# /*** EPOCH : 110/1000 ***/
# TRAIN - 1617.4476318359375, nan
# TEST - 2745.30322265625, nan
#
# Adjusting learning rate of group 0 to 5.7327e-04.
# /*** EPOCH : 111/1000 ***/
# TRAIN - 1544.39013671875, nan
# TEST - 3148.925048828125, nan
#
# Adjusting learning rate of group 0 to 5.7041e-04.
# /*** EPOCH : 112/1000 ***/
# TRAIN - 1582.967529296875, nan
# TEST - 3105.02392578125, nan
#
# Adjusting learning rate of group 0 to 5.6756e-04.
# /*** EPOCH : 113/1000 ***/
# TRAIN - 1552.566162109375, nan
# TEST - 3074.83740234375, nan
#
# Adjusting learning rate of group 0 to 5.6472e-04.
# /*** EPOCH : 114/1000 ***/
# TRAIN - 1638.56103515625, nan
# TEST - 2624.353271484375, nan
#
# Adjusting learning rate of group 0 to 5.6189e-04.
# /*** EPOCH : 115/1000 ***/
# TRAIN - 1589.6346435546875, nan
# TEST - 2568.822021484375, nan
#
# Adjusting learning rate of group 0 to 5.5908e-04.
# /*** EPOCH : 116/1000 ***/
# TRAIN - 1514.9581298828125, nan
# TEST - 3779.112548828125, nan
#
# Adjusting learning rate of group 0 to 5.5629e-04.
# /*** EPOCH : 117/1000 ***/
# TRAIN - 1604.3360595703125, nan
# TEST - 2940.06591796875, nan
#
# Adjusting learning rate of group 0 to 5.5351e-04.
# /*** EPOCH : 118/1000 ***/
# TRAIN - 1593.491455078125, nan
# TEST - 3076.021728515625, nan
#
# Adjusting learning rate of group 0 to 5.5074e-04.
# /*** EPOCH : 119/1000 ***/
# TRAIN - 1516.0751953125, nan
# TEST - 3336.927978515625, nan
#
# Adjusting learning rate of group 0 to 5.4799e-04.
# /*** EPOCH : 120/1000 ***/
# TRAIN - 1514.010009765625, nan
# TEST - 3715.94482421875, nan
#
# Adjusting learning rate of group 0 to 5.4525e-04.
# /*** EPOCH : 121/1000 ***/
# TRAIN - 1563.6290283203125, nan
# TEST - 4006.201171875, nan
# Adjusting learning rate of group 0 to 5.4252e-04.
# /*** EPOCH : 122/1000 ***/
# TRAIN - 1529.492919921875, nan
# TEST - 3326.353271484375, nan
#
# Adjusting learning rate of group 0 to 5.3981e-04.
# /*** EPOCH : 123/1000 ***/
# TRAIN - 1504.048828125, nan
# TEST - 3019.120361328125, nan
#
# Adjusting learning rate of group 0 to 5.3711e-04.
# /*** EPOCH : 124/1000 ***/
# TRAIN - 1530.2369384765625, nan
# TEST - 3126.55078125, nan
#
# Adjusting learning rate of group 0 to 5.3442e-04.
# /*** EPOCH : 125/1000 ***/
# TRAIN - 1587.4251708984375, nan
# TEST - 2795.75390625, nan
#
# Adjusting learning rate of group 0 to 5.3175e-04.
# /*** EPOCH : 126/1000 ***/
# TRAIN - 1569.89111328125, nan
# TEST - 3183.407958984375, nan
#
# Adjusting learning rate of group 0 to 5.2909e-04.
# /*** EPOCH : 127/1000 ***/
# TRAIN - 1534.37744140625, nan
# TEST - 3173.4775390625, nan
#
# Adjusting learning rate of group 0 to 5.2645e-04.
# /*** EPOCH : 128/1000 ***/
# TRAIN - 1490.3826904296875, nan
# TEST - 2325.385009765625, nan
#
# Adjusting learning rate of group 0 to 5.2381e-04.
# /*** EPOCH : 129/1000 ***/
# TRAIN - 1650.515625, nan
# TEST - 2978.984130859375, nan
#
# Adjusting learning rate of group 0 to 5.2120e-04.
# /*** EPOCH : 130/1000 ***/
# TRAIN - 1701.84228515625, nan
# TEST - 2721.33056640625, nan
#
# Adjusting learning rate of group 0 to 5.1859e-04.
# /*** EPOCH : 131/1000 ***/
# TRAIN - 1441.352294921875, nan
# TEST - 2527.43701171875, nan
#
# Adjusting learning rate of group 0 to 5.1600e-04.
# /*** EPOCH : 132/1000 ***/
# TRAIN - 1439.7781982421875, nan
# TEST - 4009.927490234375, nan
#
# Adjusting learning rate of group 0 to 5.1342e-04.
# /*** EPOCH : 133/1000 ***/
# TRAIN - 1540.111083984375, nan
# TEST - 3243.5947265625, nan
#
# Adjusting learning rate of group 0 to 5.1085e-04.
# /*** EPOCH : 134/1000 ***/
# TRAIN - 1549.7799072265625, nan
# TEST - 3344.63134765625, nan
#
# Adjusting learning rate of group 0 to 5.0830e-04.
# /*** EPOCH : 135/1000 ***/
# TRAIN - 1399.3919677734375, nan
# TEST - 3370.771240234375, nan
#
# Adjusting learning rate of group 0 to 5.0575e-04.
# /*** EPOCH : 136/1000 ***/
# TRAIN - 1478.902587890625, nan
# TEST - 3355.347412109375, nan
#
# Adjusting learning rate of group 0 to 5.0322e-04.
# /*** EPOCH : 137/1000 ***/
# TRAIN - 1379.7587890625, nan
# TEST - 2615.251953125, nan
#
# Adjusting learning rate of group 0 to 5.0071e-04.
# /*** EPOCH : 138/1000 ***/
# TRAIN - 1383.347900390625, nan
# TEST - 2749.295166015625, nan
#
# Adjusting learning rate of group 0 to 4.9821e-04.
# /*** EPOCH : 139/1000 ***/
# TRAIN - 1429.7073974609375, nan
# TEST - 3319.865966796875, nan
#
# Adjusting learning rate of group 0 to 4.9571e-04.
# /*** EPOCH : 140/1000 ***/
# TRAIN - 1365.2568359375, nan
# TEST - 4503.47216796875, nan
#
# Adjusting learning rate of group 0 to 4.9324e-04.
# /*** EPOCH : 141/1000 ***/
# TRAIN - 1429.1876220703125, nan
# TEST - 3060.279052734375, nan
#
# Adjusting learning rate of group 0 to 4.9077e-04.
# /*** EPOCH : 142/1000 ***/
# TRAIN - 1423.724853515625, nan
# TEST - 2926.749755859375, nan
#
# Adjusting learning rate of group 0 to 4.8832e-04.
# /*** EPOCH : 143/1000 ***/
# TRAIN - 1419.1959228515625, nan
# TEST - 3159.58544921875, nan
#
# Adjusting learning rate of group 0 to 4.8587e-04.
# /*** EPOCH : 144/1000 ***/
# TRAIN - 1566.3564453125, nan
# TEST - 2827.115478515625, nan
#
# Adjusting learning rate of group 0 to 4.8344e-04.
# /*** EPOCH : 145/1000 ***/
# TRAIN - 1371.9041748046875, nan
# TEST - 3151.323486328125, nan
#
# Adjusting learning rate of group 0 to 4.8103e-04.
# /*** EPOCH : 146/1000 ***/
# TRAIN - 1335.977783203125, nan
# TEST - 2866.694091796875, nan
#
# Adjusting learning rate of group 0 to 4.7862e-04.
# /*** EPOCH : 147/1000 ***/
# TRAIN - 1355.164306640625, nan
# TEST - 3412.02490234375, nan
#
# Adjusting learning rate of group 0 to 4.7623e-04.
# /*** EPOCH : 148/1000 ***/
# TRAIN - 1542.2801513671875, nan
# TEST - 3095.3017578125, nan
#
# Adjusting learning rate of group 0 to 4.7385e-04.
# /*** EPOCH : 149/1000 ***/
# TRAIN - 1569.701416015625, nan
# TEST - 3611.84228515625, nan
#
# Adjusting learning rate of group 0 to 4.7148e-04.
# /*** EPOCH : 150/1000 ***/
# TRAIN - 1337.80126953125, nan
# TEST - 3169.106689453125, nan
#
# Adjusting learning rate of group 0 to 4.6912e-04.
# /*** EPOCH : 151/1000 ***/
# TRAIN - 1493.753662109375, nan
# TEST - 3964.5380859375, nan
#
# Adjusting learning rate of group 0 to 4.6678e-04.
# /*** EPOCH : 152/1000 ***/
# TRAIN - 1397.8275146484375, nan
# TEST - 3809.082275390625, nan
#
# Adjusting learning rate of group 0 to 4.6444e-04.
# /*** EPOCH : 153/1000 ***/
# TRAIN - 1404.4017333984375, nan
# TEST - 3881.2890625, nan
#
# Adjusting learning rate of group 0 to 4.6212e-04.
# /*** EPOCH : 154/1000 ***/
# TRAIN - 1445.988525390625, nan
# TEST - 3398.03076171875, nan
#
# Adjusting learning rate of group 0 to 4.5981e-04.
# /*** EPOCH : 155/1000 ***/
# TRAIN - 1254.456298828125, nan
# TEST - 3349.406494140625, nan
#
# Adjusting learning rate of group 0 to 4.5751e-04.
# /*** EPOCH : 156/1000 ***/
# TRAIN - 1311.0386962890625, nan
# TEST - 2798.27685546875, nan
#
# Adjusting learning rate of group 0 to 4.5522e-04.
# /*** EPOCH : 157/1000 ***/
# TRAIN - 1290.26806640625, nan
# TEST - 3665.70068359375, nan
#
# Adjusting learning rate of group 0 to 4.5295e-04.
# /*** EPOCH : 158/1000 ***/
# TRAIN - 1453.164794921875, nan
# TEST - 2928.54833984375, nan
#
# Adjusting learning rate of group 0 to 4.5068e-04.
# /*** EPOCH : 159/1000 ***/
# TRAIN - 1383.428955078125, nan
# TEST - 2593.34375, nan
#
# Adjusting learning rate of group 0 to 4.4843e-04.
# /*** EPOCH : 160/1000 ***/
# TRAIN - 1550.66650390625, nan
# TEST - 3403.822998046875, nan
#
# Adjusting learning rate of group 0 to 4.4619e-04.
# /*** EPOCH : 161/1000 ***/
# TRAIN - 1321.3853759765625, nan
# TEST - 2901.63720703125, nan
#
# Adjusting learning rate of group 0 to 4.4396e-04.
# /*** EPOCH : 162/1000 ***/
# TRAIN - 1275.96875, nan
# TEST - 2834.181396484375, nan
#
# Adjusting learning rate of group 0 to 4.4174e-04.
# /*** EPOCH : 163/1000 ***/
# TRAIN - 1248.1417236328125, nan
# TEST - 3032.381591796875, nan
#
# Adjusting learning rate of group 0 to 4.3953e-04.
# /*** EPOCH : 164/1000 ***/
# TRAIN - 1104.578125, nan
# TEST - 3319.7900390625, nan
#
# Adjusting learning rate of group 0 to 4.3733e-04.
# /*** EPOCH : 165/1000 ***/
# TRAIN - 1355.7318115234375, nan
# TEST - 3823.479736328125, nan
#
# Adjusting learning rate of group 0 to 4.3514e-04.
# /*** EPOCH : 166/1000 ***/
# TRAIN - 1311.6507568359375, nan
# TEST - 2940.761474609375, nan
#
# Adjusting learning rate of group 0 to 4.3297e-04.
# /*** EPOCH : 167/1000 ***/
# TRAIN - 1298.6492919921875, nan
# TEST - 3180.22509765625, nan
#
# Adjusting learning rate of group 0 to 4.3080e-04.
# /*** EPOCH : 168/1000 ***/
# TRAIN - 1231.5570068359375, nan
# TEST - 3181.156005859375, nan
#
# Adjusting learning rate of group 0 to 4.2865e-04.
# /*** EPOCH : 169/1000 ***/
# TRAIN - 1155.0635986328125, nan
# TEST - 2830.184814453125, nan
#
# Adjusting learning rate of group 0 to 4.2650e-04.
# /*** EPOCH : 170/1000 ***/
# TRAIN - 1258.4908447265625, nan
# TEST - 2704.3427734375, nan
#
# Adjusting learning rate of group 0 to 4.2437e-04.
# /*** EPOCH : 171/1000 ***/
# TRAIN - 1040.0423583984375, nan
# TEST - 3097.427978515625, nan
#
# Adjusting learning rate of group 0 to 4.2225e-04.
# /*** EPOCH : 172/1000 ***/
# TRAIN - 1064.9503173828125, nan
# TEST - 2926.982666015625, nan
#
# Adjusting learning rate of group 0 to 4.2014e-04.
# /*** EPOCH : 173/1000 ***/
# TRAIN - 1115.0081787109375, nan
# TEST - 3041.085205078125, nan
#
# Adjusting learning rate of group 0 to 4.1804e-04.
# /*** EPOCH : 174/1000 ***/
# TRAIN - 1049.8563232421875, nan
# TEST - 3597.019775390625, nan
#
# Adjusting learning rate of group 0 to 4.1595e-04.
# /*** EPOCH : 175/1000 ***/
# TRAIN - 1022.5390014648438, nan
# TEST - 3638.092041015625, nan
#
# Adjusting learning rate of group 0 to 4.1387e-04.
# /*** EPOCH : 176/1000 ***/
# TRAIN - 1187.02294921875, nan
# TEST - 3664.300537109375, nan
#
# Adjusting learning rate of group 0 to 4.1180e-04.
# /*** EPOCH : 177/1000 ***/
# TRAIN - 1554.8604736328125, nan
# TEST - 3046.927001953125, nan
#
# Adjusting learning rate of group 0 to 4.0974e-04.
# /*** EPOCH : 178/1000 ***/
# TRAIN - 1046.470947265625, nan
# TEST - 4012.716064453125, nan
#
# Adjusting learning rate of group 0 to 4.0769e-04.
# /*** EPOCH : 179/1000 ***/
# TRAIN - 1407.5550537109375, nan
# TEST - 3490.87060546875, nan
#
# Adjusting learning rate of group 0 to 4.0565e-04.
# /*** EPOCH : 180/1000 ***/
# TRAIN - 1171.522705078125, nan
# TEST - 3513.205078125, nan
#
# Adjusting learning rate of group 0 to 4.0362e-04.
# /*** EPOCH : 181/1000 ***/
# TRAIN - 1042.4168701171875, nan
# TEST - 3269.7763671875, nan
#
# Adjusting learning rate of group 0 to 4.0161e-04.
# /*** EPOCH : 182/1000 ***/
# TRAIN - 1011.88623046875, nan
# TEST - 4134.59326171875, nan
#
# Adjusting learning rate of group 0 to 3.9960e-04.
# /*** EPOCH : 183/1000 ***/
# TRAIN - 984.449462890625, nan
# TEST - 3425.320068359375, nan
#
# Adjusting learning rate of group 0 to 3.9760e-04.
# /*** EPOCH : 184/1000 ***/
# TRAIN - 1110.7037353515625, nan
# TEST - 3792.582763671875, nan
#
# Adjusting learning rate of group 0 to 3.9561e-04.
# /*** EPOCH : 185/1000 ***/
# TRAIN - 993.4998168945312, nan
# TEST - 2830.234130859375, nan
#
# Adjusting learning rate of group 0 to 3.9363e-04.
# /*** EPOCH : 186/1000 ***/
# TRAIN - 999.7587890625, nan
# TEST - 3291.8349609375, nan
#
# Adjusting learning rate of group 0 to 3.9167e-04.
# /*** EPOCH : 187/1000 ***/
# TRAIN - 871.5001831054688, nan
# TEST - 3246.1005859375, nan
#
# Adjusting learning rate of group 0 to 3.8971e-04.
# /*** EPOCH : 188/1000 ***/
# TRAIN - 894.1767578125, nan
# TEST - 2422.16162109375, nan
#
# Adjusting learning rate of group 0 to 3.8776e-04.
# /*** EPOCH : 189/1000 ***/
# TRAIN - 836.8561401367188, nan
# TEST - 3078.423095703125, nan
#
# Adjusting learning rate of group 0 to 3.8582e-04.
# /*** EPOCH : 190/1000 ***/
# TRAIN - 845.5228271484375, nan
# TEST - 2761.5439453125, nan
#
# Adjusting learning rate of group 0 to 3.8389e-04.
# /*** EPOCH : 191/1000 ***/
# TRAIN - 833.9302368164062, nan
# TEST - 3668.399658203125, nan
#
# Adjusting learning rate of group 0 to 3.8197e-04.
# /*** EPOCH : 192/1000 ***/
# TRAIN - 811.1539306640625, nan
# TEST - 2903.9404296875, nan
#
# Adjusting learning rate of group 0 to 3.8006e-04.
# /*** EPOCH : 193/1000 ***/
# TRAIN - 727.6395263671875, nan
# TEST - 4269.58251953125, nan
#
# Adjusting learning rate of group 0 to 3.7816e-04.
# /*** EPOCH : 194/1000 ***/
# TRAIN - 744.6559448242188, nan
# TEST - 3271.430908203125, nan
#
# Adjusting learning rate of group 0 to 3.7627e-04.
# /*** EPOCH : 195/1000 ***/
# TRAIN - 776.529296875, nan
# TEST - 3006.199462890625, nan
#
# Adjusting learning rate of group 0 to 3.7439e-04.
# /*** EPOCH : 196/1000 ***/
# TRAIN - 990.598876953125, nan
# TEST - 3688.037841796875, nan
#
# Adjusting learning rate of group 0 to 3.7252e-04.
# /*** EPOCH : 197/1000 ***/
# TRAIN - 1088.0167236328125, nan
# TEST - 2908.68017578125, nan
#
# Adjusting learning rate of group 0 to 3.7066e-04.
# /*** EPOCH : 198/1000 ***/
# TRAIN - 877.3750610351562, nan
# TEST - 3316.421142578125, nan
#
# Adjusting learning rate of group 0 to 3.6880e-04.
# /*** EPOCH : 199/1000 ***/
# TRAIN - 816.9443969726562, nan
# TEST - 3749.622802734375, nan
#
# Adjusting learning rate of group 0 to 3.6696e-04.
# /*** EPOCH : 200/1000 ***/
# TRAIN - 698.535888671875, nan
# TEST - 3649.34912109375, nan
#
# Adjusting learning rate of group 0 to 3.6512e-04.
# /*** EPOCH : 201/1000 ***/
# TRAIN - 671.890625, nan
# TEST - 2992.64892578125, nan
#
# Adjusting learning rate of group 0 to 3.6330e-04.
# /*** EPOCH : 202/1000 ***/
# TRAIN - 702.6519775390625, nan
# TEST - 3241.82666015625, nan
#
# Adjusting learning rate of group 0 to 3.6148e-04.
# /*** EPOCH : 203/1000 ***/
# TRAIN - 770.5076293945312, nan
# TEST - 2640.990234375, nan
#
# Adjusting learning rate of group 0 to 3.5967e-04.
# /*** EPOCH : 204/1000 ***/
# TRAIN - 668.3428344726562, nan
# TEST - 3337.26220703125, nan
#
# Adjusting learning rate of group 0 to 3.5788e-04.
# /*** EPOCH : 205/1000 ***/
# TRAIN - 634.2725830078125, nan
# TEST - 3377.253173828125, nan
#
# Adjusting learning rate of group 0 to 3.5609e-04.
# /*** EPOCH : 206/1000 ***/
# TRAIN - 602.2022705078125, nan
# TEST - 3974.7724609375, nan
#
# Adjusting learning rate of group 0 to 3.5431e-04.
# /*** EPOCH : 207/1000 ***/
# TRAIN - 610.7869873046875, nan
# TEST - 4119.3681640625, nan
#
# Adjusting learning rate of group 0 to 3.5253e-04.
# /*** EPOCH : 208/1000 ***/
# TRAIN - 576.9239501953125, nan
# TEST - 3369.63525390625, nan
#
# Adjusting learning rate of group 0 to 3.5077e-04.
# /*** EPOCH : 209/1000 ***/
# TRAIN - 587.7274169921875, nan
# TEST - 2553.406494140625, nan
#
# Adjusting learning rate of group 0 to 3.4902e-04.
# /*** EPOCH : 210/1000 ***/
# TRAIN - 595.5736694335938, nan
# TEST - 3203.447998046875, nan
#
# Adjusting learning rate of group 0 to 3.4727e-04.
# /*** EPOCH : 211/1000 ***/
# TRAIN - 600.21337890625, nan
# TEST - 3774.514404296875, nan
#
# Adjusting learning rate of group 0 to 3.4554e-04.
# /*** EPOCH : 212/1000 ***/
# TRAIN - 561.142822265625, nan
# TEST - 2779.18505859375, nan
#
# Adjusting learning rate of group 0 to 3.4381e-04.
# /*** EPOCH : 213/1000 ***/
# TRAIN - 578.52392578125, nan
# TEST - 3157.752197265625, nan
#
# Adjusting learning rate of group 0 to 3.4209e-04.
# /*** EPOCH : 214/1000 ***/
# TRAIN - 564.5380859375, nan
# TEST - 2916.344970703125, nan
#
# Adjusting learning rate of group 0 to 3.4038e-04.
# /*** EPOCH : 215/1000 ***/
# TRAIN - 876.4172973632812, nan
# TEST - 3016.534423828125, nan
#
# Adjusting learning rate of group 0 to 3.3868e-04.
# /*** EPOCH : 216/1000 ***/
# TRAIN - 1017.5279541015625, nan
# TEST - 4199.7216796875, nan
#
# Adjusting learning rate of group 0 to 3.3698e-04.
# /*** EPOCH : 217/1000 ***/
# TRAIN - 1311.7340087890625, nan
# TEST - 3872.033447265625, nan
#
# Adjusting learning rate of group 0 to 3.3530e-04.
# /*** EPOCH : 218/1000 ***/
# TRAIN - 1019.3980712890625, nan
# TEST - 6274.13671875, nan
#
# Adjusting learning rate of group 0 to 3.3362e-04.
# /*** EPOCH : 219/1000 ***/
# TRAIN - 1114.230224609375, nan
# TEST - 4430.765625, nan
#
# Adjusting learning rate of group 0 to 3.3195e-04.
# /*** EPOCH : 220/1000 ***/
# TRAIN - 787.1306762695312, nan
# TEST - 4198.45947265625, nan
#
# Adjusting learning rate of group 0 to 3.3029e-04.
# /*** EPOCH : 221/1000 ***/
# TRAIN - 720.451904296875, nan
# TEST - 3455.233154296875, nan
#
# Adjusting learning rate of group 0 to 3.2864e-04.
# /*** EPOCH : 222/1000 ***/
# TRAIN - 691.3240356445312, nan
# TEST - 5005.5859375, nan
#
# Adjusting learning rate of group 0 to 3.2700e-04.
# /*** EPOCH : 223/1000 ***/
# TRAIN - 544.3643798828125, nan
# TEST - 3583.67431640625, nan
#
# Adjusting learning rate of group 0 to 3.2536e-04.
# /*** EPOCH : 224/1000 ***/
# TRAIN - 552.0567626953125, nan
# TEST - 3405.628173828125, nan
#
# Adjusting learning rate of group 0 to 3.2374e-04.
# /*** EPOCH : 225/1000 ***/
# TRAIN - 523.3609008789062, nan
# TEST - 3568.85400390625, nan
#
# Adjusting learning rate of group 0 to 3.2212e-04.
# /*** EPOCH : 226/1000 ***/
# TRAIN - 477.96246337890625, nan
# TEST - 3920.73095703125, nan
#
# Adjusting learning rate of group 0 to 3.2051e-04.
# /*** EPOCH : 227/1000 ***/
# TRAIN - 464.7942199707031, nan
# TEST - 3983.693359375, nan
#
# Adjusting learning rate of group 0 to 3.1891e-04.
# /*** EPOCH : 228/1000 ***/
# TRAIN - 470.4271545410156, nan
# TEST - 3454.97509765625, nan
#
# Adjusting learning rate of group 0 to 3.1731e-04.
# /*** EPOCH : 229/1000 ***/
# TRAIN - 484.23956298828125, nan
# TEST - 3431.478515625, nan
#
# Adjusting learning rate of group 0 to 3.1572e-04.
# /*** EPOCH : 230/1000 ***/
# TRAIN - 470.6959533691406, nan
# TEST - 4041.537109375, nan
#
# Adjusting learning rate of group 0 to 3.1415e-04.
# /*** EPOCH : 231/1000 ***/
# TRAIN - 441.8760986328125, nan
# TEST - 2887.733154296875, nan
#
# Adjusting learning rate of group 0 to 3.1258e-04.
# /*** EPOCH : 232/1000 ***/
# TRAIN - 446.20697021484375, nan
# TEST - 4176.65576171875, nan
#
# Adjusting learning rate of group 0 to 3.1101e-04.
# /*** EPOCH : 233/1000 ***/
# TRAIN - 463.32440185546875, nan
# TEST - 3709.990966796875, nan
#
# Adjusting learning rate of group 0 to 3.0946e-04.
# /*** EPOCH : 234/1000 ***/
# TRAIN - 474.2019958496094, nan
# TEST - 4313.9189453125, nan
#
# Adjusting learning rate of group 0 to 3.0791e-04.
# /*** EPOCH : 235/1000 ***/
# TRAIN - 561.7584228515625, nan
# TEST - 3102.037841796875, nan
#
# Adjusting learning rate of group 0 to 3.0637e-04.
# /*** EPOCH : 236/1000 ***/
# TRAIN - 654.795166015625, nan
# TEST - 3516.1640625, nan
#
# Adjusting learning rate of group 0 to 3.0484e-04.
# /*** EPOCH : 237/1000 ***/
# TRAIN - 654.04345703125, nan
# TEST - 4235.859375, nan
#
# Adjusting learning rate of group 0 to 3.0331e-04.
# /*** EPOCH : 238/1000 ***/
# TRAIN - 579.1583862304688, nan
# TEST - 3941.369140625, nan
#
# Adjusting learning rate of group 0 to 3.0180e-04.
# /*** EPOCH : 239/1000 ***/
# TRAIN - 472.2801208496094, nan
# TEST - 2987.04052734375, nan
#
# Adjusting learning rate of group 0 to 3.0029e-04.
# /*** EPOCH : 240/1000 ***/
# TRAIN - 443.4440612792969, nan
# TEST - 3074.127197265625, nan
#
# Adjusting learning rate of group 0 to 2.9879e-04.
# /*** EPOCH : 241/1000 ***/
# TRAIN - 469.5707702636719, nan
# TEST - 3678.249267578125, nan
#
# Adjusting learning rate of group 0 to 2.9729e-04.
# /*** EPOCH : 242/1000 ***/
# TRAIN - 882.259521484375, nan
# TEST - 4195.1416015625, nan
#
# Adjusting learning rate of group 0 to 2.9581e-04.
# /*** EPOCH : 243/1000 ***/
# TRAIN - 1040.7030029296875, nan
# TEST - 3320.536376953125, nan
#
# Adjusting learning rate of group 0 to 2.9433e-04.
# /*** EPOCH : 244/1000 ***/
# TRAIN - 791.360595703125, nan
# TEST - 3963.81884765625, nan
#
# Adjusting learning rate of group 0 to 2.9286e-04.
# /*** EPOCH : 245/1000 ***/
# TRAIN - 591.185546875, nan
# TEST - 3368.04052734375, nan
#
# Adjusting learning rate of group 0 to 2.9139e-04.
# /*** EPOCH : 246/1000 ***/
# TRAIN - 449.7611083984375, nan
# TEST - 4720.544921875, nan
#
# Adjusting learning rate of group 0 to 2.8994e-04.
# /*** EPOCH : 247/1000 ***/
# TRAIN - 416.2639465332031, nan
# TEST - 4019.02392578125, nan
#
# Adjusting learning rate of group 0 to 2.8849e-04.
# /*** EPOCH : 248/1000 ***/
# TRAIN - 510.004638671875, nan
# TEST - 3252.267822265625, nan
#
# Adjusting learning rate of group 0 to 2.8704e-04.
# /*** EPOCH : 249/1000 ***/
# TRAIN - 511.5119323730469, nan
# TEST - 4076.6201171875, nan
#
# Adjusting learning rate of group 0 to 2.8561e-04.
# /*** EPOCH : 250/1000 ***/
# TRAIN - 439.5054016113281, nan
# TEST - 4214.396484375, nan
#
# Adjusting learning rate of group 0 to 2.8418e-04.
# /*** EPOCH : 251/1000 ***/
# TRAIN - 469.8714904785156, nan
# TEST - 4590.0634765625, nan
#
# Adjusting learning rate of group 0 to 2.8276e-04.
# /*** EPOCH : 252/1000 ***/
# TRAIN - 397.6443176269531, nan
# TEST - 4248.49169921875, nan
#
# Adjusting learning rate of group 0 to 2.8135e-04.
# /*** EPOCH : 253/1000 ***/
# TRAIN - 376.0168151855469, nan
# TEST - 3960.523193359375, nan
#
# Adjusting learning rate of group 0 to 2.7994e-04.
# /*** EPOCH : 254/1000 ***/
# TRAIN - 352.2723083496094, nan
# TEST - 3989.973876953125, nan
#
# Adjusting learning rate of group 0 to 2.7854e-04.
# /*** EPOCH : 255/1000 ***/
# TRAIN - 348.4024658203125, nan
# TEST - 3311.893798828125, nan
#
# Adjusting learning rate of group 0 to 2.7715e-04.
# /*** EPOCH : 256/1000 ***/
# TRAIN - 330.757080078125, nan
# TEST - 3269.013427734375, nan
#
# Adjusting learning rate of group 0 to 2.7576e-04.
# /*** EPOCH : 257/1000 ***/
# TRAIN - 325.5781555175781, nan
# TEST - 3412.455810546875, nan
#
# Adjusting learning rate of group 0 to 2.7438e-04.
# /*** EPOCH : 258/1000 ***/
# TRAIN - 335.2359924316406, nan
# TEST - 3819.421875, nan
#
# Adjusting learning rate of group 0 to 2.7301e-04.
# /*** EPOCH : 259/1000 ***/
# TRAIN - 365.229736328125, nan
# TEST - 3278.289794921875, nan
#
# Adjusting learning rate of group 0 to 2.7164e-04.
# /*** EPOCH : 260/1000 ***/
# TRAIN - 375.28216552734375, nan
# TEST - 3570.50048828125, nan
#
# Adjusting learning rate of group 0 to 2.7029e-04.
# /*** EPOCH : 261/1000 ***/
# TRAIN - 373.01885986328125, nan
# TEST - 3649.448486328125, nan
#
# Adjusting learning rate of group 0 to 2.6893e-04.
# /*** EPOCH : 262/1000 ***/
# TRAIN - 384.66558837890625, nan
# TEST - 4367.8623046875, nan
#
# Adjusting learning rate of group 0 to 2.6759e-04.
# /*** EPOCH : 263/1000 ***/
# TRAIN - 384.376220703125, nan
# TEST - 3774.29931640625, nan
#
# Adjusting learning rate of group 0 to 2.6625e-04.
# /*** EPOCH : 264/1000 ***/
# TRAIN - 342.3678894042969, nan
# TEST - 4399.97998046875, nan
#
# Adjusting learning rate of group 0 to 2.6492e-04.
# /*** EPOCH : 265/1000 ***/
# TRAIN - 366.83551025390625, nan
# TEST - 3944.677490234375, nan
#
# Adjusting learning rate of group 0 to 2.6360e-04.
# /*** EPOCH : 266/1000 ***/
# TRAIN - 348.68359375, nan
# TEST - 4462.66455078125, nan
#
# Adjusting learning rate of group 0 to 2.6228e-04.
# /*** EPOCH : 267/1000 ***/
# TRAIN - 423.1732177734375, nan
# TEST - 3837.095947265625, nan
#
# Adjusting learning rate of group 0 to 2.6097e-04.
# /*** EPOCH : 268/1000 ***/
# TRAIN - 697.8077392578125, nan
# TEST - 4838.9033203125, nan
#
# Adjusting learning rate of group 0 to 2.5966e-04.
# /*** EPOCH : 269/1000 ***/
# TRAIN - 961.52001953125, nan
# TEST - 4931.55810546875, nan
#
# Adjusting learning rate of group 0 to 2.5836e-04.
# /*** EPOCH : 270/1000 ***/
# TRAIN - 723.0713500976562, nan
# TEST - 4215.576171875, nan
#
# Adjusting learning rate of group 0 to 2.5707e-04.
# /*** EPOCH : 271/1000 ***/
# TRAIN - 503.0031433105469, nan
# TEST - 4630.90380859375, nan
#
# Adjusting learning rate of group 0 to 2.5579e-04.
# /*** EPOCH : 272/1000 ***/
# TRAIN - 506.28289794921875, nan
# TEST - 3558.24462890625, nan
#
# Adjusting learning rate of group 0 to 2.5451e-04.
# /*** EPOCH : 273/1000 ***/
# TRAIN - 384.43359375, nan
# TEST - 3894.6884765625, nan
#
# Adjusting learning rate of group 0 to 2.5324e-04.
# /*** EPOCH : 274/1000 ***/
# TRAIN - 342.2186279296875, nan
# TEST - 3732.817626953125, nan
#
# Adjusting learning rate of group 0 to 2.5197e-04.
# /*** EPOCH : 275/1000 ***/
# TRAIN - 321.8362731933594, nan
# TEST - 3925.188720703125, nan
#
# Adjusting learning rate of group 0 to 2.5071e-04.
# /*** EPOCH : 276/1000 ***/
# TRAIN - 311.2718505859375, nan
# TEST - 3835.9970703125, nan
#
# Adjusting learning rate of group 0 to 2.4946e-04.
# /*** EPOCH : 277/1000 ***/
# TRAIN - 309.7384338378906, nan
# TEST - 3970.34326171875, nan
#
# Adjusting learning rate of group 0 to 2.4821e-04.
# /*** EPOCH : 278/1000 ***/
# TRAIN - 305.8231201171875, nan
# TEST - 4088.4013671875, nan
#
# Adjusting learning rate of group 0 to 2.4697e-04.
# /*** EPOCH : 279/1000 ***/
# TRAIN - 312.38116455078125, nan
# TEST - 4250.80615234375, nan
#
# Adjusting learning rate of group 0 to 2.4573e-04.
# /*** EPOCH : 280/1000 ***/
# TRAIN - 898.3439331054688, nan
# TEST - 4523.8916015625, nan
#
# Adjusting learning rate of group 0 to 2.4450e-04.
# /*** EPOCH : 281/1000 ***/
# TRAIN - 748.7642822265625, nan
# TEST - 3416.5849609375, nan
#
# Adjusting learning rate of group 0 to 2.4328e-04.
# /*** EPOCH : 282/1000 ***/
# TRAIN - 595.4845581054688, nan
# TEST - 4646.048828125, nan
#
# Adjusting learning rate of group 0 to 2.4206e-04.
# /*** EPOCH : 283/1000 ***/
# TRAIN - 424.5740051269531, nan
# TEST - 4177.67041015625, nan
#
# Adjusting learning rate of group 0 to 2.4085e-04.
# /*** EPOCH : 284/1000 ***/
# TRAIN - 336.12396240234375, nan
# TEST - 3358.7080078125, nan
#
# Adjusting learning rate of group 0 to 2.3965e-04.
# /*** EPOCH : 285/1000 ***/
# TRAIN - 318.374267578125, nan
# TEST - 3707.97216796875, nan
#
# Adjusting learning rate of group 0 to 2.3845e-04.
# /*** EPOCH : 286/1000 ***/
# TRAIN - 332.7772521972656, nan
# TEST - 4024.373046875, nan
#
# Adjusting learning rate of group 0 to 2.3726e-04.
# /*** EPOCH : 287/1000 ***/
# TRAIN - 292.38262939453125, nan
# TEST - 4400.037109375, nan
#
# Adjusting learning rate of group 0 to 2.3607e-04.
# /*** EPOCH : 288/1000 ***/
# TRAIN - 319.865478515625, nan
# TEST - 3173.74462890625, nan
#
# Adjusting learning rate of group 0 to 2.3489e-04.
# /*** EPOCH : 289/1000 ***/
# TRAIN - 309.7961120605469, nan
# TEST - 4372.88330078125, nan
#
# Adjusting learning rate of group 0 to 2.3372e-04.
# /*** EPOCH : 290/1000 ***/
# TRAIN - 306.9938659667969, nan
# TEST - 3098.699462890625, nan
#
# Adjusting learning rate of group 0 to 2.3255e-04.
# /*** EPOCH : 291/1000 ***/
# TRAIN - 311.40509033203125, nan
# TEST - 3359.96435546875, nan
#
# Adjusting learning rate of group 0 to 2.3139e-04.
# /*** EPOCH : 292/1000 ***/
# TRAIN - 276.3223876953125, nan
# TEST - 3466.089599609375, nan
#
# Adjusting learning rate of group 0 to 2.3023e-04.
# /*** EPOCH : 293/1000 ***/
# TRAIN - 292.36322021484375, nan
# TEST - 3996.060546875, nan
#
# Adjusting learning rate of group 0 to 2.2908e-04.
# /*** EPOCH : 294/1000 ***/
# TRAIN - 416.8446044921875, nan
# TEST - 4289.197265625, nan
#
# Adjusting learning rate of group 0 to 2.2793e-04.
# /*** EPOCH : 295/1000 ***/
# TRAIN - 417.09417724609375, nan
# TEST - 3690.18359375, nan
#
# Adjusting learning rate of group 0 to 2.2679e-04.
# /*** EPOCH : 296/1000 ***/
# TRAIN - 337.8125915527344, nan
# TEST - 3828.37646484375, nan
#
# Adjusting learning rate of group 0 to 2.2566e-04.
# /*** EPOCH : 297/1000 ***/
# TRAIN - 421.0953063964844, nan
# TEST - 4086.08740234375, nan
#
# Adjusting learning rate of group 0 to 2.2453e-04.
# /*** EPOCH : 298/1000 ***/
# TRAIN - 324.1399841308594, nan
# TEST - 4496.6162109375, nan
#
# Adjusting learning rate of group 0 to 2.2341e-04.
# /*** EPOCH : 299/1000 ***/
# TRAIN - 285.62371826171875, nan
# TEST - 3341.915283203125, nan
#
# Adjusting learning rate of group 0 to 2.2229e-04.
# /*** EPOCH : 300/1000 ***/
# TRAIN - 269.7848205566406, nan
# TEST - 3882.6865234375, nan
# Adjusting learning rate of group 0 to 2.2118e-04.
# /*** EPOCH : 301/1000 ***/
# TRAIN - 289.89630126953125, nan
# TEST - 4156.6904296875, nan
#
# Adjusting learning rate of group 0 to 2.2007e-04.
# /*** EPOCH : 302/1000 ***/
# TRAIN - 264.0742492675781, nan
# TEST - 4085.09716796875, nan
#
# Adjusting learning rate of group 0 to 2.1897e-04.
# /*** EPOCH : 303/1000 ***/
# TRAIN - 278.8514404296875, nan
# TEST - 3483.513916015625, nan
#
# Adjusting learning rate of group 0 to 2.1788e-04.
# /*** EPOCH : 304/1000 ***/
# TRAIN - 275.6285095214844, nan
# TEST - 4459.27880859375, nan
#
# Adjusting learning rate of group 0 to 2.1679e-04.
# /*** EPOCH : 305/1000 ***/
# TRAIN - 275.02081298828125, nan
# TEST - 3553.466796875, nan
#
# Adjusting learning rate of group 0 to 2.1571e-04.
# /*** EPOCH : 306/1000 ***/
# TRAIN - 264.5070495605469, nan
# TEST - 3760.049072265625, nan
#
# Adjusting learning rate of group 0 to 2.1463e-04.
# /*** EPOCH : 307/1000 ***/
# TRAIN - 277.8174133300781, nan
# TEST - 3553.04150390625, nan
#
# Adjusting learning rate of group 0 to 2.1355e-04.
# /*** EPOCH : 308/1000 ***/
# TRAIN - 315.4651794433594, nan
# TEST - 3666.906982421875, nan
#
# Adjusting learning rate of group 0 to 2.1249e-04.
# /*** EPOCH : 309/1000 ***/
# TRAIN - 322.09637451171875, nan
# TEST - 4392.94580078125, nan
#
# Adjusting learning rate of group 0 to 2.1142e-04.
# /*** EPOCH : 310/1000 ***/
# TRAIN - 310.74420166015625, nan
# TEST - 4431.49560546875, nan
#
# Adjusting learning rate of group 0 to 2.1037e-04.
# /*** EPOCH : 311/1000 ***/
# TRAIN - 310.6943664550781, nan
# TEST - 3798.582275390625, nan
#
# Adjusting learning rate of group 0 to 2.0932e-04.
# /*** EPOCH : 312/1000 ***/
# TRAIN - 291.6613464355469, nan
# TEST - 4647.65380859375, nan
#
# Adjusting learning rate of group 0 to 2.0827e-04.
# /*** EPOCH : 313/1000 ***/
# TRAIN - 596.1784057617188, nan
# TEST - 3729.396728515625, nan
#
# Adjusting learning rate of group 0 to 2.0723e-04.
# /*** EPOCH : 314/1000 ***/
# TRAIN - 593.6343994140625, nan
# TEST - 3346.322509765625, nan
#
# Adjusting learning rate of group 0 to 2.0619e-04.
# /*** EPOCH : 315/1000 ***/
# TRAIN - 855.3318481445312, nan
# TEST - 3402.519775390625, nan
#
# Adjusting learning rate of group 0 to 2.0516e-04.
# /*** EPOCH : 316/1000 ***/
# TRAIN - 675.8480834960938, nan
# TEST - 4231.9072265625, nan
#
# Adjusting learning rate of group 0 to 2.0413e-04.
# /*** EPOCH : 317/1000 ***/
# TRAIN - 436.1104431152344, nan
# TEST - 4400.779296875, nan
#
# Adjusting learning rate of group 0 to 2.0311e-04.
# /*** EPOCH : 318/1000 ***/
# TRAIN - 330.6905517578125, nan
# TEST - 3791.6845703125, nan
#
# Adjusting learning rate of group 0 to 2.0210e-04.
# /*** EPOCH : 319/1000 ***/
# TRAIN - 263.5335998535156, nan
# TEST - 3339.439453125, nan
#
# Adjusting learning rate of group 0 to 2.0109e-04.
# /*** EPOCH : 320/1000 ***/
# TRAIN - 249.55836486816406, nan
# TEST - 3497.72607421875, nan
#
# Adjusting learning rate of group 0 to 2.0008e-04.
# /*** EPOCH : 321/1000 ***/
# TRAIN - 227.45101928710938, nan
# TEST - 4176.544921875, nan
#
# Adjusting learning rate of group 0 to 1.9908e-04.
# /*** EPOCH : 322/1000 ***/
# TRAIN - 222.6654815673828, nan
# TEST - 4081.901123046875, nan
#
# Adjusting learning rate of group 0 to 1.9809e-04.
# /*** EPOCH : 323/1000 ***/
# TRAIN - 234.63436889648438, nan
# TEST - 4789.5361328125, nan
#
# Adjusting learning rate of group 0 to 1.9710e-04.
# /*** EPOCH : 324/1000 ***/
# TRAIN - 256.2342529296875, nan
# TEST - 3955.74951171875, nan
#
# Adjusting learning rate of group 0 to 1.9611e-04.
# /*** EPOCH : 325/1000 ***/
# TRAIN - 218.89752197265625, nan
# TEST - 4089.49462890625, nan
#
# Adjusting learning rate of group 0 to 1.9513e-04.
# /*** EPOCH : 326/1000 ***/
# TRAIN - 210.13247680664062, nan
# TEST - 4061.042724609375, nan
#
# Adjusting learning rate of group 0 to 1.9415e-04.
# /*** EPOCH : 327/1000 ***/
# TRAIN - 225.6494903564453, nan
# TEST - 4407.13330078125, nan
#
# Adjusting learning rate of group 0 to 1.9318e-04.
# /*** EPOCH : 328/1000 ***/
# TRAIN - 204.70143127441406, nan
# TEST - 3574.47216796875, nan
#
# Adjusting learning rate of group 0 to 1.9222e-04.
# /*** EPOCH : 329/1000 ***/
# TRAIN - 210.9140625, nan
# TEST - 4176.80615234375, nan
#
# Adjusting learning rate of group 0 to 1.9126e-04.
# /*** EPOCH : 330/1000 ***/
# TRAIN - 204.79029846191406, nan
# TEST - 3392.290771484375, nan
#
# Adjusting learning rate of group 0 to 1.9030e-04.
# /*** EPOCH : 331/1000 ***/
# TRAIN - 196.960693359375, nan
# TEST - 3839.731201171875, nan
#
# Adjusting learning rate of group 0 to 1.8935e-04.
# /*** EPOCH : 332/1000 ***/
# TRAIN - 204.69334411621094, nan
# TEST - 3869.167236328125, nan
#
# Adjusting learning rate of group 0 to 1.8840e-04.
# /*** EPOCH : 333/1000 ***/
# TRAIN - 191.28701782226562, nan
# TEST - 3387.43896484375, nan
#
# Adjusting learning rate of group 0 to 1.8746e-04.
# /*** EPOCH : 334/1000 ***/
# TRAIN - 209.2288818359375, nan
# TEST - 4075.648681640625, nan
#
# Adjusting learning rate of group 0 to 1.8652e-04.
# /*** EPOCH : 335/1000 ***/
# TRAIN - 248.87852478027344, nan
# TEST - 4294.01123046875, nan
#
# Adjusting learning rate of group 0 to 1.8559e-04.
# /*** EPOCH : 336/1000 ***/
# TRAIN - 201.9593048095703, nan
# TEST - 3908.017578125, nan
#
# Adjusting learning rate of group 0 to 1.8466e-04.
# /*** EPOCH : 337/1000 ***/
# TRAIN - 220.86941528320312, nan
# TEST - 3353.19921875, nan
#
# Adjusting learning rate of group 0 to 1.8374e-04.
# /*** EPOCH : 338/1000 ***/
# TRAIN - 243.47023010253906, nan
# TEST - 4243.03125, nan
#
# Adjusting learning rate of group 0 to 1.8282e-04.
# /*** EPOCH : 339/1000 ***/
# TRAIN - 225.3668212890625, nan
# TEST - 3102.1416015625, nan
#
# Adjusting learning rate of group 0 to 1.8191e-04.
# /*** EPOCH : 340/1000 ***/
# TRAIN - 197.7342529296875, nan
# TEST - 3956.667724609375, nan
#
# Adjusting learning rate of group 0 to 1.8100e-04.
# /*** EPOCH : 341/1000 ***/
# TRAIN - 226.9727325439453, nan
# TEST - 3547.939453125, nan
#
# Adjusting learning rate of group 0 to 1.8009e-04.
# /*** EPOCH : 342/1000 ***/
# TRAIN - 232.26747131347656, nan
# TEST - 3537.00341796875, nan
#
# Adjusting learning rate of group 0 to 1.7919e-04.
# /*** EPOCH : 343/1000 ***/
# TRAIN - 254.72454833984375, nan
# TEST - 4486.3642578125, nan
#
# Adjusting learning rate of group 0 to 1.7830e-04.
# /*** EPOCH : 344/1000 ***/
# TRAIN - 341.71209716796875, nan
# TEST - 3752.86767578125, nan
#
# Adjusting learning rate of group 0 to 1.7740e-04.
# /*** EPOCH : 345/1000 ***/
# TRAIN - 451.0079040527344, nan
# TEST - 4003.977294921875, nan
#
# Adjusting learning rate of group 0 to 1.7652e-04.
# /*** EPOCH : 346/1000 ***/
# TRAIN - 268.18572998046875, nan
# TEST - 4603.08203125, nan
#
# ...
# /*** EPOCH : 713/1000 ***/
# TRAIN - 6.8347015380859375, nan
# TEST - 3699.966796875, 53122.672552093936
#
# Adjusting learning rate of group 0 to 2.7905e-05.
# /*** EPOCH : 714/1000 ***/
# TRAIN - 6.819225311279297, nan
# TEST - 3068.982666015625, 52712.528777358544
#
# Adjusting learning rate of group 0 to 2.7765e-05.
# /*** EPOCH : 715/1000 ***/
# TRAIN - 6.753949165344238, nan
# TEST - 3379.04150390625, nan
#
# Adjusting learning rate of group 0 to 2.7626e-05.
# /*** EPOCH : 716/1000 ***/
# TRAIN - 6.659124851226807, nan
# TEST - 3446.78271484375, 56331.202319770164
#
# Adjusting learning rate of group 0 to 2.7488e-05.
# /*** EPOCH : 717/1000 ***/
# TRAIN - 6.698551654815674, nan
# TEST - 3524.140869140625, nan
#
# Adjusting learning rate of group 0 to 2.7351e-05.
# /*** EPOCH : 718/1000 ***/
# TRAIN - 6.706129550933838, nan
# TEST - 3988.322509765625, nan
#
# Adjusting learning rate of group 0 to 2.7214e-05.
# /*** EPOCH : 719/1000 ***/
# TRAIN - 6.670589447021484, nan
# TEST - 3418.63427734375, nan
#
# Adjusting learning rate of group 0 to 2.7078e-05.
# /*** EPOCH : 720/1000 ***/
# TRAIN - 7.439356327056885, nan
# TEST - 3976.622314453125, nan
#
# Adjusting learning rate of group 0 to 2.6943e-05.
# /*** EPOCH : 721/1000 ***/
# TRAIN - 8.394535064697266, nan
# TEST - 3715.490234375, nan
#
# Adjusting learning rate of group 0 to 2.6808e-05.
# /*** EPOCH : 722/1000 ***/
# TRAIN - 8.804289817810059, nan
# TEST - 3044.98046875, nan
#
# Adjusting learning rate of group 0 to 2.6674e-05.
# /*** EPOCH : 723/1000 ***/
# TRAIN - 9.52094554901123, nan
# TEST - 3887.86083984375, 67761.42890620654
#
# Adjusting learning rate of group 0 to 2.6541e-05.
# /*** EPOCH : 724/1000 ***/
# TRAIN - 8.661290168762207, nan
# TEST - 3649.53515625, nan
#
# Adjusting learning rate of group 0 to 2.6408e-05.
# /*** EPOCH : 725/1000 ***/
# TRAIN - 9.299459457397461, nan
# TEST - 4006.647705078125, 48053.83094969057
#
# Adjusting learning rate of group 0 to 2.6276e-05.
# /*** EPOCH : 726/1000 ***/
# TRAIN - 9.004983901977539, nan
# TEST - 3525.498779296875, 48142.287319804906
#
# Adjusting learning rate of group 0 to 2.6144e-05.
# /*** EPOCH : 727/1000 ***/
# TRAIN - 7.910207748413086, nan
# TEST - 3770.489013671875, nan
#
# Adjusting learning rate of group 0 to 2.6014e-05.
# /*** EPOCH : 728/1000 ***/
# TRAIN - 7.742918014526367, nan
# TEST - 3613.614501953125, nan
#
# Adjusting learning rate of group 0 to 2.5884e-05.
# /*** EPOCH : 729/1000 ***/
# TRAIN - 7.134787082672119, nan
# TEST - 3961.79150390625, nan
#
# Adjusting learning rate of group 0 to 2.5754e-05.
# /*** EPOCH : 730/1000 ***/
# TRAIN - 7.044826984405518, nan
# TEST - 4060.994140625, nan
#
# Adjusting learning rate of group 0 to 2.5625e-05.
# /*** EPOCH : 731/1000 ***/
# TRAIN - 6.656458854675293, nan
# TEST - 3599.02099609375, 48286.35002685158
#
# Adjusting learning rate of group 0 to 2.5497e-05.
# /*** EPOCH : 732/1000 ***/
# TRAIN - 7.3499531745910645, nan
# TEST - 3195.119873046875, nan
#
# Adjusting learning rate of group 0 to 2.5370e-05.
# /*** EPOCH : 733/1000 ***/
# TRAIN - 7.643317222595215, nan
# TEST - 3845.1689453125, nan
#
# Adjusting learning rate of group 0 to 2.5243e-05.
# /*** EPOCH : 734/1000 ***/
# TRAIN - 7.606438636779785, nan
# TEST - 3718.966552734375, 56065.33110703174
#
# Adjusting learning rate of group 0 to 2.5117e-05.
# /*** EPOCH : 735/1000 ***/
# TRAIN - 7.589472770690918, nan
# TEST - 3611.15478515625, nan
#
# Adjusting learning rate of group 0 to 2.4991e-05.
# /*** EPOCH : 736/1000 ***/
# TRAIN - 7.899986267089844, nan
# TEST - 3569.739013671875, nan
#
# Adjusting learning rate of group 0 to 2.4866e-05.
# /*** EPOCH : 737/1000 ***/
# TRAIN - 8.786758422851562, nan
# TEST - 3896.828125, nan
#
# Adjusting learning rate of group 0 to 2.4742e-05.
#
# /***CHECK_POINT***/
# TRAIN - 9.028547286987305, nan
# TEST - 3297.308349609375, 42736.645074312764
#
# /*** EPOCH : 738/1000 ***/
# TRAIN - 9.028547286987305, nan
# TEST - 3297.308349609375, 42736.645074312764
#
# Adjusting learning rate of group 0 to 2.4618e-05.
# /*** EPOCH : 739/1000 ***/
# TRAIN - 7.757087230682373, nan
# TEST - 3989.052490234375, nan
#
# Adjusting learning rate of group 0 to 2.4495e-05.
# /*** EPOCH : 740/1000 ***/
# TRAIN - 7.426732540130615, nan
# TEST - 3717.563232421875, nan
#
# Adjusting learning rate of group 0 to 2.4373e-05.
# /*** EPOCH : 741/1000 ***/
# TRAIN - 7.112618446350098, nan
# TEST - 3450.800048828125, nan
#
# Adjusting learning rate of group 0 to 2.4251e-05.
# /*** EPOCH : 742/1000 ***/
# TRAIN - 6.778989791870117, nan
# TEST - 3518.032470703125, nan
#
# Adjusting learning rate of group 0 to 2.4130e-05.
# /*** EPOCH : 743/1000 ***/
# TRAIN - 6.210424900054932, nan
# TEST - 3291.230224609375, nan
#
# Adjusting learning rate of group 0 to 2.4009e-05.
# /*** EPOCH : 744/1000 ***/
# TRAIN - 6.101300239562988, nan
# TEST - 3437.98291015625, nan
#
# Adjusting learning rate of group 0 to 2.3889e-05.
# /*** EPOCH : 745/1000 ***/
# TRAIN - 5.959383964538574, nan
# TEST - 3728.813232421875, nan
#
# Adjusting learning rate of group 0 to 2.3769e-05.
# /*** EPOCH : 746/1000 ***/
# TRAIN - 6.169347763061523, nan
# TEST - 4189.49853515625, nan
#
# Adjusting learning rate of group 0 to 2.3651e-05.
# /*** EPOCH : 747/1000 ***/
# TRAIN - 6.191746711730957, nan
# TEST - 3789.2666015625, nan
#
# Adjusting learning rate of group 0 to 2.3532e-05.
# /*** EPOCH : 748/1000 ***/
# TRAIN - 6.429855823516846, nan
# TEST - 3049.5927734375, nan
#
# Adjusting learning rate of group 0 to 2.3415e-05.
# /*** EPOCH : 749/1000 ***/
# TRAIN - 7.162136077880859, nan
# TEST - 3899.91943359375, nan
#
# Adjusting learning rate of group 0 to 2.3298e-05.
# /*** EPOCH : 750/1000 ***/
# TRAIN - 7.490049362182617, nan
# TEST - 3637.06201171875, nan
#
# Adjusting learning rate of group 0 to 2.3181e-05.
# /*** EPOCH : 751/1000 ***/
# TRAIN - 8.242928504943848, nan
# TEST - 3947.49462890625, nan
#
# Adjusting learning rate of group 0 to 2.3065e-05.
# /*** EPOCH : 752/1000 ***/
# TRAIN - 8.96781063079834, nan
# TEST - 4259.1953125, nan
#
# Adjusting learning rate of group 0 to 2.2950e-05.
# /*** EPOCH : 753/1000 ***/
# TRAIN - 8.700993537902832, nan
# TEST - 3835.5224609375, nan
#
# Adjusting learning rate of group 0 to 2.2835e-05.
# /*** EPOCH : 754/1000 ***/
# TRAIN - 7.443737030029297, nan
# TEST - 4221.31005859375, 43954.70909697426
#
# Adjusting learning rate of group 0 to 2.2721e-05.
# /*** EPOCH : 755/1000 ***/
# TRAIN - 7.402446746826172, nan
# TEST - 4158.7490234375, 50410.89695309587
#
# Adjusting learning rate of group 0 to 2.2607e-05.
# /*** EPOCH : 756/1000 ***/
# TRAIN - 8.140326499938965, nan
# TEST - 3810.3115234375, 52350.95266329362
#
# Adjusting learning rate of group 0 to 2.2494e-05.
# /*** EPOCH : 757/1000 ***/
# TRAIN - 6.806901931762695, nan
# TEST - 3184.341064453125, nan
#
# Adjusting learning rate of group 0 to 2.2382e-05.
# /*** EPOCH : 758/1000 ***/
# TRAIN - 6.076873302459717, nan
# TEST - 3192.537109375, nan
#
# Adjusting learning rate of group 0 to 2.2270e-05.
# /*** EPOCH : 759/1000 ***/
# TRAIN - 5.688798427581787, nan
# TEST - 3713.783203125, 58233.7058030757
#
# Adjusting learning rate of group 0 to 2.2159e-05.
# /*** EPOCH : 760/1000 ***/
# TRAIN - 5.57795524597168, nan
# TEST - 3137.86083984375, 47657.22635986841
#
# Adjusting learning rate of group 0 to 2.2048e-05.
# /*** EPOCH : 761/1000 ***/
# TRAIN - 5.791792869567871, nan
# TEST - 4347.03271484375, nan
#
# Adjusting learning rate of group 0 to 2.1938e-05.
# /*** EPOCH : 762/1000 ***/
# TRAIN - 5.8445725440979, nan
# TEST - 3691.863037109375, nan
#
# Adjusting learning rate of group 0 to 2.1828e-05.
# /*** EPOCH : 763/1000 ***/
# TRAIN - 6.079525947570801, nan
# TEST - 3695.615966796875, nan
#
# Adjusting learning rate of group 0 to 2.1719e-05.
# /*** EPOCH : 764/1000 ***/
# TRAIN - 5.81649923324585, nan
# TEST - 4017.956787109375, nan
#
# Adjusting learning rate of group 0 to 2.1610e-05.
# /*** EPOCH : 765/1000 ***/
# TRAIN - 5.617937088012695, nan
# TEST - 3241.44873046875, 47559.20280561128
#
# Adjusting learning rate of group 0 to 2.1502e-05.
# /*** EPOCH : 766/1000 ***/
# TRAIN - 5.694796562194824, nan
# TEST - 3566.24658203125, 48027.61951862812
#
# Adjusting learning rate of group 0 to 2.1395e-05.
# /*** EPOCH : 767/1000 ***/
# TRAIN - 6.225177764892578, nan
# TEST - 4099.1982421875, nan
#
# Adjusting learning rate of group 0 to 2.1288e-05.
# /*** EPOCH : 768/1000 ***/
# TRAIN - 6.945888042449951, nan
# TEST - 4007.408203125, 53543.56174892907
#
# Adjusting learning rate of group 0 to 2.1181e-05.
# /*** EPOCH : 769/1000 ***/
# TRAIN - 6.808629989624023, nan
# TEST - 3985.0498046875, nan
#
# Adjusting learning rate of group 0 to 2.1075e-05.
# /*** EPOCH : 770/1000 ***/
# TRAIN - 7.447561264038086, nan
# TEST - 3353.514892578125, nan
#
# Adjusting learning rate of group 0 to 2.0970e-05.
# /*** EPOCH : 771/1000 ***/
# TRAIN - 9.309526443481445, nan
# TEST - 3242.26513671875, nan
#
# Adjusting learning rate of group 0 to 2.0865e-05.
# /*** EPOCH : 772/1000 ***/
# TRAIN - 7.508828639984131, nan
# TEST - 3696.974853515625, nan
#
# Adjusting learning rate of group 0 to 2.0761e-05.
# /*** EPOCH : 773/1000 ***/
# TRAIN - 6.797963619232178, nan
# TEST - 3752.69091796875, nan
#
# Adjusting learning rate of group 0 to 2.0657e-05.
# /*** EPOCH : 774/1000 ***/
# TRAIN - 6.78123664855957, nan
# TEST - 3372.25732421875, nan
#
# Adjusting learning rate of group 0 to 2.0554e-05.
# /*** EPOCH : 775/1000 ***/
# TRAIN - 6.455557346343994, nan
# TEST - 3910.54296875, nan
#
# Adjusting learning rate of group 0 to 2.0451e-05.
# /*** EPOCH : 776/1000 ***/
# TRAIN - 5.461185932159424, nan
# TEST - 3980.41796875, nan
#
# Adjusting learning rate of group 0 to 2.0349e-05.
# /*** EPOCH : 777/1000 ***/
# TRAIN - 5.285264015197754, nan
# TEST - 3613.03759765625, nan
#
# Adjusting learning rate of group 0 to 2.0247e-05.
# /*** EPOCH : 778/1000 ***/
# TRAIN - 5.586644172668457, nan
# TEST - 3597.75732421875, 49301.231660378384
#
# Adjusting learning rate of group 0 to 2.0146e-05.
# /*** EPOCH : 779/1000 ***/
# TRAIN - 5.371312618255615, nan
# TEST - 3627.717529296875, 44840.023480311494
#
# Adjusting learning rate of group 0 to 2.0045e-05.
# /*** EPOCH : 780/1000 ***/
# TRAIN - 5.191432476043701, nan
# TEST - 3720.0615234375, 49417.02116711973
#
# Adjusting learning rate of group 0 to 1.9945e-05.
# /*** EPOCH : 781/1000 ***/
# TRAIN - 5.52858304977417, nan
# TEST - 4230.6640625, nan
#
# Adjusting learning rate of group 0 to 1.9845e-05.
#
# /***CHECK_POINT***/
# TRAIN - 5.2530035972595215, nan
# TEST - 3985.089599609375, 42667.63624628961
#
# /*** EPOCH : 782/1000 ***/
# TRAIN - 5.2530035972595215, nan
# TEST - 3985.089599609375, 42667.63624628961
#
# Adjusting learning rate of group 0 to 1.9746e-05.
# /*** EPOCH : 783/1000 ***/
# TRAIN - 5.323248386383057, nan
# TEST - 3635.7197265625, nan
#
# Adjusting learning rate of group 0 to 1.9647e-05.
# /*** EPOCH : 784/1000 ***/
# TRAIN - 5.078335762023926, nan
# TEST - 3317.04150390625, nan
#
# Adjusting learning rate of group 0 to 1.9549e-05.
# /*** EPOCH : 785/1000 ***/
# TRAIN - 5.1034932136535645, nan
# TEST - 3682.859619140625, 58527.10644453563
#
# Adjusting learning rate of group 0 to 1.9451e-05.
# /*** EPOCH : 786/1000 ***/
# TRAIN - 5.392421722412109, nan
# TEST - 3428.887939453125, nan
#
# Adjusting learning rate of group 0 to 1.9354e-05.
# /*** EPOCH : 787/1000 ***/
# TRAIN - 5.785299777984619, nan
# TEST - 3233.831298828125, nan
#
# Adjusting learning rate of group 0 to 1.9257e-05.
# /*** EPOCH : 788/1000 ***/
# TRAIN - 5.551677227020264, nan
# TEST - 3786.024169921875, nan
#
# Adjusting learning rate of group 0 to 1.9161e-05.
# /*** EPOCH : 789/1000 ***/
# TRAIN - 5.598243236541748, nan
# TEST - 3734.29541015625, nan
#
# Adjusting learning rate of group 0 to 1.9065e-05.
# /*** EPOCH : 790/1000 ***/
# TRAIN - 5.6764678955078125, nan
# TEST - 3670.947998046875, nan
#
# Adjusting learning rate of group 0 to 1.8970e-05.
# /*** EPOCH : 791/1000 ***/
# TRAIN - 5.591281414031982, nan
# TEST - 3933.00732421875, 53458.76240981658
#
# Adjusting learning rate of group 0 to 1.8875e-05.
# /*** EPOCH : 792/1000 ***/
# TRAIN - 5.22144889831543, nan
# TEST - 3313.77099609375, nan
#
# Adjusting learning rate of group 0 to 1.8780e-05.
# /*** EPOCH : 793/1000 ***/
# TRAIN - 5.476467132568359, nan
# TEST - 3866.09423828125, 46813.895067508536
#
# Adjusting learning rate of group 0 to 1.8686e-05.
# /*** EPOCH : 794/1000 ***/
# TRAIN - 5.9569172859191895, nan
# TEST - 4019.22998046875, nan
#
# Adjusting learning rate of group 0 to 1.8593e-05.
# /*** EPOCH : 795/1000 ***/
# TRAIN - 5.660627841949463, nan
# TEST - 3848.248046875, 52918.1160185379
#
# Adjusting learning rate of group 0 to 1.8500e-05.
# /*** EPOCH : 796/1000 ***/
# TRAIN - 6.160829544067383, nan
# TEST - 3008.056396484375, nan
#
# Adjusting learning rate of group 0 to 1.8408e-05.
# /*** EPOCH : 797/1000 ***/
# TRAIN - 6.026626110076904, nan
# TEST - 4006.565673828125, nan
#
# Adjusting learning rate of group 0 to 1.8315e-05.
# /*** EPOCH : 798/1000 ***/
# TRAIN - 6.120803356170654, nan
# TEST - 3480.817626953125, nan
#
# Adjusting learning rate of group 0 to 1.8224e-05.
# /*** EPOCH : 799/1000 ***/
# TRAIN - 5.698807716369629, nan
# TEST - 3319.54052734375, nan
#
# Adjusting learning rate of group 0 to 1.8133e-05.
# /*** EPOCH : 800/1000 ***/
# TRAIN - 5.213088035583496, nan
# TEST - 3943.930908203125, 48673.56369637482
#
# Adjusting learning rate of group 0 to 1.8042e-05.
# /*** EPOCH : 801/1000 ***/
# TRAIN - 5.247169017791748, nan
# TEST - 3978.152587890625, nan
#
# Adjusting learning rate of group 0 to 1.7952e-05.
# /*** EPOCH : 802/1000 ***/
# TRAIN - 5.115843772888184, nan
# TEST - 3063.0859375, nan
#
# Adjusting learning rate of group 0 to 1.7862e-05.
# /*** EPOCH : 803/1000 ***/
# TRAIN - 5.093566417694092, nan
# TEST - 4017.2763671875, 51368.239361646854
#
# Adjusting learning rate of group 0 to 1.7773e-05.
# /*** EPOCH : 804/1000 ***/
# TRAIN - 5.075262546539307, nan
# TEST - 3287.040283203125, 47133.50318101615
#
# Adjusting learning rate of group 0 to 1.7684e-05.
# /*** EPOCH : 805/1000 ***/
# TRAIN - 5.069597244262695, nan
# TEST - 3765.97607421875, 42955.32866003031
#
# Adjusting learning rate of group 0 to 1.7596e-05.
# /*** EPOCH : 806/1000 ***/
# TRAIN - 5.003726482391357, nan
# TEST - 3720.737548828125, 49158.6219838564
#
# Adjusting learning rate of group 0 to 1.7508e-05.
#
# /***CHECK_POINT***/
# TRAIN - 4.921070098876953, nan
# TEST - 3565.10498046875, 42537.543192098994
#
# /*** EPOCH : 807/1000 ***/
# TRAIN - 4.921070098876953, nan
# TEST - 3565.10498046875, 42537.543192098994
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-4fe3d1215df1> in <module>
#       9 for epoch in range(EPOCH_NUM+1):
#      10     if epoch != 0:
# ---> 11         train_loss, train_meas = train(epoch)
#      12     test_loss, test_meas = test()
#      13
#
# <ipython-input-26-6ca94d6ef215> in train(epoch)
#      17         loss = loss_func(outputs, targets)  # 출력과 훈련 데이터 정답 간의 오차를 계산
#      18         loss.backward()  # 오차를 역전파 계산
# ---> 19         optimizer.step()  # 역전파 계산한 값으로 가중치를 수정
#      20
#      21         predict.append(outputs.squeeze(dim = 0).transpose(1,0))
#
# D:\Sangwons_Room\00_SoftWares\Anaconda\envs\torch\lib\site-packages\torch\optim\lr_scheduler.py in wrapper(*args, **kwargs)
#      65                 instance._step_count += 1
#      66                 wrapped = func.__get__(instance, cls)
# ---> 67                 return wrapped(*args, **kwargs)
#      68
#      69             # Note that the returned function here is no longer a bound method,
#
# D:\Sangwons_Room\00_SoftWares\Anaconda\envs\torch\lib\site-packages\torch\autograd\grad_mode.py in decorate_context(*args, **kwargs)
#      24         def decorate_context(*args, **kwargs):
#      25             with self.__class__():
# ---> 26                 return func(*args, **kwargs)
#      27         return cast(F, decorate_context)
#      28
#
# D:\Sangwons_Room\00_SoftWares\Anaconda\envs\torch\lib\site-packages\torch\optim\adam.py in step(self, closure)
#     117                    group['lr'],
#     118                    group['weight_decay'],
# --> 119                    group['eps']
#     120                    )
#     121         return loss
#
# D:\Sangwons_Room\00_SoftWares\Anaconda\envs\torch\lib\site-packages\torch\optim\functional.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps)
#      84
#      85         # Decay the first and second moment running average coefficient
# ---> 86         exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1)
#      87         exp_avg_sq.mul_(beta2).addcmul_(grad, grad, value=1 - beta2)
#      88         if amsgrad:
#
# KeyboardInterrupt:

# %%
df_history = pd.DataFrame(history)

fig, axes = plt.subplots(2,1,figsize = (8,12))

axes[0].plot(df_history['epoch'], df_history['train_loss'])
axes[0].plot(df_history['epoch'], df_history['test_loss'])
axes[0].axvline(x = check_epoch, ymin = 0, ymax = df_history['test_loss'].max(), color = 'r')
axes[0].axhline(y = default_loss, xmin = 0, xmax = df_history['epoch'].max(), color = 'k')
axes[0].set_ylim(0, 5000)

axes[1].plot(df_history['epoch'], df_history['train_meas'])
axes[1].plot(df_history['epoch'], df_history['test_meas'])
axes[1].axvline(x = check_epoch, ymin = 0, ymax = df_history['test_meas'].max(), color = 'r')
axes[1].axhline(y = default_meas, xmin = 0, xmax = df_history['epoch'].max(), color = 'k')

# %%
del X_train, X_test, y_train, y_test

# %% [markdown]
# # Submission

# %%
df_test = pd.read_pickle(str(data_dir / "gsdc_test.pkl.gzip"))

# %%
df_test = FeatureExtraction(df_test, usecols, features)
df_test.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 91486 entries, 0 to 91485
# Data columns (total 104 columns):
#  #   Column                                     Dtype
# ---  ------                                     -----
#  0   collectionName                             object
#  1   phoneName                                  object
#  2   millisSinceGpsEpoch                        int64
#  3   latDeg                                     float64
#  4   lngDeg                                     float64
#  5   heightAboveWgs84EllipsoidM                 float64
#  6   phone                                      object
#  7   utcTimeMillis_x                            float64
#  8   elapsedRealtimeNanos_x                     float64
#  9   UncalGyroXRadPerSec                        float64
#  10  UncalGyroYRadPerSec                        float64
#  11  UncalGyroZRadPerSec                        float64
#  12  DriftXRadPerSec                            object
#  13  DriftYRadPerSec                            float64
#  14  DriftZRadPerSec                            float64
#  15  utcTimeMillis_y                            float64
#  16  elapsedRealtimeNanos_y                     float64
#  17  UncalMagXMicroT                            float64
#  18  UncalMagYMicroT                            float64
#  19  UncalMagZMicroT                            float64
#  20  BiasXMicroT                                float64
#  21  BiasYMicroT                                float64
#  22  BiasZMicroT                                float64
#  23  utcTimeMillis_x                            int64
#  24  TimeNanos                                  int64
#  25  LeapSecond                                 float64
#  26  TimeUncertaintyNanos                       float64
#  27  FullBiasNanos                              int64
#  28  BiasNanos                                  float64
#  29  BiasUncertaintyNanos                       float64
#  30  DriftNanosPerSecond                        float64
#  31  DriftUncertaintyNanosPerSecond             float64
#  32  HardwareClockDiscontinuityCount            int64
#  33  Svid_x                                     int64
#  34  TimeOffsetNanos                            float64
#  35  State                                      int64
#  36  ReceivedSvTimeNanos                        int64
#  37  ReceivedSvTimeUncertaintyNanos             int64
#  38  Cn0DbHz_x                                  float64
#  39  PseudorangeRateMetersPerSecond             float64
#  40  PseudorangeRateUncertaintyMetersPerSecond  float64
#  41  AccumulatedDeltaRangeState                 int64
#  42  AccumulatedDeltaRangeMeters                float64
#  43  AccumulatedDeltaRangeUncertaintyMeters     float64
#  44  CarrierFrequencyHz_x                       float64
#  45  CarrierCycles                              float64
#  46  CarrierPhase                               float64
#  47  CarrierPhaseUncertainty                    float64
#  48  MultipathIndicator                         int64
#  49  SnrInDb                                    float64
#  50  ConstellationType_x                        int64
#  51  AgcDb                                      float64
#  52  BasebandCn0DbHz_x                          float64
#  53  FullInterSignalBiasNanos                   float64
#  54  FullInterSignalBiasUncertaintyNanos        float64
#  55  SatelliteInterSignalBiasNanos              float64
#  56  SatelliteInterSignalBiasUncertaintyNanos   float64
#  57  CodeType                                   object
#  58  ChipsetElapsedRealtimeNanos                float64
#  59  utcTimeMillis_y                            float64
#  60  elapsedRealtimeNanos_x                     float64
#  61  UncalAccelXMps2                            float64
#  62  UncalAccelYMps2                            float64
#  63  UncalAccelZMps2                            float64
#  64  BiasXMps2                                  float64
#  65  BiasYMps2                                  float64
#  66  BiasZMps2                                  float64
#  67  utcTimeMillis_x                            float64
#  68  elapsedRealtimeNanos_y                     float64
#  69  yawDeg                                     float64
#  70  rollDeg                                    float64
#  71  pitchDeg                                   float64
#  72  utcTimeMillis_y                            float64
#  73  SignalCount                                float64
#  74  SignalIndex                                float64
#  75  ConstellationType_y                        float64
#  76  Svid_y                                     float64
#  77  CarrierFrequencyHz_y                       float64
#  78  Cn0DbHz_y                                  float64
#  79  AzimuthDegrees                             float64
#  80  ElevationDegrees                           float64
#  81  UsedInFix                                  float64
#  82  HasAlmanacData                             float64
#  83  HasEphemerisData                           float64
#  84  BasebandCn0DbHz_y                          float64
#  85  constellationType                          int64
#  86  svid                                       int64
#  87  signalType                                 object
#  88  receivedSvTimeInGpsNanos                   int64
#  89  xSatPosM                                   float64
#  90  ySatPosM                                   float64
#  91  zSatPosM                                   float64
#  92  xSatVelMps                                 float64
#  93  ySatVelMps                                 float64
#  94  zSatVelMps                                 float64
#  95  satClkBiasM                                float64
#  96  satClkDriftMps                             float64
#  97  rawPrM                                     float64
#  98  rawPrUncM                                  float64
#  99  isrbM                                      float64
#  100 ionoDelayM                                 float64
#  101 tropoDelayM                                float64
#  102 dlngDeg                                    float64
#  103 dlatDeg                                    float64
# dtypes: float64(83), int64(15), object(6)
# memory usage: 73.3+ MB

# %%
df_test = df_test.fillna(method = 'pad')
df_test = df_test.fillna(0)

# %%
for col, s in scaler.scaler.items():
    print(col)
    print(df_test[col])
    print(s.transform(np.array(df_test[col]).reshape(-1,1)))
# Out:
# dlatDeg
# 0        0.000000
# 1       -0.000033
# 2       -0.000029
# 3       -0.000043
# 4       -0.000029
#            ...
# 91481   -0.000072
# 91482   -0.000059
# 91483   -0.000065
# 91484   -0.000049
# 91485   -0.000074
# Name: dlatDeg, Length: 91486, dtype: float64
# [[0.5693947 ]
#  [0.56933041]
#  [0.56933813]
#  ...
#  [0.56926959]
#  [0.56930048]
#  [0.56925144]]
# dlngDeg
# 0        0.000000
# 1       -0.000019
# 2       -0.000029
# 3       -0.000012
# 4       -0.000011
#            ...
# 91481    0.000010
# 91482    0.000007
# 91483   -0.000011
# 91484   -0.000002
# 91485    0.000007
# Name: dlngDeg, Length: 91486, dtype: float64
# [[0.51214836]
#  [0.51212395]
#  [0.5121099 ]
#  ...
#  [0.51213366]
#  [0.51214587]
#  [0.51215808]]
# xSatVelMps
# 0         292.938
# 1        1255.685
# 2        1255.940
# 3        2808.676
# 4         813.076
#            ...
# 91481    2560.148
# 91482    -620.461
# 91483     -21.203
# 91484   -2445.674
# 91485    -235.144
# Name: xSatVelMps, Length: 91486, dtype: float64
# [[0.53344769]
#  [0.6881983 ]
#  [0.68823929]
#  ...
#  [0.48295311]
#  [0.09324703]
#  [0.44856453]]
# ySatVelMps
# 0         -62.944
# 1        1388.784
# 2        1388.826
# 3         317.171
# 4        1060.450
#            ...
# 91481     703.681
# 91482   -1406.706
# 91483     253.506
# 91484   -1033.324
# 91485    1682.793
# Name: ySatVelMps, Length: 91486, dtype: float64
# [[0.49149267]
#  [0.72310196]
#  [0.72310866]
#  ...
#  [0.54197923]
#  [0.33667783]
#  [0.77000828]]
# zSatVelMps
# 0        3162.107
# 1        2026.329
# 2        2026.043
# 3         370.156
# 4        2833.855
#            ...
# 91481     317.967
# 91482   -2374.920
# 91483   -3030.240
# 91484    -866.790
# 91485    2365.241
# Name: zSatVelMps, Length: 91486, dtype: float64
# [[0.93667505]
#  [0.7788971 ]
#  [0.77885737]
#  ...
#  [0.0764578 ]
#  [0.37699603]
#  [0.82597747]]
# xSatPosM
# 0       -1.356785e+07
# 1       -5.245784e+06
# 2       -5.244528e+06
# 3       -1.250617e+06
# 4       -5.181390e+06
#              ...
# 91481    1.644038e+06
# 91482   -1.789167e+07
# 91483   -9.088882e+06
# 91484   -1.239820e+07
# 91485    1.420142e+07
# Name: xSatPosM, Length: 91486, dtype: float64
# [[0.32717456]
#  [0.47971034]
#  [0.47973336]
#  ...
#  [0.40926995]
#  [0.34861318]
#  [0.83615945]]
# ySatPosM
# 0       -2.285292e+07
# 1       -2.240466e+07
# 2       -2.240327e+07
# 3       -1.477269e+07
# 4       -2.384672e+07
#              ...
# 91481   -1.553705e+07
# 91482   -1.795348e+07
# 91483   -2.808691e+07
# 91484    1.088900e+07
# 91485   -1.887078e+07
# Name: ySatPosM, Length: 91486, dtype: float64
# [[0.11990916]
#  [0.1278837 ]
#  [0.12790841]
#  ...
#  [0.02679661]
#  [0.7201771 ]
#  [0.19075127]]
# zSatPosM
# 0        1.439729e+06
# 1        1.861676e+07
# 2        1.861878e+07
# 3        2.173891e+07
# 4        1.047982e+07
#              ...
# 91481    2.213177e+07
# 91482    1.528863e+07
# 91483   -2.290017e+06
# 91484    2.081993e+07
# 91485    1.486136e+07
# Name: zSatPosM, Length: 91486, dtype: float64
# [[0.37012314]
#  [0.6911855 ]
#  [0.69122338]
#  ...
#  [0.30040905]
#  [0.73236587]
#  [0.62099194]]
# UncalGyroXRadPerSec
# 0       -0.005630
# 1       -0.009253
# 2       -0.000794
# 3        0.036793
# 4       -0.030948
#            ...
# 91481    0.009774
# 91482    0.009774
# 91483    0.009774
# 91484    0.009774
# 91485    0.009774
# Name: UncalGyroXRadPerSec, Length: 91486, dtype: float64
# [[0.50606885]
#  [0.50506111]
#  [0.50741431]
#  ...
#  [0.51035437]
#  [0.51035437]
#  [0.51035437]]
# UncalGyroYRadPerSec
# 0        0.001063
# 1        0.003576
# 2       -0.001525
# 3       -0.016991
# 4        0.020031
#            ...
# 91481    0.008552
# 91482    0.008552
# 91483    0.008552
# 91484    0.008552
# 91485    0.008552
# Name: UncalGyroYRadPerSec, Length: 91486, dtype: float64
# [[0.6524704 ]
#  [0.65293493]
#  [0.65199198]
#  ...
#  [0.65385491]
#  [0.65385491]
#  [0.65385491]]
# UncalGyroZRadPerSec
# 0       -0.001085
# 1       -0.003583
# 2       -0.005910
# 3       -0.001773
# 4        0.003426
#            ...
# 91481    0.014050
# 91482    0.014050
# 91483    0.014050
# 91484    0.014050
# 91485    0.014050
# Name: UncalGyroZRadPerSec, Length: 91486, dtype: float64
# [[0.51661662]
#  [0.5160868 ]
#  [0.5155931 ]
#  ...
#  [0.51982754]
#  [0.51982754]
#  [0.51982754]]
# DriftXRadPerSec
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
#             ...
# 91481    0.00524367
# 91482    0.00524367
# 91483    0.00524367
# 91484    0.00524367
# 91485    0.00524367
# Name: DriftXRadPerSec, Length: 91486, dtype: object
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-117-0f4c0d36393c> in <module>
#       2     print(col)
#       3     print(df_test[col])
# ----> 4     print(s.transform(np.array(df_test[col]).reshape(-1,1)))
#
# D:\Sangwons_Room\00_SoftWares\Anaconda\envs\torch\lib\site-packages\sklearn\preprocessing\_data.py in transform(self, X)
#     406
#     407         X = check_array(X, copy=self.copy, dtype=FLOAT_DTYPES,
# --> 408                         force_all_finite="allow-nan")
#     409
#     410         X *= self.scale_
#
# D:\Sangwons_Room\00_SoftWares\Anaconda\envs\torch\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# D:\Sangwons_Room\00_SoftWares\Anaconda\envs\torch\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     596                     array = array.astype(dtype, casting="unsafe", copy=False)
#     597                 else:
# --> 598                     array = np.asarray(array, order=order, dtype=dtype)
#     599             except ComplexWarning:
#     600                 raise ValueError("Complex data not supported\n"
#
# D:\Sangwons_Room\00_SoftWares\Anaconda\envs\torch\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: could not convert string to float: '-7.0277543E'

# %%
for v in df_test[col]:
    if  type(v) == float or  type(v) == int:
        pass
    else:
        print(type(v), v)
# Out:
# <class 'str'> -7.093253E-4
# <class 'str'> -7.088188E-4
# <class 'str'> -7.074449E-4
# <class 'str'> -7.067865E-4
# <class 'str'> -7.0526707E-4
# <class 'str'> -7.050138E-4
# <class 'str'> -7.0511515E-4
# <class 'str'> -7.0511515E-4
# <class 'str'> -7.062294E-4
# <class 'str'> -7.0648274E-4
# <class 'str'> -7.068879E-4
# <class 'str'> -7.0703984E-4
# <class 'str'> -7.06432E-4
# <class 'str'> -7.067866E-4
# <class 'str'> -7.06584E-4
# <class 'str'> -7.0638146E-4
# <class 'str'> -7.0638146E-4
# <class 'str'> -7.0724246E-4
# <class 'str'> -7.0754637E-4
# <class 'str'> -7.076477E-4
# <class 'str'> -7.0805923E-4
# <class 'str'> -7.076477E-4
# <class 'str'> -7.0795795E-4
# <class 'str'> -7.076477E-4
# <class 'str'> -7.076477E-4
# <class 'str'> -7.0795795E-4
# <class 'str'> -7.0744514E-4
# <class 'str'> -7.0734386E-4
# <class 'str'> -7.0703996E-4
# <class 'str'> -7.0714124E-4
# <class 'str'> -7.0744514E-4
# <class 'str'> -7.0703996E-4
# <class 'str'> -7.06888E-4
# <class 'str'> -7.065841E-4
# <class 'str'> -7.054698E-4
# <class 'str'> -7.0450746E-4
# <class 'str'> -7.04001E-4
# <class 'str'> -7.03083E-4
# <class 'str'> -7.023233E-4
# <class 'str'> -7.023233E-4
# <class 'str'> -7.014116E-4
# <class 'str'> -7.01361E-4
# <class 'str'> -7.010571E-4
# <class 'str'> -7.007532E-4
# <class 'str'> -6.9948065E-4
# <class 'str'> -6.9973385E-4
# <class 'str'> -6.993793E-4
# <class 'str'> -6.9851824E-4
# <class 'str'> -6.9841696E-4
# <class 'str'> -6.980118E-4
# <class 'str'> -6.979105E-4
# <class 'str'> -6.976066E-4
# <class 'str'> -6.976066E-4
# <class 'str'> -6.973027E-4
# <class 'str'> -6.964923E-4
# <class 'str'> -6.967962E-4
# <class 'str'> -6.964923E-4
# <class 'str'> -6.961378E-4
# <class 'str'> -6.961378E-4
# <class 'str'> -6.9593516E-4
# <class 'str'> -6.9552363E-4
# <class 'str'> -6.9521967E-4
# <class 'str'> -6.9491577E-4
# <class 'str'> -6.945612E-4
# <class 'str'> -6.9405476E-4
# <class 'str'> -6.9390284E-4
# <class 'str'> -6.933963E-4
# <class 'str'> -6.923833E-4
# <class 'str'> -6.916679E-4
# <class 'str'> -6.91516E-4
# <class 'str'> -6.91516E-4
# <class 'str'> -6.914147E-4
# <class 'str'> -6.911108E-4
# <class 'str'> -6.910095E-4
# <class 'str'> -6.906043E-4
# <class 'str'> -6.904017E-4
# <class 'str'> -6.901485E-4
# <class 'str'> -6.899459E-4
# <class 'str'> -6.894394E-4
# <class 'str'> -6.8873033E-4
# <class 'str'> -6.885277E-4
# <class 'str'> -6.8817317E-4
# <class 'str'> -6.87559E-4
# <class 'str'> -6.878629E-4
# <class 'str'> -6.8745774E-4
# <class 'str'> -6.873564E-4
# <class 'str'> -6.872551E-4
# <class 'str'> -6.867993E-4
# <class 'str'> -6.867993E-4
# <class 'str'> -6.858876E-4
# <class 'str'> -6.855837E-4
# <class 'str'> -6.8548234E-4
# <class 'str'> -6.8548234E-4
# <class 'str'> -6.851278E-4
# <class 'str'> -6.8639405E-4
# <class 'str'> -6.8700186E-4
# <class 'str'> -6.877616E-4
# <class 'str'> -6.8847695E-4
# <class 'str'> -6.8933796E-4
# <class 'str'> -6.8964186E-4
# <class 'str'> -6.894393E-4
# <class 'str'> -6.8862893E-4
# <class 'str'> -6.8923674E-4
# <class 'str'> -6.8943936E-4
# <class 'str'> -6.8943936E-4
# <class 'str'> -6.8984454E-4
# <class 'str'> -6.8974326E-4
# <class 'str'> -6.899458E-4
# <class 'str'> -6.90351E-4
# <class 'str'> -6.90351E-4
# <class 'str'> -6.900471E-4
# <class 'str'> -6.897432E-4
# <class 'str'> -6.891354E-4
# <class 'str'> -6.888315E-4
# <class 'str'> -6.8847695E-4
# <class 'str'> -6.8817305E-4
# <class 'str'> -6.8878086E-4
# <class 'str'> -6.882744E-4
# <class 'str'> -6.8796414E-4
# <class 'str'> -6.8786286E-4
# <class 'str'> -6.877616E-4
# <class 'str'> -6.876603E-4
# <class 'str'> -6.876603E-4
# <class 'str'> -6.873564E-4
# <class 'str'> -6.878629E-4
# <class 'str'> -6.876603E-4
# <class 'str'> -6.87559E-4
# <class 'str'> -6.880718E-4
# <class 'str'> -6.8837573E-4
# <class 'str'> -6.8817317E-4
# <class 'str'> -6.88781E-4
# <class 'str'> -6.8913546E-4
# <class 'str'> -6.8954064E-4
# <class 'str'> -6.889329E-4
# <class 'str'> -6.8933814E-4
# <class 'str'> -6.901992E-4
# <class 'str'> -6.907057E-4
# <class 'str'> -6.915161E-4
# <class 'str'> -6.9213024E-4
# <class 'str'> -6.9202896E-4
# <class 'str'> -6.930926E-4
# <class 'str'> -6.934978E-4
# <class 'str'> -6.9496664E-4
# <class 'str'> -6.95253E-4
# <class 'str'> -6.9533486E-4
# <class 'str'> -6.951711E-4
# <class 'str'> -6.9558027E-4
# <class 'str'> -6.966083E-4
# <class 'str'> -6.96281E-4
# <class 'str'> -6.9709925E-4
# <class 'str'> -6.9640373E-4
# <class 'str'> -6.96772E-4
# <class 'str'> -6.97263E-4
# <class 'str'> -6.9767213E-4
# <class 'str'> -6.971812E-4
# <class 'str'> -6.973449E-4
# <class 'str'> -6.971812E-4
# <class 'str'> -6.971812E-4
# <class 'str'> -6.969357E-4
# <class 'str'> -6.9701753E-4
# <class 'str'> -6.9701753E-4
# <class 'str'> -6.9701753E-4
# <class 'str'> -6.969357E-4
# <class 'str'> -6.9685385E-4
# <class 'str'> -6.969357E-4
# <class 'str'> -6.9669023E-4
# <class 'str'> -6.963629E-4
# <class 'str'> -6.96322E-4
# <class 'str'> -6.9660845E-4
# <class 'str'> -6.9660845E-4
# <class 'str'> -6.968539E-4
# <class 'str'> -6.9693575E-4
# <class 'str'> -6.9726305E-4
# <class 'str'> -6.9709937E-4
# <class 'str'> -6.9709937E-4
# <class 'str'> -6.973449E-4
# <class 'str'> -6.9718127E-4
# <class 'str'> -6.9718127E-4
# <class 'str'> -6.9718127E-4
# <class 'str'> -6.970994E-4
# <class 'str'> -6.9734495E-4
# <class 'str'> -6.9734495E-4
# <class 'str'> -6.9734495E-4
# <class 'str'> -6.975904E-4
# <class 'str'> -6.9771317E-4
# <class 'str'> -6.9767225E-4
# <class 'str'> -6.984497E-4
# <class 'str'> -6.976723E-4
# <class 'str'> -6.977541E-4
# <class 'str'> -6.984497E-4
# <class 'str'> -6.986952E-4
# <class 'str'> -6.9812237E-4
# <class 'str'> -6.9861335E-4
# <class 'str'> -6.9795863E-4
# <class 'str'> -6.984496E-4
# <class 'str'> -6.9767225E-4
# <class 'str'> -6.977541E-4
# <class 'str'> -6.9795863E-4
# <class 'str'> -6.9767225E-4
# <class 'str'> -6.979587E-4
# <class 'str'> -6.979996E-4
# <class 'str'> -6.977132E-4
# <class 'str'> -6.977132E-4
# <class 'str'> -6.9759047E-4
# <class 'str'> -6.979587E-4
# <class 'str'> -6.979587E-4
# <class 'str'> -6.9775415E-4
# <class 'str'> -6.9754955E-4
# <class 'str'> -6.976314E-4
# <class 'str'> -6.985315E-4
# <class 'str'> -6.985315E-4
# <class 'str'> -6.97836E-4
# <class 'str'> -6.9844973E-4
# <class 'str'> -6.985315E-4
# <class 'str'> -6.9861335E-4
# <class 'str'> -6.986952E-4
# <class 'str'> -6.9857243E-4
# <class 'str'> -6.987361E-4
# <class 'str'> -6.993141E-4
# <class 'str'> -6.9939595E-4
# <class 'str'> -6.9939595E-4
# <class 'str'> -6.994778E-4
# <class 'str'> -6.9955963E-4
# <class 'str'> -6.9980515E-4
# <class 'str'> -6.997233E-4
# <class 'str'> -6.9964153E-4
# <class 'str'> -6.9947785E-4
# <class 'str'> -6.999688E-4
# <class 'str'> -6.999688E-4
# <class 'str'> -6.999688E-4
# <class 'str'> -6.99887E-4
# <class 'str'> -7.001325E-4
# <class 'str'> -7.001325E-4
# <class 'str'> -7.0095086E-4
# <class 'str'> -7.0082815E-4
# <class 'str'> -7.016055E-4
# <class 'str'> -7.018919E-4
# <class 'str'> -7.0127816E-4
# <class 'str'> -7.0189184E-4
# <class 'str'> -7.02347E-4
# <class 'str'> -7.025925E-4
# <class 'str'> -7.025925E-4
# <class 'str'> -7.031244E-4
# <class 'str'> -7.029198E-4
# <class 'str'> -7.0353353E-4
# <class 'str'> -7.0377905E-4
# <class 'str'> -7.0390175E-4
# <class 'str'> -7.0410635E-4
# <class 'str'> -7.0459733E-4
# <class 'str'> -7.043518E-4
# <class 'str'> -7.046382E-4
# <class 'str'> -7.044336E-4
# <class 'str'> -7.048837E-4
# <class 'str'> -7.045973E-4
# <class 'str'> -7.0504734E-4
# <class 'str'> -7.049655E-4
# <class 'str'> -7.053797E-4
# <class 'str'> -7.059934E-4
# <class 'str'> -7.0648437E-4
# <class 'str'> -7.064025E-4
# <class 'str'> -7.067708E-4
# <class 'str'> -7.0767093E-4
# <class 'str'> -7.080801E-4
# <class 'str'> -7.0865796E-4
# <class 'str'> -7.084074E-4
# <class 'str'> -7.0886256E-4
# <class 'str'> -7.089444E-4
# <class 'str'> -7.102946E-4
# <class 'str'> -7.105401E-4
# <class 'str'> -7.1078556E-4
# <class 'str'> -7.1078556E-4
# <class 'str'> -7.1078556E-4
# <class 'str'> -7.1111287E-4
# <class 'str'> -7.1111287E-4
# <class 'str'> -7.1111287E-4
# <class 'str'> -7.1099016E-4
# <class 'str'> -7.1062194E-4
# <class 'str'> -7.1013096E-4
# <class 'str'> -7.105401E-4
# <class 'str'> -7.1013096E-4
# <class 'str'> -7.103764E-4
# <class 'str'> -7.1004906E-4
# <class 'str'> -7.0963986E-4
# <class 'str'> -7.093534E-4
# <class 'str'> -7.0918974E-4
# <class 'str'> -7.091079E-4
# <class 'str'> -7.087806E-4
# <class 'str'> -7.0816174E-4
# <class 'str'> -7.083254E-4
# <class 'str'> -7.0848904E-4
# <class 'str'> -7.0832536E-4
# <class 'str'> -7.0848904E-4
# <class 'str'> -7.0886244E-4
# <class 'str'> -7.0848904E-4
# <class 'str'> -7.0848904E-4
# <class 'str'> -7.091896E-4
# <class 'str'> -7.096397E-4
# <class 'str'> -7.1053987E-4
# <class 'str'> -7.1086717E-4
# <class 'str'> -7.111945E-4
# <class 'str'> -7.118952E-4
# <class 'str'> -7.12468E-4
# <class 'str'> -7.131635E-4
# <class 'str'> -7.1324536E-4
# <class 'str'> -7.136545E-4
# <class 'str'> -7.142682E-4
# <class 'str'> -7.144728E-4
# <class 'str'> -7.155416E-4
# <class 'str'> -7.155416E-4
# <class 'str'> -7.158689E-4
# <class 'str'> -7.160735E-4
# <class 'str'> -7.164417E-4
# <class 'str'> -7.160326E-4
# <class 'str'> -7.162372E-4
# <class 'str'> -7.150098E-4
# <class 'str'> -7.1459555E-4
# <class 'str'> -7.1459555E-4
# <class 'str'> -7.138182E-4
# <class 'str'> -7.138182E-4
# <class 'str'> -7.138182E-4
# <class 'str'> -7.135727E-4
# <class 'str'> -7.134909E-4
# <class 'str'> -7.134909E-4
# <class 'str'> -7.1340904E-4
# <class 'str'> -7.131636E-4
# <class 'str'> -7.131636E-4
# <class 'str'> -7.1291806E-4
# <class 'str'> -7.127135E-4
# <class 'str'> -7.1324536E-4
# <class 'str'> -7.1324536E-4
# <class 'str'> -7.1246794E-4
# <class 'str'> -7.1291794E-4
# <class 'str'> -7.1324524E-4
# <class 'str'> -7.1344984E-4
# <class 'str'> -7.1332714E-4
# <class 'str'> -7.1332714E-4
# <class 'str'> -7.130816E-4
# <class 'str'> -7.1332714E-4
# <class 'str'> -7.1332714E-4
# <class 'str'> -7.13368E-4
# <class 'str'> -7.1381807E-4
# <class 'str'> -7.136544E-4
# <class 'str'> -7.138999E-4
# <class 'str'> -7.1381807E-4
# <class 'str'> -7.138999E-4
# <class 'str'> -7.141863E-4
# <class 'str'> -7.136544E-4
# <class 'str'> -7.145136E-4
# <class 'str'> -7.143499E-4
# <class 'str'> -7.145954E-4
# <class 'str'> -7.14268E-4
# <class 'str'> -7.141862E-4
# <class 'str'> -7.14718E-4
# <class 'str'> -7.150505E-4
# <class 'str'> -7.148408E-4
# <class 'str'> -7.157051E-4
# <class 'str'> -7.157051E-4
# <class 'str'> -7.157051E-4
# <class 'str'> -7.160324E-4
# <class 'str'> -7.1623694E-4
# <class 'str'> -7.161142E-4
# <class 'str'> -7.163597E-4
# <class 'str'> -7.1660517E-4
# <class 'str'> -7.1676885E-4
# <class 'str'> -7.16687E-4
# <class 'str'> -7.1730075E-4
# <class 'str'> -7.173825E-4
# <class 'str'> -7.17137E-4
# <class 'str'> -7.1721885E-4
# <class 'str'> -7.1705517E-4
# <class 'str'> -7.1705517E-4
# <class 'str'> -7.173416E-4
# <class 'str'> -7.1705517E-4
# <class 'str'> -7.178735E-4
# <class 'str'> -7.182469E-4
# <class 'str'> -7.185333E-4
# <class 'str'> -7.184924E-4
# <class 'str'> -7.193925E-4
# <class 'str'> -7.196789E-4
# <class 'str'> -7.1926974E-4
# <class 'str'> -7.193925E-4
# <class 'str'> -7.199653E-4
# <class 'str'> -7.204154E-4
# <class 'str'> -7.2033354E-4
# <class 'str'> -7.20579E-4
# <class 'str'> -7.207427E-4
# <class 'str'> -7.204972E-4
# <class 'str'> -7.213206E-4
# <class 'str'> -7.21607E-4
# <class 'str'> -7.21607E-4
# <class 'str'> -7.213615E-4
# <class 'str'> -7.213615E-4
# <class 'str'> -7.216888E-4
# <class 'str'> -7.2193425E-4
# <class 'str'> -7.216888E-4
# <class 'str'> -7.216888E-4
# <class 'str'> -7.216479E-4
# <class 'str'> -7.2102906E-4
# <class 'str'> -7.204972E-4
# <class 'str'> -7.20579E-4
# <class 'str'> -7.199653E-4
# <class 'str'> -7.202517E-4
# <class 'str'> -7.206609E-4
# <class 'str'> -7.199653E-4
# <class 'str'> -7.20579E-4
# <class 'str'> -7.194743E-4
# <class 'str'> -7.2016986E-4
# <class 'str'> -7.1976066E-4
# <class 'str'> -7.1890146E-4
# <class 'str'> -7.1857416E-4
# <class 'str'> -7.1890146E-4
# <class 'str'> -7.181241E-4
# <class 'str'> -7.1779167E-4
# <class 'str'> -7.173825E-4
# <class 'str'> -7.17178E-4
# <class 'str'> -7.1660517E-4
# <class 'str'> -7.177099E-4
# <class 'str'> -7.183287E-4
# <class 'str'> -7.1873784E-4
# <class 'str'> -7.1873784E-4
# <class 'str'> -7.180372E-4
# <class 'str'> -7.182469E-4
# <class 'str'> -7.1824685E-4
# <class 'str'> -7.177916E-4
# <class 'str'> -7.1775075E-4
# <class 'str'> -7.173416E-4
# <class 'str'> -7.1721885E-4
# <class 'str'> -7.179144E-4
# <class 'str'> -7.175461E-4
# <class 'str'> -7.1795523E-4
# <class 'str'> -7.1857416E-4
# <class 'str'> -7.1824685E-4
# <class 'str'> -7.1824685E-4
# <class 'str'> -7.184924E-4
# <class 'str'> -7.1795535E-4
# <class 'str'> -7.184924E-4
# <class 'str'> -7.184924E-4
# <class 'str'> -7.187379E-4
# <class 'str'> -7.1869703E-4
# <class 'str'> -7.189016E-4
# <class 'str'> -7.189016E-4
# <class 'str'> -7.189016E-4
# <class 'str'> -7.192289E-4
# <class 'str'> -7.1906525E-4
# <class 'str'> -7.191471E-4
# <class 'str'> -7.1939256E-4
# <class 'str'> -7.1890163E-4
# <class 'str'> -7.193108E-4
# <class 'str'> -7.188198E-4
# <class 'str'> -7.191471E-4
# <class 'str'> -7.193107E-4
# <class 'str'> -7.1939256E-4
# <class 'str'> -7.208246E-4
# <class 'str'> -7.207427E-4
# <class 'str'> -7.204153E-4
# <class 'str'> -7.200062E-4
# <class 'str'> -7.1931066E-4
# <class 'str'> -7.190652E-4
# <class 'str'> -7.1881973E-4
# <class 'str'> -7.190652E-4
# <class 'str'> -7.1824697E-4
# <class 'str'> -7.1824697E-4
# <class 'str'> -7.171372E-4
# <class 'str'> -7.171372E-4
# <class 'str'> -7.165235E-4
# <class 'str'> -7.1611436E-4
# <class 'str'> -7.160735E-4
# <class 'str'> -7.158689E-4
# <class 'str'> -7.157052E-4
# <class 'str'> -7.15337E-4
# <class 'str'> -7.152552E-4
# <class 'str'> -7.151734E-4
# <class 'str'> -7.1500975E-4
# <class 'str'> -7.1475917E-4
# <class 'str'> -7.1554165E-4
# <class 'str'> -7.157053E-4
# <class 'str'> -7.147591E-4
# <class 'str'> -7.152552E-4
# <class 'str'> -7.146773E-4
# <class 'str'> -7.142682E-4
# <class 'str'> -7.1389996E-4
# <class 'str'> -7.1365444E-4
# <class 'str'> -7.1336806E-4
# <class 'str'> -7.13409E-4
# <class 'str'> -7.132044E-4
# <class 'str'> -7.132044E-4
# <class 'str'> -7.128362E-4
# <class 'str'> -7.133272E-4
# <class 'str'> -7.1332726E-4
# <class 'str'> -7.133682E-4
# <class 'str'> -7.1316364E-4
# <class 'str'> -7.126317E-4
# <class 'str'> -7.12509E-4
# <class 'str'> -7.1197713E-4
# <class 'str'> -7.1197713E-4
# <class 'str'> -7.1135827E-4
# <class 'str'> -7.1209983E-4
# <class 'str'> -7.1263174E-4
# <class 'str'> -7.1299996E-4
# <class 'str'> -7.1308174E-4
# <class 'str'> -7.126317E-4
# <class 'str'> -7.1291806E-4
# <class 'str'> -7.1324536E-4
# <class 'str'> -7.133272E-4
# <class 'str'> -7.1344996E-4
# <class 'str'> -7.1324536E-4
# <class 'str'> -7.1324536E-4
# <class 'str'> -7.139818E-4
# <class 'str'> -7.1430916E-4
# <class 'str'> -7.1418646E-4
# <class 'str'> -7.143501E-4
# <class 'str'> -7.139818E-4
# <class 'str'> -7.149279E-4
# <class 'str'> -7.148001E-4
# <class 'str'> -7.142682E-4
# <class 'str'> -7.139818E-4
# <class 'str'> -7.1389996E-4
# <class 'str'> -7.13409E-4
# <class 'str'> -7.1349076E-4
# <class 'str'> -7.1316346E-4
# <class 'str'> -7.127134E-4
# <class 'str'> -7.126725E-4
# <class 'str'> -7.120997E-4
# <class 'str'> -7.1164453E-4
# <class 'str'> -7.1156275E-4
# <class 'str'> -7.1103085E-4
# <class 'str'> -7.1103085E-4
# <class 'str'> -7.107036E-4
# <class 'str'> -7.106627E-4
# <class 'str'> -7.106627E-4
# <class 'str'> -7.101308E-4
# <class 'str'> -7.10008E-4
# <class 'str'> -7.0992624E-4
# <class 'str'> -7.096808E-4
# <class 'str'> -7.101309E-4
# <class 'str'> -7.099263E-4
# <class 'str'> -7.098854E-4
# <class 'str'> -7.0992636E-4
# <class 'str'> -7.0980354E-4
# <class 'str'> -7.098444E-4
# <class 'str'> -7.0959894E-4
# <class 'str'> -7.0927164E-4
# <class 'str'> -7.0927164E-4
# <class 'str'> -7.0857606E-4
# <class 'str'> -7.087806E-4
# <class 'str'> -7.0865784E-4
# <class 'str'> -7.088624E-4
# <class 'str'> -7.0832536E-4
# <class 'str'> -7.0832536E-4
# <class 'str'> -7.0832536E-4
# <class 'str'> -7.0832536E-4
# <class 'str'> -7.08039E-4
# <class 'str'> -7.082436E-4
# <class 'str'> -7.0816174E-4
# <class 'str'> -7.0783444E-4
# <class 'str'> -7.082436E-4
# <class 'str'> -7.0799806E-4
# <class 'str'> -7.0799806E-4
# <class 'str'> -7.077526E-4
# <class 'str'> -7.0828444E-4
# <class 'str'> -7.081617E-4
# <class 'str'> -7.079162E-4
# <class 'str'> -7.079162E-4
# <class 'str'> -7.082026E-4
# <class 'str'> -7.081617E-4
# <class 'str'> -7.081208E-4
# <class 'str'> -7.081208E-4
# <class 'str'> -7.078344E-4
# <class 'str'> -7.080799E-4
# <class 'str'> -7.078344E-4
# <class 'str'> -7.082026E-4
# <class 'str'> -7.07507E-4
# <class 'str'> -7.076707E-4
# <class 'str'> -7.0791616E-4
# <class 'str'> -7.0791616E-4
# <class 'str'> -7.081616E-4
# <class 'str'> -7.082844E-4
# <class 'str'> -7.091897E-4
# <class 'str'> -7.098443E-4
# <class 'str'> -7.1021257E-4
# <class 'str'> -7.1000797E-4
# <class 'str'> -7.095988E-4
# <class 'str'> -7.098443E-4
# <class 'str'> -7.0947607E-4
# <class 'str'> -7.088624E-4
# <class 'str'> -7.091897E-4
# <class 'str'> -7.09026E-4
# <class 'str'> -7.0832536E-4
# <class 'str'> -7.086578E-4
# <class 'str'> -7.0832536E-4
# <class 'str'> -7.0832536E-4
# <class 'str'> -7.082026E-4
# <class 'str'> -7.0807984E-4
# <class 'str'> -7.0820254E-4
# <class 'str'> -7.081616E-4
# <class 'str'> -7.078343E-4
# <class 'str'> -7.078343E-4
# <class 'str'> -7.078343E-4
# <class 'str'> -7.0758886E-4
# <class 'str'> -7.078343E-4
# <class 'str'> -7.0742524E-4
# <class 'str'> -7.072207E-4
# <class 'str'> -7.07057E-4
# <class 'str'> -7.0709793E-4
# <class 'str'> -7.064433E-4
# <class 'str'> -7.0693425E-4
# <class 'str'> -7.068525E-4
# <class 'str'> -7.067297E-4
# <class 'str'> -7.0648425E-4
# <class 'str'> -7.0709793E-4
# <class 'str'> -7.0730253E-4
# <class 'str'> -7.073026E-4
# <class 'str'> -7.07589E-4
# <class 'str'> -7.079163E-4
# <class 'str'> -7.070571E-4
# <class 'str'> -7.079163E-4
# <class 'str'> -7.079163E-4
# <class 'str'> -7.079981E-4
# <class 'str'> -7.0857606E-4
# <class 'str'> -7.0816185E-4
# <class 'str'> -7.0828456E-4
# <class 'str'> -7.0828456E-4
# <class 'str'> -7.09108E-4
# <class 'str'> -7.0939446E-4
# <class 'str'> -7.094354E-4
# <class 'str'> -7.0980366E-4
# <class 'str'> -7.1045826E-4
# <class 'str'> -7.1029464E-4
# <class 'str'> -7.107038E-4
# <class 'str'> -7.107038E-4
# <class 'str'> -7.1062194E-4
# <class 'str'> -7.1062194E-4
# <class 'str'> -7.1062194E-4
# <class 'str'> -7.1148115E-4
# <class 'str'> -7.1189547E-4
# <class 'str'> -7.114812E-4
# <class 'str'> -7.114812E-4
# <class 'str'> -7.1127666E-4
# <class 'str'> -7.1173185E-4
# <class 'str'> -7.1127666E-4
# <class 'str'> -7.11113E-4
# <class 'str'> -7.1135844E-4
# <class 'str'> -7.114812E-4
# <class 'str'> -7.114812E-4
# <class 'str'> -7.114812E-4
# <class 'str'> -7.114812E-4
# <class 'str'> -7.116449E-4
# <class 'str'> -7.116449E-4
# <class 'str'> -7.116448E-4
# <class 'str'> -7.116448E-4
# <class 'str'> -7.1189535E-4
# <class 'str'> -7.1189535E-4
# <class 'str'> -7.113583E-4
# <class 'str'> -7.113583E-4
# <class 'str'> -7.109492E-4
# <class 'str'> -7.111128E-4
# <class 'str'> -7.111128E-4
# <class 'str'> -7.1086735E-4
# <class 'str'> -7.106218E-4
# <class 'str'> -7.106218E-4
# <class 'str'> -7.109082E-4
# <class 'str'> -7.103763E-4
# <class 'str'> -7.1082637E-4
# <class 'str'> -7.1054E-4
# <class 'str'> -7.1078545E-4
# <class 'str'> -7.1045815E-4
# <class 'str'> -7.1037636E-4
# <class 'str'> -7.106218E-4
# <class 'str'> -7.106218E-4
# <class 'str'> -7.1037636E-4
# <class 'str'> -7.102126E-4
# <class 'str'> -7.10008E-4
# <class 'str'> -7.099262E-4
# <class 'str'> -7.094761E-4
# <class 'str'> -7.0984435E-4
# <class 'str'> -7.0968067E-4
# <class 'str'> -7.1000797E-4
# <class 'str'> -7.09517E-4
# <class 'str'> -7.090669E-4
# <class 'str'> -7.091897E-4
# <class 'str'> -7.0943515E-4
# <class 'str'> -7.088623E-4
# <class 'str'> -7.087806E-4
# <class 'str'> -7.0902606E-4
# <class 'str'> -7.089443E-4
# <class 'str'> -7.090261E-4
# <class 'str'> -7.089443E-4
# <class 'str'> -7.093534E-4
# <class 'str'> -7.094352E-4
# <class 'str'> -7.0984435E-4
# <class 'str'> -7.0939434E-4
# <class 'str'> -7.0918974E-4
# <class 'str'> -7.09517E-4
# <class 'str'> -7.1000797E-4
# <class 'str'> -7.098852E-4
# <class 'str'> -7.1037625E-4
# <class 'str'> -7.102944E-4
# <class 'str'> -7.1037625E-4
# <class 'str'> -7.10008E-4
# <class 'str'> -7.101308E-4
# <class 'str'> -7.099262E-4
# <class 'str'> -7.10008E-4
# <class 'str'> -7.0976256E-4
# <class 'str'> -7.0992624E-4
# <class 'str'> -7.0984435E-4
# <class 'str'> -7.097625E-4
# <class 'str'> -7.088623E-4
# <class 'str'> -7.0955785E-4
# <class 'str'> -7.0906687E-4
# <class 'str'> -7.0902595E-4
# <class 'str'> -7.085758E-4
# <class 'str'> -7.0902595E-4
# <class 'str'> -7.0902595E-4
# <class 'str'> -7.085758E-4
# <class 'str'> -7.0894405E-4
# <class 'str'> -7.0910767E-4
# <class 'str'> -7.0955773E-4
# <class 'str'> -7.0976233E-4
# <class 'str'> -7.0951687E-4
# <class 'str'> -7.098442E-4
# <class 'str'> -7.102124E-4
# <class 'str'> -7.103761E-4
# <class 'str'> -7.1021245E-4
# <class 'str'> -7.1070343E-4
# <class 'str'> -7.1070343E-4
# <class 'str'> -7.1074435E-4
# <class 'str'> -7.109489E-4
# <class 'str'> -7.109489E-4
# <class 'str'> -7.109489E-4
# <class 'str'> -7.116444E-4
# <class 'str'> -7.1156264E-4
# <class 'str'> -7.120996E-4
# <class 'str'> -7.120587E-4
# <class 'str'> -7.12386E-4
# <class 'str'> -7.1250874E-4
# <class 'str'> -7.132452E-4
# <class 'str'> -7.1340887E-4
# <class 'str'> -7.139817E-4
# <class 'str'> -7.152552E-4
# <class 'str'> -7.1509153E-4
# <class 'str'> -7.1500975E-4
# <class 'str'> -7.1554165E-4
# <class 'str'> -7.1570533E-4
# <class 'str'> -7.1636E-4
# <class 'str'> -7.1660546E-4
# <class 'str'> -7.165237E-4
# <class 'str'> -7.165237E-4
# <class 'str'> -7.176284E-4
# <class 'str'> -7.1857456E-4
# <class 'str'> -7.182881E-4
# <class 'str'> -7.1832904E-4
# <class 'str'> -7.184109E-4
# <class 'str'> -7.192292E-4
# <class 'str'> -7.191474E-4
# <class 'str'> -7.19311E-4
# <class 'str'> -7.1906555E-4
# <class 'str'> -7.191474E-4
# <class 'str'> -7.1906555E-4
# <class 'str'> -7.1906555E-4
# <class 'str'> -7.1906555E-4
# <class 'str'> -7.19311E-4
# <class 'str'> -7.1906555E-4
# <class 'str'> -7.1873824E-4
# <class 'str'> -7.1873824E-4
# <class 'str'> -7.1873824E-4
# <class 'str'> -7.186564E-4
# <class 'str'> -7.186564E-4
# <class 'str'> -7.1841094E-4
# <class 'str'> -7.18861E-4
# <class 'str'> -7.185337E-4
# <class 'str'> -7.185337E-4
# <class 'str'> -7.188201E-4
# <class 'str'> -7.188201E-4
# <class 'str'> -7.189019E-4
# <class 'str'> -7.1898376E-4
# <class 'str'> -7.192292E-4
# <class 'str'> -7.1865646E-4
# <class 'str'> -7.187383E-4
# <class 'str'> -7.190656E-4
# <class 'str'> -7.193929E-4
# <class 'str'> -7.190656E-4
# <class 'str'> -7.190656E-4
# <class 'str'> -7.197202E-4
# <class 'str'> -7.196793E-4
# <class 'str'> -7.200884E-4
# <class 'str'> -7.2000653E-4
# <class 'str'> -7.20252E-4
# <class 'str'> -7.209476E-4
# <class 'str'> -7.208248E-4
# <class 'str'> -7.2066113E-4
# <class 'str'> -7.211112E-4
# <class 'str'> -7.211112E-4
# <class 'str'> -7.214436E-4
# <class 'str'> -7.216891E-4
# <class 'str'> -7.217709E-4
# <class 'str'> -7.2218006E-4
# <class 'str'> -7.300626E-4
# <class 'str'> -7.3047174E-4
# <class 'str'> -7.3096267E-4
# <class 'str'> -7.307581E-4
# <class 'str'> -7.3096267E-4
# <class 'str'> -7.3096267E-4
# <class 'str'> -7.3133095E-4
# <class 'str'> -7.3133095E-4
# <class 'str'> -7.314946E-4
# <class 'str'> -7.321083E-4
# <class 'str'> -7.3239475E-4
# <class 'str'> -7.323538E-4
# <class 'str'> -7.325993E-4
# <class 'str'> -7.325175E-4
# <class 'str'> -7.32763E-4
# <class 'str'> -7.324356E-4
# <class 'str'> -7.32763E-4
# <class 'str'> -7.32763E-4
# <class 'str'> -7.328448E-4
# <class 'str'> -7.330954E-4
# <class 'str'> -7.334636E-4
# <class 'str'> -7.334636E-4
# <class 'str'> -7.3403644E-4
# <class 'str'> -7.3387276E-4
# <class 'str'> -7.3387276E-4
# <class 'str'> -7.3387276E-4
# <class 'str'> -7.3403644E-4
# <class 'str'> -7.342001E-4
# <class 'str'> -7.343638E-4
# <class 'str'> -7.341183E-4
# <class 'str'> -7.3403644E-4
# <class 'str'> -7.3403644E-4
# <class 'str'> -7.3370914E-4
# <class 'str'> -7.341183E-4
# <class 'str'> -7.342001E-4
# <class 'str'> -7.3403644E-4
# <class 'str'> -7.3403644E-4
# <class 'str'> -7.3481386E-4
# <class 'str'> -7.3481386E-4
# <class 'str'> -7.350593E-4
# <class 'str'> -7.353867E-4
# <class 'str'> -7.353867E-4
# <class 'str'> -7.360873E-4
# <class 'str'> -7.3633285E-4
# <class 'str'> -7.3600037E-4
# <class 'str'> -7.3666015E-4
# <class 'str'> -7.368238E-4
# <class 'str'> -7.374376E-4
# <class 'str'> -7.374376E-4
# <class 'str'> -7.3801033E-4
# <class 'str'> -7.377648E-4
# <class 'str'> -7.3801033E-4
# <class 'str'> -7.377648E-4
# <class 'str'> -7.380922E-4
# <class 'str'> -7.3784665E-4
# <class 'str'> -7.3784665E-4
# <class 'str'> -7.3784665E-4
# <class 'str'> -7.376012E-4
# <class 'str'> -7.379285E-4
# <class 'str'> -7.38174E-4
# <class 'str'> -7.38174E-4
# <class 'str'> -7.388287E-4
# <class 'str'> -7.391969E-4
# <class 'str'> -7.394475E-4
# <class 'str'> -7.390332E-4
# <class 'str'> -7.395293E-4
# <class 'str'> -7.405113E-4
# <class 'str'> -7.407977E-4
# <class 'str'> -7.41125E-4
# <class 'str'> -7.407977E-4
# <class 'str'> -7.419433E-4
# <class 'str'> -7.417387E-4
# <class 'str'> -7.429304E-4
# <class 'str'> -7.4333954E-4
# <class 'str'> -7.4325775E-4
# <class 'str'> -7.4325775E-4
# <class 'str'> -7.440351E-4
# <class 'str'> -7.4518076E-4
# <class 'str'> -7.455899E-4
# <class 'str'> -7.458814E-4
# <class 'str'> -7.456308E-4
# <class 'str'> -7.455899E-4
# <class 'str'> -7.453444E-4
# <class 'str'> -7.460451E-4
# <class 'str'> -7.458405E-4
# <class 'str'> -7.4518076E-4
# <class 'str'> -7.453853E-4
# <class 'str'> -7.45058E-4
# <class 'str'> -7.4567687E-4
# <class 'str'> -7.4518076E-4
# <class 'str'> -7.4518076E-4
# <class 'str'> -7.450171E-4
# <class 'str'> -7.457178E-4
# <class 'str'> -7.457996E-4
# <class 'str'> -7.462087E-4
# <class 'str'> -7.461269E-4
# <class 'str'> -7.4653607E-4
# <class 'str'> -7.460451E-4
# <class 'str'> -7.4629055E-4
# <class 'str'> -7.4731343E-4
# <class 'str'> -7.478044E-4
# <class 'str'> -7.4858184E-4
# <class 'str'> -7.492825E-4
# <class 'str'> -7.497735E-4
# <class 'str'> -7.497735E-4
# <class 'str'> -7.4960984E-4
# <class 'str'> -7.4977346E-4
# <class 'str'> -7.494051E-4
# <class 'str'> -7.4911874E-4
# <class 'str'> -7.49487E-4
# <class 'str'> -7.492825E-4
# <class 'str'> -7.489961E-4
# <class 'str'> -7.489961E-4
# <class 'str'> -7.4841816E-4
# <class 'str'> -7.486636E-4
# <class 'str'> -7.486636E-4
# <class 'str'> -7.486636E-4
# <class 'str'> -7.488273E-4
# <class 'str'> -7.4891426E-4
# <class 'str'> -7.4891426E-4
# <class 'str'> -7.490779E-4
# <class 'str'> -7.4899604E-4
# <class 'str'> -7.4911874E-4
# <class 'str'> -7.494051E-4
# <class 'str'> -7.4948696E-4
# <class 'str'> -7.499371E-4
# <class 'str'> -7.494052E-4
# <class 'str'> -7.496916E-4
# <class 'str'> -7.5010076E-4
# <class 'str'> -7.5055077E-4
# <class 'str'> -7.5018255E-4
# <class 'str'> -7.502644E-4
# <class 'str'> -7.5010076E-4
# <class 'str'> -7.504281E-4
# <class 'str'> -7.5071456E-4
# <class 'str'> -7.509601E-4
# <class 'str'> -7.509601E-4
# <class 'str'> -7.5153285E-4
# <class 'str'> -7.518193E-4
# <class 'str'> -7.5239723E-4
# <class 'str'> -7.527245E-4
# <class 'str'> -7.528882E-4
# <class 'str'> -7.523154E-4
# <class 'str'> -7.5219263E-4
# <class 'str'> -7.5202377E-4
# <class 'str'> -7.527245E-4
# <class 'str'> -7.5264263E-4
# <class 'str'> -7.529699E-4
# <class 'str'> -7.5321534E-4
# <class 'str'> -7.529699E-4
# <class 'str'> -7.5256074E-4
# <class 'str'> -7.533381E-4
# <class 'str'> -7.519009E-4
# <class 'str'> -7.525606E-4
# <class 'str'> -7.5231516E-4
# <class 'str'> -7.521106E-4
# <class 'str'> -7.5202365E-4
# <class 'str'> -7.5202365E-4
# <class 'str'> -7.523971E-4
# <class 'str'> -7.519419E-4
# <class 'str'> -7.520236E-4
# <class 'str'> -7.525607E-4
# <class 'str'> -7.5247884E-4
# <class 'str'> -7.5247884E-4
# <class 'str'> -7.5313356E-4
# <class 'str'> -7.5366546E-4
# <class 'str'> -7.535427E-4
# <class 'str'> -7.528472E-4
# <class 'str'> -7.532971E-4
# <class 'str'> -7.532971E-4
# <class 'str'> -7.525607E-4
# <class 'str'> -7.5272436E-4
# <class 'str'> -7.528471E-4
# <class 'str'> -7.5341994E-4
# <class 'str'> -7.532154E-4
# <class 'str'> -7.5321534E-4
# <class 'str'> -7.533381E-4
# <class 'str'> -7.5374724E-4
# <class 'str'> -7.53379E-4
# <class 'str'> -7.539518E-4
# <class 'str'> -7.53829E-4
# <class 'str'> -7.5440184E-4
# <class 'str'> -7.545246E-4
# <class 'str'> -7.5575715E-4
# <class 'str'> -7.5526617E-4
# <class 'str'> -7.55348E-4
# <class 'str'> -7.5645273E-4
# <class 'str'> -7.565346E-4
# <class 'str'> -7.569437E-4
# <class 'str'> -7.569437E-4
# <class 'str'> -7.5624813E-4
# <class 'str'> -7.5747556E-4
# <class 'str'> -7.58212E-4
# <class 'str'> -7.580484E-4
# <class 'str'> -7.580484E-4
# <class 'str'> -7.57803E-4
# <class 'str'> -7.586673E-4
# <class 'str'> -7.5948564E-4
# <class 'str'> -7.596493E-4
# <class 'str'> -7.5940386E-4
# <class 'str'> -7.5854466E-4
# <class 'str'> -7.5854466E-4
# <class 'str'> -7.5804855E-4
# <class 'str'> -7.574349E-4
# <class 'str'> -7.572712E-4
# <class 'str'> -7.566984E-4
# <class 'str'> -7.566984E-4
# <class 'str'> -7.565348E-4
# <class 'str'> -7.564939E-4
# <class 'str'> -7.563711E-4
# <class 'str'> -7.561666E-4
# <class 'str'> -7.5608474E-4
# <class 'str'> -7.5588014E-4
# <class 'str'> -7.560438E-4
# <class 'str'> -7.5567554E-4
# <class 'str'> -7.5543E-4
# <class 'str'> -7.5517944E-4
# <class 'str'> -7.5489306E-4
# <class 'str'> -7.550976E-4
# <class 'str'> -7.548112E-4
# <class 'str'> -7.5464754E-4
# <class 'str'> -7.5456576E-4
# <class 'str'> -7.545248E-4
# <class 'str'> -7.542384E-4
# <class 'str'> -7.54443E-4
# <class 'str'> -7.5456576E-4
# <class 'str'> -7.5456576E-4
# <class 'str'> -7.5423846E-4
# <class 'str'> -7.543203E-4
# <class 'str'> -7.543203E-4
# <class 'str'> -7.543203E-4
# <class 'str'> -7.5444306E-4
# <class 'str'> -7.543203E-4
# <class 'str'> -7.54484E-4
# <class 'str'> -7.548113E-4
# <class 'str'> -7.5472944E-4
# <class 'str'> -7.546886E-4
# <class 'str'> -7.545658E-4
# <class 'str'> -7.546476E-4
# <class 'str'> -7.546476E-4
# <class 'str'> -7.5444306E-4
# <class 'str'> -7.5444306E-4
# <class 'str'> -7.546067E-4
# <class 'str'> -6.9744623E-4
# <class 'str'> -6.9720077E-4
# <class 'str'> -6.9720077E-4
# <class 'str'> -6.9720077E-4
# <class 'str'> -6.9695525E-4
# <class 'str'> -6.964642E-4
# <class 'str'> -6.9642335E-4
# <class 'str'> -6.961778E-4
# <class 'str'> -6.961778E-4
# <class 'str'> -6.955232E-4
# <class 'str'> -6.955232E-4
# <class 'str'> -6.9540046E-4
# <class 'str'> -6.953186E-4
# <class 'str'> -6.951499E-4
# <class 'str'> -6.9486344E-4
# <class 'str'> -6.950271E-4
# <class 'str'> -6.943316E-4
# <class 'str'> -6.947407E-4
# <class 'str'> -6.9457706E-4
# <class 'str'> -6.944133E-4
# <class 'str'> -6.941679E-4
# <class 'str'> -6.940451E-4
# <class 'str'> -6.937587E-4
# <class 'str'> -6.941679E-4
# <class 'str'> -6.9396326E-4
# <class 'str'> -6.938815E-4
# <class 'str'> -6.937587E-4
# <class 'str'> -6.9384056E-4
# <class 'str'> -6.9424976E-4
# <class 'str'> -6.935542E-4
# <class 'str'> -6.9424976E-4
# <class 'str'> -6.951089E-4
# <class 'str'> -6.959323E-4
# <class 'str'> -6.9625967E-4
# <class 'str'> -6.955232E-4
# <class 'str'> -6.958505E-4
# <class 'str'> -6.9568685E-4
# <class 'str'> -6.9535954E-4
# <class 'str'> -6.9490436E-4
# <class 'str'> -6.951089E-4
# <class 'str'> -6.951089E-4
# <class 'str'> -6.9457706E-4
# <class 'str'> -6.9465884E-4
# <class 'str'> -6.947407E-4
# <class 'str'> -6.9449516E-4
# <class 'str'> -6.938815E-4
# <class 'str'> -6.9359504E-4
# <class 'str'> -6.935542E-4
# <class 'str'> -6.9347234E-4
# <class 'str'> -6.940861E-4
# <class 'str'> -6.9379964E-4
# <class 'str'> -6.933905E-4
# <class 'str'> -6.93145E-4
# <class 'str'> -6.9330866E-4
# <class 'str'> -6.928177E-4
# <class 'str'> -6.923267E-4
# <class 'str'> -6.928995E-4
# <class 'str'> -6.928995E-4
# <class 'str'> -6.937178E-4
# <class 'str'> -6.941679E-4
# <class 'str'> -6.938815E-4
# <class 'str'> -6.941679E-4
# <class 'str'> -6.943316E-4
# <class 'str'> -6.9465884E-4
# <class 'str'> -6.9490436E-4
# <class 'str'> -6.951089E-4
# <class 'str'> -6.946998E-4
# <class 'str'> -6.9449516E-4
# <class 'str'> -6.9506804E-4
# <class 'str'> -6.955232E-4
# <class 'str'> -6.9560506E-4
# <class 'str'> -6.9523166E-4
# <class 'str'> -6.9523166E-4
# <class 'str'> -6.958505E-4
# <class 'str'> -6.9630065E-4
# <class 'str'> -6.9638237E-4
# <class 'str'> -6.961778E-4
# <class 'str'> -6.957687E-4
# <class 'str'> -6.953186E-4
# <class 'str'> -6.948225E-4
# <class 'str'> -6.9490436E-4
# <class 'str'> -6.948225E-4
# <class 'str'> -6.9457706E-4
# <class 'str'> -6.937587E-4
# <class 'str'> -6.934314E-4
# <class 'str'> -6.939224E-4
# <class 'str'> -6.939224E-4
# <class 'str'> -6.9400424E-4
# <class 'str'> -6.928177E-4
# <class 'str'> -6.9363596E-4
# <class 'str'> -6.928177E-4
# <class 'str'> -6.928995E-4
# <class 'str'> -6.926131E-4
# <class 'str'> -6.926949E-4
# <class 'str'> -6.9244945E-4
# <class 'str'> -6.9224485E-4
# <class 'str'> -6.923676E-4
# <class 'str'> -6.925722E-4
# <class 'str'> -6.923676E-4
# <class 'str'> -6.923676E-4
# <class 'str'> -6.922858E-4
# <class 'str'> -6.922858E-4
# <class 'str'> -6.922858E-4
# <class 'str'> -6.918715E-4
# <class 'str'> -6.920352E-4
# <class 'str'> -6.922858E-4
# <class 'str'> -6.922858E-4
# <class 'str'> -6.920352E-4
# <class 'str'> -6.923676E-4
# <class 'str'> -6.9212215E-4
# <class 'str'> -6.9212215E-4
# <class 'str'> -6.923676E-4
# <class 'str'> -6.918715E-4
# <class 'str'> -6.92204E-4
# <class 'str'> -6.9244945E-4
# <class 'str'> -6.9212215E-4
# <class 'str'> -6.9212215E-4
# <class 'str'> -6.9212215E-4
# <class 'str'> -6.9212215E-4
# <class 'str'> -6.923676E-4
# <class 'str'> -6.9212215E-4
# <class 'str'> -6.9212215E-4
# <class 'str'> -6.9212215E-4
# <class 'str'> -6.9212215E-4
# <class 'str'> -6.9244945E-4
# <class 'str'> -6.920352E-4
# <class 'str'> -6.9212215E-4
# <class 'str'> -6.9212215E-4
# <class 'str'> -6.9212215E-4
# <class 'str'> -6.92204E-4
# <class 'str'> -6.9195335E-4
# <class 'str'> -6.920352E-4
# <class 'str'> -6.9178967E-4
# <class 'str'> -6.9212215E-4
# <class 'str'> -6.9212215E-4
# <class 'str'> -6.920352E-4
# <class 'str'> -6.9178967E-4
# <class 'str'> -6.9154415E-4
# <class 'str'> -6.918715E-4
# <class 'str'> -6.918715E-4
# <class 'str'> -6.917078E-4
# <class 'str'> -6.91626E-4
# <class 'str'> -6.918715E-4
# <class 'str'> -6.918715E-4
# <class 'str'> -6.9212215E-4
# <class 'str'> -6.917078E-4
# <class 'str'> -6.9178967E-4
# <class 'str'> -6.9178967E-4
# <class 'str'> -6.9178967E-4
# <class 'str'> -6.91626E-4
# <class 'str'> -6.920352E-4
# <class 'str'> -6.920352E-4
# <class 'str'> -6.9195335E-4
# <class 'str'> -6.91626E-4
# <class 'str'> -6.917078E-4
# <class 'str'> -6.9195335E-4
# <class 'str'> -6.9178967E-4
# <class 'str'> -6.9178967E-4
# <class 'str'> -6.913396E-4
# <class 'str'> -6.914623E-4
# <class 'str'> -6.918715E-4
# <class 'str'> -6.9212215E-4
# <class 'str'> -6.9178967E-4
# <class 'str'> -6.920352E-4
# <class 'str'> -6.9178967E-4
# <class 'str'> -6.9178967E-4
# <class 'str'> -6.918715E-4
# <class 'str'> -6.918715E-4
# <class 'str'> -6.923676E-4
# <class 'str'> -6.922858E-4
# <class 'str'> -6.92204E-4
# <class 'str'> -6.918715E-4
# <class 'str'> -6.9212215E-4
# <class 'str'> -6.920352E-4
# <class 'str'> -6.920352E-4
# <class 'str'> -6.920352E-4
# <class 'str'> -6.920352E-4
# <class 'str'> -6.923676E-4
# <class 'str'> -6.9298135E-4
# <class 'str'> -6.937587E-4
# <class 'str'> -6.938815E-4
# <class 'str'> -6.938815E-4
# <class 'str'> -6.938815E-4
# <class 'str'> -6.9457706E-4
# <class 'str'> -6.951089E-4
# <class 'str'> -6.953186E-4
# <class 'str'> -6.953186E-4
# <class 'str'> -6.9523166E-4
# <class 'str'> -6.959323E-4
# <class 'str'> -6.96096E-4
# <class 'str'> -6.965052E-4
# <class 'str'> -6.971189E-4
# <class 'str'> -6.9781445E-4
# <class 'str'> -6.977326E-4
# <class 'str'> -6.9752807E-4
# <class 'str'> -6.9728255E-4
# <class 'str'> -6.970371E-4
# <class 'str'> -6.970371E-4
# <class 'str'> -6.96587E-4
# <class 'str'> -6.966279E-4
# <class 'str'> -6.96096E-4
# <class 'str'> -6.9642335E-4
# <class 'str'> -6.9540046E-4
# <class 'str'> -6.951499E-4
# <class 'str'> -6.951499E-4
# <class 'str'> -6.9560506E-4
# <class 'str'> -6.953186E-4
# <class 'str'> -6.950271E-4
# <class 'str'> -6.954414E-4
# <class 'str'> -6.9519074E-4
# <class 'str'> -6.952777E-4
# <class 'str'> -6.949453E-4
# <class 'str'> -6.949453E-4
# <class 'str'> -6.949453E-4
# <class 'str'> -6.949862E-4
# <class 'str'> -6.951089E-4
# <class 'str'> -6.9457706E-4
# <class 'str'> -6.9478166E-4
# <class 'str'> -6.951089E-4
# <class 'str'> -6.947407E-4
# <class 'str'> -6.947407E-4
# <class 'str'> -6.952777E-4
# <class 'str'> -6.948225E-4
# <class 'str'> -6.9457706E-4
# <class 'str'> -6.947407E-4
# <class 'str'> -6.949862E-4
# <class 'str'> -6.947407E-4
# <class 'str'> -6.947407E-4
# <class 'str'> -6.947407E-4
# <class 'str'> -6.947407E-4
# <class 'str'> -6.948225E-4
# <class 'str'> -6.9465884E-4
# <class 'str'> -6.949862E-4
# <class 'str'> -6.9465884E-4
# <class 'str'> -6.947407E-4
# <class 'str'> -6.944133E-4
# <class 'str'> -6.947407E-4
# <class 'str'> -6.943316E-4
# <class 'str'> -6.9457706E-4
# <class 'str'> -6.9465884E-4
# <class 'str'> -6.9465884E-4
# <class 'str'> -6.9465884E-4
# <class 'str'> -6.947407E-4
# <class 'str'> -6.9449516E-4
# <class 'str'> -6.944133E-4
# <class 'str'> -6.9465884E-4
# <class 'str'> -6.9490436E-4
# <class 'str'> -6.9449516E-4
# <class 'str'> -6.948225E-4
# <class 'str'> -6.947407E-4
# <class 'str'> -6.947407E-4
# <class 'str'> -6.944133E-4
# <class 'str'> -6.9465884E-4
# <class 'str'> -6.9490436E-4
# <class 'str'> -6.9519074E-4
# <class 'str'> -6.949862E-4
# <class 'str'> -6.9506804E-4
# <class 'str'> -6.951089E-4
# <class 'str'> -6.947407E-4
# <class 'str'> -6.9465884E-4
# <class 'str'> -6.9490436E-4
# <class 'str'> -6.947407E-4
# <class 'str'> -6.947407E-4
# <class 'str'> -6.9449516E-4
# <class 'str'> -6.947407E-4
# <class 'str'> -6.949862E-4
# <class 'str'> -6.949862E-4
# <class 'str'> -6.9519074E-4
# <class 'str'> -6.9457706E-4
# <class 'str'> -6.9465884E-4
# <class 'str'> -6.9465884E-4
# <class 'str'> -6.9465884E-4
# <class 'str'> -6.9449516E-4
# <class 'str'> -6.948225E-4
# <class 'str'> -6.943316E-4
# <class 'str'> -6.944133E-4
# <class 'str'> -6.9424976E-4
# <class 'str'> -6.940451E-4
# <class 'str'> -6.948225E-4
# <class 'str'> -6.9490436E-4
# <class 'str'> -6.9465884E-4
# <class 'str'> -6.948225E-4
# <class 'str'> -6.9506804E-4
# <class 'str'> -6.9457706E-4
# <class 'str'> -6.948225E-4
# <class 'str'> -6.9523166E-4
# <class 'str'> -6.949862E-4
# <class 'str'> -6.9490436E-4
# <class 'str'> -6.9490436E-4
# <class 'str'> -6.949862E-4
# <class 'str'> -6.951499E-4
# <class 'str'> -6.9506804E-4
# <class 'str'> -6.951499E-4
# <class 'str'> -6.951499E-4
# <class 'str'> -6.9486344E-4
# <class 'str'> -6.951089E-4
# <class 'str'> -6.949862E-4
# <class 'str'> -6.949862E-4
# <class 'str'> -6.958505E-4
# <class 'str'> -6.970371E-4
# <class 'str'> -6.9744623E-4
# <class 'str'> -6.9720077E-4
# <class 'str'> -6.9728255E-4
# <class 'str'> -6.9748715E-4
# <class 'str'> -6.979372E-4
# <class 'str'> -6.9777353E-4
# <class 'str'> -6.982236E-4
# <class 'str'> -6.9777353E-4
# <class 'str'> -6.9871976E-4
# <class 'str'> -6.997426E-4
# <class 'str'> -6.998244E-4
# <class 'str'> -6.9990626E-4
# <class 'str'> -6.9990626E-4
# <class 'str'> -7.003154E-4
# <class 'str'> -7.0109277E-4
# <class 'str'> -7.014201E-4
# <class 'str'> -7.0150197E-4
# <class 'str'> -7.0125645E-4
# <class 'str'> -7.0150197E-4
# <class 'str'> -7.013383E-4
# <class 'str'> -7.0109277E-4
# <class 'str'> -7.008064E-4
# <class 'str'> -7.015838E-4
# <class 'str'> -7.014201E-4
# <class 'str'> -7.010109E-4
# <class 'str'> -7.0072454E-4
# <class 'str'> -7.006427E-4
# <class 'str'> -7.006427E-4
# <class 'str'> -7.0039724E-4
# <class 'str'> -7.00479E-4
# <class 'str'> -7.0006994E-4
# <class 'str'> -7.0052E-4
# <class 'str'> -7.0039724E-4
# <class 'str'> -7.003154E-4
# <class 'str'> -7.0019264E-4
# <class 'str'> -7.008064E-4
# <class 'str'> -7.0072454E-4
# <class 'str'> -7.0039724E-4
# <class 'str'> -7.009291E-4
# <class 'str'> -7.0150197E-4
# <class 'str'> -7.0150197E-4
# <class 'str'> -7.0179347E-4
# <class 'str'> -7.0228445E-4
# <class 'str'> -7.0207985E-4
# <class 'str'> -7.025299E-4
# <class 'str'> -7.0167077E-4
# <class 'str'> -7.0228445E-4
# <class 'str'> -7.025299E-4
# <class 'str'> -7.0244813E-4
# <class 'str'> -7.028573E-4
# <class 'str'> -7.0298E-4
# <class 'str'> -7.0371653E-4
# <class 'str'> -7.0461666E-4
# <class 'str'> -7.0486724E-4
# <class 'str'> -7.050718E-4
# <class 'str'> -7.0499E-4
# <class 'str'> -7.042893E-4
# <class 'str'> -7.038801E-4
# <class 'str'> -7.0371653E-4
# <class 'str'> -7.0404384E-4
# <class 'str'> -7.038801E-4
# <class 'str'> -7.036347E-4
# <class 'str'> -7.031846E-4
# <class 'str'> -7.0289813E-4
# <class 'str'> -7.0310273E-4
# <class 'str'> -7.0277543E
# <class 'str'> -7.0277543E
# <class 'str'> -7.0277543E
# <class 'str'> -7.0277543E
# <class 'str'> -7.0277543E
# <class 'str'> -7.0277543E
# <class 'str'> -7.0277543E
# <class 'str'> -7.0277543E
# <class 'str'> -7.0277543E
# <class 'str'> -7.0277543E
# <class 'str'> -7.0277543E
# <class 'str'> -7.0277543E
# <class 'str'> -7.0277543E
# <class 'str'> -7.0277543E
# <class 'str'> -7.0277543E
# <class 'str'> -7.0277543E
# <class 'str'> -7.0277543E
# <class 'str'> -7.0277543E

# %%
df_test = scaler.transform(df_test)

print(df_test.shape)
df_test.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-e320b402919f> in <module>
# ----> 1 df_test = scaler.transform(df_test)
#       2
#       3 print(df_test.shape)
#       4 df_test.head()
#
# <ipython-input-18-96fc1e243d3b> in transform(self, data)
#      10         for col in output.columns:
#      11             if col in keys:
# ---> 12                 temp = self.scaler[col].transform(self.to_numpy(data[col]))
#      13                 output[col] = self.to_series(temp, col)
#      14         return output
#
# D:\Sangwons_Room\00_SoftWares\Anaconda\envs\torch\lib\site-packages\sklearn\preprocessing\_data.py in transform(self, X)
#     406
#     407         X = check_array(X, copy=self.copy, dtype=FLOAT_DTYPES,
# --> 408                         force_all_finite="allow-nan")
#     409
#     410         X *= self.scale_
#
# D:\Sangwons_Room\00_SoftWares\Anaconda\envs\torch\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# D:\Sangwons_Room\00_SoftWares\Anaconda\envs\torch\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     596                     array = array.astype(dtype, casting="unsafe", copy=False)
#     597                 else:
# --> 598                     array = np.asarray(array, order=order, dtype=dtype)
#     599             except ComplexWarning:
#     600                 raise ValueError("Complex data not supported\n"
#
# D:\Sangwons_Room\00_SoftWares\Anaconda\envs\torch\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: could not convert string to float: '-7.0277543E'

# %%
model.load_state_dict(torch.load(checkpoint_path))
torch.save(model.state_dict(), model_path)

# %%
# Load submission sample
submission = pd.read_csv(str(data_dir / "sample_submission.csv"))
print(submission.shape)

# %%
model = SimpleNetwork(X.shape[1] * X.shape[2], y.shape[1])
model = model.to(device)
model.load_state_dict(torch.load(model_path))

# %%
X, _ = extract_features(df_test, train = False)

X = torch.Tensor(X)

loader_test = DataLoader(X, batch_size = batch_size, shuffle = False)

# %%
model.eval()  # 신경망을 추론 모드로 전환

# 데이터로더에서 미니배치를 하나씩 꺼내 추론을 수행
predict = []
with torch.no_grad():  # 추론 과정에는 미분이 필요없음
    for data in loader_test:
        data = data.to(device)

        outputs = model(data)  # 데이터를 입력하고 출력을 계산
        predict.append(outputs)
predict = torch.cat(predict, axis = 0).to('cpu')

# %%
predict.shape

# %%
print(submission.shape)
submission.columns
# Out:
# (91486, 4)
# Index(['phone', 'millisSinceGpsEpoch', 'latDeg', 'lngDeg'], dtype='object')

# %%
submission['latDeg'] = predict[:,1]
submission['lngDeg'] = predict[:,2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-293e69fd0201> in <module>
# ----> 1 submission['latDeg'] = predict[:,1]
#       2 submission['lngDeg'] = predict[:,2]
#
# NameError: name 'predict' is not defined

# %%
submission.to_csv(f"./models/{notebookName}/{num_files} - result.csv", index = False)
pd.DataFrame([]).to_csv(dummy_path)
